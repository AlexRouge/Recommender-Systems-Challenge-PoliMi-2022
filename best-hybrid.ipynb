# %%
# !cp -r ../input/recsys-repo/RecSys_Course_AT_PoliMi-master/* ./
# %config Completer.use_jedi = False
# %load_ext Cython
import pandas as pd
import numpy as np
import scipy.sparse as sps
from Evaluation.Evaluator import EvaluatorHoldout
from Recommenders.GraphBased.RP3betaRecommender import RP3betaRecommender
from Recommenders.EASE_R.EASE_R_Recommender import EASE_R_Recommender
from Recommenders.KNN.ItemKNNCustomSimilarityRecommender import ItemKNNCustomSimilarityRecommender

# %%
# !python run_compile_all_cython.py
# Out:
# run_compile_all_cython: Found 10 Cython files in 4 folders...
# run_compile_all_cython: All files will be compiled using your current python environment: '/opt/conda/bin/python'
# Compiling [1/10]: MatrixFactorizationImpressions_Cython_Epoch.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from MatrixFactorizationImpressions_Cython_Epoch.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# MatrixFactorizationImpressions_Cython_Epoch.c: In function ‘__pyx_f_43MatrixFactorizationImpressions_Cython_Epoch_32MatrixFactorization_Cython_Epoch_sampleBPR_Cython’:
# MatrixFactorizationImpressions_Cython_Epoch.c:12758:17: warning: ‘__pyx_v_start_pos_impression_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# 12758 |       __pyx_t_4 = (__pyx_v_start_pos_impression_items + __pyx_v_index);
#       |       ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# MatrixFactorizationImpressions_Cython_Epoch.c: In function ‘__pyx_pf_43MatrixFactorizationImpressions_Cython_Epoch_32MatrixFactorization_Cython_Epoch_10epochIteration_Cython_ASY_SVD_SGD’:
# MatrixFactorizationImpressions_Cython_Epoch.c:8736:7: warning: ‘__pyx_v_end_pos_seen_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  8736 |       for (__pyx_t_19 = __pyx_v_start_pos_seen_items; __pyx_t_19 < __pyx_t_18; __pyx_t_19+=1) {
#       |       ^~~
# MatrixFactorizationImpressions_Cython_Epoch.c:8736:7: warning: ‘__pyx_v_start_pos_seen_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/MatrixFactorization/Cython/MatrixFactorizationImpressions_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [1/10]: MatrixFactorizationImpressions_Cython_Epoch.pyx... PASS
#
# Compiling [2/10]: MatrixFactorization_Cython_Epoch.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from MatrixFactorization_Cython_Epoch.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# MatrixFactorization_Cython_Epoch.c: In function ‘__pyx_pf_32MatrixFactorization_Cython_Epoch_32MatrixFactorization_Cython_Epoch_10epochIteration_Cython_ASY_SVD_SGD’:
# MatrixFactorization_Cython_Epoch.c:8669:9: warning: ‘__pyx_v_end_pos_seen_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  8669 |         for (__pyx_t_19 = __pyx_v_start_pos_seen_items; __pyx_t_19 < __pyx_t_18; __pyx_t_19+=1) {
#       |         ^~~
# MatrixFactorization_Cython_Epoch.c:8669:9: warning: ‘__pyx_v_start_pos_seen_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/MatrixFactorization/Cython/MatrixFactorization_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [2/10]: MatrixFactorization_Cython_Epoch.pyx... PASS
#
# Compiling [3/10]: Compute_Similarity_Cython.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from Compute_Similarity_Cython.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/Similarity/Cython/Compute_Similarity_Cython.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [3/10]: Compute_Similarity_Cython.pyx... PASS
#
# Compiling [4/10]: Sparse_Matrix_Tree_CSR.pyx...
# warning: Sparse_Matrix_Tree_CSR.pyx:132:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:132:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from Sparse_Matrix_Tree_CSR.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# Sparse_Matrix_Tree_CSR.c: In function ‘__pyx_f_22Sparse_Matrix_Tree_CSR_22Sparse_Matrix_Tree_CSR_test_list_tree_conversion’:
# Sparse_Matrix_Tree_CSR.c:5844:15: warning: ‘__pyx_v_previous_element’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  5844 |     __pyx_t_7 = __pyx_v_current_element->lower;
#       |     ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/SLIM/Cython/Sparse_Matrix_Tree_CSR.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: Sparse_Matrix_Tree_CSR.pyx:132:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:132:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# Compiling [4/10]: Sparse_Matrix_Tree_CSR.pyx... PASS
#
# Compiling [5/10]: SLIM_BPR_Cython_Epoch.pyx...
# warning: SLIM_BPR_Cython_Epoch.pyx:633:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:633:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from SLIM_BPR_Cython_Epoch.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# SLIM_BPR_Cython_Epoch.c: In function ‘__pyx_f_21SLIM_BPR_Cython_Epoch_22Sparse_Matrix_Tree_CSR_test_list_tee_conversion’:
# SLIM_BPR_Cython_Epoch.c:10848:15: warning: ‘__pyx_v_previous_element’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# 10848 |     __pyx_t_7 = __pyx_v_current_element->lower;
#       |     ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/SLIM/Cython/SLIM_BPR_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: SLIM_BPR_Cython_Epoch.pyx:633:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:633:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# Compiling [5/10]: SLIM_BPR_Cython_Epoch.pyx... PASS
#
# Compiling [6/10]: Triangular_Matrix.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from Triangular_Matrix.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/SLIM/Cython/Triangular_Matrix.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [6/10]: Triangular_Matrix.pyx... PASS
#
# Compiling [7/10]: CFW_DVV_Similarity_Cython_SGD.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from CFW_DVV_Similarity_Cython_SGD.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/FeatureWeighting/Cython/CFW_DVV_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [7/10]: CFW_DVV_Similarity_Cython_SGD.pyx... PASS
#
# Compiling [8/10]: CFW_D_Similarity_Cython_SGD.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from CFW_D_Similarity_Cython_SGD.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# CFW_D_Similarity_Cython_SGD.c: In function ‘__pyx_pf_27CFW_D_Similarity_Cython_SGD_27CFW_D_Similarity_Cython_SGD_6fit’:
# CFW_D_Similarity_Cython_SGD.c:6056:55: warning: ‘__pyx_v_sample_num’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  6056 |   __pyx_t_3 = PyFloat_FromDouble((__pyx_v_cum_loss / ((double)__pyx_v_sample_num))); if (unlikely(!__pyx_t_3)) __PYX_ERR(0, 290, __pyx_L1_error)
#       |                                                      ~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/FeatureWeighting/Cython/CFW_D_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [8/10]: CFW_D_Similarity_Cython_SGD.pyx... PASS
#
# Compiling [9/10]: FBSM_Rating_Cython_SGD.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from FBSM_Rating_Cython_SGD.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# FBSM_Rating_Cython_SGD.c: In function ‘__pyx_pf_22FBSM_Rating_Cython_SGD_22FBSM_Rating_Cython_SGD_2fit’:
# FBSM_Rating_Cython_SGD.c:9031:55: warning: ‘__pyx_v_num_sample’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  9031 |   __pyx_t_5 = PyFloat_FromDouble((__pyx_v_cum_loss / ((double)__pyx_v_num_sample))); if (unlikely(!__pyx_t_5)) __PYX_ERR(0, 551, __pyx_L1_error)
#       |                                                      ~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/FeatureWeighting/Cython/FBSM_Rating_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [9/10]: FBSM_Rating_Cython_SGD.pyx... PASS
#
# Compiling [10/10]: HP3_Similarity_Cython_SGD.pyx...
# warning: HP3_Similarity_Cython_SGD.pyx:113:40: Index should be typed for more efficient access
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from HP3_Similarity_Cython_SGD.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# HP3_Similarity_Cython_SGD.c: In function ‘__pyx_pf_25HP3_Similarity_Cython_SGD_25HP3_Similarity_Cython_SGD_4fit’:
# HP3_Similarity_Cython_SGD.c:6303:55: warning: ‘__pyx_v_sample_num’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  6303 |   __pyx_t_1 = PyFloat_FromDouble((__pyx_v_cum_loss / ((double)__pyx_v_sample_num))); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 291, __pyx_L1_error)
#       |                                                      ~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/FeatureWeighting/Cython/HP3_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: HP3_Similarity_Cython_SGD.pyx:113:40: Index should be typed for more efficient access
# Compiling [10/10]: HP3_Similarity_Cython_SGD.pyx... PASS
#
# run_compile_all_cython: Compilation finished. SUCCESS.
# Compilation log can be found here: './result_experiments/run_compile_all_cython.txt'

# %%
ICM_type_df = pd.read_csv("/kaggle/input/competition-data/data_ICM_type.csv")
ICM_type_df

items = ICM_type_df.item_id
features = ICM_type_df.feature_id
data = ICM_type_df.data
ICM_type = sps.csr_matrix((data, (items, features)))
ICM_type = ICM_type.astype(dtype = np.int32)

n_users = 41629
n_itemsFromICM = ICM_type.shape[0]
ICM_type.shape
# Out:
# (27968, 8)

# %%
URM_train = sps.load_npz("/kaggle/input/split8020/URM_Train80.npz")
URM_train = sps.csr_matrix((URM_train.data, URM_train.indices, URM_train.indptr), shape=(n_users, n_itemsFromICM))
URM_train
# Out:
# <41629x27968 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1243712 stored elements in Compressed Sparse Row format>

# %%
URM_valid = sps.load_npz("/kaggle/input/split8020/URM_Valid20.npz")
URM_valid = sps.csr_matrix((URM_valid.data, URM_valid.indices, URM_valid.indptr), shape=(n_users, n_itemsFromICM))
URM_valid
# Out:
# <41629x27968 sparse matrix of type '<class 'numpy.float64'>'
# 	with 310928 stored elements in Compressed Sparse Row format>

# %%
URM_train_stacked = sps.vstack([URM_train, ICM_type.T])
URM_train_stacked = sps.csr_matrix(URM_train_stacked)

# %%
#create an evaluator object to evaluate validation set
#we will use it for hyperparameter tuning
evaluator_valid = EvaluatorHoldout(URM_valid, cutoff_list=[10])
# Out:
# EvaluatorHoldout: Ignoring 321 ( 0.8%) Users that have less than 1 test interactions

# %%
import implicit
from Recommenders.BaseMatrixFactorizationRecommender import BaseMatrixFactorizationRecommender
import scipy.sparse as sps
class ImplicitALSRecommender(BaseMatrixFactorizationRecommender):
    """ImplicitALSRecommender recommender"""

    RECOMMENDER_NAME = "ImplicitALSRecommender"

    def fit(self,
            factors=100,
            regularization=0.01,
            use_native=True, use_cg=True, use_gpu=False,
            iterations=15,
            calculate_training_loss=False, num_threads=0,
            confidence_scaling=None,
            icm_coeff = 1,
            **confidence_args
            ):
        self.rec = implicit.als.AlternatingLeastSquares(factors=factors, regularization=regularization,
                                                        use_native=use_native, use_cg=use_cg, use_gpu=use_gpu,
                                                        iterations=iterations,
                                                        calculate_training_loss=calculate_training_loss,
                                                        num_threads=num_threads,
                                                        random_state=5)
        self.rec.fit(confidence_scaling(self.URM_train, **confidence_args), show_progress=self.verbose)

        self.USER_factors = self.rec.user_factors
        self.ITEM_factors = self.rec.item_factors

# %%
import numpy as np
import scipy.sparse as sps
from Recommenders.Recommender_utils import check_matrix
from sklearn.linear_model import ElasticNet
from Recommenders.BaseSimilarityMatrixRecommender import BaseItemSimilarityMatrixRecommender
from Utils.seconds_to_biggest_unit import seconds_to_biggest_unit
import time, sys
from tqdm import tqdm
from sklearn.utils._testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning

# os.environ["PYTHONWARNINGS"] = ('ignore::exceptions.ConvergenceWarning:sklearn.linear_model')
# os.environ["PYTHONWARNINGS"] = ('ignore:Objective did not converge:ConvergenceWarning:')

class SLIMElasticNetRecommender(BaseItemSimilarityMatrixRecommender):
    """
    Train a Sparse Linear Methods (SLIM) item similarity model.
    NOTE: ElasticNet solver is parallel, a single intance of SLIM_ElasticNet will
          make use of half the cores available
    See:
        Efficient Top-N Recommendation by Linear Regression,
        M. Levy and K. Jack, LSRS workshop at RecSys 2013.
        SLIM: Sparse linear methods for top-n recommender systems,
        X. Ning and G. Karypis, ICDM 2011.
        http://glaros.dtc.umn.edu/gkhome/fetch/papers/SLIM2011icdm.pdf
    """

    RECOMMENDER_NAME = "SLIMElasticNetRecommender"

    def __init__(self, URM_train, verbose = True):
        super(SLIMElasticNetRecommender, self).__init__(URM_train, verbose = verbose)

    @ignore_warnings(category=ConvergenceWarning)
    def fit(self, l1_ratio=0.1, alpha = 1.0, positive_only=True, topK = 100,**earlystopping_kwargs):

        assert l1_ratio>= 0 and l1_ratio<=1, "{}: l1_ratio must be between 0 and 1, provided value was {}".format(self.RECOMMENDER_NAME, l1_ratio)

        self.l1_ratio = l1_ratio
        self.positive_only = positive_only
        self.topK = topK


        # initialize the ElasticNet model
        self.model = ElasticNet(alpha=alpha,
                                l1_ratio=self.l1_ratio,
                                positive=self.positive_only,
                                fit_intercept=False,
                                copy_X=False,
                                precompute=True,
                                selection='random',
                                max_iter=100,
                                tol=1e-4)

        URM_train = check_matrix(self.URM_train, 'csc', dtype=np.float32)

        n_items = URM_train.shape[1]

        # Use array as it reduces memory requirements compared to lists
        dataBlock = 10000000

        rows = np.zeros(dataBlock, dtype=np.int32)
        cols = np.zeros(dataBlock, dtype=np.int32)
        values = np.zeros(dataBlock, dtype=np.float32)

        numCells = 0

        start_time = time.time()
        start_time_printBatch = start_time

        # fit each item's factors sequentially (not in parallel)
        for currentItem in range(n_items):

            # get the target column
            y = URM_train[:, currentItem].toarray()

            # set the j-th column of X to zero
            start_pos = URM_train.indptr[currentItem]
            end_pos = URM_train.indptr[currentItem + 1]

            current_item_data_backup = URM_train.data[start_pos: end_pos].copy()
            URM_train.data[start_pos: end_pos] = 0.0

            # fit one ElasticNet model per column
            self.model.fit(URM_train, y)

            # self.model.coef_ contains the coefficient of the ElasticNet model
            # let's keep only the non-zero values

            # Select topK values
            # Sorting is done in three steps. Faster then plain np.argsort for higher number of items
            # - Partition the data to extract the set of relevant items
            # - Sort only the relevant items
            # - Get the original item index

            nonzero_model_coef_index = self.model.sparse_coef_.indices
            nonzero_model_coef_value = self.model.sparse_coef_.data

            local_topK = min(len(nonzero_model_coef_value)-1, self.topK)

            relevant_items_partition = (-nonzero_model_coef_value).argpartition(local_topK)[0:local_topK]
            relevant_items_partition_sorting = np.argsort(-nonzero_model_coef_value[relevant_items_partition])
            ranking = relevant_items_partition[relevant_items_partition_sorting]

            for index in range(len(ranking)):

                if numCells == len(rows):
                    rows = np.concatenate((rows, np.zeros(dataBlock, dtype=np.int32)))
                    cols = np.concatenate((cols, np.zeros(dataBlock, dtype=np.int32)))
                    values = np.concatenate((values, np.zeros(dataBlock, dtype=np.float32)))


                rows[numCells] = nonzero_model_coef_index[ranking[index]]
                cols[numCells] = currentItem
                values[numCells] = nonzero_model_coef_value[ranking[index]]

                numCells += 1

            # finally, replace the original values of the j-th column
            URM_train.data[start_pos:end_pos] = current_item_data_backup

            elapsed_time = time.time() - start_time
            new_time_value, new_time_unit = seconds_to_biggest_unit(elapsed_time)


            if time.time() - start_time_printBatch > 300 or currentItem == n_items-1:
                self._print("Processed {} ({:4.1f}%) in {:.2f} {}. Items per second: {:.2f}".format(
                    currentItem+1,
                    100.0* float(currentItem+1)/n_items,
                    new_time_value,
                    new_time_unit,
                    float(currentItem)/elapsed_time))

                sys.stdout.flush()
                sys.stderr.flush()

                start_time_printBatch = time.time()

        # generate the sparse weight matrix
        self.W_sparse = sps.csr_matrix((values[:numCells], (rows[:numCells], cols[:numCells])),
                                       shape=(n_items, n_items), dtype=np.float32)

# %%
from Recommenders.BaseMatrixFactorizationRecommender import BaseMatrixFactorizationRecommender
from Recommenders.Incremental_Training_Early_Stopping import Incremental_Training_Early_Stopping
from Recommenders.Recommender_utils import check_matrix

def linear_scaling_confidence(URM_train, alpha):
    C = check_matrix(URM_train.T, format="csr", dtype=np.float32)
    C.data = 1.0 + alpha * C.data

    return C

# %%
from Recommenders.SLIM.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython

slim_bpr = SLIM_BPR_Cython(URM_train)
slim_bpr.fit(epochs=650, sgd_mode = "sgd", topK = 483, lambda_i = 0.0006712905081189398, lambda_j = 0.06584150350451998, learning_rate = 0.0036482363905043207)
# Out:
# SLIM_BPR_Recommender: URM Detected 3461 (12.4%) items with no interactions.
# SLIM_BPR_Recommender: Automatic selection of fastest train mode. Available RAM is 30777.00 MB (95.85%) of 32110.00 MB, required is 3128.84 MB. Using dense matrix.
# Processed 41629 (100.0%) in 0.44 sec. BPR loss is 2.67E-03. Sample per second: 93917
# SLIM_BPR_Recommender: Epoch 1 of 650. Elapsed time 0.26 sec
# Processed 41629 (100.0%) in 0.70 sec. BPR loss is 1.48E-02. Sample per second: 59209
# SLIM_BPR_Recommender: Epoch 2 of 650. Elapsed time 0.52 sec
# Processed 41629 (100.0%) in 0.96 sec. BPR loss is 3.25E-02. Sample per second: 43491
# SLIM_BPR_Recommender: Epoch 3 of 650. Elapsed time 0.78 sec
# Processed 41629 (100.0%) in 1.22 sec. BPR loss is 5.63E-02. Sample per second: 34243
# SLIM_BPR_Recommender: Epoch 4 of 650. Elapsed time 1.03 sec
# Processed 41629 (100.0%) in 0.47 sec. BPR loss is 8.26E-02. Sample per second: 88784
# SLIM_BPR_Recommender: Epoch 5 of 650. Elapsed time 1.29 sec
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 1.02E-01. Sample per second: 57713
# SLIM_BPR_Recommender: Epoch 6 of 650. Elapsed time 1.54 sec
# Processed 41629 (100.0%) in 0.98 sec. BPR loss is 1.33E-01. Sample per second: 42556
# SLIM_BPR_Recommender: Epoch 7 of 650. Elapsed time 1.80 sec
# Processed 41629 (100.0%) in 1.23 sec. BPR loss is 1.68E-01. Sample per second: 33804
# SLIM_BPR_Recommender: Epoch 8 of 650. Elapsed time 2.05 sec
# Processed 41629 (100.0%) in 0.49 sec. BPR loss is 1.99E-01. Sample per second: 85763
# SLIM_BPR_Recommender: Epoch 9 of 650. Elapsed time 2.30 sec
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 2.28E-01. Sample per second: 56700
# SLIM_BPR_Recommender: Epoch 10 of 650. Elapsed time 2.55 sec
# Processed 41629 (100.0%) in 0.99 sec. BPR loss is 2.64E-01. Sample per second: 42179
# SLIM_BPR_Recommender: Epoch 11 of 650. Elapsed time 2.81 sec
# Processed 41629 (100.0%) in 1.24 sec. BPR loss is 2.93E-01. Sample per second: 33655
# SLIM_BPR_Recommender: Epoch 12 of 650. Elapsed time 3.06 sec
# Processed 41629 (100.0%) in 0.49 sec. BPR loss is 3.20E-01. Sample per second: 84974
# SLIM_BPR_Recommender: Epoch 13 of 650. Elapsed time 3.31 sec
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 3.59E-01. Sample per second: 56302
# SLIM_BPR_Recommender: Epoch 14 of 650. Elapsed time 3.56 sec
# Processed 41629 (100.0%) in 0.99 sec. BPR loss is 3.67E-01. Sample per second: 42142
# SLIM_BPR_Recommender: Epoch 15 of 650. Elapsed time 3.81 sec
# Processed 41629 (100.0%) in 1.24 sec. BPR loss is 4.11E-01. Sample per second: 33688
# SLIM_BPR_Recommender: Epoch 16 of 650. Elapsed time 4.05 sec
# Processed 41629 (100.0%) in 0.49 sec. BPR loss is 4.61E-01. Sample per second: 85704
# SLIM_BPR_Recommender: Epoch 17 of 650. Elapsed time 4.30 sec
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 4.73E-01. Sample per second: 56643
# SLIM_BPR_Recommender: Epoch 18 of 650. Elapsed time 4.55 sec
# Processed 41629 (100.0%) in 0.98 sec. BPR loss is 5.23E-01. Sample per second: 42391
# SLIM_BPR_Recommender: Epoch 19 of 650. Elapsed time 4.80 sec
# Processed 41629 (100.0%) in 1.23 sec. BPR loss is 5.44E-01. Sample per second: 33949
# SLIM_BPR_Recommender: Epoch 20 of 650. Elapsed time 5.04 sec
# Processed 41629 (100.0%) in 0.47 sec. BPR loss is 5.76E-01. Sample per second: 88012
# SLIM_BPR_Recommender: Epoch 21 of 650. Elapsed time 5.29 sec
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 6.28E-01. Sample per second: 57693
# SLIM_BPR_Recommender: Epoch 22 of 650. Elapsed time 5.54 sec
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 6.22E-01. Sample per second: 42844
# SLIM_BPR_Recommender: Epoch 23 of 650. Elapsed time 5.79 sec
# Processed 41629 (100.0%) in 1.22 sec. BPR loss is 6.84E-01. Sample per second: 34090
# SLIM_BPR_Recommender: Epoch 24 of 650. Elapsed time 6.04 sec
# Processed 41629 (100.0%) in 0.47 sec. BPR loss is 7.19E-01. Sample per second: 89038
# SLIM_BPR_Recommender: Epoch 25 of 650. Elapsed time 6.29 sec
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 7.27E-01. Sample per second: 58145
# SLIM_BPR_Recommender: Epoch 26 of 650. Elapsed time 6.53 sec
# Processed 41629 (100.0%) in 0.96 sec. BPR loss is 7.79E-01. Sample per second: 43301
# SLIM_BPR_Recommender: Epoch 27 of 650. Elapsed time 6.78 sec
# Processed 41629 (100.0%) in 1.21 sec. BPR loss is 7.85E-01. Sample per second: 34525
# SLIM_BPR_Recommender: Epoch 28 of 650. Elapsed time 7.02 sec
# Processed 41629 (100.0%) in 0.46 sec. BPR loss is 8.46E-01. Sample per second: 91408
# SLIM_BPR_Recommender: Epoch 29 of 650. Elapsed time 7.27 sec
# Processed 41629 (100.0%) in 0.71 sec. BPR loss is 8.54E-01. Sample per second: 58496
# SLIM_BPR_Recommender: Epoch 30 of 650. Elapsed time 7.53 sec
# Processed 41629 (100.0%) in 0.99 sec. BPR loss is 8.90E-01. Sample per second: 42049
# SLIM_BPR_Recommender: Epoch 31 of 650. Elapsed time 7.81 sec
# Processed 41629 (100.0%) in 1.24 sec. BPR loss is 9.10E-01. Sample per second: 33637
# SLIM_BPR_Recommender: Epoch 32 of 650. Elapsed time 8.06 sec
# Processed 41629 (100.0%) in 0.49 sec. BPR loss is 9.85E-01. Sample per second: 85383
# SLIM_BPR_Recommender: Epoch 33 of 650. Elapsed time 8.31 sec
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 9.76E-01. Sample per second: 56844
# SLIM_BPR_Recommender: Epoch 34 of 650. Elapsed time 8.55 sec
# Processed 41629 (100.0%) in 0.98 sec. BPR loss is 1.01E+00. Sample per second: 42468
# SLIM_BPR_Recommender: Epoch 35 of 650. Elapsed time 8.80 sec
# Processed 41629 (100.0%) in 1.23 sec. BPR loss is 1.06E+00. Sample per second: 33911
# SLIM_BPR_Recommender: Epoch 36 of 650. Elapsed time 9.05 sec
# Processed 41629 (100.0%) in 0.47 sec. BPR loss is 1.10E+00. Sample per second: 88306
# SLIM_BPR_Recommender: Epoch 37 of 650. Elapsed time 9.29 sec
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 1.07E+00. Sample per second: 57931
# SLIM_BPR_Recommender: Epoch 38 of 650. Elapsed time 9.54 sec
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 1.09E+00. Sample per second: 42922
# SLIM_BPR_Recommender: Epoch 39 of 650. Elapsed time 9.79 sec
# Processed 41629 (100.0%) in 1.22 sec. BPR loss is 1.21E+00. Sample per second: 34111
# SLIM_BPR_Recommender: Epoch 40 of 650. Elapsed time 10.04 sec
# Processed 41629 (100.0%) in 0.47 sec. BPR loss is 1.21E+00. Sample per second: 88173
# SLIM_BPR_Recommender: Epoch 41 of 650. Elapsed time 10.29 sec
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 1.21E+00. Sample per second: 57807
# SLIM_BPR_Recommender: Epoch 42 of 650. Elapsed time 10.54 sec
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 1.33E+00. Sample per second: 42936
# SLIM_BPR_Recommender: Epoch 43 of 650. Elapsed time 10.79 sec
# Processed 41629 (100.0%) in 1.21 sec. BPR loss is 1.28E+00. Sample per second: 34355
# SLIM_BPR_Recommender: Epoch 44 of 650. Elapsed time 11.03 sec
# Processed 41629 (100.0%) in 0.46 sec. BPR loss is 1.30E+00. Sample per second: 90926
# SLIM_BPR_Recommender: Epoch 45 of 650. Elapsed time 11.28 sec
# Processed 41629 (100.0%) in 0.70 sec. BPR loss is 1.36E+00. Sample per second: 59213
# SLIM_BPR_Recommender: Epoch 46 of 650. Elapsed time 11.52 sec
# Processed 41629 (100.0%) in 0.95 sec. BPR loss is 1.40E+00. Sample per second: 43676
# SLIM_BPR_Recommender: Epoch 47 of 650. Elapsed time 11.77 sec
# Processed 41629 (100.0%) in 1.20 sec. BPR loss is 1.41E+00. Sample per second: 34683
# SLIM_BPR_Recommender: Epoch 48 of 650. Elapsed time 12.02 sec
# Processed 41629 (100.0%) in 0.45 sec. BPR loss is 1.47E+00. Sample per second: 92784
# SLIM_BPR_Recommender: Epoch 49 of 650. Elapsed time 12.27 sec
# Processed 41629 (100.0%) in 0.69 sec. BPR loss is 1.46E+00. Sample per second: 59888
# SLIM_BPR_Recommender: Epoch 50 of 650. Elapsed time 12.51 sec
# Processed 41629 (100.0%) in 0.94 sec. BPR loss is 1.47E+00. Sample per second: 44266
# SLIM_BPR_Recommender: Epoch 51 of 650. Elapsed time 12.76 sec
# Processed 41629 (100.0%) in 1.19 sec. BPR loss is 1.54E+00. Sample per second: 34954
# SLIM_BPR_Recommender: Epoch 52 of 650. Elapsed time 13.01 sec
# Processed 41629 (100.0%) in 0.44 sec. BPR loss is 1.56E+00. Sample per second: 95580
# SLIM_BPR_Recommender: Epoch 53 of 650. Elapsed time 13.25 sec
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 1.60E+00. Sample per second: 61266
# SLIM_BPR_Recommender: Epoch 54 of 650. Elapsed time 13.50 sec
# Processed 41629 (100.0%) in 0.93 sec. BPR loss is 1.59E+00. Sample per second: 44670
# SLIM_BPR_Recommender: Epoch 55 of 650. Elapsed time 13.75 sec
# Processed 41629 (100.0%) in 1.18 sec. BPR loss is 1.66E+00. Sample per second: 35333
# SLIM_BPR_Recommender: Epoch 56 of 650. Elapsed time 14.00 sec
# Processed 41629 (100.0%) in 0.42 sec. BPR loss is 1.69E+00. Sample per second: 98023
# SLIM_BPR_Recommender: Epoch 57 of 650. Elapsed time 14.24 sec
# Processed 41629 (100.0%) in 0.67 sec. BPR loss is 1.64E+00. Sample per second: 62296
# SLIM_BPR_Recommender: Epoch 58 of 650. Elapsed time 14.49 sec
# Processed 41629 (100.0%) in 0.92 sec. BPR loss is 1.64E+00. Sample per second: 45254
# SLIM_BPR_Recommender: Epoch 59 of 650. Elapsed time 14.74 sec
# Processed 41629 (100.0%) in 1.17 sec. BPR loss is 1.71E+00. Sample per second: 35582
# SLIM_BPR_Recommender: Epoch 60 of 650. Elapsed time 14.99 sec
# Processed 41629 (100.0%) in 0.41 sec. BPR loss is 1.75E+00. Sample per second: 100560
# SLIM_BPR_Recommender: Epoch 61 of 650. Elapsed time 15.23 sec
# Processed 41629 (100.0%) in 0.66 sec. BPR loss is 1.70E+00. Sample per second: 63231
# SLIM_BPR_Recommender: Epoch 62 of 650. Elapsed time 15.48 sec
# Processed 41629 (100.0%) in 0.91 sec. BPR loss is 1.79E+00. Sample per second: 45606
# SLIM_BPR_Recommender: Epoch 63 of 650. Elapsed time 15.73 sec
# Processed 41629 (100.0%) in 1.16 sec. BPR loss is 1.88E+00. Sample per second: 35959
# SLIM_BPR_Recommender: Epoch 64 of 650. Elapsed time 15.98 sec
# Processed 41629 (100.0%) in 0.41 sec. BPR loss is 1.86E+00. Sample per second: 102505
# SLIM_BPR_Recommender: Epoch 65 of 650. Elapsed time 16.22 sec
# Processed 41629 (100.0%) in 0.65 sec. BPR loss is 1.84E+00. Sample per second: 63921
# SLIM_BPR_Recommender: Epoch 66 of 650. Elapsed time 16.47 sec
# Processed 41629 (100.0%) in 0.90 sec. BPR loss is 1.95E+00. Sample per second: 46314
# SLIM_BPR_Recommender: Epoch 67 of 650. Elapsed time 16.72 sec
# Processed 41629 (100.0%) in 1.15 sec. BPR loss is 1.90E+00. Sample per second: 36232
# SLIM_BPR_Recommender: Epoch 68 of 650. Elapsed time 16.97 sec
# Processed 41629 (100.0%) in 0.39 sec. BPR loss is 2.02E+00. Sample per second: 106114
# SLIM_BPR_Recommender: Epoch 69 of 650. Elapsed time 17.21 sec
# Processed 41629 (100.0%) in 0.64 sec. BPR loss is 2.10E+00. Sample per second: 65441
# SLIM_BPR_Recommender: Epoch 70 of 650. Elapsed time 17.45 sec
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 2.04E+00. Sample per second: 46829
# SLIM_BPR_Recommender: Epoch 71 of 650. Elapsed time 17.71 sec
# Processed 41629 (100.0%) in 1.14 sec. BPR loss is 2.09E+00. Sample per second: 36653
# SLIM_BPR_Recommender: Epoch 72 of 650. Elapsed time 17.95 sec
# Processed 41629 (100.0%) in 0.38 sec. BPR loss is 2.19E+00. Sample per second: 108699
# SLIM_BPR_Recommender: Epoch 73 of 650. Elapsed time 18.20 sec
# Processed 41629 (100.0%) in 0.62 sec. BPR loss is 2.12E+00. Sample per second: 66702
# SLIM_BPR_Recommender: Epoch 74 of 650. Elapsed time 18.44 sec
# Processed 41629 (100.0%) in 0.93 sec. BPR loss is 2.12E+00. Sample per second: 44910
# SLIM_BPR_Recommender: Epoch 75 of 650. Elapsed time 18.75 sec
# Processed 41629 (100.0%) in 1.28 sec. BPR loss is 2.20E+00. Sample per second: 32519
# SLIM_BPR_Recommender: Epoch 76 of 650. Elapsed time 19.10 sec
# Processed 41629 (100.0%) in 0.53 sec. BPR loss is 2.16E+00. Sample per second: 78603
# SLIM_BPR_Recommender: Epoch 77 of 650. Elapsed time 19.35 sec
# Processed 41629 (100.0%) in 0.78 sec. BPR loss is 2.30E+00. Sample per second: 53468
# SLIM_BPR_Recommender: Epoch 78 of 650. Elapsed time 19.60 sec
# Processed 41629 (100.0%) in 1.02 sec. BPR loss is 2.33E+00. Sample per second: 40656
# SLIM_BPR_Recommender: Epoch 79 of 650. Elapsed time 19.84 sec
# Processed 41629 (100.0%) in 0.27 sec. BPR loss is 2.31E+00. Sample per second: 156066
# SLIM_BPR_Recommender: Epoch 80 of 650. Elapsed time 20.09 sec
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 2.33E+00. Sample per second: 81731
# SLIM_BPR_Recommender: Epoch 81 of 650. Elapsed time 20.33 sec
# Processed 41629 (100.0%) in 0.75 sec. BPR loss is 2.44E+00. Sample per second: 55304
# SLIM_BPR_Recommender: Epoch 82 of 650. Elapsed time 20.57 sec
# Processed 41629 (100.0%) in 1.00 sec. BPR loss is 2.31E+00. Sample per second: 41500
# SLIM_BPR_Recommender: Epoch 83 of 650. Elapsed time 20.82 sec
# Processed 41629 (100.0%) in 0.25 sec. BPR loss is 2.54E+00. Sample per second: 167006
# SLIM_BPR_Recommender: Epoch 84 of 650. Elapsed time 21.07 sec
# Processed 41629 (100.0%) in 0.49 sec. BPR loss is 2.52E+00. Sample per second: 84473
# SLIM_BPR_Recommender: Epoch 85 of 650. Elapsed time 21.31 sec
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 2.35E+00. Sample per second: 56310
# SLIM_BPR_Recommender: Epoch 86 of 650. Elapsed time 21.56 sec
# Processed 41629 (100.0%) in 0.99 sec. BPR loss is 2.53E+00. Sample per second: 42005
# SLIM_BPR_Recommender: Epoch 87 of 650. Elapsed time 21.81 sec
# Processed 41629 (100.0%) in 1.23 sec. BPR loss is 2.39E+00. Sample per second: 33716
# SLIM_BPR_Recommender: Epoch 88 of 650. Elapsed time 22.05 sec
# Processed 41629 (100.0%) in 0.48 sec. BPR loss is 2.52E+00. Sample per second: 86340
# SLIM_BPR_Recommender: Epoch 89 of 650. Elapsed time 22.30 sec
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 2.68E+00. Sample per second: 56910
# SLIM_BPR_Recommender: Epoch 90 of 650. Elapsed time 22.55 sec
# Processed 41629 (100.0%) in 0.98 sec. BPR loss is 2.64E+00. Sample per second: 42454
# SLIM_BPR_Recommender: Epoch 91 of 650. Elapsed time 22.80 sec
# Processed 41629 (100.0%) in 1.23 sec. BPR loss is 2.61E+00. Sample per second: 33971
# SLIM_BPR_Recommender: Epoch 92 of 650. Elapsed time 23.04 sec
# Processed 41629 (100.0%) in 0.47 sec. BPR loss is 2.60E+00. Sample per second: 87819
# SLIM_BPR_Recommender: Epoch 93 of 650. Elapsed time 23.29 sec
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 2.69E+00. Sample per second: 57595
# SLIM_BPR_Recommender: Epoch 94 of 650. Elapsed time 23.54 sec
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 2.59E+00. Sample per second: 42858
# SLIM_BPR_Recommender: Epoch 95 of 650. Elapsed time 23.79 sec
# Processed 41629 (100.0%) in 1.22 sec. BPR loss is 2.64E+00. Sample per second: 34219
# SLIM_BPR_Recommender: Epoch 96 of 650. Elapsed time 24.04 sec
# Processed 41629 (100.0%) in 0.46 sec. BPR loss is 2.83E+00. Sample per second: 90263
# SLIM_BPR_Recommender: Epoch 97 of 650. Elapsed time 24.28 sec
# Processed 41629 (100.0%) in 0.71 sec. BPR loss is 2.79E+00. Sample per second: 58561
# SLIM_BPR_Recommender: Epoch 98 of 650. Elapsed time 24.53 sec
# Processed 41629 (100.0%) in 0.96 sec. BPR loss is 2.86E+00. Sample per second: 43267
# SLIM_BPR_Recommender: Epoch 99 of 650. Elapsed time 24.78 sec
# Processed 41629 (100.0%) in 1.21 sec. BPR loss is 2.75E+00. Sample per second: 34284
# SLIM_BPR_Recommender: Epoch 100 of 650. Elapsed time 25.03 sec
# Processed 41629 (100.0%) in 0.46 sec. BPR loss is 2.80E+00. Sample per second: 89644
# SLIM_BPR_Recommender: Epoch 101 of 650. Elapsed time 25.28 sec
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 2.99E+00. Sample per second: 57987
# SLIM_BPR_Recommender: Epoch 102 of 650. Elapsed time 25.54 sec
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 2.92E+00. Sample per second: 43049
# SLIM_BPR_Recommender: Epoch 103 of 650. Elapsed time 25.79 sec
# Processed 41629 (100.0%) in 1.21 sec. BPR loss is 2.83E+00. Sample per second: 34380
# SLIM_BPR_Recommender: Epoch 104 of 650. Elapsed time 26.03 sec
# Processed 41629 (100.0%) in 0.46 sec. BPR loss is 2.90E+00. Sample per second: 90172
# SLIM_BPR_Recommender: Epoch 105 of 650. Elapsed time 26.28 sec
# Processed 41629 (100.0%) in 0.71 sec. BPR loss is 2.83E+00. Sample per second: 58873
# SLIM_BPR_Recommender: Epoch 106 of 650. Elapsed time 26.53 sec
# Processed 41629 (100.0%) in 0.96 sec. BPR loss is 2.93E+00. Sample per second: 43559
# SLIM_BPR_Recommender: Epoch 107 of 650. Elapsed time 26.78 sec
# Processed 41629 (100.0%) in 1.20 sec. BPR loss is 3.13E+00. Sample per second: 34598
# SLIM_BPR_Recommender: Epoch 108 of 650. Elapsed time 27.02 sec
# Processed 41629 (100.0%) in 0.45 sec. BPR loss is 3.04E+00. Sample per second: 92707
# SLIM_BPR_Recommender: Epoch 109 of 650. Elapsed time 27.27 sec
# Processed 41629 (100.0%) in 0.70 sec. BPR loss is 3.08E+00. Sample per second: 59820
# SLIM_BPR_Recommender: Epoch 110 of 650. Elapsed time 27.51 sec
# Processed 41629 (100.0%) in 0.95 sec. BPR loss is 3.09E+00. Sample per second: 43846
# SLIM_BPR_Recommender: Epoch 111 of 650. Elapsed time 27.77 sec
# Processed 41629 (100.0%) in 1.19 sec. BPR loss is 3.23E+00. Sample per second: 34823
# SLIM_BPR_Recommender: Epoch 112 of 650. Elapsed time 28.01 sec
# Processed 41629 (100.0%) in 0.44 sec. BPR loss is 3.24E+00. Sample per second: 94380
# SLIM_BPR_Recommender: Epoch 113 of 650. Elapsed time 28.26 sec
# Processed 41629 (100.0%) in 0.70 sec. BPR loss is 3.14E+00. Sample per second: 59832
# SLIM_BPR_Recommender: Epoch 114 of 650. Elapsed time 28.51 sec
# Processed 41629 (100.0%) in 0.95 sec. BPR loss is 3.16E+00. Sample per second: 43925
# SLIM_BPR_Recommender: Epoch 115 of 650. Elapsed time 28.77 sec
# Processed 41629 (100.0%) in 1.19 sec. BPR loss is 3.29E+00. Sample per second: 34870
# SLIM_BPR_Recommender: Epoch 116 of 650. Elapsed time 29.01 sec
# Processed 41629 (100.0%) in 0.44 sec. BPR loss is 3.28E+00. Sample per second: 94984
# SLIM_BPR_Recommender: Epoch 117 of 650. Elapsed time 29.26 sec
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 3.13E+00. Sample per second: 60971
# SLIM_BPR_Recommender: Epoch 118 of 650. Elapsed time 29.50 sec
# Processed 41629 (100.0%) in 0.96 sec. BPR loss is 3.33E+00. Sample per second: 43437
# SLIM_BPR_Recommender: Epoch 119 of 650. Elapsed time 29.78 sec
# Processed 41629 (100.0%) in 1.20 sec. BPR loss is 3.22E+00. Sample per second: 34645
# SLIM_BPR_Recommender: Epoch 120 of 650. Elapsed time 30.02 sec
# Processed 41629 (100.0%) in 0.44 sec. BPR loss is 3.16E+00. Sample per second: 93994
# SLIM_BPR_Recommender: Epoch 121 of 650. Elapsed time 30.26 sec
# Processed 41629 (100.0%) in 0.69 sec. BPR loss is 3.36E+00. Sample per second: 60496
# SLIM_BPR_Recommender: Epoch 122 of 650. Elapsed time 30.51 sec
# Processed 41629 (100.0%) in 0.93 sec. BPR loss is 3.31E+00. Sample per second: 44578
# SLIM_BPR_Recommender: Epoch 123 of 650. Elapsed time 30.75 sec
# Processed 41629 (100.0%) in 1.18 sec. BPR loss is 3.45E+00. Sample per second: 35340
# SLIM_BPR_Recommender: Epoch 124 of 650. Elapsed time 31.00 sec
# Processed 41629 (100.0%) in 0.43 sec. BPR loss is 3.45E+00. Sample per second: 97500
# SLIM_BPR_Recommender: Epoch 125 of 650. Elapsed time 31.25 sec
# Processed 41629 (100.0%) in 0.67 sec. BPR loss is 3.68E+00. Sample per second: 61860
# SLIM_BPR_Recommender: Epoch 126 of 650. Elapsed time 31.49 sec
# Processed 41629 (100.0%) in 0.93 sec. BPR loss is 3.42E+00. Sample per second: 44892
# SLIM_BPR_Recommender: Epoch 127 of 650. Elapsed time 31.75 sec
# Processed 41629 (100.0%) in 1.17 sec. BPR loss is 3.47E+00. Sample per second: 35617
# SLIM_BPR_Recommender: Epoch 128 of 650. Elapsed time 31.99 sec
# Processed 41629 (100.0%) in 0.41 sec. BPR loss is 3.63E+00. Sample per second: 100441
# SLIM_BPR_Recommender: Epoch 129 of 650. Elapsed time 32.23 sec
# Processed 41629 (100.0%) in 0.66 sec. BPR loss is 3.52E+00. Sample per second: 63052
# SLIM_BPR_Recommender: Epoch 130 of 650. Elapsed time 32.48 sec
# Processed 41629 (100.0%) in 0.91 sec. BPR loss is 3.57E+00. Sample per second: 45727
# SLIM_BPR_Recommender: Epoch 131 of 650. Elapsed time 32.73 sec
# Processed 41629 (100.0%) in 1.16 sec. BPR loss is 3.52E+00. Sample per second: 35971
# SLIM_BPR_Recommender: Epoch 132 of 650. Elapsed time 32.98 sec
# Processed 41629 (100.0%) in 0.40 sec. BPR loss is 3.48E+00. Sample per second: 102837
# SLIM_BPR_Recommender: Epoch 133 of 650. Elapsed time 33.22 sec
# Processed 41629 (100.0%) in 0.65 sec. BPR loss is 3.42E+00. Sample per second: 63845
# SLIM_BPR_Recommender: Epoch 134 of 650. Elapsed time 33.47 sec
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 3.48E+00. Sample per second: 46509
# SLIM_BPR_Recommender: Epoch 135 of 650. Elapsed time 33.71 sec
# Processed 41629 (100.0%) in 1.14 sec. BPR loss is 3.83E+00. Sample per second: 36524
# SLIM_BPR_Recommender: Epoch 136 of 650. Elapsed time 33.96 sec
# Processed 41629 (100.0%) in 0.39 sec. BPR loss is 3.48E+00. Sample per second: 107053
# SLIM_BPR_Recommender: Epoch 137 of 650. Elapsed time 34.21 sec
# Processed 41629 (100.0%) in 0.63 sec. BPR loss is 3.75E+00. Sample per second: 65660
# SLIM_BPR_Recommender: Epoch 138 of 650. Elapsed time 34.45 sec
# Processed 41629 (100.0%) in 0.88 sec. BPR loss is 3.57E+00. Sample per second: 47241
# SLIM_BPR_Recommender: Epoch 139 of 650. Elapsed time 34.70 sec
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 3.50E+00. Sample per second: 36993
# SLIM_BPR_Recommender: Epoch 140 of 650. Elapsed time 34.95 sec
# Processed 41629 (100.0%) in 0.37 sec. BPR loss is 3.64E+00. Sample per second: 111227
# SLIM_BPR_Recommender: Epoch 141 of 650. Elapsed time 35.19 sec
# Processed 41629 (100.0%) in 0.62 sec. BPR loss is 3.67E+00. Sample per second: 67197
# SLIM_BPR_Recommender: Epoch 142 of 650. Elapsed time 35.44 sec
# Processed 41629 (100.0%) in 0.87 sec. BPR loss is 3.69E+00. Sample per second: 47689
# SLIM_BPR_Recommender: Epoch 143 of 650. Elapsed time 35.69 sec
# Processed 41629 (100.0%) in 1.11 sec. BPR loss is 3.90E+00. Sample per second: 37406
# SLIM_BPR_Recommender: Epoch 144 of 650. Elapsed time 35.93 sec
# Processed 41629 (100.0%) in 0.35 sec. BPR loss is 3.93E+00. Sample per second: 117205
# SLIM_BPR_Recommender: Epoch 145 of 650. Elapsed time 36.17 sec
# Processed 41629 (100.0%) in 0.60 sec. BPR loss is 3.90E+00. Sample per second: 69936
# SLIM_BPR_Recommender: Epoch 146 of 650. Elapsed time 36.41 sec
# Processed 41629 (100.0%) in 0.84 sec. BPR loss is 3.82E+00. Sample per second: 49662
# SLIM_BPR_Recommender: Epoch 147 of 650. Elapsed time 36.66 sec
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 3.88E+00. Sample per second: 38550
# SLIM_BPR_Recommender: Epoch 148 of 650. Elapsed time 36.90 sec
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 4.04E+00. Sample per second: 128577
# SLIM_BPR_Recommender: Epoch 149 of 650. Elapsed time 37.14 sec
# Processed 41629 (100.0%) in 0.57 sec. BPR loss is 4.00E+00. Sample per second: 73482
# SLIM_BPR_Recommender: Epoch 150 of 650. Elapsed time 37.39 sec
# Processed 41629 (100.0%) in 0.81 sec. BPR loss is 3.89E+00. Sample per second: 51077
# SLIM_BPR_Recommender: Epoch 151 of 650. Elapsed time 37.63 sec
# Processed 41629 (100.0%) in 1.06 sec. BPR loss is 4.09E+00. Sample per second: 39237
# SLIM_BPR_Recommender: Epoch 152 of 650. Elapsed time 37.88 sec
# Processed 41629 (100.0%) in 0.31 sec. BPR loss is 3.93E+00. Sample per second: 135350
# SLIM_BPR_Recommender: Epoch 153 of 650. Elapsed time 38.13 sec
# Processed 41629 (100.0%) in 0.55 sec. BPR loss is 3.96E+00. Sample per second: 75151
# SLIM_BPR_Recommender: Epoch 154 of 650. Elapsed time 38.37 sec
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 4.14E+00. Sample per second: 51844
# SLIM_BPR_Recommender: Epoch 155 of 650. Elapsed time 38.62 sec
# Processed 41629 (100.0%) in 1.05 sec. BPR loss is 4.16E+00. Sample per second: 39659
# SLIM_BPR_Recommender: Epoch 156 of 650. Elapsed time 38.87 sec
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 4.09E+00. Sample per second: 141118
# SLIM_BPR_Recommender: Epoch 157 of 650. Elapsed time 39.11 sec
# Processed 41629 (100.0%) in 0.54 sec. BPR loss is 4.13E+00. Sample per second: 77327
# SLIM_BPR_Recommender: Epoch 158 of 650. Elapsed time 39.36 sec
# Processed 41629 (100.0%) in 0.78 sec. BPR loss is 3.94E+00. Sample per second: 53094
# SLIM_BPR_Recommender: Epoch 159 of 650. Elapsed time 39.60 sec
# Processed 41629 (100.0%) in 1.03 sec. BPR loss is 4.24E+00. Sample per second: 40561
# SLIM_BPR_Recommender: Epoch 160 of 650. Elapsed time 39.84 sec
# Processed 41629 (100.0%) in 0.27 sec. BPR loss is 3.97E+00. Sample per second: 152872
# SLIM_BPR_Recommender: Epoch 161 of 650. Elapsed time 40.09 sec
# Processed 41629 (100.0%) in 0.53 sec. BPR loss is 4.06E+00. Sample per second: 78577
# SLIM_BPR_Recommender: Epoch 162 of 650. Elapsed time 40.35 sec
# Processed 41629 (100.0%) in 0.83 sec. BPR loss is 4.15E+00. Sample per second: 50048
# SLIM_BPR_Recommender: Epoch 163 of 650. Elapsed time 40.65 sec
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 4.19E+00. Sample per second: 38494
# SLIM_BPR_Recommender: Epoch 164 of 650. Elapsed time 40.90 sec
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 4.11E+00. Sample per second: 128777
# SLIM_BPR_Recommender: Epoch 165 of 650. Elapsed time 41.14 sec
# Processed 41629 (100.0%) in 0.57 sec. BPR loss is 4.20E+00. Sample per second: 73220
# SLIM_BPR_Recommender: Epoch 166 of 650. Elapsed time 41.39 sec
# Processed 41629 (100.0%) in 0.82 sec. BPR loss is 4.12E+00. Sample per second: 50941
# SLIM_BPR_Recommender: Epoch 167 of 650. Elapsed time 41.64 sec
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 4.29E+00. Sample per second: 38830
# SLIM_BPR_Recommender: Epoch 168 of 650. Elapsed time 41.89 sec
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 4.18E+00. Sample per second: 130226
# SLIM_BPR_Recommender: Epoch 169 of 650. Elapsed time 42.14 sec
# Processed 41629 (100.0%) in 0.56 sec. BPR loss is 4.11E+00. Sample per second: 73660
# SLIM_BPR_Recommender: Epoch 170 of 650. Elapsed time 42.39 sec
# Processed 41629 (100.0%) in 0.82 sec. BPR loss is 4.22E+00. Sample per second: 51019
# SLIM_BPR_Recommender: Epoch 171 of 650. Elapsed time 42.63 sec
# Processed 41629 (100.0%) in 1.06 sec. BPR loss is 4.41E+00. Sample per second: 39115
# SLIM_BPR_Recommender: Epoch 172 of 650. Elapsed time 42.88 sec
# Processed 41629 (100.0%) in 0.31 sec. BPR loss is 4.37E+00. Sample per second: 134236
# SLIM_BPR_Recommender: Epoch 173 of 650. Elapsed time 43.13 sec
# Processed 41629 (100.0%) in 0.55 sec. BPR loss is 4.21E+00. Sample per second: 75093
# SLIM_BPR_Recommender: Epoch 174 of 650. Elapsed time 43.37 sec
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 4.34E+00. Sample per second: 51848
# SLIM_BPR_Recommender: Epoch 175 of 650. Elapsed time 43.62 sec
# Processed 41629 (100.0%) in 1.06 sec. BPR loss is 4.59E+00. Sample per second: 39341
# SLIM_BPR_Recommender: Epoch 176 of 650. Elapsed time 43.88 sec
# Processed 41629 (100.0%) in 0.31 sec. BPR loss is 4.22E+00. Sample per second: 135265
# SLIM_BPR_Recommender: Epoch 177 of 650. Elapsed time 44.13 sec
# Processed 41629 (100.0%) in 0.55 sec. BPR loss is 4.31E+00. Sample per second: 75861
# SLIM_BPR_Recommender: Epoch 178 of 650. Elapsed time 44.37 sec
# Processed 41629 (100.0%) in 0.79 sec. BPR loss is 4.33E+00. Sample per second: 52673
# SLIM_BPR_Recommender: Epoch 179 of 650. Elapsed time 44.61 sec
# Processed 41629 (100.0%) in 1.03 sec. BPR loss is 4.41E+00. Sample per second: 40252
# SLIM_BPR_Recommender: Epoch 180 of 650. Elapsed time 44.85 sec
# Processed 41629 (100.0%) in 0.27 sec. BPR loss is 4.33E+00. Sample per second: 151292
# SLIM_BPR_Recommender: Epoch 181 of 650. Elapsed time 45.09 sec
# Processed 41629 (100.0%) in 0.52 sec. BPR loss is 4.31E+00. Sample per second: 80028
# SLIM_BPR_Recommender: Epoch 182 of 650. Elapsed time 45.34 sec
# Processed 41629 (100.0%) in 0.78 sec. BPR loss is 4.29E+00. Sample per second: 53343
# SLIM_BPR_Recommender: Epoch 183 of 650. Elapsed time 45.60 sec
# Processed 41629 (100.0%) in 1.03 sec. BPR loss is 4.38E+00. Sample per second: 40478
# SLIM_BPR_Recommender: Epoch 184 of 650. Elapsed time 45.85 sec
# Processed 41629 (100.0%) in 0.27 sec. BPR loss is 4.60E+00. Sample per second: 152636
# SLIM_BPR_Recommender: Epoch 185 of 650. Elapsed time 46.09 sec
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 4.70E+00. Sample per second: 80969
# SLIM_BPR_Recommender: Epoch 186 of 650. Elapsed time 46.33 sec
# Processed 41629 (100.0%) in 0.76 sec. BPR loss is 4.64E+00. Sample per second: 55024
# SLIM_BPR_Recommender: Epoch 187 of 650. Elapsed time 46.58 sec
# Processed 41629 (100.0%) in 1.00 sec. BPR loss is 4.54E+00. Sample per second: 41525
# SLIM_BPR_Recommender: Epoch 188 of 650. Elapsed time 46.82 sec
# Processed 41629 (100.0%) in 0.25 sec. BPR loss is 4.69E+00. Sample per second: 169719
# SLIM_BPR_Recommender: Epoch 189 of 650. Elapsed time 47.06 sec
# Processed 41629 (100.0%) in 0.49 sec. BPR loss is 4.57E+00. Sample per second: 85359
# SLIM_BPR_Recommender: Epoch 190 of 650. Elapsed time 47.31 sec
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 4.78E+00. Sample per second: 57054
# SLIM_BPR_Recommender: Epoch 191 of 650. Elapsed time 47.55 sec
# Processed 41629 (100.0%) in 0.98 sec. BPR loss is 4.74E+00. Sample per second: 42672
# SLIM_BPR_Recommender: Epoch 192 of 650. Elapsed time 47.79 sec
# Processed 41629 (100.0%) in 1.23 sec. BPR loss is 4.87E+00. Sample per second: 33957
# SLIM_BPR_Recommender: Epoch 193 of 650. Elapsed time 48.04 sec
# Processed 41629 (100.0%) in 0.47 sec. BPR loss is 4.61E+00. Sample per second: 88418
# SLIM_BPR_Recommender: Epoch 194 of 650. Elapsed time 48.29 sec
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 4.67E+00. Sample per second: 58043
# SLIM_BPR_Recommender: Epoch 195 of 650. Elapsed time 48.54 sec
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 4.78E+00. Sample per second: 42711
# SLIM_BPR_Recommender: Epoch 196 of 650. Elapsed time 48.79 sec
# Processed 41629 (100.0%) in 1.22 sec. BPR loss is 4.78E+00. Sample per second: 34080
# SLIM_BPR_Recommender: Epoch 197 of 650. Elapsed time 49.04 sec
# Processed 41629 (100.0%) in 0.47 sec. BPR loss is 4.72E+00. Sample per second: 88821
# SLIM_BPR_Recommender: Epoch 198 of 650. Elapsed time 49.29 sec
# Processed 41629 (100.0%) in 0.71 sec. BPR loss is 4.92E+00. Sample per second: 58793
# SLIM_BPR_Recommender: Epoch 199 of 650. Elapsed time 49.53 sec
# Processed 41629 (100.0%) in 1.00 sec. BPR loss is 4.99E+00. Sample per second: 41572
# SLIM_BPR_Recommender: Epoch 200 of 650. Elapsed time 49.82 sec
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 4.86E+00. Sample per second: 143949
# SLIM_BPR_Recommender: Epoch 201 of 650. Elapsed time 50.11 sec
# Processed 41629 (100.0%) in 0.54 sec. BPR loss is 4.86E+00. Sample per second: 76438
# SLIM_BPR_Recommender: Epoch 202 of 650. Elapsed time 50.36 sec
# Processed 41629 (100.0%) in 0.79 sec. BPR loss is 5.01E+00. Sample per second: 52549
# SLIM_BPR_Recommender: Epoch 203 of 650. Elapsed time 50.61 sec
# Processed 41629 (100.0%) in 1.03 sec. BPR loss is 4.92E+00. Sample per second: 40288
# SLIM_BPR_Recommender: Epoch 204 of 650. Elapsed time 50.85 sec
# Processed 41629 (100.0%) in 0.28 sec. BPR loss is 5.04E+00. Sample per second: 149534
# SLIM_BPR_Recommender: Epoch 205 of 650. Elapsed time 51.10 sec
# Processed 41629 (100.0%) in 0.52 sec. BPR loss is 4.96E+00. Sample per second: 79600
# SLIM_BPR_Recommender: Epoch 206 of 650. Elapsed time 51.34 sec
# Processed 41629 (100.0%) in 0.79 sec. BPR loss is 5.19E+00. Sample per second: 52387
# SLIM_BPR_Recommender: Epoch 207 of 650. Elapsed time 51.61 sec
# Processed 41629 (100.0%) in 1.04 sec. BPR loss is 5.00E+00. Sample per second: 40010
# SLIM_BPR_Recommender: Epoch 208 of 650. Elapsed time 51.86 sec
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 5.12E+00. Sample per second: 145873
# SLIM_BPR_Recommender: Epoch 209 of 650. Elapsed time 52.10 sec
# Processed 41629 (100.0%) in 0.53 sec. BPR loss is 4.95E+00. Sample per second: 78740
# SLIM_BPR_Recommender: Epoch 210 of 650. Elapsed time 52.35 sec
# Processed 41629 (100.0%) in 0.77 sec. BPR loss is 5.03E+00. Sample per second: 53759
# SLIM_BPR_Recommender: Epoch 211 of 650. Elapsed time 52.59 sec
# Processed 41629 (100.0%) in 1.02 sec. BPR loss is 5.12E+00. Sample per second: 40833
# SLIM_BPR_Recommender: Epoch 212 of 650. Elapsed time 52.84 sec
# Processed 41629 (100.0%) in 0.26 sec. BPR loss is 4.99E+00. Sample per second: 158136
# SLIM_BPR_Recommender: Epoch 213 of 650. Elapsed time 53.08 sec
# Processed 41629 (100.0%) in 0.50 sec. BPR loss is 5.01E+00. Sample per second: 82432
# SLIM_BPR_Recommender: Epoch 214 of 650. Elapsed time 53.32 sec
# Processed 41629 (100.0%) in 0.75 sec. BPR loss is 5.27E+00. Sample per second: 55646
# SLIM_BPR_Recommender: Epoch 215 of 650. Elapsed time 53.57 sec
# Processed 41629 (100.0%) in 1.00 sec. BPR loss is 5.27E+00. Sample per second: 41722
# SLIM_BPR_Recommender: Epoch 216 of 650. Elapsed time 53.82 sec
# Processed 41629 (100.0%) in 0.24 sec. BPR loss is 5.06E+00. Sample per second: 170999
# SLIM_BPR_Recommender: Epoch 217 of 650. Elapsed time 54.06 sec
# Processed 41629 (100.0%) in 0.49 sec. BPR loss is 5.44E+00. Sample per second: 85638
# SLIM_BPR_Recommender: Epoch 218 of 650. Elapsed time 54.31 sec
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 5.24E+00. Sample per second: 56881
# SLIM_BPR_Recommender: Epoch 219 of 650. Elapsed time 54.55 sec
# Processed 41629 (100.0%) in 0.98 sec. BPR loss is 5.44E+00. Sample per second: 42502
# SLIM_BPR_Recommender: Epoch 220 of 650. Elapsed time 54.80 sec
# Processed 41629 (100.0%) in 1.23 sec. BPR loss is 5.19E+00. Sample per second: 33921
# SLIM_BPR_Recommender: Epoch 221 of 650. Elapsed time 55.05 sec
# Processed 41629 (100.0%) in 0.47 sec. BPR loss is 5.35E+00. Sample per second: 88638
# SLIM_BPR_Recommender: Epoch 222 of 650. Elapsed time 55.29 sec
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 5.17E+00. Sample per second: 57722
# SLIM_BPR_Recommender: Epoch 223 of 650. Elapsed time 55.54 sec
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 5.37E+00. Sample per second: 42949
# SLIM_BPR_Recommender: Epoch 224 of 650. Elapsed time 55.79 sec
# Processed 41629 (100.0%) in 1.22 sec. BPR loss is 5.34E+00. Sample per second: 34246
# SLIM_BPR_Recommender: Epoch 225 of 650. Elapsed time 56.03 sec
# Processed 41629 (100.0%) in 0.46 sec. BPR loss is 5.52E+00. Sample per second: 90978
# SLIM_BPR_Recommender: Epoch 226 of 650. Elapsed time 56.28 sec
# Processed 41629 (100.0%) in 0.70 sec. BPR loss is 5.44E+00. Sample per second: 59511
# SLIM_BPR_Recommender: Epoch 227 of 650. Elapsed time 56.52 sec
# Processed 41629 (100.0%) in 0.94 sec. BPR loss is 5.18E+00. Sample per second: 44246
# SLIM_BPR_Recommender: Epoch 228 of 650. Elapsed time 56.76 sec
# Processed 41629 (100.0%) in 1.18 sec. BPR loss is 5.35E+00. Sample per second: 35130
# SLIM_BPR_Recommender: Epoch 229 of 650. Elapsed time 57.00 sec
# Processed 41629 (100.0%) in 0.43 sec. BPR loss is 5.37E+00. Sample per second: 97248
# SLIM_BPR_Recommender: Epoch 230 of 650. Elapsed time 57.25 sec
# Processed 41629 (100.0%) in 0.67 sec. BPR loss is 5.37E+00. Sample per second: 62098
# SLIM_BPR_Recommender: Epoch 231 of 650. Elapsed time 57.49 sec
# Processed 41629 (100.0%) in 0.92 sec. BPR loss is 5.39E+00. Sample per second: 45452
# SLIM_BPR_Recommender: Epoch 232 of 650. Elapsed time 57.73 sec
# Processed 41629 (100.0%) in 1.16 sec. BPR loss is 5.37E+00. Sample per second: 35853
# SLIM_BPR_Recommender: Epoch 233 of 650. Elapsed time 57.98 sec
# Processed 41629 (100.0%) in 0.40 sec. BPR loss is 5.42E+00. Sample per second: 103417
# SLIM_BPR_Recommender: Epoch 234 of 650. Elapsed time 58.22 sec
# Processed 41629 (100.0%) in 0.65 sec. BPR loss is 5.46E+00. Sample per second: 64479
# SLIM_BPR_Recommender: Epoch 235 of 650. Elapsed time 58.46 sec
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 5.31E+00. Sample per second: 46537
# SLIM_BPR_Recommender: Epoch 236 of 650. Elapsed time 58.71 sec
# Processed 41629 (100.0%) in 1.14 sec. BPR loss is 5.57E+00. Sample per second: 36360
# SLIM_BPR_Recommender: Epoch 237 of 650. Elapsed time 58.96 sec
# Processed 41629 (100.0%) in 0.39 sec. BPR loss is 5.42E+00. Sample per second: 106245
# SLIM_BPR_Recommender: Epoch 238 of 650. Elapsed time 59.21 sec
# Processed 41629 (100.0%) in 0.63 sec. BPR loss is 5.46E+00. Sample per second: 65761
# SLIM_BPR_Recommender: Epoch 239 of 650. Elapsed time 59.45 sec
# Processed 41629 (100.0%) in 0.88 sec. BPR loss is 5.46E+00. Sample per second: 47165
# SLIM_BPR_Recommender: Epoch 240 of 650. Elapsed time 59.70 sec
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 5.45E+00. Sample per second: 36980
# SLIM_BPR_Recommender: Epoch 241 of 650. Elapsed time 59.95 sec
# Processed 41629 (100.0%) in 0.37 sec. BPR loss is 5.64E+00. Sample per second: 111063
# SLIM_BPR_Recommender: Epoch 242 of 650. Elapsed time 1.00 min
# Processed 41629 (100.0%) in 0.62 sec. BPR loss is 5.52E+00. Sample per second: 67322
# SLIM_BPR_Recommender: Epoch 243 of 650. Elapsed time 1.01 min
# Processed 41629 (100.0%) in 0.86 sec. BPR loss is 5.42E+00. Sample per second: 48312
# SLIM_BPR_Recommender: Epoch 244 of 650. Elapsed time 1.01 min
# Processed 41629 (100.0%) in 1.10 sec. BPR loss is 5.60E+00. Sample per second: 37845
# SLIM_BPR_Recommender: Epoch 245 of 650. Elapsed time 1.02 min
# Processed 41629 (100.0%) in 0.34 sec. BPR loss is 5.57E+00. Sample per second: 122474
# SLIM_BPR_Recommender: Epoch 246 of 650. Elapsed time 1.02 min
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 5.65E+00. Sample per second: 71749
# SLIM_BPR_Recommender: Epoch 247 of 650. Elapsed time 1.02 min
# Processed 41629 (100.0%) in 0.83 sec. BPR loss is 5.50E+00. Sample per second: 50316
# SLIM_BPR_Recommender: Epoch 248 of 650. Elapsed time 1.03 min
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 5.68E+00. Sample per second: 38874
# SLIM_BPR_Recommender: Epoch 249 of 650. Elapsed time 1.03 min
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 5.73E+00. Sample per second: 131908
# SLIM_BPR_Recommender: Epoch 250 of 650. Elapsed time 1.04 min
# Processed 41629 (100.0%) in 0.56 sec. BPR loss is 5.69E+00. Sample per second: 74820
# SLIM_BPR_Recommender: Epoch 251 of 650. Elapsed time 1.04 min
# Processed 41629 (100.0%) in 0.83 sec. BPR loss is 5.57E+00. Sample per second: 50205
# SLIM_BPR_Recommender: Epoch 252 of 650. Elapsed time 1.04 min
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 5.61E+00. Sample per second: 38347
# SLIM_BPR_Recommender: Epoch 253 of 650. Elapsed time 1.05 min
# Processed 41629 (100.0%) in 0.34 sec. BPR loss is 5.80E+00. Sample per second: 123409
# SLIM_BPR_Recommender: Epoch 254 of 650. Elapsed time 1.05 min
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 5.86E+00. Sample per second: 71595
# SLIM_BPR_Recommender: Epoch 255 of 650. Elapsed time 1.06 min
# Processed 41629 (100.0%) in 0.83 sec. BPR loss is 5.82E+00. Sample per second: 50219
# SLIM_BPR_Recommender: Epoch 256 of 650. Elapsed time 1.06 min
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 5.63E+00. Sample per second: 38729
# SLIM_BPR_Recommender: Epoch 257 of 650. Elapsed time 1.06 min
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 5.87E+00. Sample per second: 129143
# SLIM_BPR_Recommender: Epoch 258 of 650. Elapsed time 1.07 min
# Processed 41629 (100.0%) in 0.57 sec. BPR loss is 5.91E+00. Sample per second: 73374
# SLIM_BPR_Recommender: Epoch 259 of 650. Elapsed time 1.07 min
# Processed 41629 (100.0%) in 0.81 sec. BPR loss is 5.91E+00. Sample per second: 51372
# SLIM_BPR_Recommender: Epoch 260 of 650. Elapsed time 1.08 min
# Processed 41629 (100.0%) in 1.05 sec. BPR loss is 5.82E+00. Sample per second: 39669
# SLIM_BPR_Recommender: Epoch 261 of 650. Elapsed time 1.08 min
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 5.69E+00. Sample per second: 142897
# SLIM_BPR_Recommender: Epoch 262 of 650. Elapsed time 1.09 min
# Processed 41629 (100.0%) in 0.54 sec. BPR loss is 5.91E+00. Sample per second: 77147
# SLIM_BPR_Recommender: Epoch 263 of 650. Elapsed time 1.09 min
# Processed 41629 (100.0%) in 0.79 sec. BPR loss is 5.76E+00. Sample per second: 52802
# SLIM_BPR_Recommender: Epoch 264 of 650. Elapsed time 1.09 min
# Processed 41629 (100.0%) in 1.03 sec. BPR loss is 5.64E+00. Sample per second: 40339
# SLIM_BPR_Recommender: Epoch 265 of 650. Elapsed time 1.10 min
# Processed 41629 (100.0%) in 0.27 sec. BPR loss is 5.80E+00. Sample per second: 151908
# SLIM_BPR_Recommender: Epoch 266 of 650. Elapsed time 1.10 min
# Processed 41629 (100.0%) in 0.52 sec. BPR loss is 5.77E+00. Sample per second: 80609
# SLIM_BPR_Recommender: Epoch 267 of 650. Elapsed time 1.11 min
# Processed 41629 (100.0%) in 0.76 sec. BPR loss is 6.03E+00. Sample per second: 54971
# SLIM_BPR_Recommender: Epoch 268 of 650. Elapsed time 1.11 min
# Processed 41629 (100.0%) in 1.00 sec. BPR loss is 6.07E+00. Sample per second: 41729
# SLIM_BPR_Recommender: Epoch 269 of 650. Elapsed time 1.11 min
# Processed 41629 (100.0%) in 0.24 sec. BPR loss is 6.09E+00. Sample per second: 172139
# SLIM_BPR_Recommender: Epoch 270 of 650. Elapsed time 1.12 min
# Processed 41629 (100.0%) in 0.48 sec. BPR loss is 6.06E+00. Sample per second: 86152
# SLIM_BPR_Recommender: Epoch 271 of 650. Elapsed time 1.12 min
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 5.81E+00. Sample per second: 57335
# SLIM_BPR_Recommender: Epoch 272 of 650. Elapsed time 1.13 min
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 6.16E+00. Sample per second: 42844
# SLIM_BPR_Recommender: Epoch 273 of 650. Elapsed time 1.13 min
# Processed 41629 (100.0%) in 1.21 sec. BPR loss is 6.14E+00. Sample per second: 34286
# SLIM_BPR_Recommender: Epoch 274 of 650. Elapsed time 1.13 min
# Processed 41629 (100.0%) in 0.45 sec. BPR loss is 6.07E+00. Sample per second: 91468
# SLIM_BPR_Recommender: Epoch 275 of 650. Elapsed time 1.14 min
# Processed 41629 (100.0%) in 0.70 sec. BPR loss is 5.78E+00. Sample per second: 59802
# SLIM_BPR_Recommender: Epoch 276 of 650. Elapsed time 1.14 min
# Processed 41629 (100.0%) in 0.94 sec. BPR loss is 6.38E+00. Sample per second: 44277
# SLIM_BPR_Recommender: Epoch 277 of 650. Elapsed time 1.15 min
# Processed 41629 (100.0%) in 1.19 sec. BPR loss is 6.27E+00. Sample per second: 35122
# SLIM_BPR_Recommender: Epoch 278 of 650. Elapsed time 1.15 min
# Processed 41629 (100.0%) in 0.43 sec. BPR loss is 6.10E+00. Sample per second: 97901
# SLIM_BPR_Recommender: Epoch 279 of 650. Elapsed time 1.15 min
# Processed 41629 (100.0%) in 0.67 sec. BPR loss is 5.96E+00. Sample per second: 62331
# SLIM_BPR_Recommender: Epoch 280 of 650. Elapsed time 1.16 min
# Processed 41629 (100.0%) in 0.92 sec. BPR loss is 6.10E+00. Sample per second: 45420
# SLIM_BPR_Recommender: Epoch 281 of 650. Elapsed time 1.16 min
# Processed 41629 (100.0%) in 1.16 sec. BPR loss is 5.99E+00. Sample per second: 36013
# SLIM_BPR_Recommender: Epoch 282 of 650. Elapsed time 1.17 min
# Processed 41629 (100.0%) in 0.40 sec. BPR loss is 6.04E+00. Sample per second: 104511
# SLIM_BPR_Recommender: Epoch 283 of 650. Elapsed time 1.17 min
# Processed 41629 (100.0%) in 0.64 sec. BPR loss is 6.06E+00. Sample per second: 65077
# SLIM_BPR_Recommender: Epoch 284 of 650. Elapsed time 1.17 min
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 6.29E+00. Sample per second: 46985
# SLIM_BPR_Recommender: Epoch 285 of 650. Elapsed time 1.18 min
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 5.98E+00. Sample per second: 36991
# SLIM_BPR_Recommender: Epoch 286 of 650. Elapsed time 1.18 min
# Processed 41629 (100.0%) in 0.36 sec. BPR loss is 5.92E+00. Sample per second: 114418
# SLIM_BPR_Recommender: Epoch 287 of 650. Elapsed time 1.19 min
# Processed 41629 (100.0%) in 0.60 sec. BPR loss is 6.49E+00. Sample per second: 68943
# SLIM_BPR_Recommender: Epoch 288 of 650. Elapsed time 1.19 min
# Processed 41629 (100.0%) in 0.85 sec. BPR loss is 6.25E+00. Sample per second: 49192
# SLIM_BPR_Recommender: Epoch 289 of 650. Elapsed time 1.19 min
# Processed 41629 (100.0%) in 1.09 sec. BPR loss is 6.67E+00. Sample per second: 38288
# SLIM_BPR_Recommender: Epoch 290 of 650. Elapsed time 1.20 min
# Processed 41629 (100.0%) in 0.33 sec. BPR loss is 6.39E+00. Sample per second: 124258
# SLIM_BPR_Recommender: Epoch 291 of 650. Elapsed time 1.20 min
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 6.37E+00. Sample per second: 71337
# SLIM_BPR_Recommender: Epoch 292 of 650. Elapsed time 1.21 min
# Processed 41629 (100.0%) in 0.83 sec. BPR loss is 6.42E+00. Sample per second: 50228
# SLIM_BPR_Recommender: Epoch 293 of 650. Elapsed time 1.21 min
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 6.29E+00. Sample per second: 38726
# SLIM_BPR_Recommender: Epoch 294 of 650. Elapsed time 1.21 min
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 6.29E+00. Sample per second: 130503
# SLIM_BPR_Recommender: Epoch 295 of 650. Elapsed time 1.22 min
# Processed 41629 (100.0%) in 0.56 sec. BPR loss is 6.21E+00. Sample per second: 74917
# SLIM_BPR_Recommender: Epoch 296 of 650. Elapsed time 1.22 min
# Processed 41629 (100.0%) in 0.82 sec. BPR loss is 6.17E+00. Sample per second: 50740
# SLIM_BPR_Recommender: Epoch 297 of 650. Elapsed time 1.23 min
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 6.49E+00. Sample per second: 38995
# SLIM_BPR_Recommender: Epoch 298 of 650. Elapsed time 1.23 min
# Processed 41629 (100.0%) in 0.31 sec. BPR loss is 6.50E+00. Sample per second: 134351
# SLIM_BPR_Recommender: Epoch 299 of 650. Elapsed time 1.24 min
# Processed 41629 (100.0%) in 0.56 sec. BPR loss is 6.48E+00. Sample per second: 74428
# SLIM_BPR_Recommender: Epoch 300 of 650. Elapsed time 1.24 min
# Processed 41629 (100.0%) in 0.81 sec. BPR loss is 6.40E+00. Sample per second: 51634
# SLIM_BPR_Recommender: Epoch 301 of 650. Elapsed time 1.24 min
# Processed 41629 (100.0%) in 1.05 sec. BPR loss is 6.36E+00. Sample per second: 39785
# SLIM_BPR_Recommender: Epoch 302 of 650. Elapsed time 1.25 min
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 6.37E+00. Sample per second: 143830
# SLIM_BPR_Recommender: Epoch 303 of 650. Elapsed time 1.25 min
# Processed 41629 (100.0%) in 0.54 sec. BPR loss is 6.74E+00. Sample per second: 77409
# SLIM_BPR_Recommender: Epoch 304 of 650. Elapsed time 1.26 min
# Processed 41629 (100.0%) in 0.79 sec. BPR loss is 6.38E+00. Sample per second: 52969
# SLIM_BPR_Recommender: Epoch 305 of 650. Elapsed time 1.26 min
# Processed 41629 (100.0%) in 1.02 sec. BPR loss is 6.31E+00. Sample per second: 40666
# SLIM_BPR_Recommender: Epoch 306 of 650. Elapsed time 1.26 min
# Processed 41629 (100.0%) in 0.26 sec. BPR loss is 6.30E+00. Sample per second: 157717
# SLIM_BPR_Recommender: Epoch 307 of 650. Elapsed time 1.27 min
# Processed 41629 (100.0%) in 0.50 sec. BPR loss is 6.44E+00. Sample per second: 82417
# SLIM_BPR_Recommender: Epoch 308 of 650. Elapsed time 1.27 min
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 6.35E+00. Sample per second: 55850
# SLIM_BPR_Recommender: Epoch 309 of 650. Elapsed time 1.28 min
# Processed 41629 (100.0%) in 0.99 sec. BPR loss is 6.85E+00. Sample per second: 42102
# SLIM_BPR_Recommender: Epoch 310 of 650. Elapsed time 1.28 min
# Processed 41629 (100.0%) in 1.23 sec. BPR loss is 6.74E+00. Sample per second: 33875
# SLIM_BPR_Recommender: Epoch 311 of 650. Elapsed time 1.28 min
# Processed 41629 (100.0%) in 0.47 sec. BPR loss is 6.50E+00. Sample per second: 88767
# SLIM_BPR_Recommender: Epoch 312 of 650. Elapsed time 1.29 min
# Processed 41629 (100.0%) in 0.71 sec. BPR loss is 6.46E+00. Sample per second: 58899
# SLIM_BPR_Recommender: Epoch 313 of 650. Elapsed time 1.29 min
# Processed 41629 (100.0%) in 0.95 sec. BPR loss is 6.47E+00. Sample per second: 43657
# SLIM_BPR_Recommender: Epoch 314 of 650. Elapsed time 1.30 min
# Processed 41629 (100.0%) in 1.20 sec. BPR loss is 6.58E+00. Sample per second: 34701
# SLIM_BPR_Recommender: Epoch 315 of 650. Elapsed time 1.30 min
# Processed 41629 (100.0%) in 0.44 sec. BPR loss is 6.56E+00. Sample per second: 94772
# SLIM_BPR_Recommender: Epoch 316 of 650. Elapsed time 1.30 min
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 6.85E+00. Sample per second: 61447
# SLIM_BPR_Recommender: Epoch 317 of 650. Elapsed time 1.31 min
# Processed 41629 (100.0%) in 0.92 sec. BPR loss is 6.67E+00. Sample per second: 45133
# SLIM_BPR_Recommender: Epoch 318 of 650. Elapsed time 1.31 min
# Processed 41629 (100.0%) in 1.16 sec. BPR loss is 7.02E+00. Sample per second: 35742
# SLIM_BPR_Recommender: Epoch 319 of 650. Elapsed time 1.32 min
# Processed 41629 (100.0%) in 0.41 sec. BPR loss is 6.78E+00. Sample per second: 101853
# SLIM_BPR_Recommender: Epoch 320 of 650. Elapsed time 1.32 min
# Processed 41629 (100.0%) in 0.64 sec. BPR loss is 6.60E+00. Sample per second: 64599
# SLIM_BPR_Recommender: Epoch 321 of 650. Elapsed time 1.32 min
# Processed 41629 (100.0%) in 0.88 sec. BPR loss is 6.59E+00. Sample per second: 47037
# SLIM_BPR_Recommender: Epoch 322 of 650. Elapsed time 1.33 min
# Processed 41629 (100.0%) in 1.12 sec. BPR loss is 6.64E+00. Sample per second: 36999
# SLIM_BPR_Recommender: Epoch 323 of 650. Elapsed time 1.33 min
# Processed 41629 (100.0%) in 0.36 sec. BPR loss is 6.73E+00. Sample per second: 114451
# ...
# Processed 41629 (100.0%) in 0.41 sec. BPR loss is 9.08E+00. Sample per second: 101064
# SLIM_BPR_Recommender: Epoch 543 of 650. Elapsed time 2.24 min
# Processed 41629 (100.0%) in 0.66 sec. BPR loss is 9.06E+00. Sample per second: 63476
# SLIM_BPR_Recommender: Epoch 544 of 650. Elapsed time 2.24 min
# Processed 41629 (100.0%) in 0.90 sec. BPR loss is 9.05E+00. Sample per second: 46193
# SLIM_BPR_Recommender: Epoch 545 of 650. Elapsed time 2.25 min
# Processed 41629 (100.0%) in 1.14 sec. BPR loss is 8.84E+00. Sample per second: 36431
# SLIM_BPR_Recommender: Epoch 546 of 650. Elapsed time 2.25 min
# Processed 41629 (100.0%) in 0.39 sec. BPR loss is 9.08E+00. Sample per second: 107990
# SLIM_BPR_Recommender: Epoch 547 of 650. Elapsed time 2.25 min
# Processed 41629 (100.0%) in 0.63 sec. BPR loss is 8.82E+00. Sample per second: 66054
# SLIM_BPR_Recommender: Epoch 548 of 650. Elapsed time 2.26 min
# Processed 41629 (100.0%) in 0.87 sec. BPR loss is 8.91E+00. Sample per second: 47624
# SLIM_BPR_Recommender: Epoch 549 of 650. Elapsed time 2.26 min
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 9.15E+00. Sample per second: 36909
# SLIM_BPR_Recommender: Epoch 550 of 650. Elapsed time 2.27 min
# Processed 41629 (100.0%) in 0.37 sec. BPR loss is 9.13E+00. Sample per second: 110976
# SLIM_BPR_Recommender: Epoch 551 of 650. Elapsed time 2.27 min
# Processed 41629 (100.0%) in 0.62 sec. BPR loss is 9.31E+00. Sample per second: 67265
# SLIM_BPR_Recommender: Epoch 552 of 650. Elapsed time 2.27 min
# Processed 41629 (100.0%) in 0.86 sec. BPR loss is 9.15E+00. Sample per second: 48413
# SLIM_BPR_Recommender: Epoch 553 of 650. Elapsed time 2.28 min
# Processed 41629 (100.0%) in 1.10 sec. BPR loss is 9.05E+00. Sample per second: 37842
# SLIM_BPR_Recommender: Epoch 554 of 650. Elapsed time 2.28 min
# Processed 41629 (100.0%) in 0.34 sec. BPR loss is 9.26E+00. Sample per second: 122182
# SLIM_BPR_Recommender: Epoch 555 of 650. Elapsed time 2.29 min
# Processed 41629 (100.0%) in 0.59 sec. BPR loss is 8.74E+00. Sample per second: 71095
# SLIM_BPR_Recommender: Epoch 556 of 650. Elapsed time 2.29 min
# Processed 41629 (100.0%) in 0.83 sec. BPR loss is 9.28E+00. Sample per second: 50252
# SLIM_BPR_Recommender: Epoch 557 of 650. Elapsed time 2.29 min
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 9.32E+00. Sample per second: 38718
# SLIM_BPR_Recommender: Epoch 558 of 650. Elapsed time 2.30 min
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 9.21E+00. Sample per second: 130291
# SLIM_BPR_Recommender: Epoch 559 of 650. Elapsed time 2.30 min
# Processed 41629 (100.0%) in 0.56 sec. BPR loss is 9.08E+00. Sample per second: 74120
# SLIM_BPR_Recommender: Epoch 560 of 650. Elapsed time 2.31 min
# Processed 41629 (100.0%) in 0.81 sec. BPR loss is 9.54E+00. Sample per second: 51332
# SLIM_BPR_Recommender: Epoch 561 of 650. Elapsed time 2.31 min
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 9.36E+00. Sample per second: 39021
# SLIM_BPR_Recommender: Epoch 562 of 650. Elapsed time 2.31 min
# Processed 41629 (100.0%) in 0.31 sec. BPR loss is 9.37E+00. Sample per second: 132459
# SLIM_BPR_Recommender: Epoch 563 of 650. Elapsed time 2.32 min
# Processed 41629 (100.0%) in 0.56 sec. BPR loss is 9.47E+00. Sample per second: 74061
# SLIM_BPR_Recommender: Epoch 564 of 650. Elapsed time 2.32 min
# Processed 41629 (100.0%) in 0.84 sec. BPR loss is 9.33E+00. Sample per second: 49702
# SLIM_BPR_Recommender: Epoch 565 of 650. Elapsed time 2.33 min
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 9.14E+00. Sample per second: 38416
# SLIM_BPR_Recommender: Epoch 566 of 650. Elapsed time 2.33 min
# Processed 41629 (100.0%) in 0.33 sec. BPR loss is 9.64E+00. Sample per second: 126266
# SLIM_BPR_Recommender: Epoch 567 of 650. Elapsed time 2.34 min
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 9.12E+00. Sample per second: 72216
# SLIM_BPR_Recommender: Epoch 568 of 650. Elapsed time 2.34 min
# Processed 41629 (100.0%) in 0.82 sec. BPR loss is 9.51E+00. Sample per second: 50574
# SLIM_BPR_Recommender: Epoch 569 of 650. Elapsed time 2.34 min
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 9.15E+00. Sample per second: 38915
# SLIM_BPR_Recommender: Epoch 570 of 650. Elapsed time 2.35 min
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 9.10E+00. Sample per second: 131499
# SLIM_BPR_Recommender: Epoch 571 of 650. Elapsed time 2.35 min
# Processed 41629 (100.0%) in 0.56 sec. BPR loss is 9.15E+00. Sample per second: 73789
# SLIM_BPR_Recommender: Epoch 572 of 650. Elapsed time 2.36 min
# Processed 41629 (100.0%) in 0.81 sec. BPR loss is 9.28E+00. Sample per second: 51307
# SLIM_BPR_Recommender: Epoch 573 of 650. Elapsed time 2.36 min
# Processed 41629 (100.0%) in 1.06 sec. BPR loss is 9.35E+00. Sample per second: 39379
# SLIM_BPR_Recommender: Epoch 574 of 650. Elapsed time 2.36 min
# Processed 41629 (100.0%) in 0.30 sec. BPR loss is 9.55E+00. Sample per second: 139884
# SLIM_BPR_Recommender: Epoch 575 of 650. Elapsed time 2.37 min
# Processed 41629 (100.0%) in 0.54 sec. BPR loss is 9.68E+00. Sample per second: 76645
# SLIM_BPR_Recommender: Epoch 576 of 650. Elapsed time 2.37 min
# Processed 41629 (100.0%) in 0.78 sec. BPR loss is 9.47E+00. Sample per second: 53042
# SLIM_BPR_Recommender: Epoch 577 of 650. Elapsed time 2.38 min
# Processed 41629 (100.0%) in 1.05 sec. BPR loss is 9.29E+00. Sample per second: 39553
# SLIM_BPR_Recommender: Epoch 578 of 650. Elapsed time 2.38 min
# Processed 41629 (100.0%) in 0.33 sec. BPR loss is 9.21E+00. Sample per second: 126102
# SLIM_BPR_Recommender: Epoch 579 of 650. Elapsed time 2.39 min
# Processed 41629 (100.0%) in 0.57 sec. BPR loss is 9.63E+00. Sample per second: 72756
# SLIM_BPR_Recommender: Epoch 580 of 650. Elapsed time 2.39 min
# Processed 41629 (100.0%) in 0.81 sec. BPR loss is 9.25E+00. Sample per second: 51209
# SLIM_BPR_Recommender: Epoch 581 of 650. Elapsed time 2.39 min
# Processed 41629 (100.0%) in 1.06 sec. BPR loss is 9.42E+00. Sample per second: 39227
# SLIM_BPR_Recommender: Epoch 582 of 650. Elapsed time 2.40 min
# Processed 41629 (100.0%) in 0.31 sec. BPR loss is 9.41E+00. Sample per second: 134700
# SLIM_BPR_Recommender: Epoch 583 of 650. Elapsed time 2.40 min
# Processed 41629 (100.0%) in 0.55 sec. BPR loss is 9.58E+00. Sample per second: 75103
# SLIM_BPR_Recommender: Epoch 584 of 650. Elapsed time 2.41 min
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 9.23E+00. Sample per second: 51960
# SLIM_BPR_Recommender: Epoch 585 of 650. Elapsed time 2.41 min
# Processed 41629 (100.0%) in 1.05 sec. BPR loss is 9.55E+00. Sample per second: 39552
# SLIM_BPR_Recommender: Epoch 586 of 650. Elapsed time 2.41 min
# Processed 41629 (100.0%) in 0.31 sec. BPR loss is 9.68E+00. Sample per second: 134827
# SLIM_BPR_Recommender: Epoch 587 of 650. Elapsed time 2.42 min
# Processed 41629 (100.0%) in 0.55 sec. BPR loss is 9.68E+00. Sample per second: 75247
# SLIM_BPR_Recommender: Epoch 588 of 650. Elapsed time 2.42 min
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 9.38E+00. Sample per second: 51941
# SLIM_BPR_Recommender: Epoch 589 of 650. Elapsed time 2.43 min
# Processed 41629 (100.0%) in 1.05 sec. BPR loss is 9.23E+00. Sample per second: 39771
# SLIM_BPR_Recommender: Epoch 590 of 650. Elapsed time 2.43 min
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 9.47E+00. Sample per second: 141573
# SLIM_BPR_Recommender: Epoch 591 of 650. Elapsed time 2.44 min
# Processed 41629 (100.0%) in 0.54 sec. BPR loss is 9.54E+00. Sample per second: 77123
# SLIM_BPR_Recommender: Epoch 592 of 650. Elapsed time 2.44 min
# Processed 41629 (100.0%) in 0.78 sec. BPR loss is 9.56E+00. Sample per second: 53227
# SLIM_BPR_Recommender: Epoch 593 of 650. Elapsed time 2.44 min
# Processed 41629 (100.0%) in 1.03 sec. BPR loss is 9.51E+00. Sample per second: 40573
# SLIM_BPR_Recommender: Epoch 594 of 650. Elapsed time 2.45 min
# Processed 41629 (100.0%) in 0.27 sec. BPR loss is 9.24E+00. Sample per second: 153522
# SLIM_BPR_Recommender: Epoch 595 of 650. Elapsed time 2.45 min
# Processed 41629 (100.0%) in 0.52 sec. BPR loss is 9.23E+00. Sample per second: 79806
# SLIM_BPR_Recommender: Epoch 596 of 650. Elapsed time 2.46 min
# Processed 41629 (100.0%) in 0.77 sec. BPR loss is 9.54E+00. Sample per second: 54282
# SLIM_BPR_Recommender: Epoch 597 of 650. Elapsed time 2.46 min
# Processed 41629 (100.0%) in 1.01 sec. BPR loss is 9.65E+00. Sample per second: 41219
# SLIM_BPR_Recommender: Epoch 598 of 650. Elapsed time 2.46 min
# Processed 41629 (100.0%) in 0.26 sec. BPR loss is 9.98E+00. Sample per second: 161199
# SLIM_BPR_Recommender: Epoch 599 of 650. Elapsed time 2.47 min
# Processed 41629 (100.0%) in 0.50 sec. BPR loss is 9.86E+00. Sample per second: 83390
# SLIM_BPR_Recommender: Epoch 600 of 650. Elapsed time 2.47 min
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 9.56E+00. Sample per second: 56164
# SLIM_BPR_Recommender: Epoch 601 of 650. Elapsed time 2.48 min
# Processed 41629 (100.0%) in 0.99 sec. BPR loss is 9.45E+00. Sample per second: 42008
# SLIM_BPR_Recommender: Epoch 602 of 650. Elapsed time 2.48 min
# Processed 41629 (100.0%) in 1.24 sec. BPR loss is 9.40E+00. Sample per second: 33615
# SLIM_BPR_Recommender: Epoch 603 of 650. Elapsed time 2.48 min
# Processed 41629 (100.0%) in 0.48 sec. BPR loss is 9.26E+00. Sample per second: 87307
# SLIM_BPR_Recommender: Epoch 604 of 650. Elapsed time 2.49 min
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 9.78E+00. Sample per second: 57875
# SLIM_BPR_Recommender: Epoch 605 of 650. Elapsed time 2.49 min
# Processed 41629 (100.0%) in 0.96 sec. BPR loss is 9.57E+00. Sample per second: 43217
# SLIM_BPR_Recommender: Epoch 606 of 650. Elapsed time 2.50 min
# Processed 41629 (100.0%) in 1.21 sec. BPR loss is 9.75E+00. Sample per second: 34512
# SLIM_BPR_Recommender: Epoch 607 of 650. Elapsed time 2.50 min
# Processed 41629 (100.0%) in 0.45 sec. BPR loss is 9.49E+00. Sample per second: 92159
# SLIM_BPR_Recommender: Epoch 608 of 650. Elapsed time 2.50 min
# Processed 41629 (100.0%) in 0.70 sec. BPR loss is 9.82E+00. Sample per second: 59442
# SLIM_BPR_Recommender: Epoch 609 of 650. Elapsed time 2.51 min
# Processed 41629 (100.0%) in 0.96 sec. BPR loss is 9.97E+00. Sample per second: 43180
# SLIM_BPR_Recommender: Epoch 610 of 650. Elapsed time 2.51 min
# Processed 41629 (100.0%) in 1.20 sec. BPR loss is 9.60E+00. Sample per second: 34594
# SLIM_BPR_Recommender: Epoch 611 of 650. Elapsed time 2.52 min
# Processed 41629 (100.0%) in 0.45 sec. BPR loss is 9.89E+00. Sample per second: 93471
# SLIM_BPR_Recommender: Epoch 612 of 650. Elapsed time 2.52 min
# Processed 41629 (100.0%) in 0.69 sec. BPR loss is 9.89E+00. Sample per second: 60397
# SLIM_BPR_Recommender: Epoch 613 of 650. Elapsed time 2.53 min
# Processed 41629 (100.0%) in 0.94 sec. BPR loss is 9.40E+00. Sample per second: 44341
# SLIM_BPR_Recommender: Epoch 614 of 650. Elapsed time 2.53 min
# Processed 41629 (100.0%) in 1.18 sec. BPR loss is 9.93E+00. Sample per second: 35149
# SLIM_BPR_Recommender: Epoch 615 of 650. Elapsed time 2.53 min
# Processed 41629 (100.0%) in 0.43 sec. BPR loss is 1.00E+01. Sample per second: 96771
# SLIM_BPR_Recommender: Epoch 616 of 650. Elapsed time 2.54 min
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 9.55E+00. Sample per second: 61601
# SLIM_BPR_Recommender: Epoch 617 of 650. Elapsed time 2.54 min
# Processed 41629 (100.0%) in 0.92 sec. BPR loss is 9.66E+00. Sample per second: 45088
# SLIM_BPR_Recommender: Epoch 618 of 650. Elapsed time 2.55 min
# Processed 41629 (100.0%) in 1.18 sec. BPR loss is 9.48E+00. Sample per second: 35352
# SLIM_BPR_Recommender: Epoch 619 of 650. Elapsed time 2.55 min
# Processed 41629 (100.0%) in 0.43 sec. BPR loss is 9.64E+00. Sample per second: 97891
# SLIM_BPR_Recommender: Epoch 620 of 650. Elapsed time 2.55 min
# Processed 41629 (100.0%) in 0.67 sec. BPR loss is 9.66E+00. Sample per second: 62189
# SLIM_BPR_Recommender: Epoch 621 of 650. Elapsed time 2.56 min
# Processed 41629 (100.0%) in 0.92 sec. BPR loss is 9.83E+00. Sample per second: 45330
# SLIM_BPR_Recommender: Epoch 622 of 650. Elapsed time 2.56 min
# Processed 41629 (100.0%) in 1.16 sec. BPR loss is 9.63E+00. Sample per second: 35816
# SLIM_BPR_Recommender: Epoch 623 of 650. Elapsed time 2.57 min
# Processed 41629 (100.0%) in 0.40 sec. BPR loss is 9.29E+00. Sample per second: 102789
# SLIM_BPR_Recommender: Epoch 624 of 650. Elapsed time 2.57 min
# Processed 41629 (100.0%) in 0.65 sec. BPR loss is 9.75E+00. Sample per second: 64503
# SLIM_BPR_Recommender: Epoch 625 of 650. Elapsed time 2.57 min
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 9.61E+00. Sample per second: 46792
# SLIM_BPR_Recommender: Epoch 626 of 650. Elapsed time 2.58 min
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 9.79E+00. Sample per second: 36691
# SLIM_BPR_Recommender: Epoch 627 of 650. Elapsed time 2.58 min
# Processed 41629 (100.0%) in 0.38 sec. BPR loss is 1.00E+01. Sample per second: 109952
# SLIM_BPR_Recommender: Epoch 628 of 650. Elapsed time 2.59 min
# Processed 41629 (100.0%) in 0.62 sec. BPR loss is 9.53E+00. Sample per second: 66851
# SLIM_BPR_Recommender: Epoch 629 of 650. Elapsed time 2.59 min
# Processed 41629 (100.0%) in 0.87 sec. BPR loss is 9.87E+00. Sample per second: 47812
# SLIM_BPR_Recommender: Epoch 630 of 650. Elapsed time 2.59 min
# Processed 41629 (100.0%) in 1.11 sec. BPR loss is 9.80E+00. Sample per second: 37489
# SLIM_BPR_Recommender: Epoch 631 of 650. Elapsed time 2.60 min
# Processed 41629 (100.0%) in 0.36 sec. BPR loss is 1.01E+01. Sample per second: 116510
# SLIM_BPR_Recommender: Epoch 632 of 650. Elapsed time 2.60 min
# Processed 41629 (100.0%) in 0.60 sec. BPR loss is 9.40E+00. Sample per second: 69464
# SLIM_BPR_Recommender: Epoch 633 of 650. Elapsed time 2.61 min
# Processed 41629 (100.0%) in 0.84 sec. BPR loss is 1.01E+01. Sample per second: 49280
# SLIM_BPR_Recommender: Epoch 634 of 650. Elapsed time 2.61 min
# Processed 41629 (100.0%) in 1.09 sec. BPR loss is 9.90E+00. Sample per second: 38213
# SLIM_BPR_Recommender: Epoch 635 of 650. Elapsed time 2.62 min
# Processed 41629 (100.0%) in 0.33 sec. BPR loss is 9.70E+00. Sample per second: 124216
# SLIM_BPR_Recommender: Epoch 636 of 650. Elapsed time 2.62 min
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 9.98E+00. Sample per second: 71869
# SLIM_BPR_Recommender: Epoch 637 of 650. Elapsed time 2.62 min
# Processed 41629 (100.0%) in 0.83 sec. BPR loss is 9.81E+00. Sample per second: 50294
# SLIM_BPR_Recommender: Epoch 638 of 650. Elapsed time 2.63 min
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 9.80E+00. Sample per second: 38776
# SLIM_BPR_Recommender: Epoch 639 of 650. Elapsed time 2.63 min
# Processed 41629 (100.0%) in 0.31 sec. BPR loss is 9.54E+00. Sample per second: 132702
# SLIM_BPR_Recommender: Epoch 640 of 650. Elapsed time 2.64 min
# Processed 41629 (100.0%) in 0.55 sec. BPR loss is 9.82E+00. Sample per second: 75404
# SLIM_BPR_Recommender: Epoch 641 of 650. Elapsed time 2.64 min
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 9.92E+00. Sample per second: 52259
# SLIM_BPR_Recommender: Epoch 642 of 650. Elapsed time 2.64 min
# Processed 41629 (100.0%) in 1.04 sec. BPR loss is 1.00E+01. Sample per second: 40018
# SLIM_BPR_Recommender: Epoch 643 of 650. Elapsed time 2.65 min
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 1.01E+01. Sample per second: 145594
# SLIM_BPR_Recommender: Epoch 644 of 650. Elapsed time 2.65 min
# Processed 41629 (100.0%) in 0.53 sec. BPR loss is 9.98E+00. Sample per second: 79143
# SLIM_BPR_Recommender: Epoch 645 of 650. Elapsed time 2.66 min
# Processed 41629 (100.0%) in 0.77 sec. BPR loss is 1.00E+01. Sample per second: 54196
# SLIM_BPR_Recommender: Epoch 646 of 650. Elapsed time 2.66 min
# Processed 41629 (100.0%) in 1.01 sec. BPR loss is 1.00E+01. Sample per second: 41234
# SLIM_BPR_Recommender: Epoch 647 of 650. Elapsed time 2.66 min
# Processed 41629 (100.0%) in 0.25 sec. BPR loss is 1.02E+01. Sample per second: 164549
# SLIM_BPR_Recommender: Epoch 648 of 650. Elapsed time 2.67 min
# Processed 41629 (100.0%) in 0.50 sec. BPR loss is 9.83E+00. Sample per second: 83618
# SLIM_BPR_Recommender: Epoch 649 of 650. Elapsed time 2.67 min
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 1.05E+01. Sample per second: 56107
# SLIM_BPR_Recommender: Epoch 650 of 650. Elapsed time 2.68 min
# SLIM_BPR_Recommender: Terminating at epoch 650. Elapsed time 3.33 min
# Deallocating Cython objects

# %%
ImplicitALS = ImplicitALSRecommender(URM_train)
ImplicitALS.fit(iterations= int(111.5), factors= int(64.3), regularization= 0.0001,use_gpu=False, num_threads=4, confidence_scaling=linear_scaling_confidence,**{"alpha":5.988})
# Out:
# ImplicitALSRecommender: URM Detected 3461 (12.4%) items with no interactions.
#   0%|          | 0/111 [00:00<?, ?it/s]

# %%
SLIMElasticNet = SLIMElasticNetRecommender(URM_train_stacked)
SLIMElasticNet.fit(l1_ratio= 0.02663352009457766, alpha= 0.0010777130010163724, positive_only= True, topK= 15368)
# Out:
# SLIMElasticNetRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# SLIMElasticNetRecommender: Processed 2764 ( 9.9%) in 5.00 min. Items per second: 9.21
# SLIMElasticNetRecommender: Processed 5757 (20.6%) in 10.00 min. Items per second: 9.59
# SLIMElasticNetRecommender: Processed 8766 (31.3%) in 15.00 min. Items per second: 9.74
# SLIMElasticNetRecommender: Processed 11793 (42.2%) in 20.00 min. Items per second: 9.82
# SLIMElasticNetRecommender: Processed 14812 (53.0%) in 25.01 min. Items per second: 9.87
# SLIMElasticNetRecommender: Processed 17871 (63.9%) in 30.01 min. Items per second: 9.93
# SLIMElasticNetRecommender: Processed 20885 (74.7%) in 35.01 min. Items per second: 9.94
# SLIMElasticNetRecommender: Processed 23774 (85.0%) in 40.01 min. Items per second: 9.90
# SLIMElasticNetRecommender: Processed 27968 (100.0%) in 42.40 min. Items per second: 10.99

# %%
RP3beta = RP3betaRecommender(URM_train)
RP3beta.fit(alpha= 0.8048209317587374, beta= 0.28523965008406016, topK= 56, implicit= False)
# Out:
# RP3betaRecommender: URM Detected 3461 (12.4%) items with no interactions.
# RP3betaRecommender: Similarity column 27968 (100.0%), 2242.97 column/sec. Elapsed time 12.47 sec

# %%
EASE_R = EASE_R_Recommender(URM_train_stacked)
#%%
EASE_R.fit(topK = 329, l2_norm = 143.45076856759013, normalize_matrix = False)
# Out:
# EASE_R_Recommender: URM Detected 3 ( 0.0%) users with no interactions.
# EASE_R_Recommender: Fitting model...
# EASE_R_Recommender: Fitting model... done in 15.83 min

# %%
from Recommenders.KNN.ItemKNNCFRecommender import ItemKNNCFRecommender

itemKNNCF = ItemKNNCFRecommender(URM_train)
itemKNNCF.fit(topK = 157, shrink = 463, similarity = 'cosine', normalize = True, feature_weighting = 'TF-IDF')
# Out:
# ItemKNNCFRecommender: URM Detected 3461 (12.4%) items with no interactions.
# Similarity column 27968 (100.0%), 3885.05 column/sec. Elapsed time 7.20 sec

# %%
from Recommenders.GraphBased.P3alphaRecommender import P3alphaRecommender

P3Alpha = P3alphaRecommender(URM_train)
P3Alpha.fit(topK= 113, alpha= 1.2429301516636324, implicit= True, normalize_similarity= True)
# Out:
# P3alphaRecommender: URM Detected 3461 (12.4%) items with no interactions.
# P3alphaRecommender: Similarity column 27968 (100.0%), 2178.65 column/sec. Elapsed time 12.84 sec

# %%
from Recommenders.MatrixFactorization.PureSVDRecommender import PureSVDRecommender

pure_svd = PureSVDRecommender(URM_train)
pure_svd.fit(num_factors=40)
# Out:
# PureSVDRecommender: URM Detected 3461 (12.4%) items with no interactions.
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... done in 2.16 sec

# %%
result_dict, _ = evaluator_valid.evaluateRecommender(slim_bpr)
print(f"Slim_bpr: {result_dict['MAP'][10]}")

result_dict, _ = evaluator_valid.evaluateRecommender(itemKNNCF)
print(f"ItemKNN: {result_dict['MAP'][10]}")

result_dict, _ = evaluator_valid.evaluateRecommender(ImplicitALS)
print(f"Ials: {result_dict['MAP'][10]}")

result_dict, _ = evaluator_valid.evaluateRecommender(SLIMElasticNet)
print(f"Slim_en: {result_dict['MAP'][10]}")

result_dict, _ = evaluator_valid.evaluateRecommender(RP3beta)
print(f"Rp3: {result_dict['MAP'][10]}")

result_dict, _ = evaluator_valid.evaluateRecommender(EASE_R)
print(f"Ease: {result_dict['MAP'][10]}")

result_dict, _ = evaluator_valid.evaluateRecommender(P3Alpha)
print(f"P3Alpha: {result_dict['MAP'][10]}")

result_dict, _ = evaluator_valid.evaluateRecommender(pure_svd)
print(f"Pure_svd: {result_dict['MAP'][10]}")
# Out:
# EvaluatorHoldout: Processed 41308 (100.0%) in 50.34 sec. Users per second: 821
# Slim_bpr: 0.025328946812254113
# EvaluatorHoldout: Processed 41308 (100.0%) in 41.36 sec. Users per second: 999
# ItemKNN: 0.03118264785175418
# EvaluatorHoldout: Processed 41308 (100.0%) in 39.18 sec. Users per second: 1054
# Ials: 0.026376644441062098
# EvaluatorHoldout: Processed 41308 (100.0%) in 52.90 sec. Users per second: 781
# Slim_en: 0.036479666492979256
# EvaluatorHoldout: Processed 41308 (100.0%) in 34.26 sec. Users per second: 1206
# Rp3: 0.033997700779738994
# EvaluatorHoldout: Processed 41308 (100.0%) in 54.01 sec. Users per second: 765
# Ease: 0.035505503757293576
# EvaluatorHoldout: Processed 41308 (100.0%) in 34.70 sec. Users per second: 1190
# P3Alpha: 0.031520566176503284
# EvaluatorHoldout: Processed 41308 (100.0%) in 37.68 sec. Users per second: 1096
# Pure_svd: 0.019242253508678572

# %%
from Recommenders.Recommender_utils import check_matrix, similarityMatrixTopK
from Recommenders.BaseSimilarityMatrixRecommender import BaseItemSimilarityMatrixRecommender



class ItemKNNSimilarityHybridRecommender(BaseItemSimilarityMatrixRecommender):
    """ ItemKNNSimilarityHybridRecommender
    Hybrid of two similarities S = S1*alpha + S2*(1-alpha)
    """

    RECOMMENDER_NAME = "ItemKNNSimilarityHybridRecommender"


    def __init__(self, URM_train, Similarity_1, Similarity_2, verbose = True):
        super(ItemKNNSimilarityHybridRecommender, self).__init__(URM_train, verbose = verbose)

        # CSR is faster during evaluation
        self.Similarity_1 = check_matrix(Similarity_1.copy(), 'csr')
        self.Similarity_2 = check_matrix(Similarity_2.copy(), 'csr')


    def fit(self, topK=100, alpha = 0.5, beta = 0):

        self.topK = topK
        self.alpha = alpha
        self.beta = beta


        W_sparse = self.Similarity_1*self.alpha + self.Similarity_2*self.beta

        self.W_sparse = similarityMatrixTopK(W_sparse, k=self.topK)
        self.W_sparse = check_matrix(self.W_sparse, format='csr')

# %%
slim_matrix = SLIMElasticNet.W_sparse
rp3_matrix = RP3beta.W_sparse
bpr_matrix = slim_bpr.W_sparse
knn_matrix = itemKNNCF.W_sparse

# %%
slimEn_itemKnn = ItemKNNSimilarityHybridRecommender(URM_train, slim_matrix, knn_matrix)
slimEn_itemKnn.fit(topK= 2337, alpha= 52.66663460245183, beta= 0.7828876171060497)
# Out:
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.

# %%
rp3_slimBPR = ItemKNNSimilarityHybridRecommender(URM_train, rp3_matrix, bpr_matrix)
rp3_slimBPR.fit(topK= 1686, alpha= 89.07099310062463, beta= 0.3204897377005579)
# Out:
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.

# %%
result_dict, _ = evaluator_valid.evaluateRecommender(slimEn_itemKnn)
print(f"SlimEn_itemKnn: {result_dict['MAP'][10]}")

result_dict, _ = evaluator_valid.evaluateRecommender(rp3_slimBPR)
print(f"Rp3_slimBPR: {result_dict['MAP'][10]}")
# Out:
# EvaluatorHoldout: Processed 41308 (100.0%) in 55.09 sec. Users per second: 750
# SlimEn_itemKnn: 0.0364991062110246
# EvaluatorHoldout: Processed 41308 (100.0%) in 48.35 sec. Users per second: 854
# Rp3_slimBPR: 0.034372192019377606

# %%
from Recommenders.Recommender_utils import check_matrix, similarityMatrixTopK
from Recommenders.BaseSimilarityMatrixRecommender import BaseItemSimilarityMatrixRecommender



class ItemKNNSimilarityHybridRecommender(BaseItemSimilarityMatrixRecommender):
    """ ItemKNNSimilarityHybridRecommender
    Hybrid of two similarities S = S1*alpha + S2*(1-alpha)
    """

    RECOMMENDER_NAME = "ItemKNNSimilarityHybridRecommender"


    def __init__(self, URM_train, Similarity_1, Similarity_2, verbose = True):
        super(ItemKNNSimilarityHybridRecommender, self).__init__(URM_train, verbose = verbose)

        # CSR is faster during evaluation
        self.Similarity_1 = check_matrix(Similarity_1.copy(), 'csr')
        self.Similarity_2 = check_matrix(Similarity_2.copy(), 'csr')


    def fit(self, topK=100, alpha = 0.5, beta = 0):

        self.topK = topK
        self.alpha = alpha
        self.beta = beta


        W_sparse = self.Similarity_1*self.alpha + self.Similarity_2*self.beta

        self.W_sparse = similarityMatrixTopK(W_sparse, k=self.topK)
        self.W_sparse = check_matrix(self.W_sparse, format='csr')

# %%
from numpy import linalg as LA
from Recommenders.BaseRecommender import BaseRecommender

class DifferentLossScoresHybridRecommender(BaseRecommender):

    RECOMMENDER_NAME = "DifferentLossScoresHybridRecommender"


    def __init__(self, URM_train, recommender_1, recommender_2, recommender_3, recommender_4):
        super(DifferentLossScoresHybridRecommender, self).__init__(URM_train)

        self.URM_train = sps.csr_matrix(URM_train)
        self.recommender_1 = recommender_1
        self.recommender_2 = recommender_2
        self.recommender_3 = recommender_3
        self.recommender_4 = recommender_4

        
        
        
    def fit(self, norm, alpha = 0.5, beta = 0, gamma = 0, theta = 0):

        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma
        self.theta = theta

        self.norm = norm
        


    def _compute_item_score(self, user_id_array, items_to_compute):
        
        item_weights_1 = self.recommender_1._compute_item_score(user_id_array)
        item_weights_2 = self.recommender_2._compute_item_score(user_id_array)
        item_weights_3 = self.recommender_3._compute_item_score(user_id_array)
        item_weights_4 = self.recommender_4._compute_item_score(user_id_array)

        norm_item_weights_1 = LA.norm(item_weights_1, self.norm)
        norm_item_weights_2 = LA.norm(item_weights_2, self.norm)
        norm_item_weights_3 = LA.norm(item_weights_3, self.norm)
        norm_item_weights_4 = LA.norm(item_weights_4, self.norm)
       
        
        if norm_item_weights_1 == 0:
            raise ValueError("Norm {} of item weights for recommender 1 is zero. Avoiding division by zero".format(self.norm))
        
        if norm_item_weights_2 == 0:
            raise ValueError("Norm {} of item weights for recommender 2 is zero. Avoiding division by zero".format(self.norm))
            
        if norm_item_weights_3 == 0:
            raise ValueError("Norm {} of item weights for recommender 3 is zero. Avoiding division by zero".format(self.norm))
          
        item_weights = item_weights_1 / norm_item_weights_1 * self.alpha + item_weights_2 / norm_item_weights_2 * self.beta + item_weights_3 / norm_item_weights_3 * self.gamma + item_weights_4 / norm_item_weights_4 * self.theta

        return item_weights

# %%
slimEn_itemKnn = ItemKNNSimilarityHybridRecommender(URM_train, slim_matrix, knn_matrix)
slimEn_itemKnn.fit(topK= 2337, alpha= 52.66663460245183, beta= 0.7828876171060497)
# Out:
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.

# %%
final_recommender = DifferentLossScoresHybridRecommender(URM_train, slimEn_itemKnn, rp3_slimBPR, EASE_R, ImplicitALS)
final_recommender.fit(norm= 1, alpha= 0.5971417607077779, beta= 0.2522239844950351, gamma= 0.0016350629574128922, theta= 0.1384291098602536)
# Out:
# DifferentLossScoresHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.

# %%
result_dict, _ = evaluator_valid.evaluateRecommender(final_recommender)
print(f"Final_recommender: {result_dict['MAP'][10]}")
# Out:
# EvaluatorHoldout: Processed 41308 (100.0%) in 1.93 min. Users per second: 357
# Final_recommender: 0.036769072941785906
