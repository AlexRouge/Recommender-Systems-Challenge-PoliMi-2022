# %%
# !cp -r ../input/recsys-repo/RecSys_Course_AT_PoliMi-master/* ./
# %config Completer.use_jedi = False
# %load_ext Cython
import pandas as pd
import numpy as np
import scipy.sparse as sps
import matplotlib.pyplot as pyplot
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample
from Evaluation.Evaluator import EvaluatorHoldout

# %%
URM_all_dataframe = pd.read_csv('/kaggle/input/urm-true-binary/URM_True_Binary.csv')
URM_all_dataframe
URM_all = sps.coo_matrix((URM_all_dataframe["Data"].values, 
                          (URM_all_dataframe["UserID"].values, URM_all_dataframe["ItemID"].values)))
URM_all = URM_all.tocsr() # to obtain fast access to rows (users)
URM_all
# Out:
# <41629x24507 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1554640 stored elements in Compressed Sparse Row format>

# %%
URM_train_dataframe = pd.read_csv('/kaggle/input/urm-split/Train_df.csv')
URM_train_dataframe
URM_train = sps.coo_matrix((URM_train_dataframe["Data"].values, 
                          (URM_train_dataframe["UserID"].values, URM_train_dataframe["ItemID"].values)))
URM_train = URM_train.tocsr() # to obtain fast access to rows (users)
URM_train
# Out:
# <41629x24507 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1243712 stored elements in Compressed Sparse Row format>

# %%
URM_val_dataframe = pd.read_csv('/kaggle/input/urm-split/Test_df.csv')
URM_val_dataframe
URM_valid = sps.coo_matrix((URM_val_dataframe["Data"].values, 
                          (URM_val_dataframe["UserID"].values, URM_val_dataframe["ItemID"].values)))
URM_valid = URM_valid.tocsr() # to obtain fast access to rows (users)
URM_valid
# Out:
# <41629x24507 sparse matrix of type '<class 'numpy.int64'>'
# 	with 310928 stored elements in Compressed Sparse Row format>

# %%
ICM_type_df = pd.read_csv("/kaggle/input/competition-data/data_ICM_type.csv")
ICM_type_df
items = ICM_type_df.item_id
features = ICM_type_df.feature_id
data = ICM_type_df.data
ICM_type = sps.csr_matrix((data, (items, features)))
ICM_type = ICM_type.astype(dtype = np.int32)
ICM_type.shape
# Out:
# (27968, 8)

# %%
from Evaluation.Evaluator import EvaluatorHoldout

#create an evaluator object to evaluate validation set
#we will use it for hyperparameter tuning
evaluator_valid = EvaluatorHoldout(URM_valid, cutoff_list=[10])
# Out:
# EvaluatorHoldout: Ignoring 323 ( 0.8%) Users that have less than 1 test interactions

# %%
from Recommenders.GraphBased.RP3betaRecommender import RP3betaRecommender

#try a SLIM BPR model
recommender_class = RP3betaRecommender
import os

output_folder_path = "result_experiments/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 1000
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from skopt.space import Real, Integer, Categorical
#RP3 beta
#to tuning hyperparam are typical of ML models to drive the learning process

hyperparameters_range_dictionary = {
    "alpha": Real(low=0.7, high=1.2, prior='uniform'),
    "beta": Real(low=0.1, high=0.8, prior='uniform'),
    "topK": Integer(22, 70),
    "implicit": Categorical([True, False])
}

from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

#create a bayesian optimizer object, we pass the recommender and the evaluator
hyperparameterSearch = SearchBayesianSkopt(recommender_class,
                                         evaluator_validation=evaluator_valid)
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
  
#provide data needed to create instance of model (one on URM_train, the other on URM_all)
recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train],     # For a CBF model simply put [URM_train, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {}
)
recommender_input_args_last_test = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_all],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {}
)

# %%
#let's run the bayesian search
hyperparameterSearch.search(recommender_input_args,
                       recommender_input_args_last_test = recommender_input_args_last_test,
                       hyperparameter_search_space = hyperparameters_range_dictionary,
                       n_cases = n_cases,
                       n_random_starts = n_random_starts,
                       save_model = "last",
                       output_folder_path = output_folder_path, # Where to save the results
                       output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
                       metric_to_optimize = metric_to_optimize,
                       cutoff_to_optimize = cutoff_to_optimize,
                      )
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.7045365389623022, 'beta': 0.14871375102050294, 'topK': 37, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 2628.03 column/sec. Elapsed time 9.33 sec
# EvaluatorHoldout: Processed 41306 (100.0%) in 30.42 sec. Users per second: 1358
# SearchBayesianSkopt: New best config found. Config 0: {'alpha': 0.7045365389623022, 'beta': 0.14871375102050294, 'topK': 37, 'implicit': False} - results: PRECISION: 0.0583087, PRECISION_RECALL_MIN_DEN: 0.0780889, RECALL: 0.0671935, MAP: 0.0301491, MAP_MIN_DEN: 0.0401465, MRR: 0.1916122, NDCG: 0.0835551, F1: 0.0624366, HIT_RATE: 0.3632886, ARHR_ALL_HITS: 0.2382018, NOVELTY: 0.0048828, AVERAGE_POPULARITY: 0.1123830, DIVERSITY_MEAN_INTER_LIST: 0.9781054, DIVERSITY_HERFINDAHL: 0.9978082, COVERAGE_ITEM: 0.7946709, COVERAGE_ITEM_HIT: 0.0730812, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3604699, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.1196287, SHANNON_ENTROPY: 10.8931582, RATIO_DIVERSITY_HERFINDAHL: 0.9981374, RATIO_DIVERSITY_GINI: 0.2355383, RATIO_SHANNON_ENTROPY: 0.8072904, RATIO_AVERAGE_POPULARITY: 2.2165332, RATIO_NOVELTY: 0.2968344,
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 41.6815
# Function value obtained: -0.0301
# Current minimum: -0.0301
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.9719179967288535, 'beta': 0.14516961547142632, 'topK': 45, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 2362.28 column/sec. Elapsed time 10.37 sec
# EvaluatorHoldout: Processed 41306 (100.0%) in 30.71 sec. Users per second: 1345
# SearchBayesianSkopt: New best config found. Config 1: {'alpha': 0.9719179967288535, 'beta': 0.14516961547142632, 'topK': 45, 'implicit': False} - results: PRECISION: 0.0625430, PRECISION_RECALL_MIN_DEN: 0.0841285, RECALL: 0.0725977, MAP: 0.0321673, MAP_MIN_DEN: 0.0427347, MRR: 0.2006401, NDCG: 0.0888811, F1: 0.0671963, HIT_RATE: 0.3828015, ARHR_ALL_HITS: 0.2514935, NOVELTY: 0.0047449, AVERAGE_POPULARITY: 0.1396764, DIVERSITY_MEAN_INTER_LIST: 0.9686319, DIVERSITY_HERFINDAHL: 0.9968608, COVERAGE_ITEM: 0.7754927, COVERAGE_ITEM_HIT: 0.0635329, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3798314, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.1034491, SHANNON_ENTROPY: 10.4664374, RATIO_DIVERSITY_HERFINDAHL: 0.9971897, RATIO_DIVERSITY_GINI: 0.2036822, RATIO_SHANNON_ENTROPY: 0.7756662, RATIO_AVERAGE_POPULARITY: 2.7548417, RATIO_NOVELTY: 0.2884506,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 43.1647
# Function value obtained: -0.0322
# Current minimum: -0.0322
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.9844206136281228, 'beta': 0.35297291502618344, 'topK': 46, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 2351.35 column/sec. Elapsed time 10.42 sec
# EvaluatorHoldout: Processed 41306 (100.0%) in 31.13 sec. Users per second: 1327
# SearchBayesianSkopt: New best config found. Config 2: {'alpha': 0.9844206136281228, 'beta': 0.35297291502618344, 'topK': 46, 'implicit': True} - results: PRECISION: 0.0657871, PRECISION_RECALL_MIN_DEN: 0.0891279, RECALL: 0.0769924, MAP: 0.0335913, MAP_MIN_DEN: 0.0448191, MRR: 0.2050827, NDCG: 0.0928151, F1: 0.0709500, HIT_RATE: 0.3953421, ARHR_ALL_HITS: 0.2596374, NOVELTY: 0.0046642, AVERAGE_POPULARITY: 0.1523316, DIVERSITY_MEAN_INTER_LIST: 0.9665173, DIVERSITY_HERFINDAHL: 0.9966494, COVERAGE_ITEM: 0.7357082, COVERAGE_ITEM_HIT: 0.0623495, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3922746, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0887286, SHANNON_ENTROPY: 10.2652333, RATIO_DIVERSITY_HERFINDAHL: 0.9969782, RATIO_DIVERSITY_GINI: 0.1746988, RATIO_SHANNON_ENTROPY: 0.7607550, RATIO_AVERAGE_POPULARITY: 3.0044406, RATIO_NOVELTY: 0.2835404,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 43.6665
# Function value obtained: -0.0336
# Current minimum: -0.0336
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.8408252598635259, 'beta': 0.3532800429326395, 'topK': 51, 'implicit': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 2324.82 column/sec. Elapsed time 10.54 sec
# EvaluatorHoldout: Processed 41306 (100.0%) in 31.54 sec. Users per second: 1310
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'alpha': 0.8408252598635259, 'beta': 0.3532800429326395, 'topK': 51, 'implicit': True} - results: PRECISION: 0.0661332, PRECISION_RECALL_MIN_DEN: 0.0895733, RECALL: 0.0774422, MAP: 0.0335741, MAP_MIN_DEN: 0.0447960, MRR: 0.2048787, NDCG: 0.0929844, F1: 0.0713423, HIT_RATE: 0.3982472, ARHR_ALL_HITS: 0.2595019, NOVELTY: 0.0046448, AVERAGE_POPULARITY: 0.1534288, DIVERSITY_MEAN_INTER_LIST: 0.9660928, DIVERSITY_HERFINDAHL: 0.9966069, COVERAGE_ITEM: 0.7446444, COVERAGE_ITEM_HIT: 0.0653691, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3951572, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0876283, SHANNON_ENTROPY: 10.2280618, RATIO_DIVERSITY_HERFINDAHL: 0.9969358, RATIO_DIVERSITY_GINI: 0.1725324, RATIO_SHANNON_ENTROPY: 0.7580002, RATIO_AVERAGE_POPULARITY: 3.0260814, RATIO_NOVELTY: 0.2823665,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 44.4737
# Function value obtained: -0.0336
# Current minimum: -0.0336
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.8708227583952484, 'beta': 0.6270087902581343, 'topK': 59, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 2227.40 column/sec. Elapsed time 11.00 sec
# EvaluatorHoldout: Processed 41306 (100.0%) in 32.04 sec. Users per second: 1289
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'alpha': 0.8708227583952484, 'beta': 0.6270087902581343, 'topK': 59, 'implicit': False} - results: PRECISION: 0.0609960, PRECISION_RECALL_MIN_DEN: 0.0822694, RECALL: 0.0710710, MAP: 0.0308325, MAP_MIN_DEN: 0.0410442, MRR: 0.1907549, NDCG: 0.0857052, F1: 0.0656492, HIT_RATE: 0.3731177, ARHR_ALL_HITS: 0.2401585, NOVELTY: 0.0047868, AVERAGE_POPULARITY: 0.1345010, DIVERSITY_MEAN_INTER_LIST: 0.9715079, DIVERSITY_HERFINDAHL: 0.9971484, COVERAGE_ITEM: 0.7223650, COVERAGE_ITEM_HIT: 0.0636145, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3702227, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.1021599, SHANNON_ENTROPY: 10.5225858, RATIO_DIVERSITY_HERFINDAHL: 0.9974774, RATIO_DIVERSITY_GINI: 0.2011439, RATIO_SHANNON_ENTROPY: 0.7798274, RATIO_AVERAGE_POPULARITY: 2.6527673, RATIO_NOVELTY: 0.2909967,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 45.5646
# Function value obtained: -0.0308
# Current minimum: -0.0336
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 0.7743102579193515, 'beta': 0.37166682896668013, 'topK': 38, 'implicit': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 2426.37 column/sec. Elapsed time 10.10 sec
# EvaluatorHoldout: Processed 41306 (100.0%) in 31.03 sec. Users per second: 1331
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'alpha': 0.7743102579193515, 'beta': 0.37166682896668013, 'topK': 38, 'implicit': False} - results: PRECISION: 0.0655667, PRECISION_RECALL_MIN_DEN: 0.0885045, RECALL: 0.0764126, MAP: 0.0333351, MAP_MIN_DEN: 0.0443282, MRR: 0.2034699, NDCG: 0.0920699, F1: 0.0705754, HIT_RATE: 0.3943979, ARHR_ALL_HITS: 0.2575789, NOVELTY: 0.0047380, AVERAGE_POPULARITY: 0.1379634, DIVERSITY_MEAN_INTER_LIST: 0.9726235, DIVERSITY_HERFINDAHL: 0.9972600, COVERAGE_ITEM: 0.7477455, COVERAGE_ITEM_HIT: 0.0718978, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3913378, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0972203, SHANNON_ENTROPY: 10.5407698, RATIO_DIVERSITY_HERFINDAHL: 0.9975890, RATIO_DIVERSITY_GINI: 0.1914183, RATIO_SHANNON_ENTROPY: 0.7811750, RATIO_AVERAGE_POPULARITY: 2.7210571, RATIO_NOVELTY: 0.2880286,
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 43.0622
# Function value obtained: -0.0333
# Current minimum: -0.0336
# Iteration No: 7 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'alpha': 1.1003025742557628, 'beta': 0.30325178258367236, 'topK': 47, 'implicit': False}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_27/3362859277.py in <module>
#       9                        output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
#      10                        metric_to_optimize = metric_to_optimize,
# ---> 11                        cutoff_to_optimize = cutoff_to_optimize,
#      12                       )
#
# /kaggle/working/HyperparameterTuning/SearchBayesianSkopt.py in search(self, recommender_input_args, hyperparameter_search_space, metric_to_optimize, cutoff_to_optimize, n_cases, n_random_starts, output_folder_path, output_file_name_root, save_model, save_metadata, resume_from_saved, recommender_input_args_last_test, evaluate_on_test, max_total_time, terminate_on_memory_error)
#     356                                           kappa=self.kappa,
#     357                                           noise=self.noise,
# --> 358                                           n_jobs=self.n_jobs)
#     359
#     360         except ValueError as e:
#
# /opt/conda/lib/python3.7/site-packages/skopt/optimizer/gp.py in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     266         n_restarts_optimizer=n_restarts_optimizer,
#     267         x0=x0, y0=y0, random_state=rng, verbose=verbose,
# --> 268         callback=callback, n_jobs=n_jobs, model_queue_size=model_queue_size)
#
# /opt/conda/lib/python3.7/site-packages/skopt/optimizer/base.py in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     297     for n in range(n_calls):
#     298         next_x = optimizer.ask()
# --> 299         next_y = func(next_x)
#     300         result = optimizer.tell(next_x, next_y)
#     301         result.specs = specs
#
# /kaggle/working/HyperparameterTuning/SearchBayesianSkopt.py in _objective_function_list_input(self, current_fit_hyperparameters_list_of_values)
#     413
#     414         current_fit_hyperparameters_dict = dict(zip(self.hyperparams_names, current_fit_hyperparameters_list_of_values))
# --> 415         result = self._objective_function(current_fit_hyperparameters_dict)
#     416
#     417         # The search can only progress if there is at least a valid config in the initial random start
#
# /kaggle/working/HyperparameterTuning/SearchAbstractClass.py in _objective_function(self, current_fit_hyperparameters_dict)
#     537         except (KeyboardInterrupt, SystemExit) as e:
#     538             # If getting a interrupt, terminate without saving the exception
# --> 539             raise e
#     540
#     541         # Catch exception only if terminate_on_memory_error is True
#
# /kaggle/working/HyperparameterTuning/SearchAbstractClass.py in _objective_function(self, current_fit_hyperparameters_dict)
#     466
#     467             was_already_evaluated_flag, was_already_evaluated_index = self._was_already_evaluated_check(current_fit_hyperparameters_dict)
# --> 468             result_df, recommender_instance = self._evaluate_on_validation(current_fit_hyperparameters_dict, was_already_evaluated_flag, was_already_evaluated_index)
#     469
#     470             result_series = result_df.loc[self.metadata_dict["cutoff_to_optimize"]]
#
# /kaggle/working/HyperparameterTuning/SearchAbstractClass.py in _evaluate_on_validation(self, current_fit_hyperparameters, was_already_evaluated_flag, was_already_evaluated_index)
#     324                 self.metadata_dict["hyperparameters_df"].loc[self.model_counter,key] = current_fit_hyperparameters[key]
#     325
# --> 326             recommender_instance, train_time = self._fit_model(current_fit_hyperparameters)
#     327             start_time = time.time()
#     328
#
# /kaggle/working/HyperparameterTuning/SearchAbstractClass.py in _fit_model(self, current_fit_hyperparameters)
#     298                                  **self.recommender_input_args.FIT_KEYWORD_ARGS,
#     299                                  **self.recommender_input_args.EARLYSTOPPING_KEYWORD_ARGS,
# --> 300                                  **current_fit_hyperparameters)
#     301
#     302         train_time = time.time() - start_time
#
# /kaggle/working/Recommenders/GraphBased/RP3betaRecommender.py in fit(self, alpha, beta, min_rating, topK, implicit, normalize_similarity)
#     107                     row_data = row_data[non_zero_mask]
#     108
# --> 109                 similarity_builder.add_data_lists(row_list_to_add=np.ones(len(row_data), dtype = np.int) * (current_block_start_row + row_in_block),
#     110                                                   col_list_to_add=relevant_items_partition,
#     111                                                   data_list_to_add=row_data)
#
# /opt/conda/lib/python3.7/site-packages/numpy/__init__.py in __getattr__(attr)
#     274         # module level getattr is only supported in 3.7 onwards
#     275         # https://www.python.org/dev/peps/pep-0562/
# --> 276         def __getattr__(attr):
#     277             # Warn for expired attributes, and return a dummy function
#     278             # that always raises an exception.
#
# KeyboardInterrupt:

# %%
from Recommenders.DataIO import DataIO

#explore the results of the search
data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_metadata.zip")

search_metadata.keys()

# %%
hyperparameters_df = search_metadata["hyperparameters_df"]
hyperparameters_df

# %%
result_on_validation_df = search_metadata["result_on_validation_df"]
result_on_validation_df

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters

# %%
#let's fit the model with the hyperparamethers obtained from the previous search and evaluate them on validation set

recommender = RP3betaRecommender(URM_all)
recommender.fit('alpha': 0.7743102579193515, 'beta': 0.37166682896668013, 'topK': 38, 'implicit': False)

# %%
test_users = pd.read_csv('../input/competition-data/data_target_users_test.csv')
test_users

# %%
user_id = test_users['user_id']
recommendations = []
for user in user_id:
    recommendations.append(recommender.recommend(user,cutoff = 10))
    
    
for index in range(len(recommendations)):
    recommendations[index]=np.array(recommendations[index])
    
test_users['item_list']= recommendations
test_users['item_list'] = pd.DataFrame([str(line).strip('[').strip(']').replace("'","") for line in test_users['item_list']])
test_users.to_csv('submissionRp3.csv', index=False)
