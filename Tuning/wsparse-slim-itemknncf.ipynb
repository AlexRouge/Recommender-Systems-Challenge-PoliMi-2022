# %%
# !cp -r ../input/recsys-repo/RecSys_Course_AT_PoliMi-master/* ./
# %config Completer.use_jedi = False
# %load_ext Cython
import pandas as pd
import numpy as np
import scipy.sparse as sps
import matplotlib.pyplot as pyplot
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample
from Evaluation.Evaluator import EvaluatorHoldout
from Recommenders.GraphBased.RP3betaRecommender import RP3betaRecommender
from Recommenders.GraphBased.P3alphaRecommender import P3alphaRecommender
from Recommenders.EASE_R.EASE_R_Recommender import EASE_R_Recommender
from Recommenders.KNN.ItemKNNCustomSimilarityRecommender import ItemKNNCustomSimilarityRecommender

# %%
ICM_type_df = pd.read_csv("/kaggle/input/competition-data/data_ICM_type.csv")
ICM_type_df

items = ICM_type_df.item_id
features = ICM_type_df.feature_id
data = ICM_type_df.data
ICM_type = sps.csr_matrix((data, (items, features)))
ICM_type = ICM_type.astype(dtype = np.int32)

n_users = 41629
n_itemsFromICM = ICM_type.shape[0]
ICM_type.shape
# Out:
# (27968, 8)

# %%
URM_train = sps.load_npz("/kaggle/input/reeborooba/trainDefault.npz")
URM_train = sps.csr_matrix((URM_train.data, URM_train.indices, URM_train.indptr), shape=(n_users, n_itemsFromICM))
URM_train
# Out:
# <41629x27968 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1321444 stored elements in Compressed Sparse Row format>

# %%
URM_valid = sps.load_npz("/kaggle/input/reeborooba/validDefault.npz")
URM_valid = sps.csr_matrix((URM_valid.data, URM_valid.indices, URM_valid.indptr), shape=(n_users, n_itemsFromICM))
URM_valid
# Out:
# <41629x27968 sparse matrix of type '<class 'numpy.float64'>'
# 	with 233196 stored elements in Compressed Sparse Row format>

# %%
URM_train_stacked = sps.vstack([URM_train, ICM_type.T])
URM_train_stacked = sps.csr_matrix(URM_train_stacked)

# %%
#create an evaluator object to evaluate validation set
#we will use it for hyperparameter tuning
evaluator_valid = EvaluatorHoldout(URM_valid, cutoff_list=[10])
# Out:
# EvaluatorHoldout: Ignoring 963 ( 2.3%) Users that have less than 1 test interactions

# %%
import implicit
from Recommenders.BaseMatrixFactorizationRecommender import BaseMatrixFactorizationRecommender
import scipy.sparse as sps
class ImplicitALSRecommender(BaseMatrixFactorizationRecommender):
    """ImplicitALSRecommender recommender"""

    RECOMMENDER_NAME = "ImplicitALSRecommender"

    def fit(self,
            factors=100,
            regularization=0.01,
            use_native=True, use_cg=True, use_gpu=False,
            iterations=15,
            calculate_training_loss=False, num_threads=0,
            confidence_scaling=None,
            icm_coeff = 1,
            **confidence_args
            ):
        self.rec = implicit.als.AlternatingLeastSquares(factors=factors, regularization=regularization,
                                                        use_native=use_native, use_cg=use_cg, use_gpu=use_gpu,
                                                        iterations=iterations,
                                                        calculate_training_loss=calculate_training_loss,
                                                        num_threads=num_threads,
                                                        random_state=5)
        self.rec.fit(confidence_scaling(self.URM_train, **confidence_args), show_progress=self.verbose)

        self.USER_factors = self.rec.user_factors
        self.ITEM_factors = self.rec.item_factors

# %%
import numpy as np
import scipy.sparse as sps
from Recommenders.Recommender_utils import check_matrix
from sklearn.linear_model import ElasticNet
from Recommenders.BaseSimilarityMatrixRecommender import BaseItemSimilarityMatrixRecommender
from Utils.seconds_to_biggest_unit import seconds_to_biggest_unit
import time, sys
from tqdm import tqdm
from sklearn.utils._testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning

# os.environ["PYTHONWARNINGS"] = ('ignore::exceptions.ConvergenceWarning:sklearn.linear_model')
# os.environ["PYTHONWARNINGS"] = ('ignore:Objective did not converge:ConvergenceWarning:')

class SLIMElasticNetRecommender(BaseItemSimilarityMatrixRecommender):
    """
    Train a Sparse Linear Methods (SLIM) item similarity model.
    NOTE: ElasticNet solver is parallel, a single intance of SLIM_ElasticNet will
          make use of half the cores available
    See:
        Efficient Top-N Recommendation by Linear Regression,
        M. Levy and K. Jack, LSRS workshop at RecSys 2013.
        SLIM: Sparse linear methods for top-n recommender systems,
        X. Ning and G. Karypis, ICDM 2011.
        http://glaros.dtc.umn.edu/gkhome/fetch/papers/SLIM2011icdm.pdf
    """

    RECOMMENDER_NAME = "SLIMElasticNetRecommender"

    def __init__(self, URM_train, verbose = True):
        super(SLIMElasticNetRecommender, self).__init__(URM_train, verbose = verbose)

    @ignore_warnings(category=ConvergenceWarning)
    def fit(self, l1_ratio=0.1, alpha = 1.0, positive_only=True, topK = 100,**earlystopping_kwargs):

        assert l1_ratio>= 0 and l1_ratio<=1, "{}: l1_ratio must be between 0 and 1, provided value was {}".format(self.RECOMMENDER_NAME, l1_ratio)

        self.l1_ratio = l1_ratio
        self.positive_only = positive_only
        self.topK = topK


        # initialize the ElasticNet model
        self.model = ElasticNet(alpha=alpha,
                                l1_ratio=self.l1_ratio,
                                positive=self.positive_only,
                                fit_intercept=False,
                                copy_X=False,
                                precompute=True,
                                selection='random',
                                max_iter=100,
                                tol=1e-4)

        URM_train = check_matrix(self.URM_train, 'csc', dtype=np.float32)

        n_items = URM_train.shape[1]

        # Use array as it reduces memory requirements compared to lists
        dataBlock = 10000000

        rows = np.zeros(dataBlock, dtype=np.int32)
        cols = np.zeros(dataBlock, dtype=np.int32)
        values = np.zeros(dataBlock, dtype=np.float32)

        numCells = 0

        start_time = time.time()
        start_time_printBatch = start_time

        # fit each item's factors sequentially (not in parallel)
        for currentItem in range(n_items):

            # get the target column
            y = URM_train[:, currentItem].toarray()

            # set the j-th column of X to zero
            start_pos = URM_train.indptr[currentItem]
            end_pos = URM_train.indptr[currentItem + 1]

            current_item_data_backup = URM_train.data[start_pos: end_pos].copy()
            URM_train.data[start_pos: end_pos] = 0.0

            # fit one ElasticNet model per column
            self.model.fit(URM_train, y)

            # self.model.coef_ contains the coefficient of the ElasticNet model
            # let's keep only the non-zero values

            # Select topK values
            # Sorting is done in three steps. Faster then plain np.argsort for higher number of items
            # - Partition the data to extract the set of relevant items
            # - Sort only the relevant items
            # - Get the original item index

            nonzero_model_coef_index = self.model.sparse_coef_.indices
            nonzero_model_coef_value = self.model.sparse_coef_.data

            local_topK = min(len(nonzero_model_coef_value)-1, self.topK)

            relevant_items_partition = (-nonzero_model_coef_value).argpartition(local_topK)[0:local_topK]
            relevant_items_partition_sorting = np.argsort(-nonzero_model_coef_value[relevant_items_partition])
            ranking = relevant_items_partition[relevant_items_partition_sorting]

            for index in range(len(ranking)):

                if numCells == len(rows):
                    rows = np.concatenate((rows, np.zeros(dataBlock, dtype=np.int32)))
                    cols = np.concatenate((cols, np.zeros(dataBlock, dtype=np.int32)))
                    values = np.concatenate((values, np.zeros(dataBlock, dtype=np.float32)))


                rows[numCells] = nonzero_model_coef_index[ranking[index]]
                cols[numCells] = currentItem
                values[numCells] = nonzero_model_coef_value[ranking[index]]

                numCells += 1

            # finally, replace the original values of the j-th column
            URM_train.data[start_pos:end_pos] = current_item_data_backup

            elapsed_time = time.time() - start_time
            new_time_value, new_time_unit = seconds_to_biggest_unit(elapsed_time)


            if time.time() - start_time_printBatch > 300 or currentItem == n_items-1:
                self._print("Processed {} ({:4.1f}%) in {:.2f} {}. Items per second: {:.2f}".format(
                    currentItem+1,
                    100.0* float(currentItem+1)/n_items,
                    new_time_value,
                    new_time_unit,
                    float(currentItem)/elapsed_time))

                sys.stdout.flush()
                sys.stderr.flush()

                start_time_printBatch = time.time()

        # generate the sparse weight matrix
        self.W_sparse = sps.csr_matrix((values[:numCells], (rows[:numCells], cols[:numCells])),
                                       shape=(n_items, n_items), dtype=np.float32)

# %%
from Recommenders.BaseMatrixFactorizationRecommender import BaseMatrixFactorizationRecommender
from Recommenders.Incremental_Training_Early_Stopping import Incremental_Training_Early_Stopping
from Recommenders.Recommender_utils import check_matrix

def linear_scaling_confidence(URM_train, alpha):
    C = check_matrix(URM_train.T, format="csr", dtype=np.float32)
    C.data = 1.0 + alpha * C.data

    return C

# %%
import os

output_folder_path = "result_experiments/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# %%
from Recommenders.KNN.ItemKNNCFRecommender import ItemKNNCFRecommender

itemknn_cf = ItemKNNCFRecommender(URM_train)
itemknn_cf.fit(topK = 157, shrink = 463, similarity = 'cosine', normalize = True, feature_weighting = 'TF-IDF')
# Out:
# ItemKNNCFRecommender: URM Detected 3461 (12.4%) items with no interactions.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 27968 (100.0%), 485.99 column/sec. Elapsed time 57.55 sec

# %%
recommender_implicitAls = ImplicitALSRecommender(URM_train)
recommender_implicitAls.fit(iterations= int(111.5), factors= int(64.3), regularization= 0.0001,use_gpu=False, num_threads=4, confidence_scaling=linear_scaling_confidence,**{"alpha":5.988})
# Out:
# ImplicitALSRecommender: URM Detected 3461 (12.4%) items with no interactions.
#   0%|          | 0/111 [00:00<?, ?it/s]

# %%
recommender_SLIMElasticNet1 = SLIMElasticNetRecommender(URM_train_stacked)
recommender_SLIMElasticNet1.fit(l1_ratio= 0.02663352009457766, alpha= 0.0010777130010163724, positive_only= True, topK= 15368)
# Out:
# SLIMElasticNetRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# SLIMElasticNetRecommender: Processed 3068 (11.0%) in 5.00 min. Items per second: 10.22
# SLIMElasticNetRecommender: Processed 6495 (23.2%) in 10.00 min. Items per second: 10.82
# SLIMElasticNetRecommender: Processed 10000 (35.8%) in 15.00 min. Items per second: 11.11
# SLIMElasticNetRecommender: Processed 13393 (47.9%) in 20.01 min. Items per second: 11.16
# SLIMElasticNetRecommender: Processed 16767 (60.0%) in 25.01 min. Items per second: 11.17
# SLIMElasticNetRecommender: Processed 20160 (72.1%) in 30.01 min. Items per second: 11.20
# SLIMElasticNetRecommender: Processed 23534 (84.1%) in 35.01 min. Items per second: 11.20
# SLIMElasticNetRecommender: Processed 27968 (100.0%) in 37.53 min. Items per second: 12.42

# %%
RP3beta_all = RP3betaRecommender(URM_train)
RP3beta_all.fit(alpha= 0.8048209317587374, beta= 0.28523965008406016, topK= 56, implicit= False)
# Out:
# RP3betaRecommender: URM Detected 3461 (12.4%) items with no interactions.
# RP3betaRecommender: Similarity column 27968 (100.0%), 2327.59 column/sec. Elapsed time 12.02 sec

# %%
EASE_R = EASE_R_Recommender(URM_train_stacked)
#%%
EASE_R.fit(topK = 329, l2_norm = 143.45076856759013, normalize_matrix = False)
# Out:
# EASE_R_Recommender: URM Detected 3 ( 0.0%) users with no interactions.
# EASE_R_Recommender: Fitting model...
# EASE_R_Recommender: Fitting model... done in 16.26 min

# %%
slim_matrix1 = recommender_SLIMElasticNet1.W_sparse
rp3_matrix = RP3beta_all.W_sparse
knn_matrix = itemknn_cf.W_sparse

# %%
result_dict, _ = evaluator_valid.evaluateRecommender(itemknn_cf)
print(f"ItemKNN: {result_dict['MAP'][10]}")

result_dict, _ = evaluator_valid.evaluateRecommender(recommender_implicitAls)
print(f"Ials: {result_dict['MAP'][10]}")

result_dict, _ = evaluator_valid.evaluateRecommender(recommender_SLIMElasticNet1)
print(f"Slim_en: {result_dict['MAP'][10]}")

result_dict, _ = evaluator_valid.evaluateRecommender(RP3beta_all)
print(f"Rp3: {result_dict['MAP'][10]}")

result_dict, _ = evaluator_valid.evaluateRecommender(EASE_R)
print(f"Ease: {result_dict['MAP'][10]}")
# Out:
# EvaluatorHoldout: Processed 40666 (100.0%) in 42.42 sec. Users per second: 959
# ItemKNN: 0.023232739373556667
# EvaluatorHoldout: Processed 40666 (100.0%) in 40.96 sec. Users per second: 993
# Ials: 0.01997157349964324
# EvaluatorHoldout: Processed 40666 (100.0%) in 54.37 sec. Users per second: 748
# Slim_en: 0.027839028781891654
# EvaluatorHoldout: Processed 40666 (100.0%) in 34.86 sec. Users per second: 1167
# Rp3: 0.025709229034979467
# EvaluatorHoldout: Processed 40666 (100.0%) in 58.59 sec. Users per second: 694
# Ease: 0.027119162375026283

# %%
from Recommenders.Recommender_utils import check_matrix, similarityMatrixTopK
from Recommenders.BaseSimilarityMatrixRecommender import BaseItemSimilarityMatrixRecommender



class ItemKNNSimilarityHybridRecommender(BaseItemSimilarityMatrixRecommender):
    """ ItemKNNSimilarityHybridRecommender
    Hybrid of two similarities S = S1*alpha + S2*(1-alpha)
    """

    RECOMMENDER_NAME = "ItemKNNSimilarityHybridRecommender"


    def __init__(self, URM_train, Similarity_1, Similarity_2, verbose = True):
        super(ItemKNNSimilarityHybridRecommender, self).__init__(URM_train, verbose = verbose)

        # CSR is faster during evaluation
        self.Similarity_1 = check_matrix(Similarity_1.copy(), 'csr')
        self.Similarity_2 = check_matrix(Similarity_2.copy(), 'csr')


    def fit(self, topK=100, alpha = 0.5, beta = 0):

        self.topK = topK
        self.alpha = alpha
        self.beta = beta


        W_sparse = self.Similarity_1*self.alpha + self.Similarity_2*self.beta

        self.W_sparse = similarityMatrixTopK(W_sparse, k=self.topK)
        self.W_sparse = check_matrix(self.W_sparse, format='csr')

# %%
from numpy import linalg as LA
from Recommenders.BaseRecommender import BaseRecommender

class DifferentLossScoresHybridRecommender(BaseRecommender):

    RECOMMENDER_NAME = "DifferentLossScoresHybridRecommender"


    def __init__(self, URM_train, recommender_1, recommender_2, recommender_3, recommender_4):
        super(DifferentLossScoresHybridRecommender, self).__init__(URM_train)

        self.URM_train = sps.csr_matrix(URM_train)
        self.recommender_1 = recommender_1
        self.recommender_2 = recommender_2
        self.recommender_3 = recommender_3
        self.recommender_4 = recommender_4
        
        
        
    def fit(self, alpha = 0.5, beta = 0, gamma = 0, theta = 0):

        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma
        self.theta = theta



    def _compute_item_score(self, user_id_array, items_to_compute):
        
        item_weights_1 = self.recommender_1._compute_item_score(user_id_array)
        item_weights_2 = self.recommender_2._compute_item_score(user_id_array)
        item_weights_3 = self.recommender_3._compute_item_score(user_id_array)
        item_weights_4 = self.recommender_4._compute_item_score(user_id_array)
            
        item_weights = item_weights_1 * self.alpha + item_weights_2 * self.beta + item_weights_3 * self.gamma + item_weights_4 * self.theta

        return item_weights

# %%
recommender_class = ItemKNNSimilarityHybridRecommender

import os

output_folder_path = "result_experiments/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 1000
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from skopt.space import Real, Integer, Categorical
#RP3 beta
#to tuning hyperparam are typical of ML models to drive the learning process

hyperparameters_range_dictionary = {
    "topK": Integer(100,2500),
    "alpha": Real(low=30, high=100, prior='uniform'),
    "beta": Real(low=0, high=30, prior='uniform')
}

from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

#create a bayesian optimizer object, we pass the recommender and the evaluator
hyperparameterSearch = SearchBayesianSkopt(recommender_class,
                                         evaluator_validation=evaluator_valid)
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
  
#provide data needed to create instance of model (one on URM_train, the other on URM_all)
recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train, slim_matrix1, knn_matrix],     # For a CBF model simply put [URM_train, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {}
)

# %%
hyperparameterSearch.search(recommender_input_args = recommender_input_args,
                       hyperparameter_search_space = hyperparameters_range_dictionary,
                       n_cases = n_cases,
                       n_random_starts = n_random_starts,
                       save_model = "last",
                       output_folder_path = output_folder_path, # Where to save the results
                       output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
                       metric_to_optimize = metric_to_optimize,
                       cutoff_to_optimize = cutoff_to_optimize,
                      )
# Out:
# SearchBayesianSkopt: argument save_model is 'last' but no recommender_input_args_last_test provided, saving best model on train data alone.
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 337, 'alpha': 41.911123190429244, 'beta': 5.459284278340091}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 57.87 sec. Users per second: 703
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 337, 'alpha': 41.911123190429244, 'beta': 5.459284278340091} - results: PRECISION: 0.0547116, PRECISION_RECALL_MIN_DEN: 0.0907608, RECALL: 0.0848338, MAP: 0.0271565, MAP_MIN_DEN: 0.0441767, MRR: 0.1810997, NDCG: 0.0878305, F1: 0.0665216, HIT_RATE: 0.3590223, ARHR_ALL_HITS: 0.2201507, NOVELTY: 0.0038591, AVERAGE_POPULARITY: 0.1753817, DIVERSITY_MEAN_INTER_LIST: 0.9558763, DIVERSITY_HERFINDAHL: 0.9955853, COVERAGE_ITEM: 0.1885727, COVERAGE_ITEM_HIT: 0.0555635, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3507170, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0237679, SHANNON_ENTROPY: 9.3465315, RATIO_DIVERSITY_HERFINDAHL: 0.9959136, RATIO_DIVERSITY_GINI: 0.0533566, RATIO_SHANNON_ENTROPY: 0.6926471, RATIO_AVERAGE_POPULARITY: 3.4423973, RATIO_NOVELTY: 0.2519713,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNSimilarityHybridRecommender
#
# ItemKNNSimilarityHybridRecommender: Saving model in file 'result_experiments/ItemKNNSimilarityHybridRecommender_best_model'
# ItemKNNSimilarityHybridRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 77.5225
# Function value obtained: -0.0272
# Current minimum: -0.0272
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1159, 'alpha': 52.00508201925478, 'beta': 20.287352370406346}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 58.96 sec. Users per second: 690
# SearchBayesianSkopt: Config 1 is suboptimal. Config: {'topK': 1159, 'alpha': 52.00508201925478, 'beta': 20.287352370406346} - results: PRECISION: 0.0531501, PRECISION_RECALL_MIN_DEN: 0.0889155, RECALL: 0.0832824, MAP: 0.0263810, MAP_MIN_DEN: 0.0432081, MRR: 0.1782557, NDCG: 0.0859871, F1: 0.0648887, HIT_RATE: 0.3539320, ARHR_ALL_HITS: 0.2152468, NOVELTY: 0.0037674, AVERAGE_POPULARITY: 0.2073432, DIVERSITY_MEAN_INTER_LIST: 0.9331149, DIVERSITY_HERFINDAHL: 0.9933092, COVERAGE_ITEM: 0.2028032, COVERAGE_ITEM_HIT: 0.0509511, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3457446, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0200763, SHANNON_ENTROPY: 8.9177263, RATIO_DIVERSITY_HERFINDAHL: 0.9936368, RATIO_DIVERSITY_GINI: 0.0450691, RATIO_SHANNON_ENTROPY: 0.6608695, RATIO_AVERAGE_POPULARITY: 4.0697388, RATIO_NOVELTY: 0.2459852,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 71.3352
# Function value obtained: -0.0264
# Current minimum: -0.0272
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1687, 'alpha': 23.372463530781335, 'beta': 19.800470069070506}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.47 sec. Users per second: 684
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'topK': 1687, 'alpha': 23.372463530781335, 'beta': 19.800470069070506} - results: PRECISION: 0.0512320, PRECISION_RECALL_MIN_DEN: 0.0861545, RECALL: 0.0807510, MAP: 0.0253007, MAP_MIN_DEN: 0.0416047, MRR: 0.1729250, NDCG: 0.0830937, F1: 0.0626904, HIT_RATE: 0.3455712, ARHR_ALL_HITS: 0.2076908, NOVELTY: 0.0037524, AVERAGE_POPULARITY: 0.2109708, DIVERSITY_MEAN_INTER_LIST: 0.9277782, DIVERSITY_HERFINDAHL: 0.9927755, COVERAGE_ITEM: 0.2237915, COVERAGE_ITEM_HIT: 0.0491633, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3375772, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0191309, SHANNON_ENTROPY: 8.7892415, RATIO_DIVERSITY_HERFINDAHL: 0.9931030, RATIO_DIVERSITY_GINI: 0.0429469, RATIO_SHANNON_ENTROPY: 0.6513478, RATIO_AVERAGE_POPULARITY: 4.1409427, RATIO_NOVELTY: 0.2450064,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 72.0372
# Function value obtained: -0.0253
# Current minimum: -0.0272
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 171, 'alpha': 98.46751609703442, 'beta': 3.8008028629160213}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 45.04 sec. Users per second: 903
# SearchBayesianSkopt: New best config found. Config 3: {'topK': 171, 'alpha': 98.46751609703442, 'beta': 3.8008028629160213} - results: PRECISION: 0.0553214, PRECISION_RECALL_MIN_DEN: 0.0909953, RECALL: 0.0848186, MAP: 0.0275498, MAP_MIN_DEN: 0.0443921, MRR: 0.1818651, NDCG: 0.0882426, F1: 0.0669656, HIT_RATE: 0.3585305, ARHR_ALL_HITS: 0.2220757, NOVELTY: 0.0039207, AVERAGE_POPULARITY: 0.1612344, DIVERSITY_MEAN_INTER_LIST: 0.9642230, DIVERSITY_HERFINDAHL: 0.9964199, COVERAGE_ITEM: 0.1858553, COVERAGE_ITEM_HIT: 0.0593535, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3502366, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0272456, SHANNON_ENTROPY: 9.6134834, RATIO_DIVERSITY_HERFINDAHL: 0.9967486, RATIO_DIVERSITY_GINI: 0.0611635, RATIO_SHANNON_ENTROPY: 0.7124302, RATIO_AVERAGE_POPULARITY: 3.1647148, RATIO_NOVELTY: 0.2559978,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNSimilarityHybridRecommender
#
# ItemKNNSimilarityHybridRecommender: Saving model in file 'result_experiments/ItemKNNSimilarityHybridRecommender_best_model'
# ItemKNNSimilarityHybridRecommender: Saving complete
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 57.6746
# Function value obtained: -0.0275
# Current minimum: -0.0275
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 461, 'alpha': 60.17544563638839, 'beta': 19.69116988612636}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 1.01 min. Users per second: 671
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 461, 'alpha': 60.17544563638839, 'beta': 19.69116988612636} - results: PRECISION: 0.0534525, PRECISION_RECALL_MIN_DEN: 0.0891457, RECALL: 0.0834455, MAP: 0.0265315, MAP_MIN_DEN: 0.0433486, MRR: 0.1787081, NDCG: 0.0862734, F1: 0.0651634, HIT_RATE: 0.3551862, ARHR_ALL_HITS: 0.2161245, NOVELTY: 0.0037885, AVERAGE_POPULARITY: 0.1988650, DIVERSITY_MEAN_INTER_LIST: 0.9394426, DIVERSITY_HERFINDAHL: 0.9939420, COVERAGE_ITEM: 0.2018021, COVERAGE_ITEM_HIT: 0.0516304, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3469697, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0209200, SHANNON_ENTROPY: 9.0178880, RATIO_DIVERSITY_HERFINDAHL: 0.9942698, RATIO_DIVERSITY_GINI: 0.0469632, RATIO_SHANNON_ENTROPY: 0.6682922, RATIO_AVERAGE_POPULARITY: 3.9033297, RATIO_NOVELTY: 0.2473652,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 72.7810
# Function value obtained: -0.0265
# Current minimum: -0.0275
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1248, 'alpha': 71.52457708731119, 'beta': 23.593152137814002}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.38 sec. Users per second: 685
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'topK': 1248, 'alpha': 71.52457708731119, 'beta': 23.593152137814002} - results: PRECISION: 0.0535214, PRECISION_RECALL_MIN_DEN: 0.0894935, RECALL: 0.0838040, MAP: 0.0265388, MAP_MIN_DEN: 0.0434268, MRR: 0.1788516, NDCG: 0.0864516, F1: 0.0653237, HIT_RATE: 0.3555796, ARHR_ALL_HITS: 0.2162615, NOVELTY: 0.0037708, AVERAGE_POPULARITY: 0.2067839, DIVERSITY_MEAN_INTER_LIST: 0.9340372, DIVERSITY_HERFINDAHL: 0.9934014, COVERAGE_ITEM: 0.1994065, COVERAGE_ITEM_HIT: 0.0513086, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3473540, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0203246, SHANNON_ENTROPY: 8.9454125, RATIO_DIVERSITY_HERFINDAHL: 0.9937291, RATIO_DIVERSITY_GINI: 0.0456266, RATIO_SHANNON_ENTROPY: 0.6629212, RATIO_AVERAGE_POPULARITY: 4.0587609, RATIO_NOVELTY: 0.2462070,
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 71.8503
# Function value obtained: -0.0265
# Current minimum: -0.0275
# Iteration No: 7 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 417, 'alpha': 58.81394513845781, 'beta': 9.24597771450641}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.00 sec. Users per second: 689
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'topK': 417, 'alpha': 58.81394513845781, 'beta': 9.24597771450641} - results: PRECISION: 0.0545960, PRECISION_RECALL_MIN_DEN: 0.0907877, RECALL: 0.0849117, MAP: 0.0271195, MAP_MIN_DEN: 0.0441249, MRR: 0.1812644, NDCG: 0.0877803, F1: 0.0664600, HIT_RATE: 0.3595141, ARHR_ALL_HITS: 0.2200797, NOVELTY: 0.0038359, AVERAGE_POPULARITY: 0.1817592, DIVERSITY_MEAN_INTER_LIST: 0.9519687, DIVERSITY_HERFINDAHL: 0.9951945, COVERAGE_ITEM: 0.1895380, COVERAGE_ITEM_HIT: 0.0546339, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3511975, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0227399, SHANNON_ENTROPY: 9.2485781, RATIO_DIVERSITY_HERFINDAHL: 0.9955227, RATIO_DIVERSITY_GINI: 0.0510488, RATIO_SHANNON_ENTROPY: 0.6853880, RATIO_AVERAGE_POPULARITY: 3.5675759, RATIO_NOVELTY: 0.2504588,
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 71.0207
# Function value obtained: -0.0271
# Current minimum: -0.0275
# Iteration No: 8 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 717, 'alpha': 54.676975279095565, 'beta': 12.131052728704177}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 1.00 min. Users per second: 677
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'topK': 717, 'alpha': 54.676975279095565, 'beta': 12.131052728704177} - results: PRECISION: 0.0543107, PRECISION_RECALL_MIN_DEN: 0.0904130, RECALL: 0.0846138, MAP: 0.0269915, MAP_MIN_DEN: 0.0439884, MRR: 0.1808860, NDCG: 0.0874963, F1: 0.0661573, HIT_RATE: 0.3585059, ARHR_ALL_HITS: 0.2193176, NOVELTY: 0.0037911, AVERAGE_POPULARITY: 0.1991321, DIVERSITY_MEAN_INTER_LIST: 0.9403802, DIVERSITY_HERFINDAHL: 0.9940357, COVERAGE_ITEM: 0.1925415, COVERAGE_ITEM_HIT: 0.0528819, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3502126, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0212057, SHANNON_ENTROPY: 9.0558619, RATIO_DIVERSITY_HERFINDAHL: 0.9943635, RATIO_DIVERSITY_GINI: 0.0476046, RATIO_SHANNON_ENTROPY: 0.6711063, RATIO_AVERAGE_POPULARITY: 3.9085721, RATIO_NOVELTY: 0.2475349,
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 72.6335
# Function value obtained: -0.0270
# Current minimum: -0.0275
# Iteration No: 9 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 2196, 'alpha': 28.39748483202587, 'beta': 11.063017402054037}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.81 sec. Users per second: 680
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'topK': 2196, 'alpha': 28.39748483202587, 'beta': 11.063017402054037} - results: PRECISION: 0.0531476, PRECISION_RECALL_MIN_DEN: 0.0889653, RECALL: 0.0833411, MAP: 0.0263816, MAP_MIN_DEN: 0.0432249, MRR: 0.1782227, NDCG: 0.0860102, F1: 0.0649047, HIT_RATE: 0.3540550, ARHR_ALL_HITS: 0.2152327, NOVELTY: 0.0037648, AVERAGE_POPULARITY: 0.2088503, DIVERSITY_MEAN_INTER_LIST: 0.9320728, DIVERSITY_HERFINDAHL: 0.9932050, COVERAGE_ITEM: 0.2024814, COVERAGE_ITEM_HIT: 0.0509153, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3458647, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0200157, SHANNON_ENTROPY: 8.9078136, RATIO_DIVERSITY_HERFINDAHL: 0.9935326, RATIO_DIVERSITY_GINI: 0.0449333, RATIO_SHANNON_ENTROPY: 0.6601348, RATIO_AVERAGE_POPULARITY: 4.0993201, RATIO_NOVELTY: 0.2458173,
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 72.2842
# Function value obtained: -0.0264
# Current minimum: -0.0275
# Iteration No: 10 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 2364, 'alpha': 19.44495370076755, 'beta': 26.385665203213225}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.64 sec. Users per second: 682
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'topK': 2364, 'alpha': 19.44495370076755, 'beta': 26.385665203213225} - results: PRECISION: 0.0502705, PRECISION_RECALL_MIN_DEN: 0.0844081, RECALL: 0.0790745, MAP: 0.0247745, MAP_MIN_DEN: 0.0407540, MRR: 0.1699459, NDCG: 0.0814881, F1: 0.0614653, HIT_RATE: 0.3409974, ARHR_ALL_HITS: 0.2037096, NOVELTY: 0.0037478, AVERAGE_POPULARITY: 0.2118950, DIVERSITY_MEAN_INTER_LIST: 0.9255349, DIVERSITY_HERFINDAHL: 0.9925512, COVERAGE_ITEM: 0.2378075, COVERAGE_ITEM_HIT: 0.0482337, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3331091, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0188459, SHANNON_ENTROPY: 8.7332623, RATIO_DIVERSITY_HERFINDAHL: 0.9928786, RATIO_DIVERSITY_GINI: 0.0423071, RATIO_SHANNON_ENTROPY: 0.6471993, RATIO_AVERAGE_POPULARITY: 4.1590831, RATIO_NOVELTY: 0.2447054,
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 72.3700
# Function value obtained: -0.0248
# Current minimum: -0.0275
# Iteration No: 11 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 231, 'alpha': 16.032477269591652, 'beta': 19.226052701343693}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 50.38 sec. Users per second: 807
# SearchBayesianSkopt: Config 10 is suboptimal. Config: {'topK': 231, 'alpha': 16.032477269591652, 'beta': 19.226052701343693} - results: PRECISION: 0.0504402, PRECISION_RECALL_MIN_DEN: 0.0846555, RECALL: 0.0793043, MAP: 0.0248450, MAP_MIN_DEN: 0.0408767, MRR: 0.1702064, NDCG: 0.0817045, F1: 0.0616615, HIT_RATE: 0.3416367, ARHR_ALL_HITS: 0.2041685, NOVELTY: 0.0037600, AVERAGE_POPULARITY: 0.2071281, DIVERSITY_MEAN_INTER_LIST: 0.9293183, DIVERSITY_HERFINDAHL: 0.9929295, COVERAGE_ITEM: 0.2365918, COVERAGE_ITEM_HIT: 0.0489488, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3337337, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0193089, SHANNON_ENTROPY: 8.7921408, RATIO_DIVERSITY_HERFINDAHL: 0.9932570, RATIO_DIVERSITY_GINI: 0.0433464, RATIO_SHANNON_ENTROPY: 0.6515626, RATIO_AVERAGE_POPULARITY: 4.0655182, RATIO_NOVELTY: 0.2455016,
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 59.8556
# Function value obtained: -0.0248
# Current minimum: -0.0275
# Iteration No: 12 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1781, 'alpha': 14.691744648189633, 'beta': 25.355116778789093}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.59 sec. Users per second: 682
# SearchBayesianSkopt: Config 11 is suboptimal. Config: {'topK': 1781, 'alpha': 14.691744648189633, 'beta': 25.355116778789093} - results: PRECISION: 0.0498475, PRECISION_RECALL_MIN_DEN: 0.0836075, RECALL: 0.0783123, MAP: 0.0245134, MAP_MIN_DEN: 0.0403647, MRR: 0.1682700, NDCG: 0.0807205, F1: 0.0609188, HIT_RATE: 0.3385137, ARHR_ALL_HITS: 0.2016297, NOVELTY: 0.0037462, AVERAGE_POPULARITY: 0.2121123, DIVERSITY_MEAN_INTER_LIST: 0.9246289, DIVERSITY_HERFINDAHL: 0.9924606, COVERAGE_ITEM: 0.2444222, COVERAGE_ITEM_HIT: 0.0478404, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3306829, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0187549, SHANNON_ENTROPY: 8.7103730, RATIO_DIVERSITY_HERFINDAHL: 0.9927879, RATIO_DIVERSITY_GINI: 0.0421029, RATIO_SHANNON_ENTROPY: 0.6455030, RATIO_AVERAGE_POPULARITY: 4.1633479, RATIO_NOVELTY: 0.2446010,
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 72.1436
# Function value obtained: -0.0245
# Current minimum: -0.0275
# Iteration No: 13 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1281, 'alpha': 19.136337178171875, 'beta': 29.118595675828598}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 1.00 min. Users per second: 676
# SearchBayesianSkopt: Config 12 is suboptimal. Config: {'topK': 1281, 'alpha': 19.136337178171875, 'beta': 29.118595675828598} - results: PRECISION: 0.0500320, PRECISION_RECALL_MIN_DEN: 0.0840109, RECALL: 0.0787053, MAP: 0.0246288, MAP_MIN_DEN: 0.0405459, MRR: 0.1690959, NDCG: 0.0810837, F1: 0.0611755, HIT_RATE: 0.3399154, ARHR_ALL_HITS: 0.2026016, NOVELTY: 0.0037475, AVERAGE_POPULARITY: 0.2116531, DIVERSITY_MEAN_INTER_LIST: 0.9253044, DIVERSITY_HERFINDAHL: 0.9925282, COVERAGE_ITEM: 0.2414188, COVERAGE_ITEM_HIT: 0.0481264, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3320522, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0188118, SHANNON_ENTROPY: 8.7237015, RATIO_DIVERSITY_HERFINDAHL: 0.9928555, RATIO_DIVERSITY_GINI: 0.0422305, RATIO_SHANNON_ENTROPY: 0.6464908, RATIO_AVERAGE_POPULARITY: 4.1543343, RATIO_NOVELTY: 0.2446873,
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 72.7460
# Function value obtained: -0.0246
# Current minimum: -0.0275
# Iteration No: 14 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1660, 'alpha': 67.54870584977255, 'beta': 14.586722593408144}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 1.00 min. Users per second: 675
# SearchBayesianSkopt: Config 13 is suboptimal. Config: {'topK': 1660, 'alpha': 67.54870584977255, 'beta': 14.586722593408144} - results: PRECISION: 0.0544484, PRECISION_RECALL_MIN_DEN: 0.0907862, RECALL: 0.0849759, MAP: 0.0270089, MAP_MIN_DEN: 0.0440754, MRR: 0.1809524, NDCG: 0.0876893, F1: 0.0663701, HIT_RATE: 0.3595633, ARHR_ALL_HITS: 0.2194171, NOVELTY: 0.0037784, AVERAGE_POPULARITY: 0.2059201, DIVERSITY_MEAN_INTER_LIST: 0.9357884, DIVERSITY_HERFINDAHL: 0.9935765, COVERAGE_ITEM: 0.1908610, COVERAGE_ITEM_HIT: 0.0527746, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3512455, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0208746, SHANNON_ENTROPY: 9.0067747, RATIO_DIVERSITY_HERFINDAHL: 0.9939042, RATIO_DIVERSITY_GINI: 0.0468614, RATIO_SHANNON_ENTROPY: 0.6674686, RATIO_AVERAGE_POPULARITY: 4.0418077, RATIO_NOVELTY: 0.2467054,
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 72.7968
# Function value obtained: -0.0270
# Current minimum: -0.0275
# Iteration No: 15 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 2179, 'alpha': 57.49490354654131, 'beta': 2.697961332771131}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 1.00 min. Users per second: 677
# SearchBayesianSkopt: New best config found. Config 14: {'topK': 2179, 'alpha': 57.49490354654131, 'beta': 2.697961332771131} - results: PRECISION: 0.0559706, PRECISION_RECALL_MIN_DEN: 0.0925317, RECALL: 0.0864133, MAP: 0.0277693, MAP_MIN_DEN: 0.0449856, MRR: 0.1840472, NDCG: 0.0894697, F1: 0.0679375, HIT_RATE: 0.3639650, ARHR_ALL_HITS: 0.2243155, NOVELTY: 0.0038105, AVERAGE_POPULARITY: 0.1995127, DIVERSITY_MEAN_INTER_LIST: 0.9418946, DIVERSITY_HERFINDAHL: 0.9941871, COVERAGE_ITEM: 0.1757366, COVERAGE_ITEM_HIT: 0.0549914, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3555454, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0227092, SHANNON_ENTROPY: 9.1894333, RATIO_DIVERSITY_HERFINDAHL: 0.9945150, RATIO_DIVERSITY_GINI: 0.0509799, RATIO_SHANNON_ENTROPY: 0.6810050, RATIO_AVERAGE_POPULARITY: 3.9160428, RATIO_NOVELTY: 0.2487997,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNSimilarityHybridRecommender
#
# ItemKNNSimilarityHybridRecommender: Saving model in file 'result_experiments/ItemKNNSimilarityHybridRecommender_best_model'
# ItemKNNSimilarityHybridRecommender: Saving complete
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 81.7567
# Function value obtained: -0.0278
# Current minimum: -0.0278
# Iteration No: 16 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1640, 'alpha': 74.09478690162263, 'beta': 17.464581087054732}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 1.01 min. Users per second: 669
# SearchBayesianSkopt: Config 15 is suboptimal. Config: {'topK': 1640, 'alpha': 74.09478690162263, 'beta': 17.464581087054732} - results: PRECISION: 0.0543132, PRECISION_RECALL_MIN_DEN: 0.0906309, RECALL: 0.0848427, MAP: 0.0269325, MAP_MIN_DEN: 0.0439617, MRR: 0.1806895, NDCG: 0.0875078, F1: 0.0662290, HIT_RATE: 0.3592436, ARHR_ALL_HITS: 0.2189553, NOVELTY: 0.0037761, AVERAGE_POPULARITY: 0.2063722, DIVERSITY_MEAN_INTER_LIST: 0.9352681, DIVERSITY_HERFINDAHL: 0.9935245, COVERAGE_ITEM: 0.1920409, COVERAGE_ITEM_HIT: 0.0524170, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3509332, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0207263, SHANNON_ENTROPY: 8.9915572, RATIO_DIVERSITY_HERFINDAHL: 0.9938522, RATIO_DIVERSITY_GINI: 0.0465284, RATIO_SHANNON_ENTROPY: 0.6663409, RATIO_AVERAGE_POPULARITY: 4.0506806, RATIO_NOVELTY: 0.2465557,
#
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 73.5849
# Function value obtained: -0.0269
# Current minimum: -0.0278
# Iteration No: 17 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1873, 'alpha': 1.0571952915167884, 'beta': 1.0065372636295846}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 1.00 min. Users per second: 676
# SearchBayesianSkopt: Config 16 is suboptimal. Config: {'topK': 1873, 'alpha': 1.0571952915167884, 'beta': 1.0065372636295846} - results: PRECISION: 0.0509787, PRECISION_RECALL_MIN_DEN: 0.0856673, RECALL: 0.0802818, MAP: 0.0251474, MAP_MIN_DEN: 0.0413877, MRR: 0.1721224, NDCG: 0.0826698, F1: 0.0623594, HIT_RATE: 0.3443417, ARHR_ALL_HITS: 0.2065836, NOVELTY: 0.0037509, AVERAGE_POPULARITY: 0.2113035, DIVERSITY_MEAN_INTER_LIST: 0.9271199, DIVERSITY_HERFINDAHL: 0.9927097, COVERAGE_ITEM: 0.2277961, COVERAGE_ITEM_HIT: 0.0489488, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3363761, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0190482, SHANNON_ENTROPY: 8.7732529, RATIO_DIVERSITY_HERFINDAHL: 0.9930371, RATIO_DIVERSITY_GINI: 0.0427612, RATIO_SHANNON_ENTROPY: 0.6501629, RATIO_AVERAGE_POPULARITY: 4.1474731, RATIO_NOVELTY: 0.2449121,
#
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 73.0870
# Function value obtained: -0.0251
# Current minimum: -0.0278
# Iteration No: 18 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1301, 'alpha': 16.52350401766291, 'beta': 3.943024147016646}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.97 sec. Users per second: 678
# SearchBayesianSkopt: Config 17 is suboptimal. Config: {'topK': 1301, 'alpha': 16.52350401766291, 'beta': 3.943024147016646} - results: PRECISION: 0.0542542, PRECISION_RECALL_MIN_DEN: 0.0905100, RECALL: 0.0847206, MAP: 0.0269101, MAP_MIN_DEN: 0.0439223, MRR: 0.1805267, NDCG: 0.0874179, F1: 0.0661479, HIT_RATE: 0.3588256, ARHR_ALL_HITS: 0.2187647, NOVELTY: 0.0037776, AVERAGE_POPULARITY: 0.2054061, DIVERSITY_MEAN_INTER_LIST: 0.9359203, DIVERSITY_HERFINDAHL: 0.9935897, COVERAGE_ITEM: 0.1925057, COVERAGE_ITEM_HIT: 0.0523813, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3505249, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0207542, SHANNON_ENTROPY: 8.9966921, RATIO_DIVERSITY_HERFINDAHL: 0.9939174, RATIO_DIVERSITY_GINI: 0.0465910, RATIO_SHANNON_ENTROPY: 0.6667214, RATIO_AVERAGE_POPULARITY: 4.0317185, RATIO_NOVELTY: 0.2466548,
#
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 72.3025
# Function value obtained: -0.0269
# Current minimum: -0.0278
# Iteration No: 19 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 864, 'alpha': 65.86485081808485, 'beta': 3.0675894175083505}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.96 sec. Users per second: 678
# SearchBayesianSkopt: New best config found. Config 18: {'topK': 864, 'alpha': 65.86485081808485, 'beta': 3.0675894175083505} - results: PRECISION: 0.0559386, PRECISION_RECALL_MIN_DEN: 0.0924235, RECALL: 0.0862934, MAP: 0.0277729, MAP_MIN_DEN: 0.0449638, MRR: 0.1836761, NDCG: 0.0893620, F1: 0.0678769, HIT_RATE: 0.3633502, ARHR_ALL_HITS: 0.2240788, NOVELTY: 0.0038351, AVERAGE_POPULARITY: 0.1870843, DIVERSITY_MEAN_INTER_LIST: 0.9504407, DIVERSITY_HERFINDAHL: 0.9950417, COVERAGE_ITEM: 0.1765589, COVERAGE_ITEM_HIT: 0.0554205, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3549449, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0233369, SHANNON_ENTROPY: 9.2866962, RATIO_DIVERSITY_HERFINDAHL: 0.9953699, RATIO_DIVERSITY_GINI: 0.0523889, RATIO_SHANNON_ENTROPY: 0.6882128, RATIO_AVERAGE_POPULARITY: 3.6720976, RATIO_NOVELTY: 0.2504055,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNSimilarityHybridRecommender
#
# ItemKNNSimilarityHybridRecommender: Saving model in file 'result_experiments/ItemKNNSimilarityHybridRecommender_best_model'
# ItemKNNSimilarityHybridRecommender: Saving complete
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 81.3159
# Function value obtained: -0.0278
# Current minimum: -0.0278
# Iteration No: 20 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1602, 'alpha': 88.20085263114454, 'beta': 9.580639007527434}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.24 sec. Users per second: 686
# SearchBayesianSkopt: Config 19 is suboptimal. Config: {'topK': 1602, 'alpha': 88.20085263114454, 'beta': 9.580639007527434} - results: PRECISION: 0.0554566, PRECISION_RECALL_MIN_DEN: 0.0919859, RECALL: 0.0860004, MAP: 0.0274970, MAP_MIN_DEN: 0.0446961, MRR: 0.1831053, NDCG: 0.0889068, F1: 0.0674310, HIT_RATE: 0.3631289, ARHR_ALL_HITS: 0.2226733, NOVELTY: 0.0037951, AVERAGE_POPULARITY: 0.2023227, DIVERSITY_MEAN_INTER_LIST: 0.9394207, DIVERSITY_HERFINDAHL: 0.9939398, COVERAGE_ITEM: 0.1812786, COVERAGE_ITEM_HIT: 0.0542406, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3547287, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0218170, SHANNON_ENTROPY: 9.1072043, RATIO_DIVERSITY_HERFINDAHL: 0.9942676, RATIO_DIVERSITY_GINI: 0.0489770, RATIO_SHANNON_ENTROPY: 0.6749112, RATIO_AVERAGE_POPULARITY: 3.9711973, RATIO_NOVELTY: 0.2477931,
#
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 72.2783
# Function value obtained: -0.0275
# Current minimum: -0.0278
# Iteration No: 21 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1766, 'alpha': 52.34297659758198, 'beta': 25.171668115696594}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.65 sec. Users per second: 682
# SearchBayesianSkopt: Config 20 is suboptimal. Config: {'topK': 1766, 'alpha': 52.34297659758198, 'beta': 25.171668115696594} - results: PRECISION: 0.0526312, PRECISION_RECALL_MIN_DEN: 0.0882033, RECALL: 0.0826343, MAP: 0.0260820, MAP_MIN_DEN: 0.0427780, MRR: 0.1769168, NDCG: 0.0852377, F1: 0.0643053, HIT_RATE: 0.3520877, ARHR_ALL_HITS: 0.2132626, NOVELTY: 0.0037610, AVERAGE_POPULARITY: 0.2094428, DIVERSITY_MEAN_INTER_LIST: 0.9309276, DIVERSITY_HERFINDAHL: 0.9930905, COVERAGE_ITEM: 0.2080592, COVERAGE_ITEM_HIT: 0.0502360, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3439429, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0197489, SHANNON_ENTROPY: 8.8741416, RATIO_DIVERSITY_HERFINDAHL: 0.9934180, RATIO_DIVERSITY_GINI: 0.0443344, RATIO_SHANNON_ENTROPY: 0.6576395, RATIO_AVERAGE_POPULARITY: 4.1109498, RATIO_NOVELTY: 0.2455708,
#
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 72.0650
# Function value obtained: -0.0261
# Current minimum: -0.0278
# Iteration No: 22 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1506, 'alpha': 3.1610421880909576, 'beta': 18.028946571822754}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.03 sec. Users per second: 689
# SearchBayesianSkopt: Config 21 is suboptimal. Config: {'topK': 1506, 'alpha': 3.1610421880909576, 'beta': 18.028946571822754} - results: PRECISION: 0.0485565, PRECISION_RECALL_MIN_DEN: 0.0814158, RECALL: 0.0762262, MAP: 0.0237353, MAP_MIN_DEN: 0.0390387, MRR: 0.1634475, NDCG: 0.0783636, F1: 0.0593236, HIT_RATE: 0.3316038, ARHR_ALL_HITS: 0.1955143, NOVELTY: 0.0037433, AVERAGE_POPULARITY: 0.2121549, DIVERSITY_MEAN_INTER_LIST: 0.9222921, DIVERSITY_HERFINDAHL: 0.9922269, COVERAGE_ITEM: 0.2636585, COVERAGE_ITEM_HIT: 0.0467320, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3239328, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0185930, SHANNON_ENTROPY: 8.6476815, RATIO_DIVERSITY_HERFINDAHL: 0.9925542, RATIO_DIVERSITY_GINI: 0.0417394, RATIO_SHANNON_ENTROPY: 0.6408571, RATIO_AVERAGE_POPULARITY: 4.1641833, RATIO_NOVELTY: 0.2444152,
#
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 71.5693
# Function value obtained: -0.0237
# Current minimum: -0.0278
# Iteration No: 23 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 2366, 'alpha': 78.91381855535418, 'beta': 21.77152523761009}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.29 sec. Users per second: 686
# SearchBayesianSkopt: Config 22 is suboptimal. Config: {'topK': 2366, 'alpha': 78.91381855535418, 'beta': 21.77152523761009} - results: PRECISION: 0.0539492, PRECISION_RECALL_MIN_DEN: 0.0901208, RECALL: 0.0843799, MAP: 0.0267290, MAP_MIN_DEN: 0.0436951, MRR: 0.1796512, NDCG: 0.0869965, F1: 0.0658174, HIT_RATE: 0.3577682, ARHR_ALL_HITS: 0.2175299, NOVELTY: 0.0037723, AVERAGE_POPULARITY: 0.2074335, DIVERSITY_MEAN_INTER_LIST: 0.9341262, DIVERSITY_HERFINDAHL: 0.9934103, COVERAGE_ITEM: 0.1956164, COVERAGE_ITEM_HIT: 0.0519880, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3494919, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0205120, SHANNON_ENTROPY: 8.9653064, RATIO_DIVERSITY_HERFINDAHL: 0.9937380, RATIO_DIVERSITY_GINI: 0.0460473, RATIO_SHANNON_ENTROPY: 0.6643955, RATIO_AVERAGE_POPULARITY: 4.0715113, RATIO_NOVELTY: 0.2463059,
#
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 71.8927
# Function value obtained: -0.0267
# Current minimum: -0.0278
# Iteration No: 24 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1340, 'alpha': 7.379527804947651, 'beta': 7.786994846489981}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.10 sec. Users per second: 688
# SearchBayesianSkopt: Config 23 is suboptimal. Config: {'topK': 1340, 'alpha': 7.379527804947651, 'beta': 7.786994846489981} - results: PRECISION: 0.0507623, PRECISION_RECALL_MIN_DEN: 0.0852552, RECALL: 0.0798814, MAP: 0.0250175, MAP_MIN_DEN: 0.0411657, MRR: 0.1712658, NDCG: 0.0822614, F1: 0.0620767, HIT_RATE: 0.3431614, ARHR_ALL_HITS: 0.2055203, NOVELTY: 0.0037506, AVERAGE_POPULARITY: 0.2110715, DIVERSITY_MEAN_INTER_LIST: 0.9269098, DIVERSITY_HERFINDAHL: 0.9926887, COVERAGE_ITEM: 0.2313001, COVERAGE_ITEM_HIT: 0.0488773, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3352230, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0190094, SHANNON_ENTROPY: 8.7633931, RATIO_DIVERSITY_HERFINDAHL: 0.9930161, RATIO_DIVERSITY_GINI: 0.0426742, RATIO_SHANNON_ENTROPY: 0.6494322, RATIO_AVERAGE_POPULARITY: 4.1429182, RATIO_NOVELTY: 0.2448921,
#
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 71.9732
# Function value obtained: -0.0250
# Current minimum: -0.0278
# Iteration No: 25 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1413, 'alpha': 32.46366561022679, 'beta': 15.286146437181099}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 60.00 sec. Users per second: 678
# SearchBayesianSkopt: Config 24 is suboptimal. Config: {'topK': 1413, 'alpha': 32.46366561022679, 'beta': 15.286146437181099} - results: PRECISION: 0.0526779, PRECISION_RECALL_MIN_DEN: 0.0882606, RECALL: 0.0826789, MAP: 0.0261046, MAP_MIN_DEN: 0.0428001, MRR: 0.1769700, NDCG: 0.0852820, F1: 0.0643537, HIT_RATE: 0.3520877, ARHR_ALL_HITS: 0.2133830, NOVELTY: 0.0037623, AVERAGE_POPULARITY: 0.2088601, DIVERSITY_MEAN_INTER_LIST: 0.9313914, DIVERSITY_HERFINDAHL: 0.9931368, COVERAGE_ITEM: 0.2075944, COVERAGE_ITEM_HIT: 0.0502717, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3439429, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0197985, SHANNON_ENTROPY: 8.8809558, RATIO_DIVERSITY_HERFINDAHL: 0.9934644, RATIO_DIVERSITY_GINI: 0.0444457, RATIO_SHANNON_ENTROPY: 0.6581445, RATIO_AVERAGE_POPULARITY: 4.0995129, RATIO_NOVELTY: 0.2456542,
#
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken: 72.4019
# Function value obtained: -0.0261
# Current minimum: -0.0278
# Iteration No: 26 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 434, 'alpha': 8.749007218074647, 'beta': 7.869293565882128}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 1.00 min. Users per second: 677
# SearchBayesianSkopt: Config 25 is suboptimal. Config: {'topK': 434, 'alpha': 8.749007218074647, 'beta': 7.869293565882128} - results: PRECISION: 0.0510279, PRECISION_RECALL_MIN_DEN: 0.0856698, RECALL: 0.0802718, MAP: 0.0251906, MAP_MIN_DEN: 0.0414074, MRR: 0.1723156, NDCG: 0.0827203, F1: 0.0623932, HIT_RATE: 0.3446122, ARHR_ALL_HITS: 0.2068668, NOVELTY: 0.0037607, AVERAGE_POPULARITY: 0.2070845, DIVERSITY_MEAN_INTER_LIST: 0.9303116, DIVERSITY_HERFINDAHL: 0.9930289, COVERAGE_ITEM: 0.2273670, COVERAGE_ITEM_HIT: 0.0492706, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3366403, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0193676, SHANNON_ENTROPY: 8.8175008, RATIO_DIVERSITY_HERFINDAHL: 0.9933564, RATIO_DIVERSITY_GINI: 0.0434783, RATIO_SHANNON_ENTROPY: 0.6534420, RATIO_AVERAGE_POPULARITY: 4.0646610, RATIO_NOVELTY: 0.2455511,
#
# Iteration No: 26 ended. Evaluation done at random point.
# Time taken: 72.5487
# Function value obtained: -0.0252
# Current minimum: -0.0278
# Iteration No: 27 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 224, 'alpha': 32.833781880462894, 'beta': 5.849529251245079}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 50.15 sec. Users per second: 811
# SearchBayesianSkopt: Config 26 is suboptimal. Config: {'topK': 224, 'alpha': 32.833781880462894, 'beta': 5.849529251245079} - results: PRECISION: 0.0541115, PRECISION_RECALL_MIN_DEN: 0.0898457, RECALL: 0.0840135, MAP: 0.0269261, MAP_MIN_DEN: 0.0438574, MRR: 0.1801260, NDCG: 0.0871198, F1: 0.0658259, HIT_RATE: 0.3566862, ARHR_ALL_HITS: 0.2186228, NOVELTY: 0.0038624, AVERAGE_POPULARITY: 0.1744406, DIVERSITY_MEAN_INTER_LIST: 0.9556406, DIVERSITY_HERFINDAHL: 0.9955617, COVERAGE_ITEM: 0.1942935, COVERAGE_ITEM_HIT: 0.0553132, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3484350, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0238265, SHANNON_ENTROPY: 9.3406348, RATIO_DIVERSITY_HERFINDAHL: 0.9958901, RATIO_DIVERSITY_GINI: 0.0534880, RATIO_SHANNON_ENTROPY: 0.6922101, RATIO_AVERAGE_POPULARITY: 3.4239265, RATIO_NOVELTY: 0.2521876,
#
# Iteration No: 27 ended. Evaluation done at random point.
# Time taken: 59.7873
# Function value obtained: -0.0269
# Current minimum: -0.0278
# Iteration No: 28 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 2470, 'alpha': 76.06334238572306, 'beta': 0.6750109116677251}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.55 sec. Users per second: 683
# SearchBayesianSkopt: New best config found. Config 27: {'topK': 2470, 'alpha': 76.06334238572306, 'beta': 0.6750109116677251} - results: PRECISION: 0.0561353, PRECISION_RECALL_MIN_DEN: 0.0926534, RECALL: 0.0864680, MAP: 0.0278457, MAP_MIN_DEN: 0.0450490, MRR: 0.1842420, NDCG: 0.0895949, F1: 0.0680757, HIT_RATE: 0.3640142, ARHR_ALL_HITS: 0.2247169, NOVELTY: 0.0038245, AVERAGE_POPULARITY: 0.1966142, DIVERSITY_MEAN_INTER_LIST: 0.9440052, DIVERSITY_HERFINDAHL: 0.9943982, COVERAGE_ITEM: 0.1726259, COVERAGE_ITEM_HIT: 0.0564931, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3555935, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0234490, SHANNON_ENTROPY: 9.2558209, RATIO_DIVERSITY_HERFINDAHL: 0.9947262, RATIO_DIVERSITY_GINI: 0.0526406, RATIO_SHANNON_ENTROPY: 0.6859248, RATIO_AVERAGE_POPULARITY: 3.8591509, RATIO_NOVELTY: 0.2497173,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNSimilarityHybridRecommender
#
# ItemKNNSimilarityHybridRecommender: Saving model in file 'result_experiments/ItemKNNSimilarityHybridRecommender_best_model'
# ItemKNNSimilarityHybridRecommender: Saving complete
# Iteration No: 28 ended. Evaluation done at random point.
# Time taken: 80.9049
# Function value obtained: -0.0278
# Current minimum: -0.0278
# Iteration No: 29 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 2305, 'alpha': 68.86367200697971, 'beta': 19.81186362678219}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.15 sec. Users per second: 687
# SearchBayesianSkopt: Config 28 is suboptimal. Config: {'topK': 2305, 'alpha': 68.86367200697971, 'beta': 19.81186362678219} - results: PRECISION: 0.0538312, PRECISION_RECALL_MIN_DEN: 0.0899809, RECALL: 0.0842554, MAP: 0.0266988, MAP_MIN_DEN: 0.0436583, MRR: 0.1795932, NDCG: 0.0868974, F1: 0.0656917, HIT_RATE: 0.3572763, ARHR_ALL_HITS: 0.2173669, NOVELTY: 0.0037715, AVERAGE_POPULARITY: 0.2075609, DIVERSITY_MEAN_INTER_LIST: 0.9339246, DIVERSITY_HERFINDAHL: 0.9933902, COVERAGE_ITEM: 0.1967963, COVERAGE_ITEM_HIT: 0.0518807, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3490115, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0204689, SHANNON_ENTROPY: 8.9592670, RATIO_DIVERSITY_HERFINDAHL: 0.9937178, RATIO_DIVERSITY_GINI: 0.0459506, RATIO_SHANNON_ENTROPY: 0.6639479, RATIO_AVERAGE_POPULARITY: 4.0740118, RATIO_NOVELTY: 0.2462530,
#
# Iteration No: 29 ended. Evaluation done at random point.
# Time taken: 71.5883
# Function value obtained: -0.0267
# Current minimum: -0.0278
# Iteration No: 30 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 402, 'alpha': 43.06271018148858, 'beta': 8.516830141781591}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 58.12 sec. Users per second: 700
# SearchBayesianSkopt: Config 29 is suboptimal. Config: {'topK': 402, 'alpha': 43.06271018148858, 'beta': 8.516830141781591} - results: PRECISION: 0.0542124, PRECISION_RECALL_MIN_DEN: 0.0902702, RECALL: 0.0844646, MAP: 0.0269438, MAP_MIN_DEN: 0.0439242, MRR: 0.1804359, NDCG: 0.0873374, F1: 0.0660387, HIT_RATE: 0.3580387, ARHR_ALL_HITS: 0.2188931, NOVELTY: 0.0038234, AVERAGE_POPULARITY: 0.1857463, DIVERSITY_MEAN_INTER_LIST: 0.9490898, DIVERSITY_HERFINDAHL: 0.9949066, COVERAGE_ITEM: 0.1929705, COVERAGE_ITEM_HIT: 0.0540975, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3497562, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0222361, SHANNON_ENTROPY: 9.1875732, RATIO_DIVERSITY_HERFINDAHL: 0.9952348, RATIO_DIVERSITY_GINI: 0.0499177, RATIO_SHANNON_ENTROPY: 0.6808671, RATIO_AVERAGE_POPULARITY: 3.6458348, RATIO_NOVELTY: 0.2496405,
#
# Iteration No: 30 ended. Evaluation done at random point.
# Time taken: 70.1131
# Function value obtained: -0.0269
# Current minimum: -0.0278
# Iteration No: 31 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 2302, 'alpha': 50.77900977502707, 'beta': 17.959180400233066}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.14 sec. Users per second: 688
# SearchBayesianSkopt: Config 30 is suboptimal. Config: {'topK': 2302, 'alpha': 50.77900977502707, 'beta': 17.959180400233066} - results: PRECISION: 0.0533591, PRECISION_RECALL_MIN_DEN: 0.0892365, RECALL: 0.0835799, MAP: 0.0264720, MAP_MIN_DEN: 0.0433342, MRR: 0.1786000, NDCG: 0.0862565, F1: 0.0651348, HIT_RATE: 0.3551124, ARHR_ALL_HITS: 0.2158227, NOVELTY: 0.0037669, AVERAGE_POPULARITY: 0.2084270, DIVERSITY_MEAN_INTER_LIST: 0.9326787, DIVERSITY_HERFINDAHL: 0.9932656, COVERAGE_ITEM: 0.2004791, COVERAGE_ITEM_HIT: 0.0510584, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3468976, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0201516, SHANNON_ENTROPY: 8.9241994, RATIO_DIVERSITY_HERFINDAHL: 0.9935932, RATIO_DIVERSITY_GINI: 0.0452383, RATIO_SHANNON_ENTROPY: 0.6613492, RATIO_AVERAGE_POPULARITY: 4.0910131, RATIO_NOVELTY: 0.2459545,
#
# Iteration No: 31 ended. Evaluation done at random point.
# Time taken: 71.8409
# Function value obtained: -0.0265
# Current minimum: -0.0278
# Iteration No: 32 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1890, 'alpha': 26.41685223823868, 'beta': 8.832230767614671}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 58.87 sec. Users per second: 691
# SearchBayesianSkopt: Config 31 is suboptimal. Config: {'topK': 1890, 'alpha': 26.41685223823868, 'beta': 8.832230767614671} - results: PRECISION: 0.0534894, PRECISION_RECALL_MIN_DEN: 0.0894448, RECALL: 0.0837696, MAP: 0.0265323, MAP_MIN_DEN: 0.0434176, MRR: 0.1788220, NDCG: 0.0864242, F1: 0.0652895, HIT_RATE: 0.3555058, ARHR_ALL_HITS: 0.2162157, NOVELTY: 0.0037682, AVERAGE_POPULARITY: 0.2081143, DIVERSITY_MEAN_INTER_LIST: 0.9330685, DIVERSITY_HERFINDAHL: 0.9933046, COVERAGE_ITEM: 0.1992634, COVERAGE_ITEM_HIT: 0.0511656, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3472819, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0202390, SHANNON_ENTROPY: 8.9341254, RATIO_DIVERSITY_HERFINDAHL: 0.9936322, RATIO_DIVERSITY_GINI: 0.0454345, RATIO_SHANNON_ENTROPY: 0.6620848, RATIO_AVERAGE_POPULARITY: 4.0848756, RATIO_NOVELTY: 0.2460407,
#
# Iteration No: 32 ended. Evaluation done at random point.
# Time taken: 71.1965
# Function value obtained: -0.0265
# Current minimum: -0.0278
# Iteration No: 33 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 2239, 'alpha': 60.735570355523485, 'beta': 29.661487721701164}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 58.90 sec. Users per second: 690
# SearchBayesianSkopt: Config 32 is suboptimal. Config: {'topK': 2239, 'alpha': 60.735570355523485, 'beta': 29.661487721701164} - results: PRECISION: 0.0525869, PRECISION_RECALL_MIN_DEN: 0.0881619, RECALL: 0.0826002, MAP: 0.0260646, MAP_MIN_DEN: 0.0427562, MRR: 0.1768827, NDCG: 0.0851977, F1: 0.0642619, HIT_RATE: 0.3520386, ARHR_ALL_HITS: 0.2131683, NOVELTY: 0.0037605, AVERAGE_POPULARITY: 0.2096666, DIVERSITY_MEAN_INTER_LIST: 0.9307169, DIVERSITY_HERFINDAHL: 0.9930694, COVERAGE_ITEM: 0.2082380, COVERAGE_ITEM_HIT: 0.0501645, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3438949, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0197159, SHANNON_ENTROPY: 8.8704516, RATIO_DIVERSITY_HERFINDAHL: 0.9933969, RATIO_DIVERSITY_GINI: 0.0442602, RATIO_SHANNON_ENTROPY: 0.6573661, RATIO_AVERAGE_POPULARITY: 4.1153432, RATIO_NOVELTY: 0.2455333,
#
# Iteration No: 33 ended. Evaluation done at random point.
# Time taken: 71.3360
# Function value obtained: -0.0261
# Current minimum: -0.0278
# Iteration No: 34 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 503, 'alpha': 18.40936472063697, 'beta': 24.69957783544701}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.25 sec. Users per second: 686
# SearchBayesianSkopt: Config 33 is suboptimal. Config: {'topK': 503, 'alpha': 18.40936472063697, 'beta': 24.69957783544701} - results: PRECISION: 0.0502680, PRECISION_RECALL_MIN_DEN: 0.0843645, RECALL: 0.0790191, MAP: 0.0247615, MAP_MIN_DEN: 0.0407134, MRR: 0.1697333, NDCG: 0.0814186, F1: 0.0614467, HIT_RATE: 0.3407761, ARHR_ALL_HITS: 0.2035252, NOVELTY: 0.0037536, AVERAGE_POPULARITY: 0.2090933, DIVERSITY_MEAN_INTER_LIST: 0.9275273, DIVERSITY_HERFINDAHL: 0.9927504, COVERAGE_ITEM: 0.2382366, COVERAGE_ITEM_HIT: 0.0484125, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3328929, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0190086, SHANNON_ENTROPY: 8.7573758, RATIO_DIVERSITY_HERFINDAHL: 0.9930779, RATIO_DIVERSITY_GINI: 0.0426723, RATIO_SHANNON_ENTROPY: 0.6489863, RATIO_AVERAGE_POPULARITY: 4.1040900, RATIO_NOVELTY: 0.2450890,
#
# Iteration No: 34 ended. Evaluation done at random point.
# Time taken: 71.3880
# Function value obtained: -0.0248
# Current minimum: -0.0278
# Iteration No: 35 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 2323, 'alpha': 63.284165525198176, 'beta': 10.445062609165449}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 59.34 sec. Users per second: 685
# SearchBayesianSkopt: Config 34 is suboptimal. Config: {'topK': 2323, 'alpha': 63.284165525198176, 'beta': 10.445062609165449} - results: PRECISION: 0.0549255, PRECISION_RECALL_MIN_DEN: 0.0914547, RECALL: 0.0855713, MAP: 0.0272512, MAP_MIN_DEN: 0.0443944, MRR: 0.1820533, NDCG: 0.0883161, F1: 0.0669061, HIT_RATE: 0.3614076, ARHR_ALL_HITS: 0.2210495, NOVELTY: 0.0037844, AVERAGE_POPULARITY: 0.2049229, DIVERSITY_MEAN_INTER_LIST: 0.9370160, DIVERSITY_HERFINDAHL: 0.9936993, COVERAGE_ITEM: 0.1859983, COVERAGE_ITEM_HIT: 0.0535970, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3530472, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0212253, SHANNON_ENTROPY: 9.0459236, RATIO_DIVERSITY_HERFINDAHL: 0.9940270, RATIO_DIVERSITY_GINI: 0.0476486, RATIO_SHANNON_ENTROPY: 0.6703698, RATIO_AVERAGE_POPULARITY: 4.0222342, RATIO_NOVELTY: 0.2470963,
#
# Iteration No: 35 ended. Evaluation done at random point.
# Time taken: 71.6035
# ...
# EvaluatorHoldout: Processed 40666 (100.0%) in 58.28 sec. Users per second: 698
# SearchBayesianSkopt: Config 194 is suboptimal. Config: {'topK': 1179, 'alpha': 43.67798483289472, 'beta': 12.47313084959655} - results: PRECISION: 0.0538140, PRECISION_RECALL_MIN_DEN: 0.0898342, RECALL: 0.0840956, MAP: 0.0266882, MAP_MIN_DEN: 0.0436207, MRR: 0.1794804, NDCG: 0.0868218, F1: 0.0656303, HIT_RATE: 0.3570059, ARHR_ALL_HITS: 0.2172489, NOVELTY: 0.0037747, AVERAGE_POPULARITY: 0.2057419, DIVERSITY_MEAN_INTER_LIST: 0.9352112, DIVERSITY_HERFINDAHL: 0.9935188, COVERAGE_ITEM: 0.1969751, COVERAGE_ITEM_HIT: 0.0519165, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3487473, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0205536, SHANNON_ENTROPY: 8.9723168, RATIO_DIVERSITY_HERFINDAHL: 0.9938465, RATIO_DIVERSITY_GINI: 0.0461406, RATIO_SHANNON_ENTROPY: 0.6649150, RATIO_AVERAGE_POPULARITY: 4.0383086, RATIO_NOVELTY: 0.2464608,
#
# Iteration No: 195 ended. Evaluation done at random point.
# Time taken: 70.6849
# Function value obtained: -0.0267
# Current minimum: -0.0279
# Iteration No: 196 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 732, 'alpha': 56.800215961417464, 'beta': 14.307697055698116}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 58.14 sec. Users per second: 699
# SearchBayesianSkopt: Config 195 is suboptimal. Config: {'topK': 732, 'alpha': 56.800215961417464, 'beta': 14.307697055698116} - results: PRECISION: 0.0540550, PRECISION_RECALL_MIN_DEN: 0.0900535, RECALL: 0.0842782, MAP: 0.0268356, MAP_MIN_DEN: 0.0437771, MRR: 0.1800939, NDCG: 0.0871141, F1: 0.0658650, HIT_RATE: 0.3575468, ARHR_ALL_HITS: 0.2182029, NOVELTY: 0.0037866, AVERAGE_POPULARITY: 0.2005777, DIVERSITY_MEAN_INTER_LIST: 0.9391006, DIVERSITY_HERFINDAHL: 0.9939077, COVERAGE_ITEM: 0.1950086, COVERAGE_ITEM_HIT: 0.0525243, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3492757, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0209743, SHANNON_ENTROPY: 9.0291412, RATIO_DIVERSITY_HERFINDAHL: 0.9942355, RATIO_DIVERSITY_GINI: 0.0470852, RATIO_SHANNON_ENTROPY: 0.6691261, RATIO_AVERAGE_POPULARITY: 3.9369468, RATIO_NOVELTY: 0.2472403,
#
# Iteration No: 196 ended. Evaluation done at random point.
# Time taken: 70.1934
# Function value obtained: -0.0268
# Current minimum: -0.0279
# Iteration No: 197 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 2454, 'alpha': 72.53247907367114, 'beta': 5.764896150553177}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 58.62 sec. Users per second: 694
# SearchBayesianSkopt: Config 196 is suboptimal. Config: {'topK': 2454, 'alpha': 72.53247907367114, 'beta': 5.764896150553177} - results: PRECISION: 0.0557739, PRECISION_RECALL_MIN_DEN: 0.0923920, RECALL: 0.0863391, MAP: 0.0276401, MAP_MIN_DEN: 0.0448678, MRR: 0.1835165, NDCG: 0.0892434, F1: 0.0677695, HIT_RATE: 0.3640388, ARHR_ALL_HITS: 0.2234640, NOVELTY: 0.0038008, AVERAGE_POPULARITY: 0.2016102, DIVERSITY_MEAN_INTER_LIST: 0.9401792, DIVERSITY_HERFINDAHL: 0.9940156, COVERAGE_ITEM: 0.1787400, COVERAGE_ITEM_HIT: 0.0546696, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3556175, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0221802, SHANNON_ENTROPY: 9.1401443, RATIO_DIVERSITY_HERFINDAHL: 0.9943434, RATIO_DIVERSITY_GINI: 0.0497922, RATIO_SHANNON_ENTROPY: 0.6773523, RATIO_AVERAGE_POPULARITY: 3.9572127, RATIO_NOVELTY: 0.2481699,
#
# Iteration No: 197 ended. Evaluation done at random point.
# Time taken: 70.9131
# Function value obtained: -0.0276
# Current minimum: -0.0279
# Iteration No: 198 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 2067, 'alpha': 62.872420539207084, 'beta': 3.038796310276301}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 58.33 sec. Users per second: 697
# SearchBayesianSkopt: Config 197 is suboptimal. Config: {'topK': 2067, 'alpha': 62.872420539207084, 'beta': 3.038796310276301} - results: PRECISION: 0.0559608, PRECISION_RECALL_MIN_DEN: 0.0925371, RECALL: 0.0864192, MAP: 0.0277727, MAP_MIN_DEN: 0.0449940, MRR: 0.1840964, NDCG: 0.0894787, F1: 0.0679321, HIT_RATE: 0.3639896, ARHR_ALL_HITS: 0.2243530, NOVELTY: 0.0038101, AVERAGE_POPULARITY: 0.1995538, DIVERSITY_MEAN_INTER_LIST: 0.9418574, DIVERSITY_HERFINDAHL: 0.9941834, COVERAGE_ITEM: 0.1757723, COVERAGE_ITEM_HIT: 0.0550272, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3555694, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0226849, SHANNON_ENTROPY: 9.1875156, RATIO_DIVERSITY_HERFINDAHL: 0.9945113, RATIO_DIVERSITY_GINI: 0.0509254, RATIO_SHANNON_ENTROPY: 0.6808628, RATIO_AVERAGE_POPULARITY: 3.9168499, RATIO_NOVELTY: 0.2487753,
#
# Iteration No: 198 ended. Evaluation done at random point.
# Time taken: 70.5529
# Function value obtained: -0.0278
# Current minimum: -0.0279
# Iteration No: 199 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 787, 'alpha': 55.46852656046989, 'beta': 4.899137546862954}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 58.61 sec. Users per second: 694
# SearchBayesianSkopt: Config 198 is suboptimal. Config: {'topK': 787, 'alpha': 55.46852656046989, 'beta': 4.899137546862954} - results: PRECISION: 0.0556017, PRECISION_RECALL_MIN_DEN: 0.0921198, RECALL: 0.0860944, MAP: 0.0275928, MAP_MIN_DEN: 0.0447816, MRR: 0.1832430, NDCG: 0.0890283, F1: 0.0675671, HIT_RATE: 0.3629076, ARHR_ALL_HITS: 0.2231324, NOVELTY: 0.0038247, AVERAGE_POPULARITY: 0.1886912, DIVERSITY_MEAN_INTER_LIST: 0.9488972, DIVERSITY_HERFINDAHL: 0.9948874, COVERAGE_ITEM: 0.1821367, COVERAGE_ITEM_HIT: 0.0545624, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3545125, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0227427, SHANNON_ENTROPY: 9.2315919, RATIO_DIVERSITY_HERFINDAHL: 0.9952155, RATIO_DIVERSITY_GINI: 0.0510550, RATIO_SHANNON_ENTROPY: 0.6841292, RATIO_AVERAGE_POPULARITY: 3.7036378, RATIO_NOVELTY: 0.2497286,
#
# Iteration No: 199 ended. Evaluation done at random point.
# Time taken: 71.0033
# Function value obtained: -0.0276
# Current minimum: -0.0279
# Iteration No: 200 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 2025, 'alpha': 38.6551494451513, 'beta': 7.506029524819423}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 58.76 sec. Users per second: 692
# SearchBayesianSkopt: Config 199 is suboptimal. Config: {'topK': 2025, 'alpha': 38.6551494451513, 'beta': 7.506029524819423} - results: PRECISION: 0.0546304, PRECISION_RECALL_MIN_DEN: 0.0909744, RECALL: 0.0851350, MAP: 0.0271245, MAP_MIN_DEN: 0.0442535, MRR: 0.1815197, NDCG: 0.0879704, F1: 0.0665538, HIT_RATE: 0.3601780, ARHR_ALL_HITS: 0.2202258, NOVELTY: 0.0037804, AVERAGE_POPULARITY: 0.2057083, DIVERSITY_MEAN_INTER_LIST: 0.9361677, DIVERSITY_HERFINDAHL: 0.9936145, COVERAGE_ITEM: 0.1885727, COVERAGE_ITEM_HIT: 0.0531679, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3518461, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0210039, SHANNON_ENTROPY: 9.0213171, RATIO_DIVERSITY_HERFINDAHL: 0.9939422, RATIO_DIVERSITY_GINI: 0.0471515, RATIO_SHANNON_ENTROPY: 0.6685463, RATIO_AVERAGE_POPULARITY: 4.0376501, RATIO_NOVELTY: 0.2468377,
#
# Iteration No: 200 ended. Evaluation done at random point.
# Time taken: 70.9737
# Function value obtained: -0.0271
# Current minimum: -0.0279
# Iteration No: 201 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1726, 'alpha': 62.52494813872887, 'beta': 18.522082536246547}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 58.83 sec. Users per second: 691
# SearchBayesianSkopt: Config 200 is suboptimal. Config: {'topK': 1726, 'alpha': 62.52494813872887, 'beta': 18.522082536246547} - results: PRECISION: 0.0537624, PRECISION_RECALL_MIN_DEN: 0.0898650, RECALL: 0.0841539, MAP: 0.0266754, MAP_MIN_DEN: 0.0436196, MRR: 0.1795150, NDCG: 0.0868155, F1: 0.0656096, HIT_RATE: 0.3570059, ARHR_ALL_HITS: 0.2172226, NOVELTY: 0.0037713, AVERAGE_POPULARITY: 0.2074408, DIVERSITY_MEAN_INTER_LIST: 0.9339107, DIVERSITY_HERFINDAHL: 0.9933888, COVERAGE_ITEM: 0.1973327, COVERAGE_ITEM_HIT: 0.0518092, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3487473, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0204348, SHANNON_ENTROPY: 8.9559556, RATIO_DIVERSITY_HERFINDAHL: 0.9937164, RATIO_DIVERSITY_GINI: 0.0458740, RATIO_SHANNON_ENTROPY: 0.6637025, RATIO_AVERAGE_POPULARITY: 4.0716560, RATIO_NOVELTY: 0.2462390,
#
# Iteration No: 201 ended. Evaluation done at random point.
# Time taken: 71.1213
# Function value obtained: -0.0267
# Current minimum: -0.0279
# Iteration No: 202 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 454, 'alpha': 42.09402308432013, 'beta': 28.62457743102411}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_26/678308104.py in <module>
#       7                        output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
#       8                        metric_to_optimize = metric_to_optimize,
# ----> 9                        cutoff_to_optimize = cutoff_to_optimize,
#      10                       )
#
# /kaggle/working/HyperparameterTuning/SearchBayesianSkopt.py in search(self, recommender_input_args, hyperparameter_search_space, metric_to_optimize, cutoff_to_optimize, n_cases, n_random_starts, output_folder_path, output_file_name_root, save_model, save_metadata, resume_from_saved, recommender_input_args_last_test, evaluate_on_test, max_total_time, terminate_on_memory_error)
#     356                                           kappa=self.kappa,
#     357                                           noise=self.noise,
# --> 358                                           n_jobs=self.n_jobs)
#     359
#     360         except ValueError as e:
#
# /opt/conda/lib/python3.7/site-packages/skopt/optimizer/gp.py in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     266         n_restarts_optimizer=n_restarts_optimizer,
#     267         x0=x0, y0=y0, random_state=rng, verbose=verbose,
# --> 268         callback=callback, n_jobs=n_jobs, model_queue_size=model_queue_size)
#
# /opt/conda/lib/python3.7/site-packages/skopt/optimizer/base.py in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     297     for n in range(n_calls):
#     298         next_x = optimizer.ask()
# --> 299         next_y = func(next_x)
#     300         result = optimizer.tell(next_x, next_y)
#     301         result.specs = specs
#
# /kaggle/working/HyperparameterTuning/SearchBayesianSkopt.py in _objective_function_list_input(self, current_fit_hyperparameters_list_of_values)
#     413
#     414         current_fit_hyperparameters_dict = dict(zip(self.hyperparams_names, current_fit_hyperparameters_list_of_values))
# --> 415         result = self._objective_function(current_fit_hyperparameters_dict)
#     416
#     417         # The search can only progress if there is at least a valid config in the initial random start
#
# /kaggle/working/HyperparameterTuning/SearchAbstractClass.py in _objective_function(self, current_fit_hyperparameters_dict)
#     537         except (KeyboardInterrupt, SystemExit) as e:
#     538             # If getting a interrupt, terminate without saving the exception
# --> 539             raise e
#     540
#     541         # Catch exception only if terminate_on_memory_error is True
#
# /kaggle/working/HyperparameterTuning/SearchAbstractClass.py in _objective_function(self, current_fit_hyperparameters_dict)
#     466
#     467             was_already_evaluated_flag, was_already_evaluated_index = self._was_already_evaluated_check(current_fit_hyperparameters_dict)
# --> 468             result_df, recommender_instance = self._evaluate_on_validation(current_fit_hyperparameters_dict, was_already_evaluated_flag, was_already_evaluated_index)
#     469
#     470             result_series = result_df.loc[self.metadata_dict["cutoff_to_optimize"]]
#
# /kaggle/working/HyperparameterTuning/SearchAbstractClass.py in _evaluate_on_validation(self, current_fit_hyperparameters, was_already_evaluated_flag, was_already_evaluated_index)
#     328
#     329             # Evaluate recommender and get results for the first cutoff
# --> 330             result_df, _ = self.evaluator_validation.evaluateRecommender(recommender_instance)
#     331
#     332             evaluation_time = time.time() - start_time
#
# /kaggle/working/Evaluation/Evaluator.py in evaluateRecommender(self, recommender_object)
#     274         self._n_users_evaluated = 0
#     275
# --> 276         results_dict = self._run_evaluation_on_selected_users(recommender_object, self.users_to_evaluate)
#     277
#     278
#
# /kaggle/working/Evaluation/Evaluator.py in _run_evaluation_on_selected_users(self, recommender_object, users_to_evaluate, block_size)
#     479                                                                       remove_top_pop_flag=False,
#     480                                                                       remove_custom_items_flag=self.ignore_items_flag,
# --> 481                                                                       return_scores = True
#     482                                                                      )
#     483
#
# /kaggle/working/Recommenders/BaseRecommender.py in recommend(self, user_id_array, cutoff, remove_seen_flag, items_to_compute, remove_top_pop_flag, remove_custom_items_flag, return_scores)
#     145         # Compute the scores using the model-specific function
#     146         # Vectorize over all users in user_id_array
# --> 147         scores_batch = self._compute_item_score(user_id_array, items_to_compute=items_to_compute)
#     148
#     149
#
# /kaggle/working/Recommenders/BaseSimilarityMatrixRecommender.py in _compute_item_score(self, user_id_array, items_to_compute)
#      88             item_scores[:, items_to_compute] = item_scores_all[:, items_to_compute]
#      89         else:
# ---> 90             item_scores = user_profile_array.dot(self.W_sparse).toarray()
#      91
#      92         return item_scores
#
# /opt/conda/lib/python3.7/site-packages/scipy/sparse/base.py in dot(self, other)
#     357
#     358         """
# --> 359         return self * other
#     360
#     361     def power(self, n, dtype=None):
#
# /opt/conda/lib/python3.7/site-packages/scipy/sparse/base.py in __mul__(self, other)
#     478             if self.shape[1] != other.shape[0]:
#     479                 raise ValueError('dimension mismatch')
# --> 480             return self._mul_sparse_matrix(other)
#     481
#     482         # If it's a list or whatever, treat it like a matrix
#
# /opt/conda/lib/python3.7/site-packages/scipy/sparse/compressed.py in _mul_sparse_matrix(self, other)
#     509                  np.asarray(self.indices, dtype=idx_dtype),
#     510                  np.asarray(other.indptr, dtype=idx_dtype),
# --> 511                  np.asarray(other.indices, dtype=idx_dtype))
#     512
#     513         idx_dtype = get_index_dtype((self.indptr, self.indices,
#
# KeyboardInterrupt:

# %%
from skopt.space import Real, Integer, Categorical
#RP3 beta
#to tuning hyperparam are typical of ML models to drive the learning process

hyperparameters_range_dictionary = {
    "alpha": Real(low=99.17866170336520, high=99.17866170336522, prior='uniform'),
    "beta": Real(low=40.45134622013221, high=40.45134622013223, prior='uniform'),
    "gamma": Real(low=10.962721766445173, high=10.962721766445175, prior='uniform'),
    "theta": Real(low=23.275965228118105, high=23.275965228118107, prior='uniform'),
    "sigma": Real(low=0, high=20, prior='uniform'),
    "epsilon": Real(low=0, high=60, prior='uniform')

}

from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

#create a bayesian optimizer object, we pass the recommender and the evaluator
hyperparameterSearch = SearchBayesianSkopt(recommender_class,
                                         evaluator_validation=evaluator_valid)
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
  
#provide data needed to create instance of model (one on URM_train, the other on URM_all)
recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train, recommender_SLIMElasticNet1, RP3beta_all, EASE_R, recommender_implicitAls, itemknn_cf, slim_bpr],     # For a CBF model simply put [URM_train, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {}
)

# %%
#let's run the bayesian search
hyperparameterSearch.search(recommender_input_args,
                       hyperparameter_search_space = hyperparameters_range_dictionary,
                       n_cases = n_cases,
                       n_random_starts = n_random_starts,
                       save_model = "last",
                       output_folder_path = output_folder_path, # Where to save the results
                       output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
                       metric_to_optimize = metric_to_optimize,
                       cutoff_to_optimize = cutoff_to_optimize,
                      )
