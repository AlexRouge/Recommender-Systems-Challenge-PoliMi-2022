# %%
# !cp -r ../input/recsys-repo/RecSys_Course_AT_PoliMi-master/* ./

# %%
# %config Completer.use_jedi = False
import pandas as pd
import numpy as np
import scipy.sparse as sps
import matplotlib.pyplot as pyplot
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample
#load data_train, matrix of users interaction
URM_path = "/kaggle/input/urm-true-binary/URM_True_Binary.csv"
URM_all_dataframe = pd.read_csv(filepath_or_buffer=URM_path, 
                                sep=",",
                                dtype={0:int, 1:int, 2:float},
                                header=0)
URM_all_dataframe.columns = ["UserID", "ItemID", "Interaction"]
URM_all_dataframe.head()
# Out:
#    UserID  ItemID  Interaction
# 0       0      11          1.0
# 1       0      21          1.0
# 2       0      22          1.0
# 3       0      24          1.0
# 4       0      44          1.0

# %%
userID_unique = URM_all_dataframe["UserID"].unique()
itemID_unique = URM_all_dataframe["ItemID"].unique()

n_users = len(userID_unique)
n_items = len(itemID_unique)
n_interactions = len(URM_all_dataframe)

print ("Number of items\t {}, Number of users\t {}".format(n_items, n_users))
print ("Max ID items\t {}, Max Id users\t {}\n".format(max(itemID_unique), max(userID_unique)))
print ("Average interactions per user {:.2f}".format(n_interactions/n_users))
print ("Average interactions per item {:.2f}\n".format(n_interactions/n_items))

print ("Sparsity {:.2f} %".format((1-float(n_interactions)/(n_items*n_users))*100))
# Out:
# Number of items	 24507, Number of users	 41629
# Max ID items	 24506, Max Id users	 41628
#
# Average interactions per user 37.35
# Average interactions per item 63.44
#
# Sparsity 99.85 %

# %%
URM_all = sps.coo_matrix((URM_all_dataframe["Interaction"].values, 
                          (URM_all_dataframe["UserID"].values, URM_all_dataframe["ItemID"].values)))
URM_all = URM_all.tocsr() # to obtain fast access to rows (users)
URM_all
# Out:
# <41629x24507 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1554640 stored elements in Compressed Sparse Row format>

# %%
URM_train_dataframe = pd.read_csv('/kaggle/input/urm-split/Train_df.csv')
URM_train_dataframe
URM_train = sps.coo_matrix((URM_train_dataframe["Data"].values, 
                          (URM_train_dataframe["UserID"].values, URM_train_dataframe["ItemID"].values)))
URM_train = URM_train.tocsr() # to obtain fast access to rows (users)
URM_train
# Out:
# <41629x24507 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1243712 stored elements in Compressed Sparse Row format>

# %%
URM_val_dataframe = pd.read_csv('/kaggle/input/urm-split/Test_df.csv')
URM_val_dataframe
URM_valid = sps.coo_matrix((URM_val_dataframe["Data"].values, 
                          (URM_val_dataframe["UserID"].values, URM_val_dataframe["ItemID"].values)))
URM_valid = URM_all.tocsr() # to obtain fast access to rows (users)
URM_valid
# Out:
# <41629x24507 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1554640 stored elements in Compressed Sparse Row format>

# %%
from Evaluation.Evaluator import EvaluatorHoldout

#create an evaluator object to evaluate validation set
#we will use it for hyperparameter tuning
evaluator_valid = EvaluatorHoldout(URM_valid, cutoff_list=[10])

# %%
from Recommenders.BaseMatrixFactorizationRecommender import BaseMatrixFactorizationRecommender
from Recommenders.Incremental_Training_Early_Stopping import Incremental_Training_Early_Stopping
from Recommenders.Recommender_utils import check_matrix
import numpy as np


class IALSRecommender(BaseMatrixFactorizationRecommender, Incremental_Training_Early_Stopping):
    """
    Binary/Implicit Alternating Least Squares (IALS)
    See:
    Y. Hu, Y. Koren and C. Volinsky, Collaborative filtering for implicit feedback datasets, ICDM 2008.
    http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.167.5120&rep=rep1&type=pdf
    R. Pan et al., One-class collaborative filtering, ICDM 2008.
    http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.306.4684&rep=rep1&type=pdf
    Factorization model for binary feedback.
    First, splits the feedback matrix R as the element-wise a Preference matrix P and a Confidence matrix C.
    Then computes the decomposition of them into the dot product of two matrices X and Y of latent factors.
    X represent the user latent factors, Y the item latent factors.
    The model is learned by solving the following regularized Least-squares objective function with Stochastic Gradient Descent
    \operatornamewithlimits{argmin}\limits_{x*,y*}\frac{1}{2}\sum_{i,j}{c_{ij}(p_{ij}-x_i^T y_j) + \lambda(\sum_{i}{||x_i||^2} + \sum_{j}{||y_j||^2})}
    """

    RECOMMENDER_NAME = "IALSRecommender"

    AVAILABLE_CONFIDENCE_SCALING = ["linear", "log"]


    def fit(self, epochs = 100,
            num_factors = 20,
            confidence_scaling = "linear",
            alpha = 1.0,
            epsilon = 1.0,
            reg = 1e-3,
            init_mean=0.0,
            init_std=0.1,
            **earlystopping_kwargs):
        """
        :param epochs:
        :param num_factors:
        :param confidence_scaling: supported scaling modes for the observed values: 'linear' or 'log'
        :param alpha: Confidence weight, confidence c = 1 + alpha*r where r is the observed "rating".
        :param reg: Regularization constant.
        :param epsilon: epsilon used in log scaling only
        :param init_mean: mean used to initialize the latent factors
        :param init_std: standard deviation used to initialize the latent factors
        :return:
        """

        if confidence_scaling not in self.AVAILABLE_CONFIDENCE_SCALING:
           raise ValueError("Value for 'confidence_scaling' not recognized. Acceptable values are {}, provided was '{}'".format(self.AVAILABLE_CONFIDENCE_SCALING, confidence_scaling))


        self.num_factors = num_factors
        self.alpha = alpha
        self.epsilon = epsilon
        self.reg = reg

        self.USER_factors = self._init_factors(self.n_users, False)  # don't need values, will compute them
        self.ITEM_factors = self._init_factors(self.n_items)


        self._build_confidence_matrix(confidence_scaling)


        warm_user_mask = np.ediff1d(self.URM_train.indptr) > 0
        warm_item_mask = np.ediff1d(self.URM_train.tocsc().indptr) > 0

        self.warm_users = np.arange(0, self.n_users, dtype=np.int32)[warm_user_mask]
        self.warm_items = np.arange(0, self.n_items, dtype=np.int32)[warm_item_mask]

        self.regularization_diagonal = np.diag(self.reg * np.ones(self.num_factors))

        self._update_best_model()

        self._train_with_early_stopping(epochs,
                                        algorithm_name = self.RECOMMENDER_NAME,
                                        **earlystopping_kwargs)


        self.USER_factors = self.USER_factors_best
        self.ITEM_factors = self.ITEM_factors_best




    def _build_confidence_matrix(self, confidence_scaling):

        if confidence_scaling == 'linear':
            self.C = self._linear_scaling_confidence()
        else:
            self.C = self._log_scaling_confidence()

        self.C_csc= check_matrix(self.C.copy(), format="csc", dtype = np.float32)




    def _linear_scaling_confidence(self):

        C = check_matrix(self.URM_train, format="csr", dtype = np.float32)
        C.data = 1.0 + self.alpha*C.data

        return C

    def _log_scaling_confidence(self):

        C = check_matrix(self.URM_train, format="csr", dtype = np.float32)
        C.data = 1.0 + self.alpha * np.log(1.0 + C.data / self.epsilon)

        return C




    def _prepare_model_for_validation(self):
        pass


    def _update_best_model(self):
        self.USER_factors_best = self.USER_factors.copy()
        self.ITEM_factors_best = self.ITEM_factors.copy()


    def _run_epoch(self, num_epoch):

        # fit user factors
        # VV = n_factors x n_factors
        VV = self.ITEM_factors.T.dot(self.ITEM_factors)

        for user_id in self.warm_users:
            # get (positive i.e. non-zero scored) items for user

            start_pos = self.C.indptr[user_id]
            end_pos = self.C.indptr[user_id + 1]

            user_profile = self.C.indices[start_pos:end_pos]
            user_confidence = self.C.data[start_pos:end_pos]

            self.USER_factors[user_id, :] = self._update_row(user_profile, user_confidence, self.ITEM_factors, VV)

        # fit item factors
        # UU = n_factors x n_factors
        UU = self.USER_factors.T.dot(self.USER_factors)

        for item_id in self.warm_items:

            start_pos = self.C_csc.indptr[item_id]
            end_pos = self.C_csc.indptr[item_id + 1]

            item_profile = self.C_csc.indices[start_pos:end_pos]
            item_confidence = self.C_csc.data[start_pos:end_pos]

            self.ITEM_factors[item_id, :] = self._update_row(item_profile, item_confidence, self.USER_factors, UU)



    def _update_row(self, interaction_profile, interaction_confidence, Y, YtY):
        """
        Update latent factors for a single user or item.
        Y = |n_interactions|x|n_factors|
        YtY =   |n_factors|x|n_factors|
        """

        # Latent factors ony of item/users for which an interaction exists in the interaction profile
        Y_interactions = Y[interaction_profile, :]

        # Following the notation of the original paper we report the update rule for the Item factors (User factors are identical):
        # Y are the item factors |n_items|x|n_factors|
        # Cu is a diagonal matrix |n_interactions|x|n_interactions| with the user confidence for the observed items
        # p(u) is a boolean vectors indexing only observed items. Here it will disappear as we already extract only the observed latent factors
        #       however, it will have an impact in the dimensions of the matrix, since it transforms Cu from a diagonal matrix to a row vector of 1 row and |n_interactions| columns
        # (Yt*Cu*Y + reg*I)^-1 * Yt*Cu*profile
        # which can be decomposed as
        # (YtY + Yt*(Cu-I)*Y + reg*I)^-1 * Yt*Cu*p(u)

        # A = (|n_interactions|x|n_factors|) dot (|n_interactions|x|n_interactions| ) dot (|n_interactions|x|n_factors| )
        #   = |n_factors|x|n_factors|
        # A_slow = Y_interactions.T.dot(np.diag(interaction_confidence - 1)).dot(Y_interactions)

        # if v = diag(|n_interactions|) and k = |n_interactions|x|n_factors|
        # computing np.diag(v).dot(k) will be SLOW
        # we use an equivalent formulation (v * k.T).T which is much faster
        A = Y_interactions.T.dot(((interaction_confidence - 1) * Y_interactions.T).T)

        B = YtY + A + self.regularization_diagonal

        return np.dot(np.linalg.inv(B), Y_interactions.T.dot(interaction_confidence))


    def _init_factors(self, num_factors, assign_values=True):

        if assign_values:
            return self.num_factors**-0.5*np.random.random_sample((num_factors, self.num_factors))

        else:
            return np.empty((num_factors, self.num_factors))

# %%
recommender_class = IALSRecommender

# %%
import os

output_folder_path = "result_experiments/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 20
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from skopt.space import Real, Integer, Categorical
#MF IALS is machine learning-based matrix factorization technique
#the tuning hyperparam are typical of ML models to drive the learning process

hyperparameters_range_dictionary = {

}

# %%
#We also setup the early stopping 
earlystopping_keywargs = {"validation_every_n": 15,
                          "stop_on_validation": True,
                          "evaluator_object": evaluator_valid,
                          "lower_validations_allowed": 5,
                          "validation_metric": metric_to_optimize,
                          }

# %%
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

#create a bayesian optimizer object, we pass the recommender and the evaluator
hyperparameterSearch = SearchBayesianSkopt(recommender_class,
                                         evaluator_validation=evaluator_valid)
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
  
#provide data needed to create instance of model (one on URM_train, the other on URM_all)
recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train],     # For a CBF model simply put [URM_train, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = earlystopping_keywargs
)

# %%
recommender_input_args_last_test = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_all],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = earlystopping_keywargs
)

# %%
#let's run the bayesian search
hyperparameterSearch.search(recommender_input_args,
                       recommender_input_args_last_test = recommender_input_args_last_test,
                       hyperparameter_search_space = hyperparameters_range_dictionary,
                       n_cases = n_cases,
                       n_random_starts = n_random_starts,
                       save_model = "last",
                       output_folder_path = output_folder_path, # Where to save the results
                       output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
                       metric_to_optimize = metric_to_optimize,
                       cutoff_to_optimize = cutoff_to_optimize,
                      )
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 47, 'confidence_scaling': 'log', 'alpha': 0.30370525365156464, 'epsilon': 1.0177549006261184, 'reg': 0.02087477878774013}
# IALSRecommender: Epoch 1 of 100. Elapsed time 18.97 sec
# IALSRecommender: Epoch 2 of 100. Elapsed time 37.82 sec
# IALSRecommender: Epoch 3 of 100. Elapsed time 55.51 sec
# IALSRecommender: Epoch 4 of 100. Elapsed time 1.24 min
# IALSRecommender: Epoch 5 of 100. Elapsed time 1.53 min
# IALSRecommender: Epoch 6 of 100. Elapsed time 1.85 min
# IALSRecommender: Epoch 7 of 100. Elapsed time 2.14 min
# IALSRecommender: Epoch 8 of 100. Elapsed time 2.46 min
# IALSRecommender: Epoch 9 of 100. Elapsed time 2.78 min
# IALSRecommender: Epoch 10 of 100. Elapsed time 3.07 min
# IALSRecommender: Epoch 11 of 100. Elapsed time 3.38 min
# IALSRecommender: Epoch 12 of 100. Elapsed time 3.68 min
# IALSRecommender: Epoch 13 of 100. Elapsed time 4.00 min
# IALSRecommender: Epoch 14 of 100. Elapsed time 4.29 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 41629 (100.0%) in 40.14 sec. Users per second: 1037
# IALSRecommender: CUTOFF: 10 - PRECISION: 0.0425160, PRECISION_RECALL_MIN_DEN: 0.0425160, RECALL: 0.0095787, MAP: 0.0201392, MAP_MIN_DEN: 0.0201392, MRR: 0.1349148, NDCG: 0.0492995, F1: 0.0156349, HIT_RATE: 0.2848735, ARHR_ALL_HITS: 0.1632825, NOVELTY: 0.0041973, AVERAGE_POPULARITY: 0.1467679, DIVERSITY_MEAN_INTER_LIST: 0.9415519, DIVERSITY_HERFINDAHL: 0.9941529, COVERAGE_ITEM: 0.0206472, COVERAGE_ITEM_HIT: 0.0169339, ITEMS_IN_GT: 1.0000000, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2848735, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0066667, SHANNON_ENTROPY: 7.7688411, RATIO_DIVERSITY_HERFINDAHL: 0.9944809, RATIO_DIVERSITY_GINI: 0.0131262, RATIO_SHANNON_ENTROPY: 0.5757477, RATIO_AVERAGE_POPULARITY: 2.8947084, RATIO_NOVELTY: 0.2551622,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 15 of 100. Elapsed time 5.27 min
# IALSRecommender: Epoch 16 of 100. Elapsed time 5.58 min
# IALSRecommender: Epoch 17 of 100. Elapsed time 5.87 min
# IALSRecommender: Epoch 18 of 100. Elapsed time 6.19 min
# IALSRecommender: Epoch 19 of 100. Elapsed time 6.50 min
# IALSRecommender: Epoch 20 of 100. Elapsed time 6.80 min
# IALSRecommender: Epoch 21 of 100. Elapsed time 7.11 min
# IALSRecommender: Epoch 22 of 100. Elapsed time 7.40 min
# IALSRecommender: Epoch 23 of 100. Elapsed time 7.71 min
# IALSRecommender: Epoch 24 of 100. Elapsed time 8.01 min
# IALSRecommender: Epoch 25 of 100. Elapsed time 8.32 min
# IALSRecommender: Epoch 26 of 100. Elapsed time 8.63 min
# IALSRecommender: Epoch 27 of 100. Elapsed time 8.92 min
# IALSRecommender: Epoch 28 of 100. Elapsed time 9.23 min
# IALSRecommender: Epoch 29 of 100. Elapsed time 9.52 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 41629 (100.0%) in 39.94 sec. Users per second: 1042
# IALSRecommender: CUTOFF: 10 - PRECISION: 0.0425401, PRECISION_RECALL_MIN_DEN: 0.0425401, RECALL: 0.0095907, MAP: 0.0201562, MAP_MIN_DEN: 0.0201562, MRR: 0.1350044, NDCG: 0.0493369, F1: 0.0156526, HIT_RATE: 0.2853059, ARHR_ALL_HITS: 0.1633694, NOVELTY: 0.0042035, AVERAGE_POPULARITY: 0.1451584, DIVERSITY_MEAN_INTER_LIST: 0.9428346, DIVERSITY_HERFINDAHL: 0.9942812, COVERAGE_ITEM: 0.0206880, COVERAGE_ITEM_HIT: 0.0168523, ITEMS_IN_GT: 1.0000000, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2853059, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0067712, SHANNON_ENTROPY: 7.7901871, RATIO_DIVERSITY_HERFINDAHL: 0.9946092, RATIO_DIVERSITY_GINI: 0.0133318, RATIO_SHANNON_ENTROPY: 0.5773297, RATIO_AVERAGE_POPULARITY: 2.8629640, RATIO_NOVELTY: 0.2555345,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 30 of 100. Elapsed time 10.50 min
# IALSRecommender: Epoch 31 of 100. Elapsed time 10.82 min
# IALSRecommender: Epoch 32 of 100. Elapsed time 11.10 min
# IALSRecommender: Epoch 33 of 100. Elapsed time 11.42 min
# IALSRecommender: Epoch 34 of 100. Elapsed time 11.71 min
# IALSRecommender: Epoch 35 of 100. Elapsed time 12.02 min
# IALSRecommender: Epoch 36 of 100. Elapsed time 12.33 min
# IALSRecommender: Epoch 37 of 100. Elapsed time 12.62 min
# IALSRecommender: Epoch 38 of 100. Elapsed time 12.94 min
# IALSRecommender: Epoch 39 of 100. Elapsed time 13.22 min
# IALSRecommender: Epoch 40 of 100. Elapsed time 13.54 min
# IALSRecommender: Epoch 41 of 100. Elapsed time 13.83 min
# IALSRecommender: Epoch 42 of 100. Elapsed time 14.17 min
# IALSRecommender: Epoch 43 of 100. Elapsed time 14.49 min
# IALSRecommender: Epoch 44 of 100. Elapsed time 14.81 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 41629 (100.0%) in 46.21 sec. Users per second: 901
# IALSRecommender: CUTOFF: 10 - PRECISION: 0.0426265, PRECISION_RECALL_MIN_DEN: 0.0426265, RECALL: 0.0096088, MAP: 0.0202145, MAP_MIN_DEN: 0.0202145, MRR: 0.1354404, NDCG: 0.0494616, F1: 0.0156824, HIT_RATE: 0.2855461, ARHR_ALL_HITS: 0.1638543, NOVELTY: 0.0042053, AVERAGE_POPULARITY: 0.1446641, DIVERSITY_MEAN_INTER_LIST: 0.9430996, DIVERSITY_HERFINDAHL: 0.9943077, COVERAGE_ITEM: 0.0205247, COVERAGE_ITEM_HIT: 0.0167299, ITEMS_IN_GT: 1.0000000, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2855461, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0067925, SHANNON_ENTROPY: 7.7940029, RATIO_DIVERSITY_HERFINDAHL: 0.9946358, RATIO_DIVERSITY_GINI: 0.0133739, RATIO_SHANNON_ENTROPY: 0.5776125, RATIO_AVERAGE_POPULARITY: 2.8532157, RATIO_NOVELTY: 0.2556440,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 45 of 100. Elapsed time 15.96 min
# IALSRecommender: Epoch 46 of 100. Elapsed time 16.34 min
# IALSRecommender: Epoch 47 of 100. Elapsed time 16.75 min
# IALSRecommender: Epoch 48 of 100. Elapsed time 17.17 min
# IALSRecommender: Epoch 49 of 100. Elapsed time 17.54 min
# IALSRecommender: Epoch 50 of 100. Elapsed time 17.94 min
# IALSRecommender: Epoch 51 of 100. Elapsed time 18.34 min
# IALSRecommender: Epoch 52 of 100. Elapsed time 18.75 min
# IALSRecommender: Epoch 53 of 100. Elapsed time 19.12 min
# IALSRecommender: Epoch 54 of 100. Elapsed time 19.52 min
# IALSRecommender: Epoch 55 of 100. Elapsed time 19.93 min
# IALSRecommender: Epoch 56 of 100. Elapsed time 20.33 min
# IALSRecommender: Epoch 57 of 100. Elapsed time 20.70 min
# IALSRecommender: Epoch 58 of 100. Elapsed time 21.09 min
# IALSRecommender: Epoch 59 of 100. Elapsed time 21.48 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 41629 (100.0%) in 45.03 sec. Users per second: 924
# IALSRecommender: CUTOFF: 10 - PRECISION: 0.0425040, PRECISION_RECALL_MIN_DEN: 0.0425040, RECALL: 0.0095865, MAP: 0.0201487, MAP_MIN_DEN: 0.0201487, MRR: 0.1350997, NDCG: 0.0493233, F1: 0.0156445, HIT_RATE: 0.2852819, ARHR_ALL_HITS: 0.1633823, NOVELTY: 0.0042064, AVERAGE_POPULARITY: 0.1443646, DIVERSITY_MEAN_INTER_LIST: 0.9432485, DIVERSITY_HERFINDAHL: 0.9943226, COVERAGE_ITEM: 0.0205656, COVERAGE_ITEM_HIT: 0.0165667, ITEMS_IN_GT: 1.0000000, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2852819, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0068069, SHANNON_ENTROPY: 7.7968943, RATIO_DIVERSITY_HERFINDAHL: 0.9946507, RATIO_DIVERSITY_GINI: 0.0134022, RATIO_SHANNON_ENTROPY: 0.5778268, RATIO_AVERAGE_POPULARITY: 2.8473072, RATIO_NOVELTY: 0.2557161,
#
# IALSRecommender: Epoch 60 of 100. Elapsed time 22.61 min
# IALSRecommender: Epoch 61 of 100. Elapsed time 23.00 min
# IALSRecommender: Epoch 62 of 100. Elapsed time 23.38 min
# IALSRecommender: Epoch 63 of 100. Elapsed time 23.78 min
# IALSRecommender: Epoch 64 of 100. Elapsed time 24.16 min
# IALSRecommender: Epoch 65 of 100. Elapsed time 24.54 min
# IALSRecommender: Epoch 66 of 100. Elapsed time 24.89 min
# IALSRecommender: Epoch 67 of 100. Elapsed time 25.28 min
# IALSRecommender: Epoch 68 of 100. Elapsed time 25.67 min
# IALSRecommender: Epoch 69 of 100. Elapsed time 26.03 min
# IALSRecommender: Epoch 70 of 100. Elapsed time 26.37 min
# IALSRecommender: Epoch 71 of 100. Elapsed time 26.74 min
# IALSRecommender: Epoch 72 of 100. Elapsed time 27.07 min
# IALSRecommender: Epoch 73 of 100. Elapsed time 27.40 min
# IALSRecommender: Epoch 74 of 100. Elapsed time 27.70 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 41629 (100.0%) in 40.66 sec. Users per second: 1024
# IALSRecommender: CUTOFF: 10 - PRECISION: 0.0425016, PRECISION_RECALL_MIN_DEN: 0.0425016, RECALL: 0.0095827, MAP: 0.0201419, MAP_MIN_DEN: 0.0201419, MRR: 0.1350825, NDCG: 0.0493187, F1: 0.0156393, HIT_RATE: 0.2854500, ARHR_ALL_HITS: 0.1633660, NOVELTY: 0.0042068, AVERAGE_POPULARITY: 0.1442390, DIVERSITY_MEAN_INTER_LIST: 0.9432323, DIVERSITY_HERFINDAHL: 0.9943210, COVERAGE_ITEM: 0.0206472, COVERAGE_ITEM_HIT: 0.0166891, ITEMS_IN_GT: 1.0000000, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2854500, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0068051, SHANNON_ENTROPY: 7.7964886, RATIO_DIVERSITY_HERFINDAHL: 0.9946490, RATIO_DIVERSITY_GINI: 0.0133986, RATIO_SHANNON_ENTROPY: 0.5777967, RATIO_AVERAGE_POPULARITY: 2.8448309, RATIO_NOVELTY: 0.2557398,
#
# IALSRecommender: Epoch 75 of 100. Elapsed time 28.70 min
# IALSRecommender: Epoch 76 of 100. Elapsed time 29.04 min
# IALSRecommender: Epoch 77 of 100. Elapsed time 29.37 min
# IALSRecommender: Epoch 78 of 100. Elapsed time 29.67 min
# IALSRecommender: Epoch 79 of 100. Elapsed time 30.00 min
# IALSRecommender: Epoch 80 of 100. Elapsed time 30.29 min
# IALSRecommender: Epoch 81 of 100. Elapsed time 30.61 min
# IALSRecommender: Epoch 82 of 100. Elapsed time 30.92 min
# IALSRecommender: Epoch 83 of 100. Elapsed time 31.22 min
# IALSRecommender: Epoch 84 of 100. Elapsed time 31.55 min
# IALSRecommender: Epoch 85 of 100. Elapsed time 31.84 min
# IALSRecommender: Epoch 86 of 100. Elapsed time 32.20 min
# IALSRecommender: Epoch 87 of 100. Elapsed time 32.57 min
# IALSRecommender: Epoch 88 of 100. Elapsed time 32.88 min
# IALSRecommender: Epoch 89 of 100. Elapsed time 33.23 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 41629 (100.0%) in 43.02 sec. Users per second: 968
# IALSRecommender: CUTOFF: 10 - PRECISION: 0.0424752, PRECISION_RECALL_MIN_DEN: 0.0424752, RECALL: 0.0095737, MAP: 0.0201251, MAP_MIN_DEN: 0.0201251, MRR: 0.1349109, NDCG: 0.0492752, F1: 0.0156255, HIT_RATE: 0.2852098, ARHR_ALL_HITS: 0.1631804, NOVELTY: 0.0042070, AVERAGE_POPULARITY: 0.1441796, DIVERSITY_MEAN_INTER_LIST: 0.9431928, DIVERSITY_HERFINDAHL: 0.9943170, COVERAGE_ITEM: 0.0207288, COVERAGE_ITEM_HIT: 0.0166483, ITEMS_IN_GT: 1.0000000, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2852098, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0068027, SHANNON_ENTROPY: 7.7961437, RATIO_DIVERSITY_HERFINDAHL: 0.9946451, RATIO_DIVERSITY_GINI: 0.0133940, RATIO_SHANNON_ENTROPY: 0.5777711, RATIO_AVERAGE_POPULARITY: 2.8436600, RATIO_NOVELTY: 0.2557499,
#
# IALSRecommender: Epoch 90 of 100. Elapsed time 34.33 min
# IALSRecommender: Epoch 91 of 100. Elapsed time 34.65 min
# IALSRecommender: Epoch 92 of 100. Elapsed time 34.95 min
# IALSRecommender: Epoch 93 of 100. Elapsed time 35.27 min
# IALSRecommender: Epoch 94 of 100. Elapsed time 35.56 min
# IALSRecommender: Epoch 95 of 100. Elapsed time 35.87 min
# IALSRecommender: Epoch 96 of 100. Elapsed time 36.16 min
# IALSRecommender: Epoch 97 of 100. Elapsed time 36.47 min
# IALSRecommender: Epoch 98 of 100. Elapsed time 36.79 min
# IALSRecommender: Epoch 99 of 100. Elapsed time 37.07 min
# IALSRecommender: Epoch 100 of 100. Elapsed time 37.40 min
# IALSRecommender: Terminating at epoch 100. Best value for 'MAP' at epoch 45 is 0.0202. Elapsed time 37.40 min
# EvaluatorHoldout: Processed 41629 (100.0%) in 41.14 sec. Users per second: 1012
# SearchBayesianSkopt: New best config found. Config 0: {'num_factors': 47, 'confidence_scaling': 'log', 'alpha': 0.30370525365156464, 'epsilon': 1.0177549006261184, 'reg': 0.02087477878774013, 'epochs': 45.0} - results: PRECISION: 0.0426265, PRECISION_RECALL_MIN_DEN: 0.0426265, RECALL: 0.0096088, MAP: 0.0202145, MAP_MIN_DEN: 0.0202145, MRR: 0.1354404, NDCG: 0.0494616, F1: 0.0156824, HIT_RATE: 0.2855461, ARHR_ALL_HITS: 0.1638543, NOVELTY: 0.0042053, AVERAGE_POPULARITY: 0.1446641, DIVERSITY_MEAN_INTER_LIST: 0.9430996, DIVERSITY_HERFINDAHL: 0.9943077, COVERAGE_ITEM: 0.0205247, COVERAGE_ITEM_HIT: 0.0167299, ITEMS_IN_GT: 1.0000000, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2855461, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0067925, SHANNON_ENTROPY: 7.7940029, RATIO_DIVERSITY_HERFINDAHL: 0.9946358, RATIO_DIVERSITY_GINI: 0.0133739, RATIO_SHANNON_ENTROPY: 0.5776125, RATIO_AVERAGE_POPULARITY: 2.8532157, RATIO_NOVELTY: 0.2556440,
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 2285.2927
# Function value obtained: -0.0202
# Current minimum: -0.0202
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 34, 'confidence_scaling': 'log', 'alpha': 0.295744688654436, 'epsilon': 4.240937004835804, 'reg': 0.00014094777402626975}
# IALSRecommender: Epoch 1 of 100. Elapsed time 13.76 sec
# IALSRecommender: Epoch 2 of 100. Elapsed time 27.59 sec
# IALSRecommender: Epoch 3 of 100. Elapsed time 43.85 sec
# IALSRecommender: Epoch 4 of 100. Elapsed time 1.03 min
# IALSRecommender: Epoch 5 of 100. Elapsed time 1.33 min
# IALSRecommender: Epoch 6 of 100. Elapsed time 1.61 min
# IALSRecommender: Epoch 7 of 100. Elapsed time 1.89 min
# IALSRecommender: Epoch 8 of 100. Elapsed time 2.17 min
# IALSRecommender: Epoch 9 of 100. Elapsed time 2.46 min
# IALSRecommender: Epoch 10 of 100. Elapsed time 2.74 min
# IALSRecommender: Epoch 11 of 100. Elapsed time 3.02 min
# IALSRecommender: Epoch 12 of 100. Elapsed time 3.29 min
# IALSRecommender: Epoch 13 of 100. Elapsed time 3.53 min
# IALSRecommender: Epoch 14 of 100. Elapsed time 3.75 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 41629 (100.0%) in 39.96 sec. Users per second: 1042
# IALSRecommender: CUTOFF: 10 - PRECISION: 0.0413390, PRECISION_RECALL_MIN_DEN: 0.0413390, RECALL: 0.0093352, MAP: 0.0196807, MAP_MIN_DEN: 0.0196807, MRR: 0.1328649, NDCG: 0.0481613, F1: 0.0152309, HIT_RATE: 0.2802373, ARHR_ALL_HITS: 0.1601119, NOVELTY: 0.0041378, AVERAGE_POPULARITY: 0.1629369, DIVERSITY_MEAN_INTER_LIST: 0.9262233, DIVERSITY_HERFINDAHL: 0.9926201, COVERAGE_ITEM: 0.0166075, COVERAGE_ITEM_HIT: 0.0135880, ITEMS_IN_GT: 1.0000000, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2802373, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0053646, SHANNON_ENTROPY: 7.4544817, RATIO_DIVERSITY_HERFINDAHL: 0.9929476, RATIO_DIVERSITY_GINI: 0.0105624, RATIO_SHANNON_ENTROPY: 0.5524506, RATIO_AVERAGE_POPULARITY: 3.2136094, RATIO_NOVELTY: 0.2515399,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 15 of 100. Elapsed time 4.64 min
# IALSRecommender: Epoch 16 of 100. Elapsed time 4.87 min
# IALSRecommender: Epoch 17 of 100. Elapsed time 5.12 min
# IALSRecommender: Epoch 18 of 100. Elapsed time 5.35 min
# IALSRecommender: Epoch 19 of 100. Elapsed time 5.57 min
# IALSRecommender: Epoch 20 of 100. Elapsed time 5.82 min
# IALSRecommender: Epoch 21 of 100. Elapsed time 6.05 min
# IALSRecommender: Epoch 22 of 100. Elapsed time 6.29 min
# IALSRecommender: Epoch 23 of 100. Elapsed time 6.51 min
# IALSRecommender: Epoch 24 of 100. Elapsed time 6.75 min
# IALSRecommender: Epoch 25 of 100. Elapsed time 6.97 min
# IALSRecommender: Epoch 26 of 100. Elapsed time 7.20 min
# IALSRecommender: Epoch 27 of 100. Elapsed time 7.42 min
# IALSRecommender: Epoch 28 of 100. Elapsed time 7.64 min
# IALSRecommender: Epoch 29 of 100. Elapsed time 7.88 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 41629 (100.0%) in 39.73 sec. Users per second: 1048
# IALSRecommender: CUTOFF: 10 - PRECISION: 0.0415191, PRECISION_RECALL_MIN_DEN: 0.0415207, RECALL: 0.0093613, MAP: 0.0196977, MAP_MIN_DEN: 0.0196979, MRR: 0.1325372, NDCG: 0.0482183, F1: 0.0152779, HIT_RATE: 0.2806697, ARHR_ALL_HITS: 0.1599295, NOVELTY: 0.0041452, AVERAGE_POPULARITY: 0.1607414, DIVERSITY_MEAN_INTER_LIST: 0.9281073, DIVERSITY_HERFINDAHL: 0.9928085, COVERAGE_ITEM: 0.0168931, COVERAGE_ITEM_HIT: 0.0136288, ITEMS_IN_GT: 1.0000000, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2806697, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0054637, SHANNON_ENTROPY: 7.4802049, RATIO_DIVERSITY_HERFINDAHL: 0.9931361, RATIO_DIVERSITY_GINI: 0.0107575, RATIO_SHANNON_ENTROPY: 0.5543569, RATIO_AVERAGE_POPULARITY: 3.1703083, RATIO_NOVELTY: 0.2519938,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 30 of 100. Elapsed time 8.77 min
# IALSRecommender: Epoch 31 of 100. Elapsed time 9.00 min
# IALSRecommender: Epoch 32 of 100. Elapsed time 9.22 min
# IALSRecommender: Epoch 33 of 100. Elapsed time 9.45 min
# IALSRecommender: Epoch 34 of 100. Elapsed time 9.67 min
# IALSRecommender: Epoch 35 of 100. Elapsed time 9.90 min
# IALSRecommender: Epoch 36 of 100. Elapsed time 10.12 min
# IALSRecommender: Epoch 37 of 100. Elapsed time 10.34 min
# IALSRecommender: Epoch 38 of 100. Elapsed time 10.58 min
# IALSRecommender: Epoch 39 of 100. Elapsed time 10.80 min
# IALSRecommender: Epoch 40 of 100. Elapsed time 11.04 min
# IALSRecommender: Epoch 41 of 100. Elapsed time 11.26 min
# IALSRecommender: Epoch 42 of 100. Elapsed time 11.48 min
# IALSRecommender: Epoch 43 of 100. Elapsed time 11.71 min
# IALSRecommender: Epoch 44 of 100. Elapsed time 11.93 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 41629 (100.0%) in 39.72 sec. Users per second: 1048
# IALSRecommender: CUTOFF: 10 - PRECISION: 0.0417113, PRECISION_RECALL_MIN_DEN: 0.0417129, RECALL: 0.0094029, MAP: 0.0197423, MAP_MIN_DEN: 0.0197426, MRR: 0.1327787, NDCG: 0.0483646, F1: 0.0153463, HIT_RATE: 0.2818468, ARHR_ALL_HITS: 0.1602379, NOVELTY: 0.0041474, AVERAGE_POPULARITY: 0.1601566, DIVERSITY_MEAN_INTER_LIST: 0.9285004, DIVERSITY_HERFINDAHL: 0.9928478, COVERAGE_ITEM: 0.0169747, COVERAGE_ITEM_HIT: 0.0137920, ITEMS_IN_GT: 1.0000000, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2818468, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0054910, SHANNON_ENTROPY: 7.4872548, RATIO_DIVERSITY_HERFINDAHL: 0.9931754, RATIO_DIVERSITY_GINI: 0.0108113, RATIO_SHANNON_ENTROPY: 0.5548794, RATIO_AVERAGE_POPULARITY: 3.1587742, RATIO_NOVELTY: 0.2521278,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 45 of 100. Elapsed time 12.84 min
# IALSRecommender: Epoch 46 of 100. Elapsed time 13.08 min
# IALSRecommender: Epoch 47 of 100. Elapsed time 13.30 min
# IALSRecommender: Epoch 48 of 100. Elapsed time 13.53 min
# IALSRecommender: Epoch 49 of 100. Elapsed time 13.76 min
# IALSRecommender: Epoch 50 of 100. Elapsed time 13.99 min
# IALSRecommender: Epoch 51 of 100. Elapsed time 14.23 min
# IALSRecommender: Epoch 52 of 100. Elapsed time 14.45 min
# IALSRecommender: Epoch 53 of 100. Elapsed time 14.68 min
# IALSRecommender: Epoch 54 of 100. Elapsed time 14.90 min
# IALSRecommender: Epoch 55 of 100. Elapsed time 15.12 min
# IALSRecommender: Epoch 56 of 100. Elapsed time 15.40 min
# IALSRecommender: Epoch 57 of 100. Elapsed time 15.68 min
# IALSRecommender: Epoch 58 of 100. Elapsed time 15.97 min
# IALSRecommender: Epoch 59 of 100. Elapsed time 16.24 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 41629 (100.0%) in 44.41 sec. Users per second: 937
# IALSRecommender: CUTOFF: 10 - PRECISION: 0.0418098, PRECISION_RECALL_MIN_DEN: 0.0418114, RECALL: 0.0094241, MAP: 0.0197624, MAP_MIN_DEN: 0.0197626, MRR: 0.1325643, NDCG: 0.0484029, F1: 0.0153811, HIT_RATE: 0.2819669, ARHR_ALL_HITS: 0.1601605, NOVELTY: 0.0041474, AVERAGE_POPULARITY: 0.1601659, DIVERSITY_MEAN_INTER_LIST: 0.9284170, DIVERSITY_HERFINDAHL: 0.9928395, COVERAGE_ITEM: 0.0169747, COVERAGE_ITEM_HIT: 0.0137104, ITEMS_IN_GT: 1.0000000, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2819669, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0054908, SHANNON_ENTROPY: 7.4873429, RATIO_DIVERSITY_HERFINDAHL: 0.9931671, RATIO_DIVERSITY_GINI: 0.0108109, RATIO_SHANNON_ENTROPY: 0.5548859, RATIO_AVERAGE_POPULARITY: 3.1589572, RATIO_NOVELTY: 0.2521292,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 60 of 100. Elapsed time 17.28 min
# IALSRecommender: Epoch 61 of 100. Elapsed time 17.52 min
# IALSRecommender: Epoch 62 of 100. Elapsed time 17.74 min
# IALSRecommender: Epoch 63 of 100. Elapsed time 17.98 min
# IALSRecommender: Epoch 64 of 100. Elapsed time 18.20 min
# IALSRecommender: Epoch 65 of 100. Elapsed time 18.42 min
# IALSRecommender: Epoch 66 of 100. Elapsed time 18.64 min
# IALSRecommender: Epoch 67 of 100. Elapsed time 18.86 min
# IALSRecommender: Epoch 68 of 100. Elapsed time 19.09 min
# IALSRecommender: Epoch 69 of 100. Elapsed time 19.31 min
# IALSRecommender: Epoch 70 of 100. Elapsed time 19.53 min
# IALSRecommender: Epoch 71 of 100. Elapsed time 19.75 min
# IALSRecommender: Epoch 72 of 100. Elapsed time 19.97 min
# IALSRecommender: Epoch 73 of 100. Elapsed time 20.21 min
# IALSRecommender: Epoch 74 of 100. Elapsed time 20.42 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 41629 (100.0%) in 39.69 sec. Users per second: 1049
# IALSRecommender: CUTOFF: 10 - PRECISION: 0.0418122, PRECISION_RECALL_MIN_DEN: 0.0418141, RECALL: 0.0094270, MAP: 0.0197982, MAP_MIN_DEN: 0.0197986, MRR: 0.1328508, NDCG: 0.0484530, F1: 0.0153853, HIT_RATE: 0.2817987, ARHR_ALL_HITS: 0.1604715, NOVELTY: 0.0041475, AVERAGE_POPULARITY: 0.1601812, DIVERSITY_MEAN_INTER_LIST: 0.9284475, DIVERSITY_HERFINDAHL: 0.9928425, COVERAGE_ITEM: 0.0168931, COVERAGE_ITEM_HIT: 0.0136696, ITEMS_IN_GT: 1.0000000, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2817987, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0054933, SHANNON_ENTROPY: 7.4880264, RATIO_DIVERSITY_HERFINDAHL: 0.9931701, RATIO_DIVERSITY_GINI: 0.0108158, RATIO_SHANNON_ENTROPY: 0.5549366, RATIO_AVERAGE_POPULARITY: 3.1592590, RATIO_NOVELTY: 0.2521305,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 75 of 100. Elapsed time 21.32 min
# IALSRecommender: Epoch 76 of 100. Elapsed time 21.55 min
# IALSRecommender: Epoch 77 of 100. Elapsed time 21.78 min
# IALSRecommender: Epoch 78 of 100. Elapsed time 22.00 min
# IALSRecommender: Epoch 79 of 100. Elapsed time 22.23 min
# IALSRecommender: Epoch 80 of 100. Elapsed time 22.45 min
# IALSRecommender: Epoch 81 of 100. Elapsed time 22.69 min
# IALSRecommender: Epoch 82 of 100. Elapsed time 22.91 min
# IALSRecommender: Epoch 83 of 100. Elapsed time 23.13 min
# IALSRecommender: Epoch 84 of 100. Elapsed time 23.36 min
# IALSRecommender: Epoch 85 of 100. Elapsed time 23.58 min
# IALSRecommender: Epoch 86 of 100. Elapsed time 23.82 min
# IALSRecommender: Epoch 87 of 100. Elapsed time 24.04 min
# IALSRecommender: Epoch 88 of 100. Elapsed time 24.26 min
# IALSRecommender: Epoch 89 of 100. Elapsed time 24.49 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 41629 (100.0%) in 39.65 sec. Users per second: 1050
# IALSRecommender: CUTOFF: 10 - PRECISION: 0.0417449, PRECISION_RECALL_MIN_DEN: 0.0417468, RECALL: 0.0094020, MAP: 0.0197638, MAP_MIN_DEN: 0.0197642, MRR: 0.1325170, NDCG: 0.0483560, F1: 0.0153474, HIT_RATE: 0.2812703, ARHR_ALL_HITS: 0.1601061, NOVELTY: 0.0041476, AVERAGE_POPULARITY: 0.1601841, DIVERSITY_MEAN_INTER_LIST: 0.9285513, DIVERSITY_HERFINDAHL: 0.9928529, COVERAGE_ITEM: 0.0168523, COVERAGE_ITEM_HIT: 0.0137512, ITEMS_IN_GT: 1.0000000, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2812703, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0054990, SHANNON_ENTROPY: 7.4892561, RATIO_DIVERSITY_HERFINDAHL: 0.9931805, RATIO_DIVERSITY_GINI: 0.0108270, RATIO_SHANNON_ENTROPY: 0.5550277, RATIO_AVERAGE_POPULARITY: 3.1593157, RATIO_NOVELTY: 0.2521376,
#
# IALSRecommender: Epoch 90 of 100. Elapsed time 25.37 min
# IALSRecommender: Epoch 91 of 100. Elapsed time 25.59 min
# IALSRecommender: Epoch 92 of 100. Elapsed time 25.81 min
# IALSRecommender: Epoch 93 of 100. Elapsed time 26.05 min
# IALSRecommender: Epoch 94 of 100. Elapsed time 26.27 min
# IALSRecommender: Epoch 95 of 100. Elapsed time 26.51 min
# IALSRecommender: Epoch 96 of 100. Elapsed time 26.73 min
# IALSRecommender: Epoch 97 of 100. Elapsed time 26.97 min
# IALSRecommender: Epoch 98 of 100. Elapsed time 27.19 min
# IALSRecommender: Epoch 99 of 100. Elapsed time 27.40 min
# IALSRecommender: Epoch 100 of 100. Elapsed time 27.64 min
# IALSRecommender: Terminating at epoch 100. Best value for 'MAP' at epoch 75 is 0.0198. Elapsed time 27.64 min
# EvaluatorHoldout: Processed 41629 (100.0%) in 39.78 sec. Users per second: 1046
# SearchBayesianSkopt: Config 1 is suboptimal. Config: {'num_factors': 34, 'confidence_scaling': 'log', 'alpha': 0.295744688654436, 'epsilon': 4.240937004835804, 'reg': 0.00014094777402626975, 'epochs': 75.0} - results: PRECISION: 0.0418122, PRECISION_RECALL_MIN_DEN: 0.0418141, RECALL: 0.0094270, MAP: 0.0197982, MAP_MIN_DEN: 0.0197986, MRR: 0.1328508, NDCG: 0.0484530, F1: 0.0153853, HIT_RATE: 0.2817987, ARHR_ALL_HITS: 0.1604715, NOVELTY: 0.0041475, AVERAGE_POPULARITY: 0.1601812, DIVERSITY_MEAN_INTER_LIST: 0.9284475, DIVERSITY_HERFINDAHL: 0.9928425, COVERAGE_ITEM: 0.0168931, COVERAGE_ITEM_HIT: 0.0136696, ITEMS_IN_GT: 1.0000000, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2817987, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0054933, SHANNON_ENTROPY: 7.4880264, RATIO_DIVERSITY_HERFINDAHL: 0.9931701, RATIO_DIVERSITY_GINI: 0.0108158, RATIO_SHANNON_ENTROPY: 0.5549366, RATIO_AVERAGE_POPULARITY: 3.1592590, RATIO_NOVELTY: 0.2521305,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 1698.5507
# Function value obtained: -0.0198
# Current minimum: -0.0202
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'num_factors': 40, 'confidence_scaling': 'log', 'alpha': 0.10815197964327143, 'epsilon': 2.477421354387816, 'reg': 0.3390283968396903}
# IALSRecommender: Epoch 1 of 100. Elapsed time 15.57 sec
# IALSRecommender: Epoch 2 of 100. Elapsed time 29.81 sec
# IALSRecommender: Epoch 3 of 100. Elapsed time 43.96 sec
# IALSRecommender: Epoch 4 of 100. Elapsed time 59.03 sec
# IALSRecommender: Epoch 5 of 100. Elapsed time 1.22 min
# IALSRecommender: Epoch 6 of 100. Elapsed time 1.46 min
# IALSRecommender: Epoch 7 of 100. Elapsed time 1.69 min
# IALSRecommender: Epoch 8 of 100. Elapsed time 1.95 min
# IALSRecommender: Epoch 9 of 100. Elapsed time 2.19 min
# IALSRecommender: Epoch 10 of 100. Elapsed time 2.44 min
# IALSRecommender: Epoch 11 of 100. Elapsed time 2.68 min
# IALSRecommender: Epoch 12 of 100. Elapsed time 2.93 min
# IALSRecommender: Epoch 13 of 100. Elapsed time 3.16 min
# IALSRecommender: Epoch 14 of 100. Elapsed time 3.40 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 41629 (100.0%) in 40.18 sec. Users per second: 1036
# IALSRecommender: CUTOFF: 10 - PRECISION: 0.0406279, PRECISION_RECALL_MIN_DEN: 0.0406282, RECALL: 0.0091516, MAP: 0.0191434, MAP_MIN_DEN: 0.0191434, MRR: 0.1296878, NDCG: 0.0470833, F1: 0.0149383, HIT_RATE: 0.2766341, ARHR_ALL_HITS: 0.1559173, NOVELTY: 0.0041740, AVERAGE_POPULARITY: 0.1520415, DIVERSITY_MEAN_INTER_LIST: 0.9326571, DIVERSITY_HERFINDAHL: 0.9932635, COVERAGE_ITEM: 0.0178724, COVERAGE_ITEM_HIT: 0.0144040, ITEMS_IN_GT: 1.0000000, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2766341, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0058215, SHANNON_ENTROPY: 7.5711509, RATIO_DIVERSITY_HERFINDAHL: 0.9935912, RATIO_DIVERSITY_GINI: 0.0114620, RATIO_SHANNON_ENTROPY: 0.5610969, RATIO_AVERAGE_POPULARITY: 2.9987199, RATIO_NOVELTY: 0.2537419,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 15 of 100. Elapsed time 4.32 min
# IALSRecommender: Epoch 16 of 100. Elapsed time 4.57 min
# IALSRecommender: Epoch 17 of 100. Elapsed time 4.81 min
# IALSRecommender: Epoch 18 of 100. Elapsed time 5.05 min
# IALSRecommender: Epoch 19 of 100. Elapsed time 5.29 min
# IALSRecommender: Epoch 20 of 100. Elapsed time 5.53 min
# IALSRecommender: Epoch 21 of 100. Elapsed time 5.78 min
# IALSRecommender: Epoch 22 of 100. Elapsed time 6.02 min
# IALSRecommender: Epoch 23 of 100. Elapsed time 6.27 min
# IALSRecommender: Epoch 24 of 100. Elapsed time 6.52 min
# IALSRecommender: Epoch 25 of 100. Elapsed time 6.77 min
# IALSRecommender: Epoch 26 of 100. Elapsed time 7.01 min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_27/3362859277.py in <module>
#       9                        output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
#      10                        metric_to_optimize = metric_to_optimize,
# ---> 11                        cutoff_to_optimize = cutoff_to_optimize,
#      12                       )
#
# /kaggle/working/HyperparameterTuning/SearchBayesianSkopt.py in search(self, recommender_input_args, hyperparameter_search_space, metric_to_optimize, cutoff_to_optimize, n_cases, n_random_starts, output_folder_path, output_file_name_root, save_model, save_metadata, resume_from_saved, recommender_input_args_last_test, evaluate_on_test, max_total_time, terminate_on_memory_error)
#     356                                           kappa=self.kappa,
#     357                                           noise=self.noise,
# --> 358                                           n_jobs=self.n_jobs)
#     359
#     360         except ValueError as e:
#
# /opt/conda/lib/python3.7/site-packages/skopt/optimizer/gp.py in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     266         n_restarts_optimizer=n_restarts_optimizer,
#     267         x0=x0, y0=y0, random_state=rng, verbose=verbose,
# --> 268         callback=callback, n_jobs=n_jobs, model_queue_size=model_queue_size)
#
# /opt/conda/lib/python3.7/site-packages/skopt/optimizer/base.py in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     297     for n in range(n_calls):
#     298         next_x = optimizer.ask()
# --> 299         next_y = func(next_x)
#     300         result = optimizer.tell(next_x, next_y)
#     301         result.specs = specs
#
# /kaggle/working/HyperparameterTuning/SearchBayesianSkopt.py in _objective_function_list_input(self, current_fit_hyperparameters_list_of_values)
#     413
#     414         current_fit_hyperparameters_dict = dict(zip(self.hyperparams_names, current_fit_hyperparameters_list_of_values))
# --> 415         result = self._objective_function(current_fit_hyperparameters_dict)
#     416
#     417         # The search can only progress if there is at least a valid config in the initial random start
#
# /kaggle/working/HyperparameterTuning/SearchAbstractClass.py in _objective_function(self, current_fit_hyperparameters_dict)
#     537         except (KeyboardInterrupt, SystemExit) as e:
#     538             # If getting a interrupt, terminate without saving the exception
# --> 539             raise e
#     540
#     541         # Catch exception only if terminate_on_memory_error is True
#
# /kaggle/working/HyperparameterTuning/SearchAbstractClass.py in _objective_function(self, current_fit_hyperparameters_dict)
#     466
#     467             was_already_evaluated_flag, was_already_evaluated_index = self._was_already_evaluated_check(current_fit_hyperparameters_dict)
# --> 468             result_df, recommender_instance = self._evaluate_on_validation(current_fit_hyperparameters_dict, was_already_evaluated_flag, was_already_evaluated_index)
#     469
#     470             result_series = result_df.loc[self.metadata_dict["cutoff_to_optimize"]]
#
# /kaggle/working/HyperparameterTuning/SearchAbstractClass.py in _evaluate_on_validation(self, current_fit_hyperparameters, was_already_evaluated_flag, was_already_evaluated_index)
#     324                 self.metadata_dict["hyperparameters_df"].loc[self.model_counter,key] = current_fit_hyperparameters[key]
#     325
# --> 326             recommender_instance, train_time = self._fit_model(current_fit_hyperparameters)
#     327             start_time = time.time()
#     328
#
# /kaggle/working/HyperparameterTuning/SearchAbstractClass.py in _fit_model(self, current_fit_hyperparameters)
#     298                                  **self.recommender_input_args.FIT_KEYWORD_ARGS,
#     299                                  **self.recommender_input_args.EARLYSTOPPING_KEYWORD_ARGS,
# --> 300                                  **current_fit_hyperparameters)
#     301
#     302         train_time = time.time() - start_time
#
# /tmp/ipykernel_27/3275789706.py in fit(self, epochs, num_factors, confidence_scaling, alpha, epsilon, reg, init_mean, init_std, **earlystopping_kwargs)
#      75         self._train_with_early_stopping(epochs,
#      76                                         algorithm_name = self.RECOMMENDER_NAME,
# ---> 77                                         **earlystopping_kwargs)
#      78
#      79
#
# /kaggle/working/Recommenders/Incremental_Training_Early_Stopping.py in _train_with_early_stopping(self, epochs_max, epochs_min, validation_every_n, stop_on_validation, validation_metric, lower_validations_allowed, evaluator_object, algorithm_name)
#     197         while epochs_current < epochs_max and not convergence:
#     198
# --> 199             self._run_epoch(epochs_current)
#     200
#     201             # If no validation required, always keep the latest
#
# /tmp/ipykernel_27/3275789706.py in _run_epoch(self, num_epoch)
#     137             user_confidence = self.C.data[start_pos:end_pos]
#     138
# --> 139             self.USER_factors[user_id, :] = self._update_row(user_profile, user_confidence, self.ITEM_factors, VV)
#     140
#     141         # fit item factors
#
# /tmp/ipykernel_27/3275789706.py in _update_row(self, interaction_profile, interaction_confidence, Y, YtY)
#     185         B = YtY + A + self.regularization_diagonal
#     186
# --> 187         return np.dot(np.linalg.inv(B), Y_interactions.T.dot(interaction_confidence))
#     188
#     189
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# /opt/conda/lib/python3.7/site-packages/numpy/linalg/linalg.py in inv(a)
#     543     signature = 'D->D' if isComplexType(t) else 'd->d'
#     544     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 545     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     546     return wrap(ainv.astype(result_t, copy=False))
#     547
#
# KeyboardInterrupt:
