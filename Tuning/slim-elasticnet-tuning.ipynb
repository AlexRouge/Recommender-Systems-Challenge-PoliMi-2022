# %%
# !cp -r ../input/recsys-repo/RecSys_Course_AT_PoliMi-master/* ./

# %%
# %config Completer.use_jedi = False
import pandas as pd
import numpy as np
import scipy.sparse as sps
import matplotlib.pyplot as pyplot

# %%
URM_all_dataframe = pd.read_csv('/kaggle/input/urm-true-binary/URM_True_Binary.csv')
URM_all_dataframe
URM_all = sps.coo_matrix((URM_all_dataframe["Data"].values, 
                          (URM_all_dataframe["UserID"].values, URM_all_dataframe["ItemID"].values)))
URM_all = URM_all.tocsr() # to obtain fast access to rows (users)
URM_all
# Out:
# <41629x24507 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1554640 stored elements in Compressed Sparse Row format>

# %%
URM_train_dataframe = pd.read_csv('/kaggle/input/urm-split/Train_df.csv')
URM_train_dataframe
URM_train = sps.coo_matrix((URM_train_dataframe["Data"].values, 
                          (URM_train_dataframe["UserID"].values, URM_train_dataframe["ItemID"].values)))
URM_train = URM_train.tocsr() # to obtain fast access to rows (users)
URM_train
# Out:
# <41629x24507 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1243712 stored elements in Compressed Sparse Row format>

# %%
URM_val_dataframe = pd.read_csv('/kaggle/input/urm-split/Test_df.csv')
URM_val_dataframe
URM_valid = sps.coo_matrix((URM_val_dataframe["Data"].values, 
                          (URM_val_dataframe["UserID"].values, URM_val_dataframe["ItemID"].values)))
URM_valid = URM_valid.tocsr() # to obtain fast access to rows (users)
URM_valid
# Out:
# <41629x24507 sparse matrix of type '<class 'numpy.int64'>'
# 	with 310928 stored elements in Compressed Sparse Row format>

# %%
from Evaluation.Evaluator import EvaluatorHoldout

#create an evaluator object to evaluate validation set
#we will use it for hyperparameter tuning
evaluator_valid = EvaluatorHoldout(URM_valid, cutoff_list=[10])
# Out:
# EvaluatorHoldout: Ignoring 323 ( 0.8%) Users that have less than 1 test interactions

# %%
import scipy.sparse as sps
from Recommenders.Recommender_utils import check_matrix
from sklearn.linear_model import ElasticNet
from Recommenders.BaseSimilarityMatrixRecommender import BaseItemSimilarityMatrixRecommender
from Utils.seconds_to_biggest_unit import seconds_to_biggest_unit
import time, sys
from tqdm import tqdm
from sklearn.utils._testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning

# %%
class SLIMElasticNetRecommender(BaseItemSimilarityMatrixRecommender):
    """
    Train a Sparse Linear Methods (SLIM) item similarity model.
    NOTE: ElasticNet solver is parallel, a single intance of SLIM_ElasticNet will
          make use of half the cores available
    See:
        Efficient Top-N Recommendation by Linear Regression,
        M. Levy and K. Jack, LSRS workshop at RecSys 2013.
        SLIM: Sparse linear methods for top-n recommender systems,
        X. Ning and G. Karypis, ICDM 2011.
        http://glaros.dtc.umn.edu/gkhome/fetch/papers/SLIM2011icdm.pdf
    """

    RECOMMENDER_NAME = "SLIMElasticNetRecommender"

    def __init__(self, URM_train, verbose = True):
        super(SLIMElasticNetRecommender, self).__init__(URM_train, verbose = verbose)

    @ignore_warnings(category=ConvergenceWarning)
    def fit(self, l1_ratio=0.1, alpha = 1.0, positive_only=True, topK = 100,**earlystopping_kwargs):

        assert l1_ratio>= 0 and l1_ratio<=1, "{}: l1_ratio must be between 0 and 1, provided value was {}".format(self.RECOMMENDER_NAME, l1_ratio)

        self.l1_ratio = l1_ratio
        self.positive_only = positive_only
        self.topK = topK


        # initialize the ElasticNet model
        self.model = ElasticNet(alpha=alpha,
                                l1_ratio=self.l1_ratio,
                                positive=self.positive_only,
                                fit_intercept=False,
                                copy_X=False,
                                precompute=True,
                                selection='random',
                                max_iter=100,
                                tol=1e-4)

        URM_train = check_matrix(self.URM_train, 'csc', dtype=np.float32)

        n_items = URM_train.shape[1]

        # Use array as it reduces memory requirements compared to lists
        dataBlock = 10000000

        rows = np.zeros(dataBlock, dtype=np.int32)
        cols = np.zeros(dataBlock, dtype=np.int32)
        values = np.zeros(dataBlock, dtype=np.float32)

        numCells = 0

        start_time = time.time()
        start_time_printBatch = start_time

        # fit each item's factors sequentially (not in parallel)
        for currentItem in range(n_items):

            # get the target column
            y = URM_train[:, currentItem].toarray()

            # set the j-th column of X to zero
            start_pos = URM_train.indptr[currentItem]
            end_pos = URM_train.indptr[currentItem + 1]

            current_item_data_backup = URM_train.data[start_pos: end_pos].copy()
            URM_train.data[start_pos: end_pos] = 0.0

            # fit one ElasticNet model per column
            self.model.fit(URM_train, y)

            # self.model.coef_ contains the coefficient of the ElasticNet model
            # let's keep only the non-zero values

            # Select topK values
            # Sorting is done in three steps. Faster then plain np.argsort for higher number of items
            # - Partition the data to extract the set of relevant items
            # - Sort only the relevant items
            # - Get the original item index

            nonzero_model_coef_index = self.model.sparse_coef_.indices
            nonzero_model_coef_value = self.model.sparse_coef_.data

            local_topK = min(len(nonzero_model_coef_value)-1, self.topK)

            relevant_items_partition = (-nonzero_model_coef_value).argpartition(local_topK)[0:local_topK]
            relevant_items_partition_sorting = np.argsort(-nonzero_model_coef_value[relevant_items_partition])
            ranking = relevant_items_partition[relevant_items_partition_sorting]

            for index in range(len(ranking)):

                if numCells == len(rows):
                    rows = np.concatenate((rows, np.zeros(dataBlock, dtype=np.int32)))
                    cols = np.concatenate((cols, np.zeros(dataBlock, dtype=np.int32)))
                    values = np.concatenate((values, np.zeros(dataBlock, dtype=np.float32)))


                rows[numCells] = nonzero_model_coef_index[ranking[index]]
                cols[numCells] = currentItem
                values[numCells] = nonzero_model_coef_value[ranking[index]]

                numCells += 1

            # finally, replace the original values of the j-th column
            URM_train.data[start_pos:end_pos] = current_item_data_backup

            elapsed_time = time.time() - start_time
            new_time_value, new_time_unit = seconds_to_biggest_unit(elapsed_time)


            if time.time() - start_time_printBatch > 300 or currentItem == n_items-1:
                self._print("Processed {} ({:4.1f}%) in {:.2f} {}. Items per second: {:.2f}".format(
                    currentItem+1,
                    100.0* float(currentItem+1)/n_items,
                    new_time_value,
                    new_time_unit,
                    float(currentItem)/elapsed_time))

                sys.stdout.flush()
                sys.stderr.flush()

                start_time_printBatch = time.time()

        # generate the sparse weight matrix
        self.W_sparse = sps.csr_matrix((values[:numCells], (rows[:numCells], cols[:numCells])),
                                       shape=(n_items, n_items), dtype=np.float32)

# %%
recommender_class = SLIMElasticNetRecommender

# %%
import os

output_folder_path = "result_experiments/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 50
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from skopt.space import Real, Integer, Categorical

#param = l1_ratio=0.1, alpha = 1.0, positive_only=True, topK = 100

hyperparameters_range_dictionary = {
    "l1_ratio": Real(low = 0.004, high = 0.8, prior = 'log-uniform'),
    "alpha": Real(low = 0.001, high = 0.4, prior = 'log-uniform'),
    "positive_only": Categorical([True, False]),
    "topK": Integer(4000,20000)
}

# %%
#We also setup the early stopping 
earlystopping_keywargs = {"validation_every_n": 5,
                          "stop_on_validation": True,
                          "evaluator_object": evaluator_valid,
                          "lower_validations_allowed": 5,
                          "validation_metric": metric_to_optimize,
                          }

# %%
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

#create a bayesian optimizer object, we pass the recommender and the evaluator
hyperparameterSearch = SearchBayesianSkopt(recommender_class,
                                         evaluator_validation=evaluator_valid)

# %%
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
  
#provide data needed to create instance of model (one on URM_train, the other on URM_all)
recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train],     # For a CBF model simply put [URM_train, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = earlystopping_keywargs
)

# %%
recommender_input_args_last_test = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_all],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = earlystopping_keywargs
)

# %%
#let's run the bayesian search
hyperparameterSearch.search(recommender_input_args = recommender_input_args,
                       recommender_input_args_last_test = recommender_input_args_last_test,
                       hyperparameter_search_space = hyperparameters_range_dictionary,
                       n_cases = n_cases,
                       n_random_starts = n_random_starts,
                       save_model = "last",
                       output_folder_path = output_folder_path, # Where to save the results
                       output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
                       metric_to_optimize = metric_to_optimize,
                       cutoff_to_optimize = cutoff_to_optimize,
                      )
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.005949732331469106, 'alpha': 0.04679384803262339, 'positive_only': False, 'topK': 13470}
# SLIMElasticNetRecommender: Processed 14796 (60.4%) in 5.00 min. Items per second: 49.31
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 7.53 min. Items per second: 54.22
# EvaluatorHoldout: Processed 41306 (100.0%) in 22.80 sec. Users per second: 1812
# SearchBayesianSkopt: New best config found. Config 0: {'l1_ratio': 0.005949732331469106, 'alpha': 0.04679384803262339, 'positive_only': False, 'topK': 13470} - results: PRECISION: 0.0592529, PRECISION_RECALL_MIN_DEN: 0.0819598, RECALL: 0.0715336, MAP: 0.0295761, MAP_MIN_DEN: 0.0402181, MRR: 0.1907001, NDCG: 0.0847283, F1: 0.0648167, HIT_RATE: 0.3780807, ARHR_ALL_HITS: 0.2352305, NOVELTY: 0.0039963, AVERAGE_POPULARITY: 0.2785873, DIVERSITY_MEAN_INTER_LIST: 0.8692003, DIVERSITY_HERFINDAHL: 0.9869179, COVERAGE_ITEM: 0.0754478, COVERAGE_ITEM_HIT: 0.0257886, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3751471, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0071041, SHANNON_ENTROPY: 7.5135994, RATIO_DIVERSITY_HERFINDAHL: 0.9872436, RATIO_DIVERSITY_GINI: 0.0139874, RATIO_SHANNON_ENTROPY: 0.5568318, RATIO_AVERAGE_POPULARITY: 5.4945863, RATIO_NOVELTY: 0.2429393,
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 475.0744
# Function value obtained: -0.0296
# Current minimum: -0.0296
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.12464768022026804, 'alpha': 0.00597602449745428, 'positive_only': True, 'topK': 11538}
# SLIMElasticNetRecommender: Processed 19095 (77.9%) in 5.00 min. Items per second: 63.64
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 6.29 min. Items per second: 64.98
# EvaluatorHoldout: Processed 41306 (100.0%) in 19.79 sec. Users per second: 2087
# SearchBayesianSkopt: New best config found. Config 1: {'l1_ratio': 0.12464768022026804, 'alpha': 0.00597602449745428, 'positive_only': True, 'topK': 11538} - results: PRECISION: 0.0602745, PRECISION_RECALL_MIN_DEN: 0.0826743, RECALL: 0.0719029, MAP: 0.0309888, MAP_MIN_DEN: 0.0417926, MRR: 0.1977686, NDCG: 0.0870086, F1: 0.0655772, HIT_RATE: 0.3779596, ARHR_ALL_HITS: 0.2452737, NOVELTY: 0.0041685, AVERAGE_POPULARITY: 0.2383286, DIVERSITY_MEAN_INTER_LIST: 0.9084664, DIVERSITY_HERFINDAHL: 0.9908444, COVERAGE_ITEM: 0.0388460, COVERAGE_ITEM_HIT: 0.0232179, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3750270, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0077677, SHANNON_ENTROPY: 7.8360374, RATIO_DIVERSITY_HERFINDAHL: 0.9911714, RATIO_DIVERSITY_GINI: 0.0152939, RATIO_SHANNON_ENTROPY: 0.5807276, RATIO_AVERAGE_POPULARITY: 4.7005631, RATIO_NOVELTY: 0.2534111,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 397.0536
# Function value obtained: -0.0310
# Current minimum: -0.0310
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.004819592660105437, 'alpha': 0.00809190962524172, 'positive_only': False, 'topK': 8191}
# SLIMElasticNetRecommender: Processed 4287 (17.5%) in 5.00 min. Items per second: 14.28
# SLIMElasticNetRecommender: Processed 9944 (40.6%) in 10.00 min. Items per second: 16.57
# SLIMElasticNetRecommender: Processed 15679 (64.0%) in 15.00 min. Items per second: 17.42
# SLIMElasticNetRecommender: Processed 21472 (87.6%) in 20.00 min. Items per second: 17.89
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 22.58 min. Items per second: 18.09
# EvaluatorHoldout: Processed 41306 (100.0%) in 44.60 sec. Users per second: 926
# SearchBayesianSkopt: New best config found. Config 2: {'l1_ratio': 0.004819592660105437, 'alpha': 0.00809190962524172, 'positive_only': False, 'topK': 8191} - results: PRECISION: 0.0678884, PRECISION_RECALL_MIN_DEN: 0.0934129, RECALL: 0.0813357, MAP: 0.0345313, MAP_MIN_DEN: 0.0465998, MRR: 0.2128432, NDCG: 0.0965718, F1: 0.0740062, HIT_RATE: 0.4121677, ARHR_ALL_HITS: 0.2682668, NOVELTY: 0.0041353, AVERAGE_POPULARITY: 0.2431618, DIVERSITY_MEAN_INTER_LIST: 0.9074064, DIVERSITY_HERFINDAHL: 0.9907384, COVERAGE_ITEM: 0.1336353, COVERAGE_ITEM_HIT: 0.0467621, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.4089697, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0133103, SHANNON_ENTROPY: 8.3251356, RATIO_DIVERSITY_HERFINDAHL: 0.9910653, RATIO_DIVERSITY_GINI: 0.0262067, RATIO_SHANNON_ENTROPY: 0.6169746, RATIO_AVERAGE_POPULARITY: 4.7958885, RATIO_NOVELTY: 0.2513934,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 1399.8676
# Function value obtained: -0.0345
# Current minimum: -0.0345
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.1259381452180477, 'alpha': 0.16123964866484844, 'positive_only': False, 'topK': 9443}
# SLIMElasticNetRecommender: Processed 21695 (88.5%) in 5.00 min. Items per second: 72.31
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 5.64 min. Items per second: 72.39
# EvaluatorHoldout: Processed 41306 (100.0%) in 17.47 sec. Users per second: 2364
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'l1_ratio': 0.1259381452180477, 'alpha': 0.16123964866484844, 'positive_only': False, 'topK': 9443} - results: PRECISION: 0.0084612, PRECISION_RECALL_MIN_DEN: 0.0117344, RECALL: 0.0102963, MAP: 0.0060929, MAP_MIN_DEN: 0.0083270, MRR: 0.0553345, NDCG: 0.0170228, F1: 0.0092890, HIT_RATE: 0.0765022, ARHR_ALL_HITS: 0.0580347, NOVELTY: 0.0059711, AVERAGE_POPULARITY: 0.0755243, DIVERSITY_MEAN_INTER_LIST: 0.4018825, DIVERSITY_HERFINDAHL: 0.9401873, COVERAGE_ITEM: 0.0050598, COVERAGE_ITEM_HIT: 0.0012649, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.0759086, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0006761, SHANNON_ENTROPY: 4.3572963, RATIO_DIVERSITY_HERFINDAHL: 0.9404975, RATIO_DIVERSITY_GINI: 0.0013312, RATIO_SHANNON_ENTROPY: 0.3229186, RATIO_AVERAGE_POPULARITY: 1.4895676, RATIO_NOVELTY: 0.3629914,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 356.1484
# Function value obtained: -0.0061
# Current minimum: -0.0345
# Iteration No: 5 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.4531789755999364, 'alpha': 0.0221353257945328, 'positive_only': True, 'topK': 13671}
# SLIMElasticNetRecommender: Processed 21259 (86.7%) in 5.00 min. Items per second: 70.86
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 5.74 min. Items per second: 71.13
# EvaluatorHoldout: Processed 41306 (100.0%) in 17.83 sec. Users per second: 2316
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'l1_ratio': 0.4531789755999364, 'alpha': 0.0221353257945328, 'positive_only': True, 'topK': 13671} - results: PRECISION: 0.0269477, PRECISION_RECALL_MIN_DEN: 0.0357428, RECALL: 0.0303910, MAP: 0.0139762, MAP_MIN_DEN: 0.0185395, MRR: 0.1016578, NDCG: 0.0400653, F1: 0.0285660, HIT_RATE: 0.1906987, ARHR_ALL_HITS: 0.1184779, NOVELTY: 0.0050041, AVERAGE_POPULARITY: 0.2064342, DIVERSITY_MEAN_INTER_LIST: 0.6948440, DIVERSITY_HERFINDAHL: 0.9694827, COVERAGE_ITEM: 0.0054678, COVERAGE_ITEM_HIT: 0.0020402, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.1892191, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0012731, SHANNON_ENTROPY: 5.3217224, RATIO_DIVERSITY_HERFINDAHL: 0.9698026, RATIO_DIVERSITY_GINI: 0.0025067, RATIO_SHANNON_ENTROPY: 0.3943921, RATIO_AVERAGE_POPULARITY: 4.0715098, RATIO_NOVELTY: 0.3042064,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 362.5161
# Function value obtained: -0.0140
# Current minimum: -0.0345
# Iteration No: 6 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.005345116073711807, 'alpha': 0.033381446010851454, 'positive_only': False, 'topK': 5772}
# SLIMElasticNetRecommender: Processed 11997 (49.0%) in 5.00 min. Items per second: 39.99
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 8.73 min. Items per second: 46.78
# EvaluatorHoldout: Processed 41306 (100.0%) in 25.08 sec. Users per second: 1647
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'l1_ratio': 0.005345116073711807, 'alpha': 0.033381446010851454, 'positive_only': False, 'topK': 5772} - results: PRECISION: 0.0615044, PRECISION_RECALL_MIN_DEN: 0.0848720, RECALL: 0.0739905, MAP: 0.0308445, MAP_MIN_DEN: 0.0418359, MRR: 0.1961730, NDCG: 0.0877353, F1: 0.0671721, HIT_RATE: 0.3871108, ARHR_ALL_HITS: 0.2436017, NOVELTY: 0.0040256, AVERAGE_POPULARITY: 0.2668445, DIVERSITY_MEAN_INTER_LIST: 0.8835408, DIVERSITY_HERFINDAHL: 0.9883519, COVERAGE_ITEM: 0.0982168, COVERAGE_ITEM_HIT: 0.0293794, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3841072, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0085795, SHANNON_ENTROPY: 7.7417125, RATIO_DIVERSITY_HERFINDAHL: 0.9886780, RATIO_DIVERSITY_GINI: 0.0168922, RATIO_SHANNON_ENTROPY: 0.5737372, RATIO_AVERAGE_POPULARITY: 5.2629834, RATIO_NOVELTY: 0.2447250,
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 549.0873
# Function value obtained: -0.0308
# Current minimum: -0.0345
# Iteration No: 7 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.24691405832762076, 'alpha': 0.007375195439341689, 'positive_only': False, 'topK': 11188}
# SLIMElasticNetRecommender: Processed 20794 (84.8%) in 5.00 min. Items per second: 69.31
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 5.88 min. Items per second: 69.42
# EvaluatorHoldout: Processed 41306 (100.0%) in 18.79 sec. Users per second: 2198
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'l1_ratio': 0.24691405832762076, 'alpha': 0.007375195439341689, 'positive_only': False, 'topK': 11188} - results: PRECISION: 0.0527647, PRECISION_RECALL_MIN_DEN: 0.0721790, RECALL: 0.0626715, MAP: 0.0271244, MAP_MIN_DEN: 0.0366657, MRR: 0.1790270, NDCG: 0.0769465, F1: 0.0572930, HIT_RATE: 0.3432189, ARHR_ALL_HITS: 0.2186145, NOVELTY: 0.0042160, AVERAGE_POPULARITY: 0.2531546, DIVERSITY_MEAN_INTER_LIST: 0.8786279, DIVERSITY_HERFINDAHL: 0.9878607, COVERAGE_ITEM: 0.0171788, COVERAGE_ITEM_HIT: 0.0133431, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3405559, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0046896, SHANNON_ENTROPY: 7.1766928, RATIO_DIVERSITY_HERFINDAHL: 0.9881866, RATIO_DIVERSITY_GINI: 0.0092333, RATIO_SHANNON_ENTROPY: 0.5318637, RATIO_AVERAGE_POPULARITY: 4.9929763, RATIO_NOVELTY: 0.2562993,
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 371.9368
# Function value obtained: -0.0271
# Current minimum: -0.0345
# Iteration No: 8 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.004183925530102214, 'alpha': 0.005400710621584064, 'positive_only': True, 'topK': 17121}
# SLIMElasticNetRecommender: Processed 5110 (20.9%) in 5.00 min. Items per second: 17.03
# SLIMElasticNetRecommender: Processed 10683 (43.6%) in 10.00 min. Items per second: 17.80
# SLIMElasticNetRecommender: Processed 16320 (66.6%) in 15.00 min. Items per second: 18.13
# SLIMElasticNetRecommender: Processed 21984 (89.7%) in 20.00 min. Items per second: 18.32
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 22.22 min. Items per second: 18.38
# EvaluatorHoldout: Processed 41306 (100.0%) in 47.49 sec. Users per second: 870
# SearchBayesianSkopt: New best config found. Config 7: {'l1_ratio': 0.004183925530102214, 'alpha': 0.005400710621584064, 'positive_only': True, 'topK': 17121} - results: PRECISION: 0.0689222, PRECISION_RECALL_MIN_DEN: 0.0946840, RECALL: 0.0824200, MAP: 0.0352368, MAP_MIN_DEN: 0.0474550, MRR: 0.2160567, NDCG: 0.0980907, F1: 0.0750692, HIT_RATE: 0.4152908, ARHR_ALL_HITS: 0.2730731, NOVELTY: 0.0041711, AVERAGE_POPULARITY: 0.2334944, DIVERSITY_MEAN_INTER_LIST: 0.9161865, DIVERSITY_HERFINDAHL: 0.9916164, COVERAGE_ITEM: 0.1304933, COVERAGE_ITEM_HIT: 0.0515363, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.4120685, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0146690, SHANNON_ENTROPY: 8.4699606, RATIO_DIVERSITY_HERFINDAHL: 0.9919436, RATIO_DIVERSITY_GINI: 0.0288819, RATIO_SHANNON_ENTROPY: 0.6277076, RATIO_AVERAGE_POPULARITY: 4.6052182, RATIO_NOVELTY: 0.2535658,
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 1381.3402
# Function value obtained: -0.0352
# Current minimum: -0.0352
# Iteration No: 9 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.04820220008301614, 'alpha': 0.02025257751649143, 'positive_only': True, 'topK': 13615}
# SLIMElasticNetRecommender: Processed 19559 (79.8%) in 5.00 min. Items per second: 65.19
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 6.16 min. Items per second: 66.28
# EvaluatorHoldout: Processed 41306 (100.0%) in 19.50 sec. Users per second: 2118
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'l1_ratio': 0.04820220008301614, 'alpha': 0.02025257751649143, 'positive_only': True, 'topK': 13615} - results: PRECISION: 0.0566407, PRECISION_RECALL_MIN_DEN: 0.0778297, RECALL: 0.0677528, MAP: 0.0287932, MAP_MIN_DEN: 0.0388997, MRR: 0.1865805, NDCG: 0.0816858, F1: 0.0617004, HIT_RATE: 0.3627802, ARHR_ALL_HITS: 0.2297112, NOVELTY: 0.0041099, AVERAGE_POPULARITY: 0.2610163, DIVERSITY_MEAN_INTER_LIST: 0.8832785, DIVERSITY_HERFINDAHL: 0.9883257, COVERAGE_ITEM: 0.0284817, COVERAGE_ITEM_HIT: 0.0178724, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3599654, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0057877, SHANNON_ENTROPY: 7.4216039, RATIO_DIVERSITY_HERFINDAHL: 0.9886518, RATIO_DIVERSITY_GINI: 0.0113956, RATIO_SHANNON_ENTROPY: 0.5500140, RATIO_AVERAGE_POPULARITY: 5.1480342, RATIO_NOVELTY: 0.2498481,
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 389.3837
# Function value obtained: -0.0288
# Current minimum: -0.0352
# Iteration No: 10 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.02982854781713627, 'alpha': 0.016960055709276303, 'positive_only': True, 'topK': 9844}
# SLIMElasticNetRecommender: Processed 17990 (73.4%) in 5.00 min. Items per second: 59.96
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 6.57 min. Items per second: 62.15
# EvaluatorHoldout: Processed 41306 (100.0%) in 20.86 sec. Users per second: 1980
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'l1_ratio': 0.02982854781713627, 'alpha': 0.016960055709276303, 'positive_only': True, 'topK': 9844} - results: PRECISION: 0.0606643, PRECISION_RECALL_MIN_DEN: 0.0835886, RECALL: 0.0728267, MAP: 0.0308523, MAP_MIN_DEN: 0.0417495, MRR: 0.1968659, NDCG: 0.0872183, F1: 0.0661915, HIT_RATE: 0.3820995, ARHR_ALL_HITS: 0.2441354, NOVELTY: 0.0040992, AVERAGE_POPULARITY: 0.2518405, DIVERSITY_MEAN_INTER_LIST: 0.8977223, DIVERSITY_HERFINDAHL: 0.9897701, COVERAGE_ITEM: 0.0523116, COVERAGE_ITEM_HIT: 0.0253397, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3791347, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0077712, SHANNON_ENTROPY: 7.7749085, RATIO_DIVERSITY_HERFINDAHL: 0.9900966, RATIO_DIVERSITY_GINI: 0.0153008, RATIO_SHANNON_ENTROPY: 0.5761974, RATIO_AVERAGE_POPULARITY: 4.9670598, RATIO_NOVELTY: 0.2491951,
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 415.3446
# Function value obtained: -0.0309
# Current minimum: -0.0352
# Iteration No: 11 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.01689896709903489, 'alpha': 0.021827238621875536, 'positive_only': True, 'topK': 18177}
# SLIMElasticNetRecommender: Processed 15319 (62.5%) in 5.00 min. Items per second: 51.06
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 7.31 min. Items per second: 55.88
# EvaluatorHoldout: Processed 41306 (100.0%) in 21.48 sec. Users per second: 1923
# SearchBayesianSkopt: Config 10 is suboptimal. Config: {'l1_ratio': 0.01689896709903489, 'alpha': 0.021827238621875536, 'positive_only': True, 'topK': 18177} - results: PRECISION: 0.0611703, PRECISION_RECALL_MIN_DEN: 0.0843780, RECALL: 0.0735652, MAP: 0.0310007, MAP_MIN_DEN: 0.0419736, MRR: 0.1974397, NDCG: 0.0877666, F1: 0.0667976, HIT_RATE: 0.3852467, ARHR_ALL_HITS: 0.2450395, NOVELTY: 0.0040732, AVERAGE_POPULARITY: 0.2562329, DIVERSITY_MEAN_INTER_LIST: 0.8942001, DIVERSITY_HERFINDAHL: 0.9894178, COVERAGE_ITEM: 0.0656139, COVERAGE_ITEM_HIT: 0.0275023, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3822576, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0081490, SHANNON_ENTROPY: 7.7907099, RATIO_DIVERSITY_HERFINDAHL: 0.9897443, RATIO_DIVERSITY_GINI: 0.0160448, RATIO_SHANNON_ENTROPY: 0.5773684, RATIO_AVERAGE_POPULARITY: 5.0536901, RATIO_NOVELTY: 0.2476142,
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 460.2036
# Function value obtained: -0.0310
# Current minimum: -0.0352
# Iteration No: 12 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.020636987877583068, 'alpha': 0.012373176355335306, 'positive_only': True, 'topK': 16271}
# SLIMElasticNetRecommender: Processed 14509 (59.2%) in 5.00 min. Items per second: 48.36
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 7.70 min. Items per second: 53.01
# EvaluatorHoldout: Processed 41306 (100.0%) in 22.73 sec. Users per second: 1817
# SearchBayesianSkopt: Config 11 is suboptimal. Config: {'l1_ratio': 0.020636987877583068, 'alpha': 0.012373176355335306, 'positive_only': True, 'topK': 16271} - results: PRECISION: 0.0640827, PRECISION_RECALL_MIN_DEN: 0.0882189, RECALL: 0.0768548, MAP: 0.0326138, MAP_MIN_DEN: 0.0440512, MRR: 0.2048228, NDCG: 0.0916839, F1: 0.0698900, HIT_RATE: 0.3966010, ARHR_ALL_HITS: 0.2559227, NOVELTY: 0.0041228, AVERAGE_POPULARITY: 0.2402347, DIVERSITY_MEAN_INTER_LIST: 0.9103919, DIVERSITY_HERFINDAHL: 0.9910370, COVERAGE_ITEM: 0.0861795, COVERAGE_ITEM_HIT: 0.0339903, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3935237, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0104013, SHANNON_ENTROPY: 8.1091317, RATIO_DIVERSITY_HERFINDAHL: 0.9913640, RATIO_DIVERSITY_GINI: 0.0204792, RATIO_SHANNON_ENTROPY: 0.6009666, RATIO_AVERAGE_POPULARITY: 4.7381578, RATIO_NOVELTY: 0.2506324,
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 485.1685
# Function value obtained: -0.0326
# Current minimum: -0.0352
# Iteration No: 13 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.25440135451093054, 'alpha': 0.15332558412788602, 'positive_only': True, 'topK': 17187}
# SLIMElasticNetRecommender: Processed 21718 (88.6%) in 5.00 min. Items per second: 72.39
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 5.64 min. Items per second: 72.39
# EvaluatorHoldout: Processed 41306 (100.0%) in 17.57 sec. Users per second: 2351
# SearchBayesianSkopt: Config 12 is suboptimal. Config: {'l1_ratio': 0.25440135451093054, 'alpha': 0.15332558412788602, 'positive_only': True, 'topK': 17187} - results: PRECISION: 0.0001864, PRECISION_RECALL_MIN_DEN: 0.0002833, RECALL: 0.0002472, MAP: 0.0000465, MAP_MIN_DEN: 0.0000655, MRR: 0.0004646, NDCG: 0.0002135, F1: 0.0002125, HIT_RATE: 0.0018641, ARHR_ALL_HITS: 0.0004646, NOVELTY: 0.0063241, AVERAGE_POPULARITY: 0.0036737, DIVERSITY_MEAN_INTER_LIST: 0.2760730, DIVERSITY_HERFINDAHL: 0.9276066, COVERAGE_ITEM: 0.0049374, COVERAGE_ITEM_HIT: 0.0011017, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.0018497, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0005576, SHANNON_ENTROPY: 4.0064963, RATIO_DIVERSITY_HERFINDAHL: 0.9279127, RATIO_DIVERSITY_GINI: 0.0010978, RATIO_SHANNON_ENTROPY: 0.2969209, RATIO_AVERAGE_POPULARITY: 0.0724561, RATIO_NOVELTY: 0.3844538,
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 356.2466
# Function value obtained: -0.0000
# Current minimum: -0.0352
# Iteration No: 14 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.01084236979263938, 'alpha': 0.3466914451156643, 'positive_only': True, 'topK': 6803}
# SLIMElasticNetRecommender: Processed 21375 (87.2%) in 5.00 min. Items per second: 71.25
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 5.72 min. Items per second: 71.39
# EvaluatorHoldout: Processed 41306 (100.0%) in 18.27 sec. Users per second: 2261
# SearchBayesianSkopt: Config 13 is suboptimal. Config: {'l1_ratio': 0.01084236979263938, 'alpha': 0.3466914451156643, 'positive_only': True, 'topK': 6803} - results: PRECISION: 0.0399191, PRECISION_RECALL_MIN_DEN: 0.0551266, RECALL: 0.0479692, MAP: 0.0195228, MAP_MIN_DEN: 0.0266532, MRR: 0.1380440, NDCG: 0.0579576, F1: 0.0435755, HIT_RATE: 0.2790394, ARHR_ALL_HITS: 0.1630671, NOVELTY: 0.0041662, AVERAGE_POPULARITY: 0.3260290, DIVERSITY_MEAN_INTER_LIST: 0.7372593, DIVERSITY_HERFINDAHL: 0.9737241, COVERAGE_ITEM: 0.0077937, COVERAGE_ITEM_HIT: 0.0056718, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.2768743, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0017490, SHANNON_ENTROPY: 5.8082759, RATIO_DIVERSITY_HERFINDAHL: 0.9740454, RATIO_DIVERSITY_GINI: 0.0034436, RATIO_SHANNON_ENTROPY: 0.4304505, RATIO_AVERAGE_POPULARITY: 6.4302822, RATIO_NOVELTY: 0.2532690,
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 361.6770
# Function value obtained: -0.0195
# Current minimum: -0.0352
# Iteration No: 15 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.007164245868582859, 'alpha': 0.006276996815905547, 'positive_only': True, 'topK': 8170}
# SLIMElasticNetRecommender: Processed 5774 (23.6%) in 5.00 min. Items per second: 19.24
# SLIMElasticNetRecommender: Processed 12171 (49.7%) in 10.00 min. Items per second: 20.28
# SLIMElasticNetRecommender: Processed 18687 (76.3%) in 15.00 min. Items per second: 20.76
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 19.47 min. Items per second: 20.97
# EvaluatorHoldout: Processed 41306 (100.0%) in 39.53 sec. Users per second: 1045
# SearchBayesianSkopt: Config 14 is suboptimal. Config: {'l1_ratio': 0.007164245868582859, 'alpha': 0.006276996815905547, 'positive_only': True, 'topK': 8170} - results: PRECISION: 0.0683775, PRECISION_RECALL_MIN_DEN: 0.0939514, RECALL: 0.0817878, MAP: 0.0349477, MAP_MIN_DEN: 0.0470684, MRR: 0.2148170, NDCG: 0.0973720, F1: 0.0744839, HIT_RATE: 0.4133056, ARHR_ALL_HITS: 0.2711979, NOVELTY: 0.0041839, AVERAGE_POPULARITY: 0.2276968, DIVERSITY_MEAN_INTER_LIST: 0.9213430, DIVERSITY_HERFINDAHL: 0.9921321, COVERAGE_ITEM: 0.1426531, COVERAGE_ITEM_HIT: 0.0492920, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.4100987, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0151484, SHANNON_ENTROPY: 8.5229773, RATIO_DIVERSITY_HERFINDAHL: 0.9924594, RATIO_DIVERSITY_GINI: 0.0298258, RATIO_SHANNON_ENTROPY: 0.6316367, RATIO_AVERAGE_POPULARITY: 4.4908727, RATIO_NOVELTY: 0.2543464,
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 1208.8641
# Function value obtained: -0.0349
# Current minimum: -0.0352
# Iteration No: 16 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.023890679750732377, 'alpha': 0.001, 'positive_only': False, 'topK': 20000}
# SLIMElasticNetRecommender: Processed 3039 (12.4%) in 5.00 min. Items per second: 10.13
# SLIMElasticNetRecommender: Processed 7404 (30.2%) in 10.00 min. Items per second: 12.34
# SLIMElasticNetRecommender: Processed 12134 (49.5%) in 15.00 min. Items per second: 13.48
# SLIMElasticNetRecommender: Processed 16854 (68.8%) in 20.00 min. Items per second: 14.04
# SLIMElasticNetRecommender: Processed 21666 (88.4%) in 25.00 min. Items per second: 14.44
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 27.92 min. Items per second: 14.63
# EvaluatorHoldout: Processed 41306 (100.0%) in 53.14 sec. Users per second: 777
# SearchBayesianSkopt: New best config found. Config 15: {'l1_ratio': 0.023890679750732377, 'alpha': 0.001, 'positive_only': False, 'topK': 20000} - results: PRECISION: 0.0691280, PRECISION_RECALL_MIN_DEN: 0.0938482, RECALL: 0.0812420, MAP: 0.0355978, MAP_MIN_DEN: 0.0474220, MRR: 0.2157390, NDCG: 0.0978249, F1: 0.0746970, HIT_RATE: 0.4129908, ARHR_ALL_HITS: 0.2741670, NOVELTY: 0.0042826, AVERAGE_POPULARITY: 0.2104600, DIVERSITY_MEAN_INTER_LIST: 0.9352708, DIVERSITY_HERFINDAHL: 0.9935248, COVERAGE_ITEM: 0.1538744, COVERAGE_ITEM_HIT: 0.0700208, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.4097864, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0212455, SHANNON_ENTROPY: 8.9519621, RATIO_DIVERSITY_HERFINDAHL: 0.9938526, RATIO_DIVERSITY_GINI: 0.0418305, RATIO_SHANNON_ENTROPY: 0.6634287, RATIO_AVERAGE_POPULARITY: 4.1509099, RATIO_NOVELTY: 0.2603475,
#
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 1729.0168
# Function value obtained: -0.0356
# Current minimum: -0.0356
# Iteration No: 17 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.7934516312001124, 'alpha': 0.001022694996502107, 'positive_only': True, 'topK': 5616}
# SLIMElasticNetRecommender: Processed 19148 (78.1%) in 5.00 min. Items per second: 63.82
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 6.27 min. Items per second: 65.19
# EvaluatorHoldout: Processed 41306 (100.0%) in 20.52 sec. Users per second: 2013
# SearchBayesianSkopt: Config 16 is suboptimal. Config: {'l1_ratio': 0.7934516312001124, 'alpha': 0.001022694996502107, 'positive_only': True, 'topK': 5616} - results: PRECISION: 0.0606788, PRECISION_RECALL_MIN_DEN: 0.0830065, RECALL: 0.0721161, MAP: 0.0312780, MAP_MIN_DEN: 0.0420873, MRR: 0.1989263, NDCG: 0.0875408, F1: 0.0659049, HIT_RATE: 0.3795574, ARHR_ALL_HITS: 0.2471736, NOVELTY: 0.0042145, AVERAGE_POPULARITY: 0.2281453, DIVERSITY_MEAN_INTER_LIST: 0.9165107, DIVERSITY_HERFINDAHL: 0.9916488, COVERAGE_ITEM: 0.0363162, COVERAGE_ITEM_HIT: 0.0241156, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3766125, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0083626, SHANNON_ENTROPY: 7.9514799, RATIO_DIVERSITY_HERFINDAHL: 0.9919760, RATIO_DIVERSITY_GINI: 0.0164652, RATIO_SHANNON_ENTROPY: 0.5892831, RATIO_AVERAGE_POPULARITY: 4.4997181, RATIO_NOVELTY: 0.2562035,
#
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 396.9083
# Function value obtained: -0.0313
# Current minimum: -0.0356
# Iteration No: 18 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.004124052209762431, 'alpha': 0.0010331536481986445, 'positive_only': True, 'topK': 4576}
# SLIMElasticNetRecommender: Processed 4495 (18.3%) in 5.00 min. Items per second: 14.98
# SLIMElasticNetRecommender: Processed 9550 (39.0%) in 10.00 min. Items per second: 15.91
# SLIMElasticNetRecommender: Processed 14580 (59.5%) in 15.00 min. Items per second: 16.20
# SLIMElasticNetRecommender: Processed 19634 (80.1%) in 20.00 min. Items per second: 16.36
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 24.85 min. Items per second: 16.44
# EvaluatorHoldout: Processed 41306 (100.0%) in 47.19 sec. Users per second: 875
# SearchBayesianSkopt: New best config found. Config 17: {'l1_ratio': 0.004124052209762431, 'alpha': 0.0010331536481986445, 'positive_only': True, 'topK': 4576} - results: PRECISION: 0.0689295, PRECISION_RECALL_MIN_DEN: 0.0936831, RECALL: 0.0811468, MAP: 0.0356167, MAP_MIN_DEN: 0.0474135, MRR: 0.2160985, NDCG: 0.0977624, F1: 0.0745408, HIT_RATE: 0.4111025, ARHR_ALL_HITS: 0.2745116, NOVELTY: 0.0042158, AVERAGE_POPULARITY: 0.2282754, DIVERSITY_MEAN_INTER_LIST: 0.9205669, DIVERSITY_HERFINDAHL: 0.9920545, COVERAGE_ITEM: 0.1371445, COVERAGE_ITEM_HIT: 0.0647978, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.4079128, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0179610, SHANNON_ENTROPY: 8.6813661, RATIO_DIVERSITY_HERFINDAHL: 0.9923818, RATIO_DIVERSITY_GINI: 0.0353636, RATIO_SHANNON_ENTROPY: 0.6433748, RATIO_AVERAGE_POPULARITY: 4.5022839, RATIO_NOVELTY: 0.2562834,
#
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 1539.1152
# Function value obtained: -0.0356
# Current minimum: -0.0356
# Iteration No: 19 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.14337760412152176, 'alpha': 0.0010014576317967905, 'positive_only': False, 'topK': 4078}
# SLIMElasticNetRecommender: Processed 10443 (42.6%) in 5.00 min. Items per second: 34.81
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 9.84 min. Items per second: 41.52
# EvaluatorHoldout: Processed 41306 (100.0%) in 24.86 sec. Users per second: 1662
# SearchBayesianSkopt: Config 18 is suboptimal. Config: {'l1_ratio': 0.14337760412152176, 'alpha': 0.0010014576317967905, 'positive_only': False, 'topK': 4078} - results: PRECISION: 0.0688423, PRECISION_RECALL_MIN_DEN: 0.0940329, RECALL: 0.0816410, MAP: 0.0355242, MAP_MIN_DEN: 0.0475464, MRR: 0.2168952, NDCG: 0.0980636, F1: 0.0746974, HIT_RATE: 0.4134024, ARHR_ALL_HITS: 0.2747782, NOVELTY: 0.0043214, AVERAGE_POPULARITY: 0.1982045, DIVERSITY_MEAN_INTER_LIST: 0.9430168, DIVERSITY_HERFINDAHL: 0.9942994, COVERAGE_ITEM: 0.1363692, COVERAGE_ITEM_HIT: 0.0543518, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.4101948, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0209284, SHANNON_ENTROPY: 9.0286335, RATIO_DIVERSITY_HERFINDAHL: 0.9946275, RATIO_DIVERSITY_GINI: 0.0412063, RATIO_SHANNON_ENTROPY: 0.6691108, RATIO_AVERAGE_POPULARITY: 3.9091951, RATIO_NOVELTY: 0.2627016,
#
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 615.4554
# Function value obtained: -0.0355
# Current minimum: -0.0356
# Iteration No: 20 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.004007684400990822, 'alpha': 0.39510342239887525, 'positive_only': False, 'topK': 18138}
# SLIMElasticNetRecommender: Processed 20444 (83.4%) in 5.00 min. Items per second: 68.14
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 5.99 min. Items per second: 68.17
# EvaluatorHoldout: Processed 41306 (100.0%) in 19.21 sec. Users per second: 2150
# SearchBayesianSkopt: Config 19 is suboptimal. Config: {'l1_ratio': 0.004007684400990822, 'alpha': 0.39510342239887525, 'positive_only': False, 'topK': 18138} - results: PRECISION: 0.0456738, PRECISION_RECALL_MIN_DEN: 0.0639407, RECALL: 0.0560706, MAP: 0.0219284, MAP_MIN_DEN: 0.0302190, MRR: 0.1516769, NDCG: 0.0656168, F1: 0.0503410, HIT_RATE: 0.3142885, ARHR_ALL_HITS: 0.1810061, NOVELTY: 0.0039012, AVERAGE_POPULARITY: 0.3545510, DIVERSITY_MEAN_INTER_LIST: 0.7315409, DIVERSITY_HERFINDAHL: 0.9731523, COVERAGE_ITEM: 0.0166483, COVERAGE_ITEM_HIT: 0.0115069, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3118499, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0024621, SHANNON_ENTROPY: 6.1372254, RATIO_DIVERSITY_HERFINDAHL: 0.9734734, RATIO_DIVERSITY_GINI: 0.0048476, RATIO_SHANNON_ENTROPY: 0.4548289, RATIO_AVERAGE_POPULARITY: 6.9928219, RATIO_NOVELTY: 0.2371596,
#
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 379.1741
# Function value obtained: -0.0219
# Current minimum: -0.0356
# Iteration No: 21 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.03961247819573929, 'alpha': 0.0023233415102479208, 'positive_only': False, 'topK': 4549}
# SLIMElasticNetRecommender: Processed 5810 (23.7%) in 5.00 min. Items per second: 19.36
# SLIMElasticNetRecommender: Processed 14874 (60.7%) in 10.00 min. Items per second: 24.79
# SLIMElasticNetRecommender: Processed 24505 (100.0%) in 15.00 min. Items per second: 27.23
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 15.00 min. Items per second: 27.23
# EvaluatorHoldout: Processed 41306 (100.0%) in 30.47 sec. Users per second: 1356
# SearchBayesianSkopt: New best config found. Config 20: {'l1_ratio': 0.03961247819573929, 'alpha': 0.0023233415102479208, 'positive_only': False, 'topK': 4549} - results: PRECISION: 0.0693483, PRECISION_RECALL_MIN_DEN: 0.0948490, RECALL: 0.0823945, MAP: 0.0357151, MAP_MIN_DEN: 0.0479428, MRR: 0.2177906, NDCG: 0.0987435, F1: 0.0753106, HIT_RATE: 0.4150245, ARHR_ALL_HITS: 0.2760099, NOVELTY: 0.0042747, AVERAGE_POPULARITY: 0.2075993, DIVERSITY_MEAN_INTER_LIST: 0.9367468, DIVERSITY_HERFINDAHL: 0.9936724, COVERAGE_ITEM: 0.1558330, COVERAGE_ITEM_HIT: 0.0540254, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.4118043, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0195976, SHANNON_ENTROPY: 8.8929383, RATIO_DIVERSITY_HERFINDAHL: 0.9940003, RATIO_DIVERSITY_GINI: 0.0385859, RATIO_SHANNON_ENTROPY: 0.6590544, RATIO_AVERAGE_POPULARITY: 4.0944879, RATIO_NOVELTY: 0.2598625,
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 931.0699
# Function value obtained: -0.0357
# Current minimum: -0.0357
# Iteration No: 22 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.006964455304478809, 'alpha': 0.00203499236422369, 'positive_only': False, 'topK': 20000}
# SLIMElasticNetRecommender: Processed 2011 ( 8.2%) in 5.00 min. Items per second: 6.70
# SLIMElasticNetRecommender: Processed 4588 (18.7%) in 10.00 min. Items per second: 7.64
# SLIMElasticNetRecommender: Processed 7461 (30.4%) in 15.00 min. Items per second: 8.29
# SLIMElasticNetRecommender: Processed 10410 (42.5%) in 20.00 min. Items per second: 8.67
# SLIMElasticNetRecommender: Processed 13323 (54.4%) in 25.00 min. Items per second: 8.88
# SLIMElasticNetRecommender: Processed 16343 (66.7%) in 30.00 min. Items per second: 9.08
# SLIMElasticNetRecommender: Processed 19344 (78.9%) in 35.01 min. Items per second: 9.21
# SLIMElasticNetRecommender: Processed 22444 (91.6%) in 40.01 min. Items per second: 9.35
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 43.30 min. Items per second: 9.43
# EvaluatorHoldout: Processed 41306 (100.0%) in 1.21 min. Users per second: 568
# SearchBayesianSkopt: Config 21 is suboptimal. Config: {'l1_ratio': 0.006964455304478809, 'alpha': 0.00203499236422369, 'positive_only': False, 'topK': 20000} - results: PRECISION: 0.0690118, PRECISION_RECALL_MIN_DEN: 0.0942100, RECALL: 0.0817013, MAP: 0.0355088, MAP_MIN_DEN: 0.0474602, MRR: 0.2158096, NDCG: 0.0979284, F1: 0.0748223, HIT_RATE: 0.4136929, ARHR_ALL_HITS: 0.2738634, NOVELTY: 0.0042310, AVERAGE_POPULARITY: 0.2190266, DIVERSITY_MEAN_INTER_LIST: 0.9292981, DIVERSITY_HERFINDAHL: 0.9929276, COVERAGE_ITEM: 0.1348186, COVERAGE_ITEM_HIT: 0.0643082, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.4104831, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0178221, SHANNON_ENTROPY: 8.7456465, RATIO_DIVERSITY_HERFINDAHL: 0.9932552, RATIO_DIVERSITY_GINI: 0.0350902, RATIO_SHANNON_ENTROPY: 0.6481386, RATIO_AVERAGE_POPULARITY: 4.3198701, RATIO_NOVELTY: 0.2572083,
#
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 2671.8995
# Function value obtained: -0.0355
# Current minimum: -0.0357
# Iteration No: 23 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.05652649721548329, 'alpha': 0.001, 'positive_only': True, 'topK': 4000}
# SLIMElasticNetRecommender: Processed 6316 (25.8%) in 5.00 min. Items per second: 21.05
# SLIMElasticNetRecommender: Processed 13373 (54.6%) in 10.00 min. Items per second: 22.28
# SLIMElasticNetRecommender: Processed 20599 (84.1%) in 15.00 min. Items per second: 22.88
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 17.68 min. Items per second: 23.10
# EvaluatorHoldout: Processed 41306 (100.0%) in 34.71 sec. Users per second: 1190
# SearchBayesianSkopt: New best config found. Config 22: {'l1_ratio': 0.05652649721548329, 'alpha': 0.001, 'positive_only': True, 'topK': 4000} - results: PRECISION: 0.0701399, PRECISION_RECALL_MIN_DEN: 0.0954885, RECALL: 0.0827870, MAP: 0.0360934, MAP_MIN_DEN: 0.0481341, MRR: 0.2182221, NDCG: 0.0992577, F1: 0.0759405, HIT_RATE: 0.4171307, ARHR_ALL_HITS: 0.2776846, NOVELTY: 0.0043483, AVERAGE_POPULARITY: 0.1994145, DIVERSITY_MEAN_INTER_LIST: 0.9413053, DIVERSITY_HERFINDAHL: 0.9941283, COVERAGE_ITEM: 0.1759497, COVERAGE_ITEM_HIT: 0.0646346, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.4138942, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0252453, SHANNON_ENTROPY: 9.1887078, RATIO_DIVERSITY_HERFINDAHL: 0.9944563, RATIO_DIVERSITY_GINI: 0.0497058, RATIO_SHANNON_ENTROPY: 0.6809739, RATIO_AVERAGE_POPULARITY: 3.9330596, RATIO_NOVELTY: 0.2643380,
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 1095.9968
# Function value obtained: -0.0361
# Current minimum: -0.0361
# Iteration No: 24 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.7890073227455744, 'alpha': 0.0026720900268913054, 'positive_only': True, 'topK': 19918}
# SLIMElasticNetRecommender: Processed 20995 (85.7%) in 5.00 min. Items per second: 69.98
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 5.81 min. Items per second: 70.25
# EvaluatorHoldout: Processed 41306 (100.0%) in 18.83 sec. Users per second: 2193
# SearchBayesianSkopt: Config 23 is suboptimal. Config: {'l1_ratio': 0.7890073227455744, 'alpha': 0.0026720900268913054, 'positive_only': True, 'topK': 19918} - results: PRECISION: 0.0509296, PRECISION_RECALL_MIN_DEN: 0.0694382, RECALL: 0.0601439, MAP: 0.0263616, MAP_MIN_DEN: 0.0355547, MRR: 0.1752348, NDCG: 0.0746137, F1: 0.0551546, HIT_RATE: 0.3330751, ARHR_ALL_HITS: 0.2132376, NOVELTY: 0.0042763, AVERAGE_POPULARITY: 0.2476274, DIVERSITY_MEAN_INTER_LIST: 0.8755810, DIVERSITY_HERFINDAHL: 0.9875560, COVERAGE_ITEM: 0.0151385, COVERAGE_ITEM_HIT: 0.0117517, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3304908, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0042938, SHANNON_ENTROPY: 7.0670647, RATIO_DIVERSITY_HERFINDAHL: 0.9878818, RATIO_DIVERSITY_GINI: 0.0084540, RATIO_SHANNON_ENTROPY: 0.5237392, RATIO_AVERAGE_POPULARITY: 4.8839646, RATIO_NOVELTY: 0.2599632,
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 368.2892
# Function value obtained: -0.0264
# Current minimum: -0.0361
# Iteration No: 25 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.7487168586406016, 'alpha': 0.37161734984588296, 'positive_only': False, 'topK': 6439}
# SLIMElasticNetRecommender: Processed 21641 (88.3%) in 5.00 min. Items per second: 72.13
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 5.66 min. Items per second: 72.13
# EvaluatorHoldout: Processed 41306 (100.0%) in 17.37 sec. Users per second: 2378
# SearchBayesianSkopt: Config 24 is suboptimal. Config: {'l1_ratio': 0.7487168586406016, 'alpha': 0.37161734984588296, 'positive_only': False, 'topK': 6439} - results: PRECISION: 0.0001864, PRECISION_RECALL_MIN_DEN: 0.0002833, RECALL: 0.0002472, MAP: 0.0000465, MAP_MIN_DEN: 0.0000655, MRR: 0.0004646, NDCG: 0.0002135, F1: 0.0002125, HIT_RATE: 0.0018641, ARHR_ALL_HITS: 0.0004646, NOVELTY: 0.0063241, AVERAGE_POPULARITY: 0.0036737, DIVERSITY_MEAN_INTER_LIST: 0.2760730, DIVERSITY_HERFINDAHL: 0.9276066, COVERAGE_ITEM: 0.0049374, COVERAGE_ITEM_HIT: 0.0011017, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.0018497, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0005576, SHANNON_ENTROPY: 4.0064963, RATIO_DIVERSITY_HERFINDAHL: 0.9279127, RATIO_DIVERSITY_GINI: 0.0010978, RATIO_SHANNON_ENTROPY: 0.2969209, RATIO_AVERAGE_POPULARITY: 0.0724561, RATIO_NOVELTY: 0.3844538,
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 357.6160
# Function value obtained: -0.0000
# Current minimum: -0.0361
# Iteration No: 26 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.05983317827794857, 'alpha': 0.0014132118717925359, 'positive_only': True, 'topK': 20000}
# SLIMElasticNetRecommender: Processed 7244 (29.6%) in 5.00 min. Items per second: 24.14
# SLIMElasticNetRecommender: Processed 15655 (63.9%) in 10.00 min. Items per second: 26.09
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 14.83 min. Items per second: 27.54
# EvaluatorHoldout: Processed 41306 (100.0%) in 31.21 sec. Users per second: 1323
# SearchBayesianSkopt: Config 25 is suboptimal. Config: {'l1_ratio': 0.05983317827794857, 'alpha': 0.0014132118717925359, 'positive_only': True, 'topK': 20000} - results: PRECISION: 0.0694839, PRECISION_RECALL_MIN_DEN: 0.0948286, RECALL: 0.0822954, MAP: 0.0358141, MAP_MIN_DEN: 0.0478974, MRR: 0.2174092, NDCG: 0.0987075, F1: 0.0753489, HIT_RATE: 0.4149760, ARHR_ALL_HITS: 0.2761755, NOVELTY: 0.0043282, AVERAGE_POPULARITY: 0.1982739, DIVERSITY_MEAN_INTER_LIST: 0.9427892, DIVERSITY_HERFINDAHL: 0.9942766, COVERAGE_ITEM: 0.1651773, COVERAGE_ITEM_HIT: 0.0584731, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.4117562, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0229247, SHANNON_ENTROPY: 9.1053518, RATIO_DIVERSITY_HERFINDAHL: 0.9946047, RATIO_DIVERSITY_GINI: 0.0451368, RATIO_SHANNON_ENTROPY: 0.6747964, RATIO_AVERAGE_POPULARITY: 3.9105635, RATIO_NOVELTY: 0.2631161,
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 921.6947
# Function value obtained: -0.0358
# Current minimum: -0.0361
# Iteration No: 27 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.004000000000000001, 'alpha': 0.0021800597317147446, 'positive_only': False, 'topK': 4000}
# SLIMElasticNetRecommender: Processed 1557 ( 6.4%) in 5.00 min. Items per second: 5.19
# SLIMElasticNetRecommender: Processed 3169 (12.9%) in 10.00 min. Items per second: 5.28
# SLIMElasticNetRecommender: Processed 4728 (19.3%) in 15.00 min. Items per second: 5.25
# SLIMElasticNetRecommender: Processed 6869 (28.0%) in 20.00 min. Items per second: 5.72
# SLIMElasticNetRecommender: Processed 9143 (37.3%) in 25.01 min. Items per second: 6.09
# SLIMElasticNetRecommender: Processed 11435 (46.7%) in 30.01 min. Items per second: 6.35
# SLIMElasticNetRecommender: Processed 13653 (55.7%) in 35.01 min. Items per second: 6.50
# SLIMElasticNetRecommender: Processed 15906 (64.9%) in 40.01 min. Items per second: 6.63
# SLIMElasticNetRecommender: Processed 18181 (74.2%) in 45.01 min. Items per second: 6.73
# SLIMElasticNetRecommender: Processed 20502 (83.7%) in 50.01 min. Items per second: 6.83
# SLIMElasticNetRecommender: Processed 22792 (93.0%) in 55.01 min. Items per second: 6.90
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 58.57 min. Items per second: 6.97
# EvaluatorHoldout: Processed 41306 (100.0%) in 1.40 min. Users per second: 491
# SearchBayesianSkopt: Config 26 is suboptimal. Config: {'l1_ratio': 0.004000000000000001, 'alpha': 0.0021800597317147446, 'positive_only': False, 'topK': 4000} - results: PRECISION: 0.0662180, PRECISION_RECALL_MIN_DEN: 0.0913354, RECALL: 0.0799077, MAP: 0.0337770, MAP_MIN_DEN: 0.0457208, MRR: 0.2113160, NDCG: 0.0949171, F1: 0.0724216, HIT_RATE: 0.4070111, ARHR_ALL_HITS: 0.2646464, NOVELTY: 0.0040358, AVERAGE_POPULARITY: 0.2685947, DIVERSITY_MEAN_INTER_LIST: 0.8826830, DIVERSITY_HERFINDAHL: 0.9882662, COVERAGE_ITEM: 0.0985025, COVERAGE_ITEM_HIT: 0.0467621, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.4038531, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0102160, SHANNON_ENTROPY: 7.9023018, RATIO_DIVERSITY_HERFINDAHL: 0.9885922, RATIO_DIVERSITY_GINI: 0.0201145, RATIO_SHANNON_ENTROPY: 0.5856385, RATIO_AVERAGE_POPULARITY: 5.2975022, RATIO_NOVELTY: 0.2453413,
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 3599.6621
# Function value obtained: -0.0338
# Current minimum: -0.0361
# Iteration No: 28 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.2917985797724063, 'alpha': 0.001001006215223822, 'positive_only': True, 'topK': 12440}
# SLIMElasticNetRecommender: Processed 15176 (61.9%) in 5.00 min. Items per second: 50.58
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 7.42 min. Items per second: 55.03
# EvaluatorHoldout: Processed 41306 (100.0%) in 21.72 sec. Users per second: 1902
# SearchBayesianSkopt: Config 27 is suboptimal. Config: {'l1_ratio': 0.2917985797724063, 'alpha': 0.001001006215223822, 'positive_only': True, 'topK': 12440} - results: PRECISION: 0.0667990, PRECISION_RECALL_MIN_DEN: 0.0913705, RECALL: 0.0793654, MAP: 0.0343503, MAP_MIN_DEN: 0.0461066, MRR: 0.2116279, NDCG: 0.0953286, F1: 0.0725420, HIT_RATE: 0.4050017, ARHR_ALL_HITS: 0.2669171, NOVELTY: 0.0042729, AVERAGE_POPULARITY: 0.2066135, DIVERSITY_MEAN_INTER_LIST: 0.9371999, DIVERSITY_HERFINDAHL: 0.9937177, COVERAGE_ITEM: 0.0839352, COVERAGE_ITEM_HIT: 0.0436202, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.4018593, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0152364, SHANNON_ENTROPY: 8.6855901, RATIO_DIVERSITY_HERFINDAHL: 0.9940456, RATIO_DIVERSITY_GINI: 0.0299991, RATIO_SHANNON_ENTROPY: 0.6436879, RATIO_AVERAGE_POPULARITY: 4.0750454, RATIO_NOVELTY: 0.2597568,
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 467.5647
# Function value obtained: -0.0344
# Current minimum: -0.0361
# Iteration No: 29 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.004015147031842882, 'alpha': 0.1307108934188105, 'positive_only': True, 'topK': 4607}
# SLIMElasticNetRecommender: Processed 18041 (73.6%) in 5.00 min. Items per second: 60.13
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 6.56 min. Items per second: 62.25
# EvaluatorHoldout: Processed 41306 (100.0%) in 21.13 sec. Users per second: 1955
# SearchBayesianSkopt: Config 28 is suboptimal. Config: {'l1_ratio': 0.004015147031842882, 'alpha': 0.1307108934188105, 'positive_only': True, 'topK': 4607} - results: PRECISION: 0.0532998, PRECISION_RECALL_MIN_DEN: 0.0742902, RECALL: 0.0650253, MAP: 0.0260517, MAP_MIN_DEN: 0.0356086, MRR: 0.1732479, NDCG: 0.0762244, F1: 0.0585816, HIT_RATE: 0.3524670, ARHR_ALL_HITS: 0.2106491, NOVELTY: 0.0039054, AVERAGE_POPULARITY: 0.3190994, DIVERSITY_MEAN_INTER_LIST: 0.8101375, DIVERSITY_HERFINDAHL: 0.9810118, COVERAGE_ITEM: 0.0452932, COVERAGE_ITEM_HIT: 0.0186477, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3497322, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0044474, SHANNON_ENTROPY: 6.8684189, RATIO_DIVERSITY_HERFINDAHL: 0.9813355, RATIO_DIVERSITY_GINI: 0.0087566, RATIO_SHANNON_ENTROPY: 0.5090176, RATIO_AVERAGE_POPULARITY: 6.2936089, RATIO_NOVELTY: 0.2374178,
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 415.3077
# Function value obtained: -0.0261
# Current minimum: -0.0361
# Iteration No: 30 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.1918479804049117, 'alpha': 0.0019026828241802852, 'positive_only': True, 'topK': 4102}
# SLIMElasticNetRecommender: Processed 16268 (66.4%) in 5.00 min. Items per second: 54.22
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 7.09 min. Items per second: 57.64
# EvaluatorHoldout: Processed 41306 (100.0%) in 21.85 sec. Users per second: 1891
# SearchBayesianSkopt: Config 29 is suboptimal. Config: {'l1_ratio': 0.1918479804049117, 'alpha': 0.0019026828241802852, 'positive_only': True, 'topK': 4102} - results: PRECISION: 0.0654723, PRECISION_RECALL_MIN_DEN: 0.0896484, RECALL: 0.0779615, MAP: 0.0336091, MAP_MIN_DEN: 0.0452030, MRR: 0.2092664, NDCG: 0.0937002, F1: 0.0711732, HIT_RATE: 0.4011282, ARHR_ALL_HITS: 0.2626331, NOVELTY: 0.0042350, AVERAGE_POPULARITY: 0.2152162, DIVERSITY_MEAN_INTER_LIST: 0.9306405, DIVERSITY_HERFINDAHL: 0.9930618, COVERAGE_ITEM: 0.0710409, COVERAGE_ITEM_HIT: 0.0376219, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3980158, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0127589, SHANNON_ENTROPY: 8.4634832, RATIO_DIVERSITY_HERFINDAHL: 0.9933894, RATIO_DIVERSITY_GINI: 0.0251212, RATIO_SHANNON_ENTROPY: 0.6272276, RATIO_AVERAGE_POPULARITY: 4.2447159, RATIO_NOVELTY: 0.2574491,
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 447.5024
# Function value obtained: -0.0336
# Current minimum: -0.0361
# Iteration No: 31 started. Searching for the next optimal point.
# ...
#
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 353.8592
# Function value obtained: -0.0000
# Current minimum: -0.0361
# Iteration No: 42 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.006722022673099866, 'alpha': 0.001, 'positive_only': True, 'topK': 20000}
# SLIMElasticNetRecommender: Processed 4591 (18.7%) in 5.00 min. Items per second: 15.30
# SLIMElasticNetRecommender: Processed 9662 (39.4%) in 10.00 min. Items per second: 16.10
# SLIMElasticNetRecommender: Processed 14816 (60.5%) in 15.00 min. Items per second: 16.46
# SLIMElasticNetRecommender: Processed 19949 (81.4%) in 20.00 min. Items per second: 16.62
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 24.40 min. Items per second: 16.74
# EvaluatorHoldout: Processed 41306 (100.0%) in 44.14 sec. Users per second: 936
# SearchBayesianSkopt: Config 41 is suboptimal. Config: {'l1_ratio': 0.006722022673099866, 'alpha': 0.001, 'positive_only': True, 'topK': 20000} - results: PRECISION: 0.0691667, PRECISION_RECALL_MIN_DEN: 0.0940816, RECALL: 0.0815237, MAP: 0.0357488, MAP_MIN_DEN: 0.0476273, MRR: 0.2168968, NDCG: 0.0981562, F1: 0.0748385, HIT_RATE: 0.4121193, ARHR_ALL_HITS: 0.2755290, NOVELTY: 0.0042180, AVERAGE_POPULARITY: 0.2312412, DIVERSITY_MEAN_INTER_LIST: 0.9172297, DIVERSITY_HERFINDAHL: 0.9917207, COVERAGE_ITEM: 0.1401232, COVERAGE_ITEM_HIT: 0.0657363, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.4089217, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0184289, SHANNON_ENTROPY: 8.6910787, RATIO_DIVERSITY_HERFINDAHL: 0.9920480, RATIO_DIVERSITY_GINI: 0.0362850, RATIO_SHANNON_ENTROPY: 0.6440946, RATIO_AVERAGE_POPULARITY: 4.5607777, RATIO_NOVELTY: 0.2564158,
#
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 1509.5155
# Function value obtained: -0.0357
# Current minimum: -0.0361
# Iteration No: 43 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.08618895409608669, 'alpha': 0.047806531005953085, 'positive_only': True, 'topK': 5893}
# SLIMElasticNetRecommender: Processed 21481 (87.7%) in 5.00 min. Items per second: 71.60
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 5.70 min. Items per second: 71.69
# EvaluatorHoldout: Processed 41306 (100.0%) in 18.21 sec. Users per second: 2268
# SearchBayesianSkopt: Config 42 is suboptimal. Config: {'l1_ratio': 0.08618895409608669, 'alpha': 0.047806531005953085, 'positive_only': True, 'topK': 5893} - results: PRECISION: 0.0407519, PRECISION_RECALL_MIN_DEN: 0.0554228, RECALL: 0.0478243, MAP: 0.0207510, MAP_MIN_DEN: 0.0279632, MRR: 0.1445138, NDCG: 0.0598269, F1: 0.0440058, HIT_RATE: 0.2785068, ARHR_ALL_HITS: 0.1719022, NOVELTY: 0.0044045, AVERAGE_POPULARITY: 0.2685731, DIVERSITY_MEAN_INTER_LIST: 0.7979556, DIVERSITY_HERFINDAHL: 0.9797936, COVERAGE_ITEM: 0.0077937, COVERAGE_ITEM_HIT: 0.0054678, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.2763458, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0021062, SHANNON_ENTROPY: 6.0945670, RATIO_DIVERSITY_HERFINDAHL: 0.9801169, RATIO_DIVERSITY_GINI: 0.0041469, RATIO_SHANNON_ENTROPY: 0.4516675, RATIO_AVERAGE_POPULARITY: 5.2970774, RATIO_NOVELTY: 0.2677549,
#
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 360.7434
# Function value obtained: -0.0208
# Current minimum: -0.0361
# Iteration No: 44 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.09383439010217515, 'alpha': 0.002873257467955618, 'positive_only': False, 'topK': 19519}
# SLIMElasticNetRecommender: Processed 14953 (61.0%) in 5.00 min. Items per second: 49.84
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 7.51 min. Items per second: 54.35
# EvaluatorHoldout: Processed 41306 (100.0%) in 22.06 sec. Users per second: 1872
# SearchBayesianSkopt: Config 43 is suboptimal. Config: {'l1_ratio': 0.09383439010217515, 'alpha': 0.002873257467955618, 'positive_only': False, 'topK': 19519} - results: PRECISION: 0.0663221, PRECISION_RECALL_MIN_DEN: 0.0909389, RECALL: 0.0791013, MAP: 0.0341095, MAP_MIN_DEN: 0.0459318, MRR: 0.2118077, NDCG: 0.0950035, F1: 0.0721502, HIT_RATE: 0.4046386, ARHR_ALL_HITS: 0.2661076, NOVELTY: 0.0042289, AVERAGE_POPULARITY: 0.2156072, DIVERSITY_MEAN_INTER_LIST: 0.9307829, DIVERSITY_HERFINDAHL: 0.9930760, COVERAGE_ITEM: 0.0881381, COVERAGE_ITEM_HIT: 0.0413759, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.4014990, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0138392, SHANNON_ENTROPY: 8.5375970, RATIO_DIVERSITY_HERFINDAHL: 0.9934037, RATIO_DIVERSITY_GINI: 0.0272482, RATIO_SHANNON_ENTROPY: 0.6327201, RATIO_AVERAGE_POPULARITY: 4.2524289, RATIO_NOVELTY: 0.2570822,
#
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 473.5673
# Function value obtained: -0.0341
# Current minimum: -0.0361
# Iteration No: 45 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.015959495529271516, 'alpha': 0.005093766390354948, 'positive_only': False, 'topK': 5426}
# SLIMElasticNetRecommender: Processed 6874 (28.0%) in 5.00 min. Items per second: 22.91
# SLIMElasticNetRecommender: Processed 15626 (63.8%) in 10.00 min. Items per second: 26.04
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 14.84 min. Items per second: 27.52
# EvaluatorHoldout: Processed 41306 (100.0%) in 32.21 sec. Users per second: 1282
# SearchBayesianSkopt: Config 44 is suboptimal. Config: {'l1_ratio': 0.015959495529271516, 'alpha': 0.005093766390354948, 'positive_only': False, 'topK': 5426} - results: PRECISION: 0.0683484, PRECISION_RECALL_MIN_DEN: 0.0937380, RECALL: 0.0815370, MAP: 0.0350568, MAP_MIN_DEN: 0.0471532, MRR: 0.2150984, NDCG: 0.0973860, F1: 0.0743625, HIT_RATE: 0.4120467, ARHR_ALL_HITS: 0.2717809, NOVELTY: 0.0042055, AVERAGE_POPULARITY: 0.2208058, DIVERSITY_MEAN_INTER_LIST: 0.9271945, DIVERSITY_HERFINDAHL: 0.9927172, COVERAGE_ITEM: 0.1474273, COVERAGE_ITEM_HIT: 0.0487208, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.4088496, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0159959, SHANNON_ENTROPY: 8.6127573, RATIO_DIVERSITY_HERFINDAHL: 0.9930447, RATIO_DIVERSITY_GINI: 0.0314945, RATIO_SHANNON_ENTROPY: 0.6382902, RATIO_AVERAGE_POPULARITY: 4.3549604, RATIO_NOVELTY: 0.2556559,
#
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 923.4967
# Function value obtained: -0.0351
# Current minimum: -0.0361
# Iteration No: 46 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.11425008719960143, 'alpha': 0.01392203748680539, 'positive_only': False, 'topK': 4364}
# SLIMElasticNetRecommender: Processed 20678 (84.4%) in 5.00 min. Items per second: 68.92
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 5.88 min. Items per second: 69.51
# EvaluatorHoldout: Processed 41306 (100.0%) in 18.71 sec. Users per second: 2208
# SearchBayesianSkopt: Config 45 is suboptimal. Config: {'l1_ratio': 0.11425008719960143, 'alpha': 0.01392203748680539, 'positive_only': False, 'topK': 4364} - results: PRECISION: 0.0535128, PRECISION_RECALL_MIN_DEN: 0.0733494, RECALL: 0.0637697, MAP: 0.0273429, MAP_MIN_DEN: 0.0369579, MRR: 0.1798790, NDCG: 0.0777082, F1: 0.0581928, HIT_RATE: 0.3473103, ARHR_ALL_HITS: 0.2199515, NOVELTY: 0.0041717, AVERAGE_POPULARITY: 0.2588190, DIVERSITY_MEAN_INTER_LIST: 0.8771779, DIVERSITY_HERFINDAHL: 0.9877157, COVERAGE_ITEM: 0.0193006, COVERAGE_ITEM_HIT: 0.0143632, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3446155, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0048392, SHANNON_ENTROPY: 7.2088514, RATIO_DIVERSITY_HERFINDAHL: 0.9880415, RATIO_DIVERSITY_GINI: 0.0095279, RATIO_SHANNON_ENTROPY: 0.5342470, RATIO_AVERAGE_POPULARITY: 5.1046970, RATIO_NOVELTY: 0.2536056,
#
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 371.9056
# Function value obtained: -0.0273
# Current minimum: -0.0361
# Iteration No: 47 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.009378145983447297, 'alpha': 0.1296045452419314, 'positive_only': False, 'topK': 4208}
# SLIMElasticNetRecommender: Processed 20461 (83.5%) in 5.00 min. Items per second: 68.20
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 5.94 min. Items per second: 68.71
# EvaluatorHoldout: Processed 41306 (100.0%) in 19.34 sec. Users per second: 2136
# SearchBayesianSkopt: Config 46 is suboptimal. Config: {'l1_ratio': 0.009378145983447297, 'alpha': 0.1296045452419314, 'positive_only': False, 'topK': 4208} - results: PRECISION: 0.0502954, PRECISION_RECALL_MIN_DEN: 0.0699219, RECALL: 0.0610838, MAP: 0.0247472, MAP_MIN_DEN: 0.0337961, MRR: 0.1665610, NDCG: 0.0723814, F1: 0.0551671, HIT_RATE: 0.3359560, ARHR_ALL_HITS: 0.2013392, NOVELTY: 0.0039694, AVERAGE_POPULARITY: 0.3167221, DIVERSITY_MEAN_INTER_LIST: 0.8054278, DIVERSITY_HERFINDAHL: 0.9805408, COVERAGE_ITEM: 0.0211368, COVERAGE_ITEM_HIT: 0.0142816, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3333493, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0035341, SHANNON_ENTROPY: 6.6682698, RATIO_DIVERSITY_HERFINDAHL: 0.9808644, RATIO_DIVERSITY_GINI: 0.0069583, RATIO_SHANNON_ENTROPY: 0.4941845, RATIO_AVERAGE_POPULARITY: 6.2467210, RATIO_NOVELTY: 0.2413054,
#
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 376.6939
# Function value obtained: -0.0247
# Current minimum: -0.0361
# Iteration No: 48 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.012207397279854298, 'alpha': 0.0016497882677792939, 'positive_only': True, 'topK': 4000}
# SLIMElasticNetRecommender: Processed 5111 (20.9%) in 5.00 min. Items per second: 17.03
# SLIMElasticNetRecommender: Processed 10600 (43.3%) in 10.00 min. Items per second: 17.66
# SLIMElasticNetRecommender: Processed 16101 (65.7%) in 15.00 min. Items per second: 17.89
# SLIMElasticNetRecommender: Processed 21614 (88.2%) in 20.00 min. Items per second: 18.01
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 22.62 min. Items per second: 18.05
# EvaluatorHoldout: Processed 41306 (100.0%) in 45.34 sec. Users per second: 911
# SearchBayesianSkopt: Config 47 is suboptimal. Config: {'l1_ratio': 0.012207397279854298, 'alpha': 0.0016497882677792939, 'positive_only': True, 'topK': 4000} - results: PRECISION: 0.0700673, PRECISION_RECALL_MIN_DEN: 0.0956728, RECALL: 0.0830279, MAP: 0.0360244, MAP_MIN_DEN: 0.0481209, MRR: 0.2182862, NDCG: 0.0992946, F1: 0.0759990, HIT_RATE: 0.4174938, ARHR_ALL_HITS: 0.2774692, NOVELTY: 0.0042570, AVERAGE_POPULARITY: 0.2189621, DIVERSITY_MEAN_INTER_LIST: 0.9273639, DIVERSITY_HERFINDAHL: 0.9927341, COVERAGE_ITEM: 0.1497939, COVERAGE_ITEM_HIT: 0.0638185, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.4142545, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0197929, SHANNON_ENTROPY: 8.8311132, RATIO_DIVERSITY_HERFINDAHL: 0.9930617, RATIO_DIVERSITY_GINI: 0.0389705, RATIO_SHANNON_ENTROPY: 0.6544726, RATIO_AVERAGE_POPULARITY: 4.3185966, RATIO_NOVELTY: 0.2587885,
#
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 1403.8210
# Function value obtained: -0.0360
# Current minimum: -0.0361
# Iteration No: 49 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.3554212414402604, 'alpha': 0.003152236397276775, 'positive_only': False, 'topK': 7924}
# SLIMElasticNetRecommender: Processed 19799 (80.8%) in 5.00 min. Items per second: 65.99
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 6.10 min. Items per second: 66.97
# EvaluatorHoldout: Processed 41306 (100.0%) in 19.08 sec. Users per second: 2165
# SearchBayesianSkopt: Config 48 is suboptimal. Config: {'l1_ratio': 0.3554212414402604, 'alpha': 0.003152236397276775, 'positive_only': False, 'topK': 7924} - results: PRECISION: 0.0574565, PRECISION_RECALL_MIN_DEN: 0.0785129, RECALL: 0.0681855, MAP: 0.0296714, MAP_MIN_DEN: 0.0399766, MRR: 0.1916364, NDCG: 0.0833447, F1: 0.0623629, HIT_RATE: 0.3641844, ARHR_ALL_HITS: 0.2363145, NOVELTY: 0.0041973, AVERAGE_POPULARITY: 0.2396862, DIVERSITY_MEAN_INTER_LIST: 0.9027527, DIVERSITY_HERFINDAHL: 0.9902731, COVERAGE_ITEM: 0.0260742, COVERAGE_ITEM_HIT: 0.0182805, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.3613587, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0065380, SHANNON_ENTROPY: 7.6248781, RATIO_DIVERSITY_HERFINDAHL: 0.9905998, RATIO_DIVERSITY_GINI: 0.0128728, RATIO_SHANNON_ENTROPY: 0.5650787, RATIO_AVERAGE_POPULARITY: 4.7273385, RATIO_NOVELTY: 0.2551619,
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 385.7260
# Function value obtained: -0.0297
# Current minimum: -0.0361
# Iteration No: 50 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'l1_ratio': 0.027464197854653975, 'alpha': 0.19255520202002396, 'positive_only': False, 'topK': 15847}
# SLIMElasticNetRecommender: Processed 21505 (87.8%) in 5.00 min. Items per second: 71.68
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 5.69 min. Items per second: 71.75
# EvaluatorHoldout: Processed 41306 (100.0%) in 18.30 sec. Users per second: 2257
# SearchBayesianSkopt: Config 49 is suboptimal. Config: {'l1_ratio': 0.027464197854653975, 'alpha': 0.19255520202002396, 'positive_only': False, 'topK': 15847} - results: PRECISION: 0.0364717, PRECISION_RECALL_MIN_DEN: 0.0497760, RECALL: 0.0430189, MAP: 0.0181818, MAP_MIN_DEN: 0.0246293, MRR: 0.1298102, NDCG: 0.0533965, F1: 0.0394757, HIT_RATE: 0.2559434, ARHR_ALL_HITS: 0.1526454, NOVELTY: 0.0044078, AVERAGE_POPULARITY: 0.2889318, DIVERSITY_MEAN_INTER_LIST: 0.7505874, DIVERSITY_HERFINDAHL: 0.9750569, COVERAGE_ITEM: 0.0065696, COVERAGE_ITEM_HIT: 0.0040805, ITEMS_IN_GT: 0.9983678, COVERAGE_USER: 0.9922410, COVERAGE_USER_HIT: 0.2539576, USERS_IN_GT: 0.9922410, DIVERSITY_GINI: 0.0016231, SHANNON_ENTROPY: 5.7112000, RATIO_DIVERSITY_HERFINDAHL: 0.9753786, RATIO_DIVERSITY_GINI: 0.0031956, RATIO_SHANNON_ENTROPY: 0.4232562, RATIO_AVERAGE_POPULARITY: 5.6986114, RATIO_NOVELTY: 0.2679538,
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 360.6739
# Function value obtained: -0.0182
# Current minimum: -0.0361
# SearchBayesianSkopt: Search complete. Best config is 22: {'l1_ratio': 0.05652649721548329, 'alpha': 0.001, 'positive_only': True, 'topK': 4000}
#
# SearchBayesianSkopt: Evaluation with constructor data for final test. Using best config: {'l1_ratio': 0.05652649721548329, 'alpha': 0.001, 'positive_only': True, 'topK': 4000}
# SLIMElasticNetRecommender: Processed 4596 (18.8%) in 5.00 min. Items per second: 15.32
# SLIMElasticNetRecommender: Processed 9744 (39.8%) in 10.00 min. Items per second: 16.24
# SLIMElasticNetRecommender: Processed 14844 (60.6%) in 15.00 min. Items per second: 16.49
# SLIMElasticNetRecommender: Processed 20021 (81.7%) in 20.00 min. Items per second: 16.68
# SLIMElasticNetRecommender: Processed 24507 (100.0%) in 24.29 min. Items per second: 16.81
# SearchBayesianSkopt: Saving model in result_experiments/SLIMElasticNetRecommender
#
# SLIMElasticNetRecommender: Saving model in file 'result_experiments/SLIMElasticNetRecommender_best_model_last'
# SLIMElasticNetRecommender: Saving complete

# %%
from Recommenders.DataIO import DataIO

#explore the results of the search
data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_metadata.zip")

search_metadata.keys()
# Out:
# dict_keys(['algorithm_name_recommender', 'time_on_validation_total', 'time_on_train_total', 'result_on_validation_df', 'time_df', 'exception_list', 'hyperparameters_df', 'result_on_test_df', 'result_on_earlystopping_df', 'time_on_validation_avg', 'time_on_last_df', 'cutoff_to_optimize', 'result_on_last', 'time_on_train_avg', 'time_on_test_avg', 'result_on_test_best', 'algorithm_name_search', 'time_on_test_total', 'result_on_validation_best', 'hyperparameters_best', 'metric_to_optimize', 'hyperparameters_best_index'])

# %%
hyperparameters_df = search_metadata["hyperparameters_df"]
hyperparameters_df
# Out:
#     l1_ratio     alpha positive_only   topK
# 0    0.00595  0.046794         False  13470
# 1   0.124648  0.005976          True  11538
# 2    0.00482  0.008092         False   8191
# 3   0.125938   0.16124         False   9443
# 4   0.453179  0.022135          True  13671
# 5   0.005345  0.033381         False   5772
# 6   0.246914  0.007375         False  11188
# 7   0.004184  0.005401          True  17121
# 8   0.048202  0.020253          True  13615
# 9   0.029829   0.01696          True   9844
# 10  0.016899  0.021827          True  18177
# 11  0.020637  0.012373          True  16271
# 12  0.254401  0.153326          True  17187
# 13  0.010842  0.346691          True   6803
# 14  0.007164  0.006277          True   8170
# 15  0.023891     0.001         False  20000
# 16  0.793452  0.001023          True   5616
# 17  0.004124  0.001033          True   4576
# 18  0.143378  0.001001         False   4078
# 19  0.004008  0.395103         False  18138
# 20  0.039612  0.002323         False   4549
# 21  0.006964  0.002035         False  20000
# 22  0.056526     0.001          True   4000
# 23  0.789007  0.002672          True  19918
# 24  0.748717  0.371617         False   6439
# 25  0.059833  0.001413          True  20000
# 26     0.004   0.00218         False   4000
# 27  0.291799  0.001001          True  12440
# 28  0.004015  0.130711          True   4607
# 29  0.191848  0.001903          True   4102
# 30  0.011842  0.001009          True   8286
# 31  0.004072  0.018489          True  19782
# 32   0.75407  0.001041         False  10670
# 33     0.004     0.001          True  20000
# 34  0.015859  0.002499          True  20000
# 35  0.022687  0.079778          True   6353
# 36  0.023321  0.014622         False  18793
# 37  0.063298  0.396857          True  19570
# 38  0.781349  0.014458         False  12402
# 39  0.036693  0.005477          True  19667
# 40  0.788569  0.070577         False  12343
# 41  0.006722     0.001          True  20000
# 42  0.086189  0.047807          True   5893
# 43  0.093834  0.002873         False  19519
# 44  0.015959  0.005094         False   5426
# 45   0.11425  0.013922         False   4364
# 46  0.009378  0.129605         False   4208
# 47  0.012207   0.00165          True   4000
# 48  0.355421  0.003152         False   7924
# 49  0.027464  0.192555         False  15847

# %%
result_on_validation_df = search_metadata["result_on_validation_df"]
result_on_validation_df
# Out:
#           PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#    cutoff
# 0  10      0.059253                  0.08196  0.071534  0.029576    0.040218
# 1  10      0.060275                 0.082674  0.071903  0.030989    0.041793
# 2  10      0.067888                 0.093413  0.081336  0.034531      0.0466
# 3  10      0.008461                 0.011734  0.010296  0.006093    0.008327
# 4  10      0.026948                 0.035743  0.030391  0.013976    0.018539
# 5  10      0.061504                 0.084872  0.073991  0.030845    0.041836
# 6  10      0.052765                 0.072179  0.062672  0.027124    0.036666
# 7  10      0.068922                 0.094684   0.08242  0.035237    0.047455
# 8  10      0.056641                  0.07783  0.067753  0.028793      0.0389
# 9  10      0.060664                 0.083589  0.072827  0.030852    0.041749
# 10 10       0.06117                 0.084378  0.073565  0.031001    0.041974
# 11 10      0.064083                 0.088219  0.076855  0.032614    0.044051
# 12 10      0.000186                 0.000283  0.000247  0.000046    0.000065
# 13 10      0.039919                 0.055127  0.047969  0.019523    0.026653
# 14 10      0.068377                 0.093951  0.081788  0.034948    0.047068
# 15 10      0.069128                 0.093848  0.081242  0.035598    0.047422
# 16 10      0.060679                 0.083006  0.072116  0.031278    0.042087
# 17 10      0.068929                 0.093683  0.081147  0.035617    0.047413
# 18 10      0.068842                 0.094033  0.081641  0.035524    0.047546
# 19 10      0.045674                 0.063941  0.056071  0.021928    0.030219
# 20 10      0.069348                 0.094849  0.082395  0.035715    0.047943
# 21 10      0.069012                  0.09421  0.081701  0.035509     0.04746
# 22 10       0.07014                 0.095489  0.082787  0.036093    0.048134
# 23 10       0.05093                 0.069438  0.060144  0.026362    0.035555
# 24 10      0.000186                 0.000283  0.000247  0.000046    0.000065
# 25 10      0.069484                 0.094829  0.082295  0.035814    0.047897
# 26 10      0.066218                 0.091335  0.079908  0.033777    0.045721
# 27 10      0.066799                 0.091371  0.079365   0.03435    0.046107
# 28 10        0.0533                  0.07429  0.065025  0.026052    0.035609
# 29 10      0.065472                 0.089648  0.077961  0.033609    0.045203
# 30 10      0.069506                 0.094587  0.081992   0.03589    0.047829
# 31 10      0.065083                 0.089605  0.078057  0.032857    0.044412
# 32 10      0.060885                 0.083268  0.072351  0.031363    0.042219
# 33 10      0.068925                 0.093752  0.081238  0.035611     0.04744
# 34 10      0.069878                 0.095506   0.08295  0.035891    0.048106
# 35 10      0.049286                 0.068236   0.05948  0.024549    0.033476
# 36 10      0.062497                 0.086157   0.07508   0.03185    0.043097
# 37 10       0.00483                 0.006751  0.005951   0.00449    0.006268
# 38 10      0.024304                 0.032326    0.0275  0.012894    0.017129
# 39 10      0.066443                 0.091264  0.079434  0.034018    0.045863
# 40 10      0.000186                 0.000283  0.000247  0.000046    0.000065
# 41 10      0.069167                 0.094082  0.081524  0.035749    0.047627
# 42 10      0.040752                 0.055423  0.047824  0.020751    0.027963
# 43 10      0.066322                 0.090939  0.079101   0.03411    0.045932
# 44 10      0.068348                 0.093738  0.081537  0.035057    0.047153
# 45 10      0.053513                 0.073349   0.06377  0.027343    0.036958
# 46 10      0.050295                 0.069922  0.061084  0.024747    0.033796
# 47 10      0.070067                 0.095673  0.083028  0.036024    0.048121
# 48 10      0.057457                 0.078513  0.068185  0.029671    0.039977
# 49 10      0.036472                 0.049776  0.043019  0.018182    0.024629
#
#                 MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#    cutoff                                                        ...
# 0  10        0.1907  0.084728  0.064817  0.378081      0.235231  ...
# 1  10      0.197769  0.087009  0.065577   0.37796      0.245274  ...
# 2  10      0.212843  0.096572  0.074006  0.412168      0.268267  ...
# 3  10      0.055334  0.017023  0.009289  0.076502      0.058035  ...
# 4  10      0.101658  0.040065  0.028566  0.190699      0.118478  ...
# 5  10      0.196173  0.087735  0.067172  0.387111      0.243602  ...
# 6  10      0.179027  0.076947  0.057293  0.343219      0.218614  ...
# 7  10      0.216057  0.098091  0.075069  0.415291      0.273073  ...
# 8  10      0.186581  0.081686    0.0617   0.36278      0.229711  ...
# 9  10      0.196866  0.087218  0.066191  0.382099      0.244135  ...
# 10 10       0.19744  0.087767  0.066798  0.385247       0.24504  ...
# 11 10      0.204823  0.091684   0.06989  0.396601      0.255923  ...
# 12 10      0.000465  0.000213  0.000213  0.001864      0.000465  ...
# 13 10      0.138044  0.057958  0.043576  0.279039      0.163067  ...
# 14 10      0.214817  0.097372  0.074484  0.413306      0.271198  ...
# 15 10      0.215739  0.097825  0.074697  0.412991      0.274167  ...
# 16 10      0.198926  0.087541  0.065905  0.379557      0.247174  ...
# 17 10      0.216098  0.097762  0.074541  0.411103      0.274512  ...
# 18 10      0.216895  0.098064  0.074697  0.413402      0.274778  ...
# 19 10      0.151677  0.065617  0.050341  0.314288      0.181006  ...
# 20 10      0.217791  0.098743  0.075311  0.415024       0.27601  ...
# 21 10       0.21581  0.097928  0.074822  0.413693      0.273863  ...
# 22 10      0.218222  0.099258   0.07594  0.417131      0.277685  ...
# 23 10      0.175235  0.074614  0.055155  0.333075      0.213238  ...
# 24 10      0.000465  0.000213  0.000213  0.001864      0.000465  ...
# 25 10      0.217409  0.098707  0.075349  0.414976      0.276175  ...
# 26 10      0.211316  0.094917  0.072422  0.407011      0.264646  ...
# 27 10      0.211628  0.095329  0.072542  0.405002      0.266917  ...
# 28 10      0.173248  0.076224  0.058582  0.352467      0.210649  ...
# 29 10      0.209266    0.0937  0.071173  0.401128      0.262633  ...
# 30 10      0.217645  0.098594  0.075234  0.414226      0.276528  ...
# 31 10       0.20525  0.092572  0.070982  0.401177        0.2571  ...
# 32 10      0.199317  0.087793  0.066125   0.38055      0.247734  ...
# 33 10      0.216324  0.097815  0.074577  0.411514      0.274605  ...
# 34 10      0.218253  0.099218  0.075855  0.417349       0.27698  ...
# 35 10      0.165695  0.071374  0.053905  0.329177      0.200002  ...
# 36 10      0.201528  0.089766  0.068213  0.390064      0.250913  ...
# 37 10      0.044159  0.012068  0.005332  0.047499      0.044529  ...
# 38 10      0.095265  0.036859  0.025803  0.175108      0.110257  ...
# 39 10      0.210912   0.09495   0.07236  0.405437      0.265132  ...
# 40 10      0.000465  0.000213  0.000213  0.001864      0.000465  ...
# 41 10      0.216897  0.098156  0.074839  0.412119      0.275529  ...
# 42 10      0.144514  0.059827  0.044006  0.278507      0.171902  ...
# 43 10      0.211808  0.095004   0.07215  0.404639      0.266108  ...
# 44 10      0.215098  0.097386  0.074362  0.412047      0.271781  ...
# 45 10      0.179879  0.077708  0.058193   0.34731      0.219951  ...
# 46 10      0.166561  0.072381  0.055167  0.335956      0.201339  ...
# 47 10      0.218286  0.099295  0.075999  0.417494      0.277469  ...
# 48 10      0.191636  0.083345  0.062363  0.364184      0.236315  ...
# 49 10       0.12981  0.053396  0.039476  0.255943      0.152645  ...
#
#           COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
#    cutoff
# 0  10          0.992241          0.375147    0.992241       0.007104
# 1  10          0.992241          0.375027    0.992241       0.007768
# 2  10          0.992241           0.40897    0.992241        0.01331
# 3  10          0.992241          0.075909    0.992241       0.000676
# 4  10          0.992241          0.189219    0.992241       0.001273
# 5  10          0.992241          0.384107    0.992241       0.008579
# 6  10          0.992241          0.340556    0.992241        0.00469
# 7  10          0.992241          0.412069    0.992241       0.014669
# 8  10          0.992241          0.359965    0.992241       0.005788
# 9  10          0.992241          0.379135    0.992241       0.007771
# 10 10          0.992241          0.382258    0.992241       0.008149
# 11 10          0.992241          0.393524    0.992241       0.010401
# 12 10          0.992241           0.00185    0.992241       0.000558
# 13 10          0.992241          0.276874    0.992241       0.001749
# 14 10          0.992241          0.410099    0.992241       0.015148
# 15 10          0.992241          0.409786    0.992241       0.021245
# 16 10          0.992241          0.376612    0.992241       0.008363
# 17 10          0.992241          0.407913    0.992241       0.017961
# 18 10          0.992241          0.410195    0.992241       0.020928
# 19 10          0.992241           0.31185    0.992241       0.002462
# 20 10          0.992241          0.411804    0.992241       0.019598
# 21 10          0.992241          0.410483    0.992241       0.017822
# 22 10          0.992241          0.413894    0.992241       0.025245
# 23 10          0.992241          0.330491    0.992241       0.004294
# 24 10          0.992241           0.00185    0.992241       0.000558
# 25 10          0.992241          0.411756    0.992241       0.022925
# 26 10          0.992241          0.403853    0.992241       0.010216
# 27 10          0.992241          0.401859    0.992241       0.015236
# 28 10          0.992241          0.349732    0.992241       0.004447
# 29 10          0.992241          0.398016    0.992241       0.012759
# 30 10          0.992241          0.411012    0.992241       0.019719
# 31 10          0.992241          0.398064    0.992241       0.010984
# 32 10          0.992241          0.377597    0.992241       0.008526
# 33 10          0.992241          0.408321    0.992241       0.017742
# 34 10          0.992241           0.41411    0.992241       0.019722
# 35 10          0.992241          0.326623    0.992241       0.003423
# 36 10          0.992241          0.387038    0.992241       0.009165
# 37 10          0.992241          0.047131    0.992241       0.000605
# 38 10          0.992241          0.173749    0.992241       0.001154
# 39 10          0.992241          0.402292    0.992241       0.013596
# 40 10          0.992241           0.00185    0.992241       0.000558
# 41 10          0.992241          0.408922    0.992241       0.018429
# 42 10          0.992241          0.276346    0.992241       0.002106
# 43 10          0.992241          0.401499    0.992241       0.013839
# 44 10          0.992241           0.40885    0.992241       0.015996
# 45 10          0.992241          0.344616    0.992241       0.004839
# 46 10          0.992241          0.333349    0.992241       0.003534
# 47 10          0.992241          0.414254    0.992241       0.019793
# 48 10          0.992241          0.361359    0.992241       0.006538
# 49 10          0.992241          0.253958    0.992241       0.001623
#
#           SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
#    cutoff
# 0  10            7.513599                   0.987244             0.013987
# 1  10            7.836037                   0.991171             0.015294
# 2  10            8.325136                   0.991065             0.026207
# 3  10            4.357296                   0.940497             0.001331
# 4  10            5.321722                   0.969803             0.002507
# 5  10            7.741713                   0.988678             0.016892
# 6  10            7.176693                   0.988187             0.009233
# 7  10            8.469961                   0.991944             0.028882
# 8  10            7.421604                   0.988652             0.011396
# 9  10            7.774909                   0.990097             0.015301
# 10 10             7.79071                   0.989744             0.016045
# 11 10            8.109132                   0.991364             0.020479
# 12 10            4.006496                   0.927913             0.001098
# 13 10            5.808276                   0.974045             0.003444
# 14 10            8.522977                   0.992459             0.029826
# 15 10            8.951962                   0.993853              0.04183
# 16 10             7.95148                   0.991976             0.016465
# 17 10            8.681366                   0.992382             0.035364
# 18 10            9.028634                   0.994627             0.041206
# 19 10            6.137225                   0.973473             0.004848
# 20 10            8.892938                      0.994             0.038586
# 21 10            8.745647                   0.993255              0.03509
# 22 10            9.188708                   0.994456             0.049706
# 23 10            7.067065                   0.987882             0.008454
# 24 10            4.006496                   0.927913             0.001098
# 25 10            9.105352                   0.994605             0.045137
# 26 10            7.902302                   0.988592             0.020114
# 27 10             8.68559                   0.994046             0.029999
# 28 10            6.868419                   0.981335             0.008757
# 29 10            8.463483                   0.993389             0.025121
# 30 10            8.779665                   0.992392             0.038825
# 31 10            8.064016                     0.9905             0.021626
# 32 10            7.976452                   0.992063             0.016788
# 33 10            8.641388                   0.991853             0.034933
# 34 10            8.857854                   0.993397              0.03883
# 35 10              6.6909                    0.98271             0.006739
# 36 10            7.962444                   0.990791             0.018044
# 37 10            4.164147                   0.933886             0.001192
# 38 10            5.180227                   0.966118             0.002272
# 39 10            8.472778                   0.992938              0.02677
# 40 10            4.006496                   0.927913             0.001098
# 41 10            8.691079                   0.992048             0.036285
# 42 10            6.094567                   0.980117             0.004147
# 43 10            8.537597                   0.993404             0.027248
# 44 10            8.612757                   0.993045             0.031494
# 45 10            7.208851                   0.988042             0.009528
# 46 10             6.66827                   0.980864             0.006958
# 47 10            8.831113                   0.993062              0.03897
# 48 10            7.624878                     0.9906             0.012873
# 49 10              5.7112                   0.975379             0.003196
#
#           RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
#    cutoff
# 0  10                  0.556832                 5.494586      0.242939
# 1  10                  0.580728                 4.700563      0.253411
# 2  10                  0.616975                 4.795888      0.251393
# 3  10                  0.322919                 1.489568      0.362991
# 4  10                  0.394392                  4.07151      0.304206
# 5  10                  0.573737                 5.262983      0.244725
# 6  10                  0.531864                 4.992976      0.256299
# 7  10                  0.627708                 4.605218      0.253566
# 8  10                  0.550014                 5.148034      0.249848
# 9  10                  0.576197                  4.96706      0.249195
# 10 10                  0.577368                  5.05369      0.247614
# 11 10                  0.600967                 4.738158      0.250632
# 12 10                  0.296921                 0.072456      0.384454
# 13 10                  0.430451                 6.430282      0.253269
# 14 10                  0.631637                 4.490873      0.254346
# 15 10                  0.663429                  4.15091      0.260347
# 16 10                  0.589283                 4.499718      0.256204
# 17 10                  0.643375                 4.502284      0.256283
# 18 10                  0.669111                 3.909195      0.262702
# 19 10                  0.454829                 6.992822       0.23716
# 20 10                  0.659054                 4.094488      0.259862
# 21 10                  0.648139                  4.31987      0.257208
# 22 10                  0.680974                  3.93306      0.264338
# 23 10                  0.523739                 4.883965      0.259963
# 24 10                  0.296921                 0.072456      0.384454
# 25 10                  0.674796                 3.910563      0.263116
# 26 10                  0.585638                 5.297502      0.245341
# 27 10                  0.643688                 4.075045      0.259757
# 28 10                  0.509018                 6.293609      0.237418
# 29 10                  0.627228                 4.244716      0.257449
# 30 10                   0.65066                 4.472008      0.257821
# 31 10                  0.597623                 4.927956      0.248103
# 32 10                  0.591134                 4.485561      0.256235
# 33 10                  0.640412                 4.609933      0.255633
# 34 10                  0.656454                 4.235632      0.259214
# 35 10                  0.495862                 5.899416      0.247099
# 36 10                  0.590096                 4.850402      0.249687
# 37 10                  0.308604                 0.878171       0.37447
# 38 10                  0.383906                 3.637895      0.314468
# 39 10                  0.627916                 4.377126      0.255075
# 40 10                  0.296921                 0.072456      0.384454
# 41 10                  0.644095                 4.560778      0.256416
# 42 10                  0.451668                 5.297077      0.267755
# 43 10                   0.63272                 4.252429      0.257082
# 44 10                   0.63829                  4.35496      0.255656
# 45 10                  0.534247                 5.104697      0.253606
# 46 10                  0.494185                 6.246721      0.241305
# 47 10                  0.654473                 4.318597      0.258789
# 48 10                  0.565079                 4.727339      0.255162
# 49 10                  0.423256                 5.698611      0.267954
#
# [50 rows x 27 columns]

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters
# Out:
# {'l1_ratio': 0.05652649721548329,
#  'alpha': 0.001,
#  'positive_only': True,
#  'topK': 4000}

# %%
#recommender = SLIMElasticNetRecommender(URM_all)
#recommender.fit(l1_ratio = 0.001, alpha = 0.01, positive_only = True, topK = 200)

# %%
#recommender.save_model(output_folder_path, file_name = recommender.RECOMMENDER_NAME + "_my_own_save.zip" )

# %%
#test_users = pd.read_csv('../input/recsyschallenge/data_target_users_test.csv')

# %%
#user_id = test_users['user_id']
#recommendations = []
#for user in user_id:
 #   recommendations.append(recommender.recommend(user,cutoff = 10))
#for index in range(len(recommendations)):
 #   recommendations[index]=np.array(recommendations[index])
    
#test_users['item_list']= recommendations
#test_users['item_list'] = pd.DataFrame([str(line).strip('[').strip(']').replace("'","") for line in test_users['item_list']])
#test_users.to_csv('submission.csv', index=False)
