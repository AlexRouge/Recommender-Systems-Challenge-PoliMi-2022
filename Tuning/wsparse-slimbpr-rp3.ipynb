# %%
# !cp -r ../input/recsys-repo/RecSys_Course_AT_PoliMi-master/* ./
# %config Completer.use_jedi = False
# %load_ext Cython
import pandas as pd
import numpy as np
import scipy.sparse as sps
import matplotlib.pyplot as pyplot
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample
from Evaluation.Evaluator import EvaluatorHoldout
from Recommenders.GraphBased.RP3betaRecommender import RP3betaRecommender
from Recommenders.GraphBased.P3alphaRecommender import P3alphaRecommender
from Recommenders.EASE_R.EASE_R_Recommender import EASE_R_Recommender
from Recommenders.KNN.ItemKNNCustomSimilarityRecommender import ItemKNNCustomSimilarityRecommender

# %%
# !python run_compile_all_cython.py
# Out:
# run_compile_all_cython: Found 10 Cython files in 4 folders...
# run_compile_all_cython: All files will be compiled using your current python environment: '/opt/conda/bin/python'
# Compiling [1/10]: MatrixFactorizationImpressions_Cython_Epoch.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from MatrixFactorizationImpressions_Cython_Epoch.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# MatrixFactorizationImpressions_Cython_Epoch.c: In function ‘__pyx_f_43MatrixFactorizationImpressions_Cython_Epoch_32MatrixFactorization_Cython_Epoch_sampleBPR_Cython’:
# MatrixFactorizationImpressions_Cython_Epoch.c:12758:17: warning: ‘__pyx_v_start_pos_impression_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# 12758 |       __pyx_t_4 = (__pyx_v_start_pos_impression_items + __pyx_v_index);
#       |       ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# MatrixFactorizationImpressions_Cython_Epoch.c: In function ‘__pyx_pf_43MatrixFactorizationImpressions_Cython_Epoch_32MatrixFactorization_Cython_Epoch_10epochIteration_Cython_ASY_SVD_SGD’:
# MatrixFactorizationImpressions_Cython_Epoch.c:8736:7: warning: ‘__pyx_v_end_pos_seen_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  8736 |       for (__pyx_t_19 = __pyx_v_start_pos_seen_items; __pyx_t_19 < __pyx_t_18; __pyx_t_19+=1) {
#       |       ^~~
# MatrixFactorizationImpressions_Cython_Epoch.c:8736:7: warning: ‘__pyx_v_start_pos_seen_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/MatrixFactorization/Cython/MatrixFactorizationImpressions_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [1/10]: MatrixFactorizationImpressions_Cython_Epoch.pyx... PASS
#
# Compiling [2/10]: MatrixFactorization_Cython_Epoch.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from MatrixFactorization_Cython_Epoch.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# MatrixFactorization_Cython_Epoch.c: In function ‘__pyx_pf_32MatrixFactorization_Cython_Epoch_32MatrixFactorization_Cython_Epoch_10epochIteration_Cython_ASY_SVD_SGD’:
# MatrixFactorization_Cython_Epoch.c:8669:9: warning: ‘__pyx_v_end_pos_seen_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  8669 |         for (__pyx_t_19 = __pyx_v_start_pos_seen_items; __pyx_t_19 < __pyx_t_18; __pyx_t_19+=1) {
#       |         ^~~
# MatrixFactorization_Cython_Epoch.c:8669:9: warning: ‘__pyx_v_start_pos_seen_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/MatrixFactorization/Cython/MatrixFactorization_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [2/10]: MatrixFactorization_Cython_Epoch.pyx... PASS
#
# Compiling [3/10]: Compute_Similarity_Cython.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from Compute_Similarity_Cython.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/Similarity/Cython/Compute_Similarity_Cython.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [3/10]: Compute_Similarity_Cython.pyx... PASS
#
# Compiling [4/10]: Triangular_Matrix.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from Triangular_Matrix.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/SLIM/Cython/Triangular_Matrix.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [4/10]: Triangular_Matrix.pyx... PASS
#
# Compiling [5/10]: SLIM_BPR_Cython_Epoch.pyx...
# warning: SLIM_BPR_Cython_Epoch.pyx:633:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:633:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from SLIM_BPR_Cython_Epoch.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# SLIM_BPR_Cython_Epoch.c: In function ‘__pyx_f_21SLIM_BPR_Cython_Epoch_22Sparse_Matrix_Tree_CSR_test_list_tee_conversion’:
# SLIM_BPR_Cython_Epoch.c:10848:15: warning: ‘__pyx_v_previous_element’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# 10848 |     __pyx_t_7 = __pyx_v_current_element->lower;
#       |     ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/SLIM/Cython/SLIM_BPR_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: SLIM_BPR_Cython_Epoch.pyx:633:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:633:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# Compiling [5/10]: SLIM_BPR_Cython_Epoch.pyx... PASS
#
# Compiling [6/10]: Sparse_Matrix_Tree_CSR.pyx...
# warning: Sparse_Matrix_Tree_CSR.pyx:132:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:132:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from Sparse_Matrix_Tree_CSR.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# Sparse_Matrix_Tree_CSR.c: In function ‘__pyx_f_22Sparse_Matrix_Tree_CSR_22Sparse_Matrix_Tree_CSR_test_list_tree_conversion’:
# Sparse_Matrix_Tree_CSR.c:5844:15: warning: ‘__pyx_v_previous_element’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  5844 |     __pyx_t_7 = __pyx_v_current_element->lower;
#       |     ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/SLIM/Cython/Sparse_Matrix_Tree_CSR.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: Sparse_Matrix_Tree_CSR.pyx:132:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:132:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# Compiling [6/10]: Sparse_Matrix_Tree_CSR.pyx... PASS
#
# Compiling [7/10]: FBSM_Rating_Cython_SGD.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from FBSM_Rating_Cython_SGD.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# FBSM_Rating_Cython_SGD.c: In function ‘__pyx_pf_22FBSM_Rating_Cython_SGD_22FBSM_Rating_Cython_SGD_2fit’:
# FBSM_Rating_Cython_SGD.c:9031:55: warning: ‘__pyx_v_num_sample’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  9031 |   __pyx_t_5 = PyFloat_FromDouble((__pyx_v_cum_loss / ((double)__pyx_v_num_sample))); if (unlikely(!__pyx_t_5)) __PYX_ERR(0, 551, __pyx_L1_error)
#       |                                                      ~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/FeatureWeighting/Cython/FBSM_Rating_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [7/10]: FBSM_Rating_Cython_SGD.pyx... PASS
#
# Compiling [8/10]: CFW_DVV_Similarity_Cython_SGD.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from CFW_DVV_Similarity_Cython_SGD.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/FeatureWeighting/Cython/CFW_DVV_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [8/10]: CFW_DVV_Similarity_Cython_SGD.pyx... PASS
#
# Compiling [9/10]: CFW_D_Similarity_Cython_SGD.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from CFW_D_Similarity_Cython_SGD.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# CFW_D_Similarity_Cython_SGD.c: In function ‘__pyx_pf_27CFW_D_Similarity_Cython_SGD_27CFW_D_Similarity_Cython_SGD_6fit’:
# CFW_D_Similarity_Cython_SGD.c:6056:55: warning: ‘__pyx_v_sample_num’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  6056 |   __pyx_t_3 = PyFloat_FromDouble((__pyx_v_cum_loss / ((double)__pyx_v_sample_num))); if (unlikely(!__pyx_t_3)) __PYX_ERR(0, 290, __pyx_L1_error)
#       |                                                      ~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/FeatureWeighting/Cython/CFW_D_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [9/10]: CFW_D_Similarity_Cython_SGD.pyx... PASS
#
# Compiling [10/10]: HP3_Similarity_Cython_SGD.pyx...
# warning: HP3_Similarity_Cython_SGD.pyx:113:40: Index should be typed for more efficient access
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1969,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from HP3_Similarity_Cython_SGD.c:746:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# HP3_Similarity_Cython_SGD.c: In function ‘__pyx_pf_25HP3_Similarity_Cython_SGD_25HP3_Similarity_Cython_SGD_4fit’:
# HP3_Similarity_Cython_SGD.c:6303:55: warning: ‘__pyx_v_sample_num’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  6303 |   __pyx_t_1 = PyFloat_FromDouble((__pyx_v_cum_loss / ((double)__pyx_v_sample_num))); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 291, __pyx_L1_error)
#       |                                                      ~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/FeatureWeighting/Cython/HP3_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: HP3_Similarity_Cython_SGD.pyx:113:40: Index should be typed for more efficient access
# Compiling [10/10]: HP3_Similarity_Cython_SGD.pyx... PASS
#
# run_compile_all_cython: Compilation finished. SUCCESS.
# Compilation log can be found here: './result_experiments/run_compile_all_cython.txt'

# %%
ICM_type_df = pd.read_csv("/kaggle/input/competition-data/data_ICM_type.csv")
ICM_type_df

items = ICM_type_df.item_id
features = ICM_type_df.feature_id
data = ICM_type_df.data
ICM_type = sps.csr_matrix((data, (items, features)))
ICM_type = ICM_type.astype(dtype = np.int32)

n_users = 41629
n_itemsFromICM = ICM_type.shape[0]
ICM_type.shape
# Out:
# (27968, 8)

# %%
URM_train = sps.load_npz("/kaggle/input/reeborooba/trainDefault.npz")
URM_train = sps.csr_matrix((URM_train.data, URM_train.indices, URM_train.indptr), shape=(n_users, n_itemsFromICM))
URM_train
# Out:
# <41629x27968 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1321444 stored elements in Compressed Sparse Row format>

# %%
URM_valid = sps.load_npz("/kaggle/input/reeborooba/validDefault.npz")
URM_valid = sps.csr_matrix((URM_valid.data, URM_valid.indices, URM_valid.indptr), shape=(n_users, n_itemsFromICM))
URM_valid
# Out:
# <41629x27968 sparse matrix of type '<class 'numpy.float64'>'
# 	with 233196 stored elements in Compressed Sparse Row format>

# %%
URM_train_stacked = sps.vstack([URM_train, ICM_type.T])
URM_train_stacked = sps.csr_matrix(URM_train_stacked)

# %%
#create an evaluator object to evaluate validation set
#we will use it for hyperparameter tuning
evaluator_valid = EvaluatorHoldout(URM_valid, cutoff_list=[10])
# Out:
# EvaluatorHoldout: Ignoring 963 ( 2.3%) Users that have less than 1 test interactions

# %%
import implicit
from Recommenders.BaseMatrixFactorizationRecommender import BaseMatrixFactorizationRecommender
import scipy.sparse as sps
class ImplicitALSRecommender(BaseMatrixFactorizationRecommender):
    """ImplicitALSRecommender recommender"""

    RECOMMENDER_NAME = "ImplicitALSRecommender"

    def fit(self,
            factors=100,
            regularization=0.01,
            use_native=True, use_cg=True, use_gpu=False,
            iterations=15,
            calculate_training_loss=False, num_threads=0,
            confidence_scaling=None,
            icm_coeff = 1,
            **confidence_args
            ):
        self.rec = implicit.als.AlternatingLeastSquares(factors=factors, regularization=regularization,
                                                        use_native=use_native, use_cg=use_cg, use_gpu=use_gpu,
                                                        iterations=iterations,
                                                        calculate_training_loss=calculate_training_loss,
                                                        num_threads=num_threads,
                                                        random_state=5)
        self.rec.fit(confidence_scaling(self.URM_train, **confidence_args), show_progress=self.verbose)

        self.USER_factors = self.rec.user_factors
        self.ITEM_factors = self.rec.item_factors

# %%
import numpy as np
import scipy.sparse as sps
from Recommenders.Recommender_utils import check_matrix
from sklearn.linear_model import ElasticNet
from Recommenders.BaseSimilarityMatrixRecommender import BaseItemSimilarityMatrixRecommender
from Utils.seconds_to_biggest_unit import seconds_to_biggest_unit
import time, sys
from tqdm import tqdm
from sklearn.utils._testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning

# os.environ["PYTHONWARNINGS"] = ('ignore::exceptions.ConvergenceWarning:sklearn.linear_model')
# os.environ["PYTHONWARNINGS"] = ('ignore:Objective did not converge:ConvergenceWarning:')

class SLIMElasticNetRecommender(BaseItemSimilarityMatrixRecommender):
    """
    Train a Sparse Linear Methods (SLIM) item similarity model.
    NOTE: ElasticNet solver is parallel, a single intance of SLIM_ElasticNet will
          make use of half the cores available
    See:
        Efficient Top-N Recommendation by Linear Regression,
        M. Levy and K. Jack, LSRS workshop at RecSys 2013.
        SLIM: Sparse linear methods for top-n recommender systems,
        X. Ning and G. Karypis, ICDM 2011.
        http://glaros.dtc.umn.edu/gkhome/fetch/papers/SLIM2011icdm.pdf
    """

    RECOMMENDER_NAME = "SLIMElasticNetRecommender"

    def __init__(self, URM_train, verbose = True):
        super(SLIMElasticNetRecommender, self).__init__(URM_train, verbose = verbose)

    @ignore_warnings(category=ConvergenceWarning)
    def fit(self, l1_ratio=0.1, alpha = 1.0, positive_only=True, topK = 100,**earlystopping_kwargs):

        assert l1_ratio>= 0 and l1_ratio<=1, "{}: l1_ratio must be between 0 and 1, provided value was {}".format(self.RECOMMENDER_NAME, l1_ratio)

        self.l1_ratio = l1_ratio
        self.positive_only = positive_only
        self.topK = topK


        # initialize the ElasticNet model
        self.model = ElasticNet(alpha=alpha,
                                l1_ratio=self.l1_ratio,
                                positive=self.positive_only,
                                fit_intercept=False,
                                copy_X=False,
                                precompute=True,
                                selection='random',
                                max_iter=100,
                                tol=1e-4)

        URM_train = check_matrix(self.URM_train, 'csc', dtype=np.float32)

        n_items = URM_train.shape[1]

        # Use array as it reduces memory requirements compared to lists
        dataBlock = 10000000

        rows = np.zeros(dataBlock, dtype=np.int32)
        cols = np.zeros(dataBlock, dtype=np.int32)
        values = np.zeros(dataBlock, dtype=np.float32)

        numCells = 0

        start_time = time.time()
        start_time_printBatch = start_time

        # fit each item's factors sequentially (not in parallel)
        for currentItem in range(n_items):

            # get the target column
            y = URM_train[:, currentItem].toarray()

            # set the j-th column of X to zero
            start_pos = URM_train.indptr[currentItem]
            end_pos = URM_train.indptr[currentItem + 1]

            current_item_data_backup = URM_train.data[start_pos: end_pos].copy()
            URM_train.data[start_pos: end_pos] = 0.0

            # fit one ElasticNet model per column
            self.model.fit(URM_train, y)

            # self.model.coef_ contains the coefficient of the ElasticNet model
            # let's keep only the non-zero values

            # Select topK values
            # Sorting is done in three steps. Faster then plain np.argsort for higher number of items
            # - Partition the data to extract the set of relevant items
            # - Sort only the relevant items
            # - Get the original item index

            nonzero_model_coef_index = self.model.sparse_coef_.indices
            nonzero_model_coef_value = self.model.sparse_coef_.data

            local_topK = min(len(nonzero_model_coef_value)-1, self.topK)

            relevant_items_partition = (-nonzero_model_coef_value).argpartition(local_topK)[0:local_topK]
            relevant_items_partition_sorting = np.argsort(-nonzero_model_coef_value[relevant_items_partition])
            ranking = relevant_items_partition[relevant_items_partition_sorting]

            for index in range(len(ranking)):

                if numCells == len(rows):
                    rows = np.concatenate((rows, np.zeros(dataBlock, dtype=np.int32)))
                    cols = np.concatenate((cols, np.zeros(dataBlock, dtype=np.int32)))
                    values = np.concatenate((values, np.zeros(dataBlock, dtype=np.float32)))


                rows[numCells] = nonzero_model_coef_index[ranking[index]]
                cols[numCells] = currentItem
                values[numCells] = nonzero_model_coef_value[ranking[index]]

                numCells += 1

            # finally, replace the original values of the j-th column
            URM_train.data[start_pos:end_pos] = current_item_data_backup

            elapsed_time = time.time() - start_time
            new_time_value, new_time_unit = seconds_to_biggest_unit(elapsed_time)


            if time.time() - start_time_printBatch > 300 or currentItem == n_items-1:
                self._print("Processed {} ({:4.1f}%) in {:.2f} {}. Items per second: {:.2f}".format(
                    currentItem+1,
                    100.0* float(currentItem+1)/n_items,
                    new_time_value,
                    new_time_unit,
                    float(currentItem)/elapsed_time))

                sys.stdout.flush()
                sys.stderr.flush()

                start_time_printBatch = time.time()

        # generate the sparse weight matrix
        self.W_sparse = sps.csr_matrix((values[:numCells], (rows[:numCells], cols[:numCells])),
                                       shape=(n_items, n_items), dtype=np.float32)

# %%
from Recommenders.BaseMatrixFactorizationRecommender import BaseMatrixFactorizationRecommender
from Recommenders.Incremental_Training_Early_Stopping import Incremental_Training_Early_Stopping
from Recommenders.Recommender_utils import check_matrix

def linear_scaling_confidence(URM_train, alpha):
    C = check_matrix(URM_train.T, format="csr", dtype=np.float32)
    C.data = 1.0 + alpha * C.data

    return C

# %%
import os

output_folder_path = "result_experiments/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# %%
from Recommenders.SLIM.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython

slim_bpr = SLIM_BPR_Cython(URM_train)
slim_bpr.fit(epochs=650, sgd_mode = "sgd", topK = 483, lambda_i = 0.0006712905081189398, lambda_j = 0.06584150350451998, learning_rate = 0.0036482363905043207)
# Out:
# SLIM_BPR_Recommender: URM Detected 3461 (12.4%) items with no interactions.
# SLIM_BPR_Recommender: Automatic selection of fastest train mode. Available RAM is 30777.00 MB (95.85%) of 32110.00 MB, required is 3128.84 MB. Using dense matrix.
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 2.69E-03. Sample per second: 36708
# SLIM_BPR_Recommender: Epoch 1 of 650. Elapsed time 0.26 sec
# Processed 41629 (100.0%) in 0.39 sec. BPR loss is 1.71E-02. Sample per second: 106222
# SLIM_BPR_Recommender: Epoch 2 of 650. Elapsed time 0.51 sec
# Processed 41629 (100.0%) in 0.65 sec. BPR loss is 3.71E-02. Sample per second: 64378
# SLIM_BPR_Recommender: Epoch 3 of 650. Elapsed time 0.77 sec
# Processed 41629 (100.0%) in 0.90 sec. BPR loss is 6.29E-02. Sample per second: 46384
# SLIM_BPR_Recommender: Epoch 4 of 650. Elapsed time 1.02 sec
# Processed 41629 (100.0%) in 1.15 sec. BPR loss is 9.29E-02. Sample per second: 36217
# SLIM_BPR_Recommender: Epoch 5 of 650. Elapsed time 1.27 sec
# Processed 41629 (100.0%) in 0.41 sec. BPR loss is 1.22E-01. Sample per second: 102336
# SLIM_BPR_Recommender: Epoch 6 of 650. Elapsed time 1.53 sec
# Processed 41629 (100.0%) in 0.66 sec. BPR loss is
min
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 1.07E+01. Sample per second: 42693
# SLIM_BPR_Recommender: Epoch 646 of 650. Elapsed time 2.68 min
# Processed 41629 (100.0%) in 1.22 sec. BPR loss is 1.07E+01. Sample per second: 34124
# SLIM_BPR_Recommender: Epoch 647 of 650. Elapsed time 2.69 min
# Processed 41629 (100.0%) in 0.47 sec. BPR loss is 1.03E+01. Sample per second: 89372
# SLIM_BPR_Recommender: Epoch 648 of 650. Elapsed time 2.69 min
# Processed 41629 (100.0%) in 0.71 sec. BPR loss is 1.05E+01. Sample per second: 58597
# SLIM_BPR_Recommender: Epoch 649 of 650. Elapsed time 2.70 min
# Processed 41629 (100.0%) in 0.95 sec. BPR loss is 1.04E+01. Sample per second: 43731
# SLIM_BPR_Recommender: Epoch 650 of 650. Elapsed time 2.70 min
# SLIM_BPR_Recommender: Terminating at epoch 650. Elapsed time 3.33 min
# Deallocating Cython objects

# %%
recommender_SLIMElasticNet1 = SLIMElasticNetRecommender(URM_train_stacked)
recommender_SLIMElasticNet1.fit(l1_ratio= 0.02663352009457766, alpha= 0.0010777130010163724, positive_only= True, topK= 15368)
# Out:
# SLIMElasticNetRecommender: URM Detected 3 ( 0.0%) users with no interactions.
# SLIMElasticNetRecommender: Processed 2774 ( 9.9%) in 5.00 min. Items per second: 9.24
# SLIMElasticNetRecommender: Processed 5666 (20.3%) in 10.00 min. Items per second: 9.44
# SLIMElasticNetRecommender: Processed 8792 (31.4%) in 15.00 min. Items per second: 9.77
# SLIMElasticNetRecommender: Processed 11864 (42.4%) in 20.00 min. Items per second: 9.88
# SLIMElasticNetRecommender: Processed 14937 (53.4%) in 25.00 min. Items per second: 9.96
# SLIMElasticNetRecommender: Processed 18162 (64.9%) in 30.00 min. Items per second: 10.09
# SLIMElasticNetRecommender: Processed 21342 (76.3%) in 35.01 min. Items per second: 10.16
# SLIMElasticNetRecommender: Processed 24482 (87.5%) in 40.01 min. Items per second: 10.20
# SLIMElasticNetRecommender: Processed 27968 (100.0%) in 41.12 min. Items per second: 11.34

# %%
RP3beta_all = RP3betaRecommender(URM_train)
RP3beta_all.fit(alpha= 0.8048209317587374, beta= 0.28523965008406016, topK= 56, implicit= False)
# Out:
# RP3betaRecommender: URM Detected 3461 (12.4%) items with no interactions.
# RP3betaRecommender: Similarity column 27968 (100.0%), 2408.88 column/sec. Elapsed time 11.61 sec

# %%
slim_matrix1 = recommender_SLIMElasticNet1.W_sparse
rp3_matrix = RP3beta_all.W_sparse
bpr_matrix = slim_bpr.W_sparse

# %%
result_dict, _ = evaluator_valid.evaluateRecommender(recommender_SLIMElasticNet1)
print(f"Slim_en: {result_dict['MAP'][10]}")

result_dict, _ = evaluator_valid.evaluateRecommender(RP3beta_all)
print(f"Rp3: {result_dict['MAP'][10]}")
# Out:
# EvaluatorHoldout: Processed 40666 (100.0%) in 52.12 sec. Users per second: 780
# Slim_en: 0.02783886484477793
# EvaluatorHoldout: Processed 40666 (100.0%) in 32.75 sec. Users per second: 1242
# Rp3: 0.025709229034979467

# %%
from Recommenders.Recommender_utils import check_matrix, similarityMatrixTopK
from Recommenders.BaseSimilarityMatrixRecommender import BaseItemSimilarityMatrixRecommender



class ItemKNNSimilarityHybridRecommender(BaseItemSimilarityMatrixRecommender):
    """ ItemKNNSimilarityHybridRecommender
    Hybrid of two similarities S = S1*alpha + S2*(1-alpha)
    """

    RECOMMENDER_NAME = "ItemKNNSimilarityHybridRecommender"


    def __init__(self, URM_train, Similarity_1, Similarity_2, verbose = True):
        super(ItemKNNSimilarityHybridRecommender, self).__init__(URM_train, verbose = verbose)

        # CSR is faster during evaluation
        self.Similarity_1 = check_matrix(Similarity_1.copy(), 'csr')
        self.Similarity_2 = check_matrix(Similarity_2.copy(), 'csr')


    def fit(self, topK=100, alpha = 0.5, beta = 0):

        self.topK = topK
        self.alpha = alpha
        self.beta = beta


        W_sparse = self.Similarity_1*self.alpha + self.Similarity_2*self.beta

        self.W_sparse = similarityMatrixTopK(W_sparse, k=self.topK)
        self.W_sparse = check_matrix(self.W_sparse, format='csr')

# %%
from numpy import linalg as LA
from Recommenders.BaseRecommender import BaseRecommender

class DifferentLossScoresHybridRecommender(BaseRecommender):

    RECOMMENDER_NAME = "DifferentLossScoresHybridRecommender"


    def __init__(self, URM_train, recommender_1, recommender_2, recommender_3, recommender_4):
        super(DifferentLossScoresHybridRecommender, self).__init__(URM_train)

        self.URM_train = sps.csr_matrix(URM_train)
        self.recommender_1 = recommender_1
        self.recommender_2 = recommender_2
        self.recommender_3 = recommender_3
        self.recommender_4 = recommender_4
        
        
        
    def fit(self, alpha = 0.5, beta = 0, gamma = 0, theta = 0):

        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma
        self.theta = theta



    def _compute_item_score(self, user_id_array, items_to_compute):
        
        item_weights_1 = self.recommender_1._compute_item_score(user_id_array)
        item_weights_2 = self.recommender_2._compute_item_score(user_id_array)
        item_weights_3 = self.recommender_3._compute_item_score(user_id_array)
        item_weights_4 = self.recommender_4._compute_item_score(user_id_array)
            
        item_weights = item_weights_1 * self.alpha + item_weights_2 * self.beta + item_weights_3 * self.gamma + item_weights_4 * self.theta

        return item_weights

# %%
recommender_class = ItemKNNSimilarityHybridRecommender

import os

output_folder_path = "result_experiments/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 1000
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
from skopt.space import Real, Integer, Categorical
#RP3 beta
#to tuning hyperparam are typical of ML models to drive the learning process

hyperparameters_range_dictionary = {
    "topK": Integer(100,2000),
    "alpha": Real(low=0, high=100, prior='uniform'),
    "beta": Real(low=0, high=50, prior='uniform')
}

from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

#create a bayesian optimizer object, we pass the recommender and the evaluator
hyperparameterSearch = SearchBayesianSkopt(recommender_class,
                                         evaluator_validation=evaluator_valid)
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
  
#provide data needed to create instance of model (one on URM_train, the other on URM_all)
recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train, rp3_matrix, bpr_matrix],     # For a CBF model simply put [URM_train, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {}
)

# %%
hyperparameterSearch.search(recommender_input_args = recommender_input_args,
                       hyperparameter_search_space = hyperparameters_range_dictionary,
                       n_cases = n_cases,
                       n_random_starts = n_random_starts,
                       save_model = "last",
                       output_folder_path = output_folder_path, # Where to save the results
                       output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
                       metric_to_optimize = metric_to_optimize,
                       cutoff_to_optimize = cutoff_to_optimize,
                      )
# Out:
# SearchBayesianSkopt: argument save_model is 'last' but no recommender_input_args_last_test provided, saving best model on train data alone.
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1520, 'alpha': 99.96013008102457, 'beta': 24.71303956238881}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.52 sec. Users per second: 838
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 1520, 'alpha': 99.96013008102457, 'beta': 24.71303956238881} - results: PRECISION: 0.0449688, PRECISION_RECALL_MIN_DEN: 0.0778021, RECALL: 0.0734357, MAP: 0.0204603, MAP_MIN_DEN: 0.0349393, MRR: 0.1481533, NDCG: 0.0721226, F1: 0.0557802, HIT_RATE: 0.3230217, ARHR_ALL_HITS: 0.1732853, NOVELTY: 0.0034418, AVERAGE_POPULARITY: 0.3222603, DIVERSITY_MEAN_INTER_LIST: 0.8034911, DIVERSITY_HERFINDAHL: 0.9803471, COVERAGE_ITEM: 0.2644451, COVERAGE_ITEM_HIT: 0.0289974, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3155493, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0110562, SHANNON_ENTROPY: 7.3413988, RATIO_DIVERSITY_HERFINDAHL: 0.9806705, RATIO_DIVERSITY_GINI: 0.0248201, RATIO_SHANNON_ENTROPY: 0.5440519, RATIO_AVERAGE_POPULARITY: 6.3253356, RATIO_NOVELTY: 0.2247245,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNSimilarityHybridRecommender
#
# ItemKNNSimilarityHybridRecommender: Saving model in file 'result_experiments/ItemKNNSimilarityHybridRecommender_best_model'
# ItemKNNSimilarityHybridRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 72.5489
# Function value obtained: -0.0205
# Current minimum: -0.0205
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1565, 'alpha': 32.12683572894793, 'beta': 42.986897285344774}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.73 sec. Users per second: 834
# SearchBayesianSkopt: Config 1 is suboptimal. Config: {'topK': 1565, 'alpha': 32.12683572894793, 'beta': 42.986897285344774} - results: PRECISION: 0.0429032, PRECISION_RECALL_MIN_DEN: 0.0747209, RECALL: 0.0706286, MAP: 0.0192695, MAP_MIN_DEN: 0.0330574, MRR: 0.1416050, NDCG: 0.0687762, F1: 0.0533805, HIT_RATE: 0.3137265, ARHR_ALL_HITS: 0.1644814, NOVELTY: 0.0033960, AVERAGE_POPULARITY: 0.3370617, DIVERSITY_MEAN_INTER_LIST: 0.7784455, DIVERSITY_HERFINDAHL: 0.9778426, COVERAGE_ITEM: 0.2251502, COVERAGE_ITEM_HIT: 0.0250286, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3064690, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0086832, SHANNON_ENTROPY: 7.0731954, RATIO_DIVERSITY_HERFINDAHL: 0.9781651, RATIO_DIVERSITY_GINI: 0.0194928, RATIO_SHANNON_ENTROPY: 0.5241761, RATIO_AVERAGE_POPULARITY: 6.6158579, RATIO_NOVELTY: 0.2217343,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 62.2514
# Function value obtained: -0.0193
# Current minimum: -0.0205
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1664, 'alpha': 64.69175092973693, 'beta': 2.2461805552343344}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.68 sec. Users per second: 835
# SearchBayesianSkopt: New best config found. Config 2: {'topK': 1664, 'alpha': 64.69175092973693, 'beta': 2.2461805552343344} - results: PRECISION: 0.0514926, PRECISION_RECALL_MIN_DEN: 0.0870723, RECALL: 0.0817420, MAP: 0.0244786, MAP_MIN_DEN: 0.0406495, MRR: 0.1679414, NDCG: 0.0822123, F1: 0.0631834, HIT_RATE: 0.3497270, ARHR_ALL_HITS: 0.2013732, NOVELTY: 0.0036523, AVERAGE_POPULARITY: 0.2530852, DIVERSITY_MEAN_INTER_LIST: 0.8938385, DIVERSITY_HERFINDAHL: 0.9893817, COVERAGE_ITEM: 0.4090031, COVERAGE_ITEM_HIT: 0.0426916, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3416368, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0241260, SHANNON_ENTROPY: 8.4239584, RATIO_DIVERSITY_HERFINDAHL: 0.9897080, RATIO_DIVERSITY_GINI: 0.0541605, RATIO_SHANNON_ENTROPY: 0.6242776, RATIO_AVERAGE_POPULARITY: 4.9675646, RATIO_NOVELTY: 0.2384698,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNSimilarityHybridRecommender
#
# ItemKNNSimilarityHybridRecommender: Saving model in file 'result_experiments/ItemKNNSimilarityHybridRecommender_best_model'
# ItemKNNSimilarityHybridRecommender: Saving complete
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 71.9329
# Function value obtained: -0.0245
# Current minimum: -0.0245
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1242, 'alpha': 30.209599874597508, 'beta': 46.058282958306435}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.41 sec. Users per second: 840
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK':

#
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 61.8625
# Function value obtained: -0.0202
# Current minimum: -0.0245
# Iteration No: 21 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1848, 'alpha': 89.04459907310414, 'beta': 1.3509405242962962}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.62 sec. Users per second: 836
# SearchBayesianSkopt: New best config found. Config 20: {'topK': 1848, 'alpha': 89.04459907310414, 'beta': 1.3509405242962962} - results: PRECISION: 0.0529681, PRECISION_RECALL_MIN_DEN: 0.0886405, RECALL: 0.0829878, MAP: 0.0255549, MAP_MIN_DEN: 0.0419066, MRR: 0.1722873, NDCG: 0.0843056, F1: 0.0646637, HIT_RATE: 0.3543255, ARHR_ALL_HITS: 0.2082361, NOVELTY: 0.0037822, AVERAGE_POPULARITY: 0.2176593, DIVERSITY_MEAN_INTER_LIST: 0.9254484, DIVERSITY_HERFINDAHL: 0.9925426, COVERAGE_ITEM: 0.4941719, COVERAGE_ITEM_HIT: 0.0482337, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3461289, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0360845, SHANNON_ENTROPY: 9.0141283, RATIO_DIVERSITY_HERFINDAHL: 0.9928699, RATIO_DIVERSITY_GINI: 0.0810061, RATIO_SHANNON_ENTROPY: 0.6680136, RATIO_AVERAGE_POPULARITY: 4.2722252, RATIO_NOVELTY: 0.2469561,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNSimilarityHybridRecommender
#
# ItemKNNSimilarityHybridRecommender: Saving model in file 'result_experiments/ItemKNNSimilarityHybridRecommender_best_model'
# ItemKNNSimilarityHybridRecommender: Saving complete
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 71.7682
# Function value obtained: -0.0256
# Current minimum: -0.0256
# Iteration No: 22 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1686, 'alpha': 89.07099310062463, 'beta': 0.3204897377005579}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.46 sec. Users per second: 839
# SearchBayesianSkopt: New best config found. Config 21: {'topK': 1686, 'alpha': 89.07099310062463, 'beta': 0.3204897377005579} - results: PRECISION: 0.0528599, PRECISION_RECALL_MIN_DEN: 0.0875578, RECALL: 0.0817726, MAP: 0.0258805, MAP_MIN_DEN: 0.0420394, MRR: 0.1731800, NDCG: 0.0841777, F1: 0.0642117, HIT_RATE: 0.3503910, ARHR_ALL_HITS: 0.2100208, NOVELTY: 0.0039501, AVERAGE_POPULARITY: 0.1784712, DIVERSITY_MEAN_INTER_LIST: 0.9523694, DIVERSITY_HERFINDAHL: 0.9952346, COVERAGE_ITEM: 0.5915332, COVERAGE_ITEM_HIT: 0.0536685, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3422854, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0564018, SHANNON_ENTROPY: 9.7258355, RATIO_DIVERSITY_HERFINDAHL: 0.9955628, RATIO_DIVERSITY_GINI: 0.1266164, RATIO_SHANNON_ENTROPY: 0.7207563, RATIO_AVERAGE_POPULARITY: 3.5030387, RATIO_NOVELTY: 0.2579190,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNSimilarityHybridRecommender
#
# ItemKNNSimilarityHybridRecommender: Saving model in file 'result_experiments/ItemKNNSimilarityHybridRecommender_best_model'
# ItemKNNSimilarityHybridRecommender: Saving complete
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 72.1561
# Function value obtained: -0.0259
# Current minimum: -0.0259
# Iteration No: 23 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 533, 'alpha': 93.31856702082735, 'beta': 3.2344512091644915}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.51 sec. Users per second: 838
# SearchBayesianSkopt: Config 22 is suboptimal. Config: {'topK': 533, 'alpha': 93.31856702082735, 'beta': 3.2344512091644915} - results: PRECISION: 0.0514926, PRECISION_RECALL_MIN_DEN: 0.0870764, RECALL: 0.0817475, MAP: 0.0244808, MAP_MIN_DEN: 0.0406530, MRR: 0.1679445, NDCG: 0.0822166, F1: 0.0631851, HIT_RATE: 0.3497270, ARHR_ALL_HITS: 0.2013850, NOVELTY: 0.0036526, AVERAGE_POPULARITY: 0.2529969, DIVERSITY_MEAN_INTER_LIST: 0.8939267, DIVERSITY_HERFINDAHL: 0.9893905, COVERAGE_ITEM: 0.4091819, COVERAGE_ITEM_HIT: 0.0427274, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3416368, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0241514, SHANNON_ENTROPY: 8.4252818, RATIO_DIVERSITY_HERFINDAHL: 0.9897168, RATIO_DIVERSITY_GINI: 0.0542175, RATIO_SHANNON_ENTROPY: 0.6243757, RATIO_AVERAGE_POPULARITY: 4.9658325, RATIO_NOVELTY: 0.2384882,
#
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 61.5919
# Function value obtained: -0.0245
# Current minimum: -0.0259
# Iteration No: 24 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1271, 'alpha': 80.00566933227378, 'beta': 19.603640545090446}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.42 sec. Users per second: 840
# SearchBayesianSkopt: Config 23 is suboptimal. Config: {'topK': 1271, 'alpha': 80.00566933227378, 'beta': 19.603640545090446} - results: PRECISION: 0.0450007, PRECISION_RECALL_MIN_DEN: 0.0778519, RECALL: 0.0734825, MAP: 0.0204690, MAP_MIN_DEN: 0.0349586, MRR: 0.1481975, NDCG: 0.0721610, F1: 0.0558183, HIT_RATE: 0.3231938, ARHR_ALL_HITS: 0.1733484, NOVELTY: 0.0034422, AVERAGE_POPULARITY: 0.3221176, DIVERSITY_MEAN_INTER_LIST: 0.8037269, DIVERSITY_HERFINDAHL: 0.9803707, COVERAGE_ITEM: 0.2645881, COVERAGE_ITEM_HIT: 0.0290689, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3157174, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0110726, SHANNON_ENTROPY: 7.3438245, RATIO_DIVERSITY_HERFINDAHL: 0.9806940, RATIO_DIVERSITY_GINI: 0.0248568, RATIO_SHANNON_ENTROPY: 0.5442317, RATIO_AVERAGE_POPULARITY: 6.3225362, RATIO_NOVELTY: 0.2247518,
#
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 61.2606
# Function value obtained: -0.0205
# Current minimum: -0.0259
# Iteration No: 25 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 105, 'alpha': 93.71418876784219, 'beta': 19.990985927814727}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 40.67 sec. Users per second: 1000
# SearchBayesianSkopt: Config 24 is suboptimal. Config: {'topK': 105, 'alpha': 93.71418876784219, 'beta': 19.990985927814727} - results: PRECISION: 0.0488934, PRECISION_RECALL_MIN_DEN: 0.0830344, RECALL: 0.0780069, MAP: 0.0232340, MAP_MIN_DEN: 0.0387542, MRR: 0.1621079, NDCG: 0.0786112, F1: 0.0601106, HIT_RATE: 0.3375793, ARHR_ALL_HITS: 0.1928295, NOVELTY: 0.0035795, AVERAGE_POPULARITY: 0.2604247, DIVERSITY_MEAN_INTER_LIST: 0.8892185, DIVERSITY_HERFINDAHL: 0.9889197, COVERAGE_ITEM: 0.2903318, COVERAGE_ITEM_HIT: 0.0352188, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3297701, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0147021, SHANNON_ENTROPY: 8.0880737, RATIO_DIVERSITY_HERFINDAHL: 0.9892458, RATIO_DIVERSITY_GINI: 0.0330047, RATIO_SHANNON_ENTROPY: 0.5993861, RATIO_AVERAGE_POPULARITY: 5.1116243, RATIO_NOVELTY: 0.2337200,
#
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken:
ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3102645, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0095903, SHANNON_ENTROPY: 7.1785864, RATIO_DIVERSITY_HERFINDAHL: 0.9791488, RATIO_DIVERSITY_GINI: 0.0215292, RATIO_SHANNON_ENTROPY: 0.5319863, RATIO_AVERAGE_POPULARITY: 6.5046031, RATIO_NOVELTY: 0.2228897,
#
# Iteration No: 31 ended. Evaluation done at random point.
# Time taken: 62.1461
# Function value obtained: -0.0198
# Current minimum: -0.0259
# Iteration No: 32 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 259, 'alpha': 82.13475227241555, 'beta': 39.25932989399208}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 46.33 sec. Users per second: 878
# SearchBayesianSkopt: Config 31 is suboptimal. Config: {'topK': 259, 'alpha': 82.13475227241555, 'beta': 39.25932989399208} - results: PRECISION: 0.0452884, PRECISION_RECALL_MIN_DEN: 0.0781708, RECALL: 0.0737316, MAP: 0.0208448, MAP_MIN_DEN: 0.0353590, MRR: 0.1507847, NDCG: 0.0728796, F1: 0.0561114, HIT_RATE: 0.3245217, ARHR_ALL_HITS: 0.1763900, NOVELTY: 0.0034671, AVERAGE_POPULARITY: 0.3073718, DIVERSITY_MEAN_INTER_LIST: 0.8272384, DIVERSITY_HERFINDAHL: 0.9827218, COVERAGE_ITEM: 0.2635154, COVERAGE_ITEM_HIT: 0.0287471, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3170146, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0112883, SHANNON_ENTROPY: 7.4816837, RATIO_DIVERSITY_HERFINDAHL: 0.9830459, RATIO_DIVERSITY_GINI: 0.0253410, RATIO_SHANNON_ENTROPY: 0.5544481, RATIO_AVERAGE_POPULARITY: 6.0331041, RATIO_NOVELTY: 0.2263772,
#
# Iteration No: 32 ended. Evaluation done at random point.
# Time taken: 56.2169
# Function value obtained: -0.0208
# Current minimum: -0.0259
# Iteration No: 33 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 864, 'alpha': 39.806386607070884, 'beta': 21.323436549796863}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.74 sec. Users per second: 834
# SearchBayesianSkopt: Config 32 is suboptimal. Config: {'topK': 864, 'alpha': 39.806386607070884, 'beta': 21.323436549796863} - results: PRECISION: 0.0436384, PRECISION_RECALL_MIN_DEN: 0.0758680, RECALL: 0.0716803, MAP: 0.0197097, MAP_MIN_DEN: 0.0338162, MRR: 0.1442032, NDCG: 0.0700684, F1: 0.0542499, HIT_RATE: 0.3172429, ARHR_ALL_HITS: 0.1678328, NOVELTY: 0.0034120, AVERAGE_POPULARITY: 0.3319394, DIVERSITY_MEAN_INTER_LIST: 0.7873396, DIVERSITY_HERFINDAHL: 0.9787320, COVERAGE_ITEM: 0.2397025, COVERAGE_ITEM_HIT: 0.0266018, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3099042, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0095073, SHANNON_ENTROPY: 7.1686173, RATIO_DIVERSITY_HERFINDAHL: 0.9790548, RATIO_DIVERSITY_GINI: 0.0213429, RATIO_SHANNON_ENTROPY: 0.5312475, RATIO_AVERAGE_POPULARITY: 6.5153183, RATIO_NOVELTY: 0.2227783,
#
# Iteration No: 33 ended. Evaluation done at random point.
# Time taken: 61.8014
# Function value obtained: -0.0197
# Current minimum: -0.0259
# Iteration No: 34 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1779, 'alpha': 79.6296239321961, 'beta': 18.768994781361993}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.62 sec. Users per second: 836
# SearchBayesianSkopt: Config 33 is suboptimal. Config: {'topK': 1779, 'alpha': 79.6296239321961, 'beta': 18.768994781361993} - results: PRECISION: 0.0451163, PRECISION_RECALL_MIN_DEN: 0.0780038, RECALL: 0.0736173, MAP: 0.0205163, MAP_MIN_DEN: 0.0350266, MRR: 0.1484148, NDCG: 0.0722997, F1: 0.0559461, HIT_RATE: 0.3237840, ARHR_ALL_HITS: 0.1736729, NOVELTY: 0.0034443, AVERAGE_POPULARITY: 0.3214090, DIVERSITY_MEAN_INTER_LIST: 0.8048864, DIVERSITY_HERFINDAHL: 0.9804867, COVERAGE_ITEM: 0.2657680, COVERAGE_ITEM_HIT: 0.0294980, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3162939, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0111715, SHANNON_ENTROPY: 7.3561544, RATIO_DIVERSITY_HERFINDAHL: 0.9808100, RATIO_DIVERSITY_GINI: 0.0250788, RATIO_SHANNON_ENTROPY: 0.5451454, RATIO_AVERAGE_POPULARITY: 6.3086261, RATIO_NOVELTY: 0.2248899,
#
# Iteration No: 34 ended. Evaluation done at random point.
# Time taken: 61.6919
# Function value obtained: -0.0205
# Current minimum: -0.0259
# Iteration No: 35 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1303, 'alpha': 31.769347323606507, 'beta': 5.539463147534114}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.59 sec. Users per second: 837
# SearchBayesianSkopt: Config 34 is suboptimal. Config: {'topK': 1303, 'alpha': 31.769347323606507, 'beta': 5.539463147534114} - results: PRECISION: 0.0458958, PRECISION_RECALL_MIN_DEN: 0.0790258, RECALL: 0.0745315, MAP: 0.0209765, MAP_MIN_DEN: 0.0356779, MRR: 0.1508002, NDCG: 0.0734742, F1: 0.0568091, HIT_RATE: 0.3273004, ARHR_ALL_HITS: 0.1769387, NOVELTY: 0.0034629, AVERAGE_POPULARITY: 0.3150538, DIVERSITY_MEAN_INTER_LIST: 0.8149872, DIVERSITY_HERFINDAHL: 0.9814967, COVERAGE_ITEM: 0.2774957, COVERAGE_ITEM_HIT: 0.0309640, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3197290, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0120669, SHANNON_ENTROPY: 7.4613785, RATIO_DIVERSITY_HERFINDAHL: 0.9818204, RATIO_DIVERSITY_GINI: 0.0270890, RATIO_SHANNON_ENTROPY: 0.5529433, RATIO_AVERAGE_POPULARITY: 6.1838862, RATIO_NOVELTY: 0.2261021,
#
# Iteration No: 35 ended. Evaluation done at random point.
# Time taken: 61.6742
# Function value obtained: -0.0210
# Current minimum: -0.0259
# Iteration No: 36 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1855, 'alpha': 96.09292004720945, 'beta': 23.888632918529368}
# ...
# SearchBayesianSkopt: Config 73 is suboptimal. Config: {'topK': 1666, 'alpha': 39.38356694418089, 'beta': 43.27341402995735} - results: PRECISION: 0.0430089, PRECISION_RECALL_MIN_DEN: 0.0749040, RECALL: 0.0708083, MAP: 0.0193311, MAP_MIN_DEN: 0.0331620, MRR: 0.1420088, NDCG: 0.0689634, F1: 0.0535137, HIT_RATE: 0.3143658, ARHR_ALL_HITS: 0.1649746, NOVELTY: 0.0033982, AVERAGE_POPULARITY: 0.3363641, DIVERSITY_MEAN_INTER_LIST: 0.7796951, DIVERSITY_HERFINDAHL: 0.9779676, COVERAGE_ITEM: 0.2272240, COVERAGE_ITEM_HIT: 0.0253862, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3070936, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0087978, SHANNON_ENTROPY: 7.0866104, RATIO_DIVERSITY_HERFINDAHL: 0.9782901, RATIO_DIVERSITY_GINI: 0.0197503, RATIO_SHANNON_ENTROPY: 0.5251702, RATIO_AVERAGE_POPULARITY: 6.6021663, RATIO_NOVELTY: 0.2218801,
#
# Iteration No: 74 ended. Evaluation done at random point.
# Time taken: 61.8379
# Function value obtained: -0.0193
# Current minimum: -0.0259
# Iteration No: 75 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1443, 'alpha': 44.692283221618354, 'beta': 27.64403708503834}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.64 sec. Users per second: 836
# SearchBayesianSkopt: Config 74 is suboptimal. Config: {'topK': 1443, 'alpha': 44.692283221618354, 'beta': 27.64403708503834} - results: PRECISION: 0.0434958, PRECISION_RECALL_MIN_DEN: 0.0755833, RECALL: 0.0714112, MAP: 0.0196181, MAP_MIN_DEN: 0.0336570, MRR: 0.1436439, NDCG: 0.0697852, F1: 0.0540626, HIT_RATE: 0.3164806, ARHR_ALL_HITS: 0.1671231, NOVELTY: 0.0034083, AVERAGE_POPULARITY: 0.3330790, DIVERSITY_MEAN_INTER_LIST: 0.7854139, DIVERSITY_HERFINDAHL: 0.9785395, COVERAGE_ITEM: 0.2365203, COVERAGE_ITEM_HIT: 0.0262443, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3091595, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0093177, SHANNON_ENTROPY: 7.1472914, RATIO_DIVERSITY_HERFINDAHL: 0.9788622, RATIO_DIVERSITY_GINI: 0.0209174, RATIO_SHANNON_ENTROPY: 0.5296671, RATIO_AVERAGE_POPULARITY: 6.5376860, RATIO_NOVELTY: 0.2225417,
#
# Iteration No: 75 ended. Evaluation done at random point.
# Time taken: 61.4944
# Function value obtained: -0.0196
# Current minimum: -0.0259
# Iteration No: 76 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 159, 'alpha': 87.56908940391152, 'beta': 38.92769928974179}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 43.04 sec. Users per second: 945
# SearchBayesianSkopt: Config 75 is suboptimal. Config: {'topK': 159, 'alpha': 87.56908940391152, 'beta': 38.92769928974179} - results: PRECISION: 0.0465844, PRECISION_RECALL_MIN_DEN: 0.0798898, RECALL: 0.0752506, MAP: 0.0217069, MAP_MIN_DEN: 0.0366076, MRR: 0.1551232, NDCG: 0.0749848, F1: 0.0575451, HIT_RATE: 0.3296120, ARHR_ALL_HITS: 0.1825107, NOVELTY: 0.0035121, AVERAGE_POPULARITY: 0.2872324, DIVERSITY_MEAN_INTER_LIST: 0.8559852, DIVERSITY_HERFINDAHL: 0.9855964, COVERAGE_ITEM: 0.2725257, COVERAGE_ITEM_HIT: 0.0307852, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3219871, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0124657, SHANNON_ENTROPY: 7.7316695, RATIO_DIVERSITY_HERFINDAHL: 0.9859215, RATIO_DIVERSITY_GINI: 0.0279841, RATIO_SHANNON_ENTROPY: 0.5729739, RATIO_AVERAGE_POPULARITY: 5.6378081, RATIO_NOVELTY: 0.2293182,
#
# Iteration No: 76 ended. Evaluation done at random point.
# Time taken: 49.8713
# Function value obtained: -0.0217
# Current minimum: -0.0259
# Iteration No: 77 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1473, 'alpha': 53.35741405315804, 'beta': 4.859189217447442}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.65 sec. Users per second: 836
# SearchBayesianSkopt: Config 76 is suboptimal. Config: {'topK': 1473, 'alpha': 53.35741405315804, 'beta': 4.859189217447442} - results: PRECISION: 0.0480229, PRECISION_RECALL_MIN_DEN: 0.0822233, RECALL: 0.0774331, MAP: 0.0222528, MAP_MIN_DEN: 0.0376246, MRR: 0.1572673, NDCG: 0.0768723, F1: 0.0592808, HIT_RATE: 0.3365711, ARHR_ALL_HITS: 0.1859565, NOVELTY: 0.0035203, AVERAGE_POPULARITY: 0.2955593, DIVERSITY_MEAN_INTER_LIST: 0.8436000, DIVERSITY_HERFINDAHL: 0.9843579, COVERAGE_ITEM: 0.3164688, COVERAGE_ITEM_HIT: 0.0347182, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3287852, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0151338, SHANNON_ENTROPY: 7.7716456, RATIO_DIVERSITY_HERFINDAHL: 0.9846826, RATIO_DIVERSITY_GINI: 0.0339739, RATIO_SHANNON_ENTROPY: 0.5759364, RATIO_AVERAGE_POPULARITY: 5.8012487, RATIO_NOVELTY: 0.2298500,
#
# Iteration No: 77 ended. Evaluation done at random point.
# Time taken: 61.9316
# Function value obtained: -0.0223
# Current minimum: -0.0259
# Iteration No: 78 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1563, 'alpha': 59.19291439664295, 'beta': 34.79140529154067}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.56 sec. Users per second: 837
# SearchBayesianSkopt: Config 77 is suboptimal. Config: {'topK': 1563, 'alpha': 59.19291439664295, 'beta': 34.79140529154067} - results: PRECISION: 0.0435450, PRECISION_RECALL_MIN_DEN: 0.0757006, RECALL: 0.0715230, MAP: 0.0196553, MAP_MIN_DEN: 0.0337229, MRR: 0.1438806, NDCG: 0.0699004, F1: 0.0541326, HIT_RATE: 0.3168249, ARHR_ALL_HITS: 0.1674153, NOVELTY: 0.0034096, AVERAGE_POPULARITY: 0.3326528, DIVERSITY_MEAN_INTER_LIST: 0.7861361, DIVERSITY_HERFINDAHL: 0.9786117, COVERAGE_ITEM: 0.2377360, COVERAGE_ITEM_HIT: 0.0264946, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3094958, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0093862, SHANNON_ENTROPY: 7.1550495, RATIO_DIVERSITY_HERFINDAHL: 0.9789344, RATIO_DIVERSITY_GINI: 0.0210711, RATIO_SHANNON_ENTROPY: 0.5302421, RATIO_AVERAGE_POPULARITY: 6.5293212, RATIO_NOVELTY: 0.2226277,
#
# Iteration No: 78 ended. Evaluation done at random point.
# Time taken: 61.8077
# Function value obtained: -0.0197
# Current minimum: -0.0259
# Iteration No: 79 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1465, 'alpha': 45.43865609748528, 'beta': 14.3819211560802}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.66 sec. Users per second: 836
# SearchBayesianSkopt: Config 78 is suboptimal. Config: {'topK': 1465, 'alpha': 45.43865609748528, 'beta': 14.3819211560802} - results: PRECISION: 0.0444622, PRECISION_RECALL_MIN_DEN: 0.0770434, RECALL: 0.0727512, MAP: 0.0201487, MAP_MIN_DEN: 0.0344688, MRR: 0.1465137, NDCG: 0.0712919, F1: 0.0551930, HIT_RATE: 0.3207102, ARHR_ALL_HITS: 0.1710277, NOVELTY: 0.0034298, AVERAGE_POPULARITY: 0.3261208, DIVERSITY_MEAN_INTER_LIST: 0.7972088, DIVERSITY_HERFINDAHL: 0.9797189, COVERAGE_ITEM: 0.2551130, COVERAGE_ITEM_HIT: 0.0281035, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3132912, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0104377, SHANNON_ENTROPY: 7.2727881, RATIO_DIVERSITY_HERFINDAHL: 0.9800420, RATIO_DIVERSITY_GINI: 0.0234315, RATIO_SHANNON_ENTROPY: 0.5389674, RATIO_AVERAGE_POPULARITY: 6.4011110, RATIO_NOVELTY: 0.2239465,
#
# Iteration No: 79 ended. Evaluation done at random point.
# Time taken: 61.7047
# Function value obtained: -0.0201
# Current minimum: -0.0259
# Iteration No: 80 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1796, 'alpha': 71.83525882250463, 'beta': 48.41044024200758}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.79 sec. Users per second: 834
# SearchBayesianSkopt: Config 79 is suboptimal. Config: {'topK': 1796, 'alpha': 71.83525882250463, 'beta': 48.41044024200758} - results: PRECISION: 0.0433925, PRECISION_RECALL_MIN_DEN: 0.0754434, RECALL: 0.0712862, MAP: 0.0195656, MAP_MIN_DEN: 0.0335648, MRR: 0.1433258, NDCG: 0.0696237, F1: 0.0539470, HIT_RATE: 0.3158904, ARHR_ALL_HITS: 0.1667279, NOVELTY: 0.0034065, AVERAGE_POPULARITY: 0.3336495, DIVERSITY_MEAN_INTER_LIST: 0.7844414, DIVERSITY_HERFINDAHL: 0.9784422, COVERAGE_ITEM: 0.2346610, COVERAGE_ITEM_HIT: 0.0260655, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3085830, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0092138, SHANNON_ENTROPY: 7.1363382, RATIO_DIVERSITY_HERFINDAHL: 0.9787649, RATIO_DIVERSITY_GINI: 0.0206840, RATIO_SHANNON_ENTROPY: 0.5288554, RATIO_AVERAGE_POPULARITY: 6.5488831, RATIO_NOVELTY: 0.2224237,
#
# Iteration No: 80 ended. Evaluation done at random point.
# Time taken: 62.1692
# Function value obtained: -0.0196
# Current minimum: -0.0259
# Iteration No: 81 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 300, 'alpha': 4.788591218184569, 'beta': 21.62834361261542}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 46.58 sec. Users per second: 873
# SearchBayesianSkopt: Config 80 is suboptimal. Config: {'topK': 300, 'alpha': 4.788591218184569, 'beta': 21.62834361261542} - results: PRECISION: 0.0434638, PRECISION_RECALL_MIN_DEN: 0.0753409, RECALL: 0.0711356, MAP: 0.0197969, MAP_MIN_DEN: 0.0337502, MRR: 0.1450367, NDCG: 0.0699550, F1: 0.0539588, HIT_RATE: 0.3160626, ARHR_ALL_HITS: 0.1686903, NOVELTY: 0.0034288, AVERAGE_POPULARITY: 0.3216707, DIVERSITY_MEAN_INTER_LIST: 0.8045705, DIVERSITY_HERFINDAHL: 0.9804551, COVERAGE_ITEM: 0.2450300, COVERAGE_ITEM_HIT: 0.0258152, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3087511, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0098065, SHANNON_ENTROPY: 7.2616244, RATIO_DIVERSITY_HERFINDAHL: 0.9807784, RATIO_DIVERSITY_GINI: 0.0220147, RATIO_SHANNON_ENTROPY: 0.5381401, RATIO_AVERAGE_POPULARITY: 6.3137644, RATIO_NOVELTY: 0.2238760,
#
# Iteration No: 81 ended. Evaluation done at random point.
# Time taken: 57.4500
# Function value obtained: -0.0198
# Current minimum: -0.0259
# Iteration No: 82 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1104, 'alpha': 55.56685182536302, 'beta': 36.53360118073696}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.60 sec. Users per second: 837
# SearchBayesianSkopt: Config 81 is suboptimal. Config: {'topK': 1104, 'alpha': 55.56685182536302, 'beta': 36.53360118073696} - results: PRECISION: 0.0434245, PRECISION_RECALL_MIN_DEN: 0.0755004, RECALL: 0.0713404, MAP: 0.0195853, MAP_MIN_DEN: 0.0336051, MRR: 0.1434742, NDCG: 0.0696899, F1: 0.0539872, HIT_RATE: 0.3161363, ARHR_ALL_HITS: 0.1668937, NOVELTY: 0.0034070, AVERAGE_POPULARITY: 0.3334764, DIVERSITY_MEAN_INTER_LIST: 0.7847387, DIVERSITY_HERFINDAHL: 0.9784719, COVERAGE_ITEM: 0.2351616, COVERAGE_ITEM_HIT: 0.0261728, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3088232, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0092430, SHANNON_ENTROPY: 7.1396138, RATIO_DIVERSITY_HERFINDAHL: 0.9787946, RATIO_DIVERSITY_GINI: 0.0207496, RATIO_SHANNON_ENTROPY: 0.5290982, RATIO_AVERAGE_POPULARITY: 6.5454864, RATIO_NOVELTY: 0.2224579,
#
# Iteration No: 82 ended. Evaluation done at random point.
# Time taken: 61.7151
# Function value obtained: -0.0196
# Current minimum: -0.0259
# Iteration No: 83 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1829, 'alpha': 89.32838803241337, 'beta': 5.734358051598294}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.55 sec. Users per second: 838
# SearchBayesianSkopt: Config 82 is suboptimal. Config: {'topK': 1829, 'alpha': 89.32838803241337, 'beta': 5.734358051598294} - results: PRECISION: 0.0492303, PRECISION_RECALL_MIN_DEN: 0.0840296, RECALL: 0.0790718, MAP: 0.0230432, MAP_MIN_DEN: 0.0387944, MRR: 0.1612023, NDCG: 0.0788686, F1: 0.0606807, HIT_RATE: 0.3413663, ARHR_ALL_HITS: 0.1915212, NOVELTY: 0.0035627, AVERAGE_POPULARITY: 0.2814853, DIVERSITY_MEAN_INTER_LIST: 0.8619858, DIVERSITY_HERFINDAHL: 0.9861965, COVERAGE_ITEM: 0.3452875, COVERAGE_ITEM_HIT: 0.0376144, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3334695, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0176977, SHANNON_ENTROPY: 7.9891705, RATIO_DIVERSITY_HERFINDAHL: 0.9865217, RATIO_DIVERSITY_GINI: 0.0397294, RATIO_SHANNON_ENTROPY: 0.5920566, RATIO_AVERAGE_POPULARITY: 5.5250025, RATIO_NOVELTY: 0.2326210,
#
# Iteration No: 83 ended. Evaluation done at random point.
# Time taken: 61.6306
# Function value obtained: -0.0230
# Current minimum: -0.0259
# Iteration No: 84 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1604, 'alpha': 18.958021142149967, 'beta': 16.00299993317812}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.74 sec. Users per second: 834
# SearchBayesianSkopt: Config 83 is suboptimal. Config: {'topK': 1604, 'alpha': 18.958021142149967, 'beta': 16.00299993317812} - results: PRECISION: 0.0431638, PRECISION_RECALL_MIN_DEN: 0.0750979, RECALL: 0.0709768, MAP: 0.0194388, MAP_MIN_DEN: 0.0333372, MRR: 0.1426352, NDCG: 0.0692484, F1: 0.0536817, HIT_RATE: 0.3149314, ARHR_ALL_HITS: 0.1657937, NOVELTY: 0.0034021, AVERAGE_POPULARITY: 0.3351141, DIVERSITY_MEAN_INTER_LIST: 0.7818925, DIVERSITY_HERFINDAHL: 0.9781873, COVERAGE_ITEM: 0.2311928, COVERAGE_ITEM_HIT: 0.0256364, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3076461, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0090021, SHANNON_ENTROPY: 7.1100241, RATIO_DIVERSITY_HERFINDAHL: 0.9785099, RATIO_DIVERSITY_GINI: 0.0202089, RATIO_SHANNON_ENTROPY: 0.5269054, RATIO_AVERAGE_POPULARITY: 6.5776319, RATIO_NOVELTY: 0.2221356,
#
# Iteration No: 84 ended. Evaluation done at random point.
# Time taken: 61.7038
# Function value obtained: -0.0194
# Current minimum: -0.0259
# Iteration No: 85 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1680, 'alpha': 19.45853748869329, 'beta': 34.470921346978955}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.60 sec. Users per second: 837
# SearchBayesianSkopt: Config 84 is suboptimal. Config: {'topK': 1680, 'alpha': 19.45853748869329, 'beta': 34.470921346978955} - results: PRECISION: 0.0427114, PRECISION_RECALL_MIN_DEN: 0.0744267, RECALL: 0.0703581, MAP: 0.0192005, MAP_MIN_DEN: 0.0329750, MRR: 0.1413274, NDCG: 0.0685673, F1: 0.0531548, HIT_RATE: 0.3127674, ARHR_ALL_HITS: 0.1640383, NOVELTY: 0.0033932, AVERAGE_POPULARITY: 0.3379485, DIVERSITY_MEAN_INTER_LIST: 0.7768339, DIVERSITY_HERFINDAHL: 0.9776815, COVERAGE_ITEM: 0.2219322, COVERAGE_ITEM_HIT: 0.0248498, ITEMS_IN_GT: 0.8701015, COVERAGE_USER: 0.9768671, COVERAGE_USER_HIT: 0.3055322, USERS_IN_GT: 0.9768671, DIVERSITY_GINI: 0.0085300, SHANNON_ENTROPY: 7.0564630, RATIO_DIVERSITY_HERFINDAHL: 0.9780039, RATIO_DIVERSITY_GINI: 0.0191491, RATIO_SHANNON_ENTROPY: 0.5229361, RATIO_AVERAGE_POPULARITY: 6.6332644, RATIO_NOVELTY: 0.2215529,
#
# Iteration No: 85 ended. Evaluation done at random point.
# Time taken: 61.7759
# Function value obtained: -0.0192
# Current minimum: -0.0259
# Iteration No: 86 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1938, 'alpha': 82.17597619889804, 'beta': 17.445564522949024}
# ItemKNNSimilarityHybridRecommender: URM Detected 3461 (12.4%) items with no interactions.
# EvaluatorHoldout: Processed 40666 (100.0%) in 48.76 sec. Users per second: 834

# %%
from skopt.space import Real, Integer, Categorical
#RP3 beta
#to tuning hyperparam are typical of ML models to drive the learning process

hyperparameters_range_dictionary = {
    "alpha": Real(low=99.17866170336520, high=99.17866170336522, prior='uniform'),
    "beta": Real(low=40.45134622013221, high=40.45134622013223, prior='uniform'),
    "gamma": Real(low=10.962721766445173, high=10.962721766445175, prior='uniform'),
    "theta": Real(low=23.275965228118105, high=23.275965228118107, prior='uniform'),
    "sigma": Real(low=0, high=20, prior='uniform'),
    "epsilon": Real(low=0, high=60, prior='uniform')

}

from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

#create a bayesian optimizer object, we pass the recommender and the evaluator
hyperparameterSearch = SearchBayesianSkopt(recommender_class,
                                         evaluator_validation=evaluator_valid)
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
  
#provide data needed to create instance of model (one on URM_train, the other on URM_all)
recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train, recommender_SLIMElasticNet1, RP3beta_all, EASE_R, recommender_implicitAls, itemknn_cf, slim_bpr],     # For a CBF model simply put [URM_train, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {}
)

# %%
#let's run the bayesian search
hyperparameterSearch.search(recommender_input_args,
                       hyperparameter_search_space = hyperparameters_range_dictionary,
                       n_cases = n_cases,
                       n_random_starts = n_random_starts,
                       save_model = "last",
                       output_folder_path = output_folder_path, # Where to save the results
                       output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
                       metric_to_optimize = metric_to_optimize,
                       cutoff_to_optimize = cutoff_to_optimize,
                      )
